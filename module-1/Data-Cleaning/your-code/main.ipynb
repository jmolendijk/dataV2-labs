# %% [markdown]
# # Data Cleaning
#
# #### 1. Import pandas library.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data.

# %%
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/dataset/Stats).

# %%
engine = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/stats')
sqlstr = 'select * from users'

# %% [markdown]
# #### 4. Import the users table.

# %%
users_df = pd.read_sql_query(sqlstr,engine)
users_df
# Out:
#           Id  Reputation        CreationDate     DisplayName  \
# 0         -1           1 2010-07-19 06:55:26       Community
# 1          2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27          Emmett
# 4          5        6792 2010-07-19 19:03:57           Shane
# ...      ...         ...                 ...             ...
# 40320  55743           1 2014-09-13 21:03:50       AussieMeg
# 40321  55744           6 2014-09-13 21:39:30       Mia Maria
# 40322  55745         101 2014-09-13 23:45:27    tronbabylove
# 40323  55746         106 2014-09-14 00:29:41             GPP
# 40324  55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 5. Rename Id column to userId.

# %%
users_df = users_df.rename(columns={"Id":"userId"})
users_df
# Out:
#        userId  Reputation        CreationDate     DisplayName  \
# 0          -1           1 2010-07-19 06:55:26       Community
# 1           2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101 2010-07-19 19:03:27          Emmett
# 4           5        6792 2010-07-19 19:03:57           Shane
# ...       ...         ...                 ...             ...
# 40320   55743           1 2014-09-13 21:03:50       AussieMeg
# 40321   55744           6 2014-09-13 21:39:30       Mia Maria
# 40322   55745         101 2014-09-13 23:45:27    tronbabylove
# 40323   55746         106 2014-09-14 00:29:41             GPP
# 40324   55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
sqlstr2 = 'select * from posts'
posts_df = pd.read_sql_query(sqlstr2,engine)
posts_df
# Out:
#            Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# ...       ...         ...               ...                 ...    ...
# 91971  115374           2               NaN 2014-09-13 23:45:39      2
# 91972  115375           1               NaN 2014-09-13 23:46:05      0
# 91973  115376           1               NaN 2014-09-14 01:27:54      1
# 91974  115377           2               NaN 2014-09-14 02:03:28      0
# 91975  115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body  \
# ...

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId.

# %%
posts_df = posts_df.rename(columns={"Id":"postId","OwnerUserId":"userId"})
posts_df
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# ...       ...         ...               ...                 ...    ...
# 91971  115374           2               NaN 2014-09-13 23:45:39      2
# 91972  115375           1               NaN 2014-09-13 23:46:05      0
# 91973  115376           1               NaN 2014-09-14 01:27:54      1
# 91974  115377           2               NaN 2014-09-14 02:03:28      0
# 91975  115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body   userId  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
# **users columns**: userId, Reputation, Views, UpVotes, DownVotes
# **posts columns**: postId, Score, userID, ViewCount, CommentCount

# %%
new_users_df = users_df[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
new_users_df
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# ...       ...         ...    ...      ...        ...
# 40320   55743           1      0        0          0
# 40321   55744           6      1        0          0
# 40322   55745         101      0        0          0
# 40323   55746         106      1        0          0
# 40324   55747           1      0        0          0
#
# [40325 rows x 5 columns]

# %%
#Here, I deliberately changed the capital D in 'userId' because it gave me an error
new_posts_df = posts_df[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]
new_posts_df
# Out:
#        postId  Score   userId  ViewCount  CommentCount
# 0           1     23      8.0     1278.0             1
# 1           2     22     24.0     8198.0             1
# 2           3     54     18.0     3613.0             4
# 3           4     13     23.0     5224.0             2
# 4           5     81     23.0        NaN             3
# ...       ...    ...      ...        ...           ...
# 91971  115374      2    805.0        NaN             2
# 91972  115375      0  49365.0        9.0             0
# 91973  115376      1  55746.0        5.0             2
# 91974  115377      0    805.0        NaN             0
# 91975  115378      0   7250.0        NaN             0
#
# [91976 rows x 5 columns]

# %% [markdown]
# #### 9. Merge the new dataframes you have created, of users and posts.
# You will need to make an inner [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
#I want to see what for data do we have
#new_users_df.head(60)
new_posts_df.head(60)
# Out:
#     postId  Score  userId  ViewCount  CommentCount
# 0        1     23     8.0     1278.0             1
# 1        2     22    24.0     8198.0             1
# 2        3     54    18.0     3613.0             4
# 3        4     13    23.0     5224.0             2
# 4        5     81    23.0        NaN             3
# 5        6    152     5.0    29229.0             5
# 6        7     76    38.0     5808.0             3
# 7        8      0    37.0      288.0             2
# 8        9     13    50.0        NaN             3
# 9       10     23    24.0    21925.0             4
# 10      11      2    34.0      224.0             2
# 11      12     20     5.0        NaN             1
# 12      13     14    23.0        NaN             4
# 13      14      5    36.0        NaN             1
# 14      15     13     6.0        NaN             0
# 15      16     16     8.0        NaN             3
# 16      17      9     NaN     1261.0             0
# ...

# %%
#I assume here (for the purpose of this exercice) that both userId columns are refering to the same user in both dataframes

new_users_posts = pd.merge(new_users_df,new_posts_df[['userId','postId','Score','ViewCount','CommentCount']], on = 'userId')
new_users_posts
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90579   55734           1      0        0          0  115352      0
# 90580   55738          11      0        0          0  115360      2
# 90581   55742           6      0        0          0  115366      1
# 90582   55744           6      1        0          0  115370      1
# 90583   55746         106      1        0          0  115376      1
#
#        ViewCount  CommentCount
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# ...

# %% [markdown]
# #### 10. How many missing values do you have in your merged dataframe? On which columns?

# %%
#we have 48396 in column ViewCount
null_Columns = new_users_posts.isnull().sum()

# %% [markdown]
# #### 11. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before going to the next step.

# %%
#We do have data != 0 in the column ViewCount representing more than 40% of the data in the column therefeore I will not delete them
new_users_posts[['ViewCount']]=new_users_posts[['ViewCount']].fillna(0)
new_users_posts.isnull().sum()
# Out:
# userId          0
# Reputation      0
# Views           0
# UpVotes         0
# DownVotes       0
# postId          0
# Score           0
# ViewCount       0
# CommentCount    0
# dtype: int64

# %% [markdown]
# #### 12. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
#To check the data types
new_users_posts.dtypes
# Out:
# userId            int64
# Reputation        int64
# Views             int64
# UpVotes           int64
# DownVotes         int64
# postId            int64
# Score             int64
# ViewCount       float64
# CommentCount      int64
# dtype: object

# %%
# the comment
'''ViewCount into int64?
Not sure id userId and postId in case they get a leter in the future?'''

# %%
#To change the data type
new_users_posts['ViewCount'] = new_users_posts['ViewCount'].astype('int64')

# %%
new_users_posts.dtypes
# Out:
# userId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# postId          int64
# Score           int64
# ViewCount       int64
# CommentCount    int64
# dtype: object
