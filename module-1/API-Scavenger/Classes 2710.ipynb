# %%
import json
import requests
import pandas as pd

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(10)
# Out:
#             id               type  \
# 0  13986662937        CreateEvent
# 1  13986662938   PullRequestEvent
# 2  13986662922  IssueCommentEvent
# 3  13986662919          PushEvent
# 4  13986662914          PushEvent
# 5  13986662915          PushEvent
# 6  13986662909   PullRequestEvent
# 7  13986662901        CreateEvent
# 8  13986662890          PushEvent
# 9  13986662878          PushEvent
#
#                                                actor  \
# 0  {'id': 27856297, 'login': 'dependabot-preview[...
# 1  {'id': 13507232, 'login': 'SonyaMoisset', 'dis...
# 2  {'id': 56601466, 'login': 'tanujdhiman', 'disp...
# 3  {'id': 28653235, 'login': 'Dobby233Liu', 'disp...
# 4  {'id': 22623307, 'login': 'peter-clifford', 'd...
# 5  {'id': 4160220, 'login': 'gsaltis', 'display_l...
# 6  {'id': 1540531, 'login': 'tbrisker', 'display_...
# 7  {'id': 71586577, 'login': 'Flinegx', 'display_...
# 8  {'id': 23096478, 'login': 'breaklinux', 'displ...
# 9  {'id': 71103415, 'login': 'rjpagano', 'display...
#
#                                                 repo  \
# 0  {'id': 307709382, 'name': 'hsbt/chatwoot', 'ur...
# 1  {'id': 165382005, 'name': 'PrideInLondon/pride...
# 2  {'id': 63476337, 'name': 'TheAlgorithms/Python...
# 3  {'id': 251171908, 'name': 'd2lmirrors/blastem-...
# 4  {'id': 287289752, 'name': 'peter-clifford/grax...
# 5  {'id': 286749941, 'name': 'gsaltis/GBBCANSim',...
# 6  {'id': 5928690, 'name': 'theforeman/theforeman...
# 7  {'id': 307710219, 'name': 'Flinegx/Cheatsheet-...
# 8  {'id': 307705195, 'name': 'breaklinux/kubernet...
# 9  {'id': 297515003, 'name': 'rjpagano/covid_19_c...
#
#                                              payload  public  \
# 0  {'ref': 'dependabot/npm_and_yarn/expect-more-j...    True
# 1  {'action': 'closed', 'number': 1747, 'pull_req...    True
# 2  {'action': 'created', 'issue': {'url': 'https:...    True
# 3  {'push_id': 5926676152, 'size': 0, 'distinct_s...    True
# 4  {'push_id': 5926676137, 'size': 1, 'distinct_s...    True
# 5  {'push_id': 5926676155, 'size': 1, 'distinct_s...    True
# 6  {'action': 'closed', 'number': 1685, 'pull_req...    True
# 7  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 8  {'push_id': 5926676135, 'size': 1, 'distinct_s...    True
# 9  {'push_id': 5926676129, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2020-10-27T13:32:35Z                                                NaN
# 1  2020-10-27T13:32:35Z  {'id': 36210826, 'login': 'PrideInLondon', 'gr...
# 2  2020-10-27T13:32:35Z  {'id': 20487725, 'login': 'TheAlgorithms', 'gr...
# 3  2020-10-27T13:32:35Z  {'id': 63226830, 'login': 'd2lmirrors', 'grava...
# 4  2020-10-27T13:32:35Z                                                NaN
# 5  2020-10-27T13:32:35Z                                                NaN
# 6  2020-10-27T13:32:35Z  {'id': 1439844, 'login': 'theforeman', 'gravat...
# 7  2020-10-27T13:32:35Z                                                NaN
# 8  2020-10-27T13:32:35Z                                                NaN
# 9  2020-10-27T13:32:35Z                                                NaN

# %%
def flatten (data, col_list):
    for columns in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
#Simpler to work with with the flatten function
dict(data['actor'])
pd.DataFrame(dict(data['actor']))
pd.DataFrame(dict(data['actor'])).transpose()
# Out:
#           id                    login       display_login gravatar_id  \
# 0   27856297  dependabot-preview[bot]  dependabot-preview
# 1   13507232             SonyaMoisset        SonyaMoisset
# 2   56601466              tanujdhiman         tanujdhiman
# 3   28653235              Dobby233Liu         Dobby233Liu
# 4   22623307           peter-clifford      peter-clifford
# 5    4160220                  gsaltis             gsaltis
# 6    1540531                 tbrisker            tbrisker
# 7   71586577                  Flinegx             Flinegx
# 8   23096478               breaklinux          breaklinux
# 9   71103415                 rjpagano            rjpagano
# 10  54895950           Neighborwang87      Neighborwang87
# 11  41656094               JIANTONGJI          JIANTONGJI
# 12  39970166                   vctrop              vctrop
# 13  34338348              srinisundar         srinisundar
# 14  35613825              vercel[bot]              vercel
# 15  51705930               chenhs1641          chenhs1641
# 16   4170616                 cmsbuild            cmsbuild
# 17  10914751                    htuch               htuch
# 18   2064609               tchiotludo          tchiotludo
# 19  39814207                pull[bot]                pull
# 20  70901150                 vugeuepp            vugeuepp
# 21  20217397                GuanRainy           GuanRainy
# 22  10914751                    htuch               htuch
# 23  10914751                    htuch               htuch
# 24  27856297  dependabot-preview[bot]  dependabot-preview
# 25  10914751                    htuch               htuch
# 26  69792285        KingBeefSteak2007   KingBeefSteak2007
# 27  38261526                  Amit998             Amit998
# 28  73422884                 krisnacp            krisnacp
# 29  27856297  dependabot-preview[bot]  dependabot-preview
#
#                                                   url  \
# 0   https://api.github.com/users/dependabot-previe...
# 1           https://api.github.com/users/SonyaMoisset
# 2            https://api.github.com/users/tanujdhiman
# 3            https://api.github.com/users/Dobby233Liu
# 4         https://api.github.com/users/peter-clifford
# 5                https://api.github.com/users/gsaltis
# 6               https://api.github.com/users/tbrisker
# 7                https://api.github.com/users/Flinegx
# 8             https://api.github.com/users/breaklinux
# 9               https://api.github.com/users/rjpagano
# 10        https://api.github.com/users/Neighborwang87
# 11            https://api.github.com/users/JIANTONGJI
# 12                https://api.github.com/users/vctrop
# 13           https://api.github.com/users/srinisundar
# 14           https://api.github.com/users/vercel[bot]
# 15            https://api.github.com/users/chenhs1641
# 16              https://api.github.com/users/cmsbuild
# 17                 https://api.github.com/users/htuch
# 18            https://api.github.com/users/tchiotludo
# 19             https://api.github.com/users/pull[bot]
# 20              https://api.github.com/users/vugeuepp
# 21             https://api.github.com/users/GuanRainy
# 22                 https://api.github.com/users/htuch
# 23                 https://api.github.com/users/htuch
# 24  https://api.github.com/users/dependabot-previe...
# 25                 https://api.github.com/users/htuch
# 26     https://api.github.com/users/KingBeefSteak2007
# 27               https://api.github.com/users/Amit998
# 28              https://api.github.com/users/krisnacp
# 29  https://api.github.com/users/dependabot-previe...
#
#                                            avatar_url
# 0   https://avatars.githubusercontent.com/u/27856297?
# 1   https://avatars.githubusercontent.com/u/13507232?
# 2   https://avatars.githubusercontent.com/u/56601466?
# 3   https://avatars.githubusercontent.com/u/28653235?
# 4   https://avatars.githubusercontent.com/u/22623307?
# 5    https://avatars.githubusercontent.com/u/4160220?
# 6    https://avatars.githubusercontent.com/u/1540531?
# 7   https://avatars.githubusercontent.com/u/71586577?
# 8   https://avatars.githubusercontent.com/u/23096478?
# 9   https://avatars.githubusercontent.com/u/71103415?
# 10  https://avatars.githubusercontent.com/u/54895950?
# 11  https://avatars.githubusercontent.com/u/41656094?
# 12  https://avatars.githubusercontent.com/u/39970166?
# 13  https://avatars.githubusercontent.com/u/34338348?
# 14  https://avatars.githubusercontent.com/u/35613825?
# 15  https://avatars.githubusercontent.com/u/51705930?
# 16   https://avatars.githubusercontent.com/u/4170616?
# 17  https://avatars.githubusercontent.com/u/10914751?
# 18   https://avatars.githubusercontent.com/u/2064609?
# 19  https://avatars.githubusercontent.com/u/39814207?
# 20  https://avatars.githubusercontent.com/u/70901150?
# 21  https://avatars.githubusercontent.com/u/20217397?
# 22  https://avatars.githubusercontent.com/u/10914751?
# 23  https://avatars.githubusercontent.com/u/10914751?
# 24  https://avatars.githubusercontent.com/u/27856297?
# 25  https://avatars.githubusercontent.com/u/10914751?
# 26  https://avatars.githubusercontent.com/u/69792285?
# 27  https://avatars.githubusercontent.com/u/38261526?
# 28  https://avatars.githubusercontent.com/u/73422884?
# 29  https://avatars.githubusercontent.com/u/27856297?
