# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks')


data = pd.DataFrame(response.json())
data.head(10)
# Out:
#           id                           node_id           name  \
# 0  286608878  MDEwOlJlcG9zaXRvcnkyODY2MDg4Nzg=    dataV2-labs
# 1  286525274  MDEwOlJlcG9zaXRvcnkyODY1MjUyNzQ=    dataV2-labs
# 2  286521316  MDEwOlJlcG9zaXRvcnkyODY1MjEzMTY=    dataV2-labs
# 3  286520497  MDEwOlJlcG9zaXRvcnkyODY1MjA0OTc=    dataV2-labs
# 4  286517824  MDEwOlJlcG9zaXRvcnkyODY1MTc4MjQ=    dataV2-labs
# 5  284744809  MDEwOlJlcG9zaXRvcnkyODQ3NDQ4MDk=  dataV2-labs-1
# 6  281243768  MDEwOlJlcG9zaXRvcnkyODEyNDM3Njg=    dataV2-labs
# 7  276714038  MDEwOlJlcG9zaXRvcnkyNzY3MTQwMzg=    dataV2-labs
# 8  274415901  MDEwOlJlcG9zaXRvcnkyNzQ0MTU5MDE=    dataV2-labs
# 9  274151443  MDEwOlJlcG9zaXRvcnkyNzQxNTE0NDM=    dataV2-labs
#
#                    full_name  private  \
# 0         joaopq/dataV2-labs    False
# 1        JoanRBC/dataV2-labs    False
# 2  rafaelmello82/dataV2-labs    False
# 3         cfmago/dataV2-labs    False
# 4       jinverno/dataV2-labs    False
# 5      NellyCR/dataV2-labs-1    False
# 6     soniagondo/dataV2-labs    False
# 7     cmerticaru/dataV2-labs    False
# 8       aaronepv/dataV2-labs    False
# 9       Sanka101/dataV2-labs    False
#
#                                                owner  \
# 0  {'login': 'joaopq', 'id': 63979330, 'node_id':...
# 1  {'login': 'JoanRBC', 'id': 60225388, 'node_id'...
# 2  {'login': 'rafaelmello82', 'id': 64922281, 'no...
# 3  {'login': 'cfmago', 'id': 36172682, 'node_id':...
# 4  {'login': 'jinverno', 'id': 65239409, 'node_id...
# 5  {'login': 'NellyCR', 'id': 66942490, 'node_id'...
# 6  {'login': 'soniagondo', 'id': 67465742, 'node_...
# 7  {'login': 'cmerticaru', 'id': 61248268, 'node_...
# 8  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 9  {'login': 'Sanka101', 'id': 67108167, 'node_id...
#
#                                        html_url description  fork  \
# 0         https://github.com/joaopq/dataV2-labs        None  True
# 1        https://github.com/JoanRBC/dataV2-labs        None  True
# 2  https://github.com/rafaelmello82/dataV2-labs        None  True
# 3         https://github.com/cfmago/dataV2-labs        None  True
# 4       https://github.com/jinverno/dataV2-labs        None  True
# 5      https://github.com/NellyCR/dataV2-labs-1        None  True
# 6     https://github.com/soniagondo/dataV2-labs        None  True
# 7     https://github.com/cmerticaru/dataV2-labs        None  True
# 8       https://github.com/aaronepv/dataV2-labs        None  True
# 9       https://github.com/Sanka101/dataV2-labs        None  True
#
#                                                  url  ... forks_count  \
# 0    https://api.github.com/repos/joaopq/dataV2-labs  ...           0
# 1   https://api.github.com/repos/JoanRBC/dataV2-labs  ...           0
# 2  https://api.github.com/repos/rafaelmello82/dat...  ...           0
# 3    https://api.github.com/repos/cfmago/dataV2-labs  ...           0
# 4  https://api.github.com/repos/jinverno/dataV2-labs  ...           0
# 5  https://api.github.com/repos/NellyCR/dataV2-la...  ...           0
# 6  https://api.github.com/repos/soniagondo/dataV2...  ...           0
# 7  https://api.github.com/repos/cmerticaru/dataV2...  ...           0
# 8  https://api.github.com/repos/aaronepv/dataV2-labs  ...           0
# 9  https://api.github.com/repos/Sanka101/dataV2-labs  ...           0
#
#   mirror_url archived disabled open_issues_count license forks open_issues  \
# 0       None    False    False                 0    None     0           0
# 1       None    False    False                 0    None     0           0
# 2       None    False    False                 0    None     0           0
# 3       None    False    False                 0    None     0           0
# 4       None    False    False                 0    None     0           0
# 5       None    False    False                 0    None     0           0
# 6       None    False    False                 0    None     0           0
# 7       None    False    False                 0    None     0           0
# 8       None    False    False                 0    None     0           0
# 9       None    False    False                 0    None     0           0
#
#   watchers default_branch
# 0        0         master
# 1        0         master
# 2        0         master
# 3        0         master
# 4        0         master
# 5        0         master
# 6        0         master
# 7        0         master
# 8        0         master
# 9        0         master
#
# [10 rows x 73 columns]

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
languages = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/languages')

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
dates = requests.get('https://api.github.com/search/commits?q=committer-email:foo@bar.com&committer-date=2019-01-01..2019-01-01')

dates
# Out:
# <Response [415]>

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger')


data3 = pd.DataFrame(response.json())
data3.head()
# Out:
#                     id                           node_id       name  \
# login        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# id           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# node_id      162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# avatar_url   162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gravatar_id  162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
#
#                                full_name  private  \
# login        ironhack-datalabs/scavenger    False
# id           ironhack-datalabs/scavenger    False
# node_id      ironhack-datalabs/scavenger    False
# avatar_url   ironhack-datalabs/scavenger    False
# gravatar_id  ironhack-datalabs/scavenger    False
#
#                                                          owner  \
# login                                        ironhack-datalabs
# id                                                    44225188
# node_id                       MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4
# avatar_url   https://avatars2.githubusercontent.com/u/44225...
# gravatar_id
#
#                                                    html_url description  \
# login        https://github.com/ironhack-datalabs/scavenger        None
# id           https://github.com/ironhack-datalabs/scavenger        None
# node_id      https://github.com/ironhack-datalabs/scavenger        None
# avatar_url   https://github.com/ironhack-datalabs/scavenger        None
# gravatar_id  https://github.com/ironhack-datalabs/scavenger        None
#
#               fork                                                url  ...  \
# login        False  https://api.github.com/repos/ironhack-datalabs...  ...
# id           False  https://api.github.com/repos/ironhack-datalabs...  ...
# node_id      False  https://api.github.com/repos/ironhack-datalabs...  ...
# avatar_url   False  https://api.github.com/repos/ironhack-datalabs...  ...
# gravatar_id  False  https://api.github.com/repos/ironhack-datalabs...  ...
#
#             open_issues_count license forks open_issues watchers  \
# login                       0    None     5           0        0
# id                          0    None     5           0        0
# node_id                     0    None     5           0        0
# avatar_url                  0    None     5           0        0
# gravatar_id                 0    None     5           0        0
#
#             default_branch temp_clone_token  \
# login               master             None
# id                  master             None
# node_id             master             None
# avatar_url          master             None
# gravatar_id         master             None
#
#                                                   organization network_count  \
# login                                        ironhack-datalabs             5
# id                                                    44225188             5
# node_id                       MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4             5
# avatar_url   https://avatars2.githubusercontent.com/u/44225...             5
# gravatar_id                                                                5
#
#             subscribers_count
# login                       2
# id                          2
# node_id                     2
# avatar_url                  2
# gravatar_id                 2
#
# [5 rows x 77 columns]

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
