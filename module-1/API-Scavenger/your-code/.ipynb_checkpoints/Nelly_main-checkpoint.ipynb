# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here

import json
import requests
import pandas as pd

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here

response = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks')

results = response.json()

results

data = pd.DataFrame(results)
 
data = pd.DataFrame(response.json())

data
# Out:
#            id                           node_id             name  \
# 0   281180827  MDEwOlJlcG9zaXRvcnkyODExODA4Mjc=     mad-oct-2018
# 1   220066216  MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=     mad-oct-2018
# 2   204100911  MDEwOlJlcG9zaXRvcnkyMDQxMDA5MTE=     mad-oct-2018
# 3   200138127  MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=     mad-oct-2018
# 4   198273438  MDEwOlJlcG9zaXRvcnkxOTgyNzM0Mzg=     mad-oct-2018
# 5   167001044  MDEwOlJlcG9zaXRvcnkxNjcwMDEwNDQ=      datamad0119
# 6   162498469  MDEwOlJlcG9zaXRvcnkxNjI0OTg0Njk=  madrid-oct-2018
# 7   154625001  MDEwOlJlcG9zaXRvcnkxNTQ2MjUwMDE=  madrid-oct-2018
# 8   154291113  MDEwOlJlcG9zaXRvcnkxNTQyOTExMTM=  madrid-oct-2018
# 9   154191482  MDEwOlJlcG9zaXRvcnkxNTQxOTE0ODI=  madrid-oct-2018
# 10  154105473  MDEwOlJlcG9zaXRvcnkxNTQxMDU0NzM=  madrid-oct-2018
# 11  153788059  MDEwOlJlcG9zaXRvcnkxNTM3ODgwNTk=  madrid-oct-2018
# 12  153787890  MDEwOlJlcG9zaXRvcnkxNTM3ODc4OTA=  madrid-oct-2018
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here

data['language']

data.language.unique()
# Out:
# array([None, 'Jupyter Notebook', 'HTML'], dtype=object)

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

response = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits')

results = response.json()

results

data = pd.DataFrame(results)
 
data = pd.DataFrame(response.json())

data

from pandas.io.json import json_normalize

results = response.json()
flattened_data = json_normalize(results)

flattened_data
# Out:
# <ipython-input-35-52d3f9a2044d>:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#                                          sha  \
# 0   1638e5506e6947b77bfe78761d345476ae80d017
# 1   f332b5e6fcea965dc80f62220d7ee1457b04b90d
# 2   4c048c3efc18cf9d50e34c76919c8049ee7f2dbd
# 3   41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310
# 4   750eb91e4535c14ec4bf03f60cb5756a1c93f68f
# 5   4a8cc3cb64821cb58182a3a94be38f17d27a8e8f
# 6   1501bac01f8183d223a47ca7f23649a5d98d7e00
# 7   6c2a1247d4e13a37261081279f250ffa82ed5c96
# 8   cc02db3df76c8a16ecee3f7a937366ff427a7c3a
# 9   49ba929952728ab17635591cf55137c8af01babb
# 10  ba93368ee5593b15c7b1829f82cbacb9a003476c
# 11  2034c389cb81f30d30f94acc2a5237377d387dc1
# 12  09cf3f0163fe3895128cb322f5450672435ede7e
# 13  825dea0b3aab60bf587130441fab30d8abab775c
# 14  ced5e055e9313f60c57a7daab4ee89eac9f2c409
# 15  2cda9ab92b0f4dbfbe72e39a1bc26b9d7e41d28f
# ...

# %%
response1 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2/commits?page=1&per_page=100')

results1 = response1.json()

results1

data1 = pd.DataFrame(results1)
data1 = pd.DataFrame(response1.json())

data1

from pandas.io.json import json_normalize
results1 = response1.json()
flattened_data1 = json_normalize(results1)

flattened_data1
# Out:
# <ipython-input-61-3195ea6949c1>:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(results1)
#                                          sha  \
# 0   1638e5506e6947b77bfe78761d345476ae80d017
# 1   f332b5e6fcea965dc80f62220d7ee1457b04b90d
# 2   4c048c3efc18cf9d50e34c76919c8049ee7f2dbd
# 3   41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310
# 4   750eb91e4535c14ec4bf03f60cb5756a1c93f68f
# ..                                       ...
# 95  601b1853cb55ab7f6019f8ea75c35cce53865233
# 96  d0112ea8f7255773db5518ff2d81d56a62830e0d
# 97  d99bd4908561d60066d6e37bf714efa69b2119da
# 98  a0a4e5c5d5575d4ad4d2237e978484a137dca94b
# 99  a493b1e15ef9edd3853134f4fd9f6acb08e07198
#
#                                               node_id  \
# 0   MDY6Q29tbWl0MTUzNzIwODA0OjE2MzhlNTUwNmU2OTQ3Yj...
# 1   MDY6Q29tbWl0MTUzNzIwODA0OmYzMzJiNWU2ZmNlYTk2NW...
# 2   MDY6Q29tbWl0MTUzNzIwODA0OjRjMDQ4YzNlZmMxOGNmOW...
# ...

# %%
#This was the first option
#Count the number of commits made on 2018
import re

author_date = flattened_data1['commit.author.date']
counter = 0
for i in author_date:
    if author_date[:4] == 2018:
        counter += 1
print(counter) 

# This was the other option but it didn’t work

response2 = requests.get('https://api.github.com/search/commits?commit.author.date=2018-10-01..2018-10-31')
results2 = response2.json()
data2 = pd.DataFrame(results2)

data2
# Out:
#              message                                             errors  \
# 0  Validation Failed  {'resource': 'Search', 'field': 'q', 'code': '...
#
#                    documentation_url
# 0  https://docs.github.com/v3/search

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here

flattened_data1.count()
# Out:
# sha                              100
# node_id                          100
# url                              100
# html_url                         100
# comments_url                     100
# parents                          100
# commit.author.name               100
# commit.author.email              100
# commit.author.date               100
# commit.committer.name            100
# commit.committer.email           100
# commit.committer.date            100
# commit.message                   100
# commit.tree.sha                  100
# commit.tree.url                  100
# commit.url                       100
# commit.comment_count             100
# commit.verification.verified     100
# commit.verification.reason       100
# commit.verification.signature      6
# commit.verification.payload        6
# author.login                     100
# author.id                        100
# author.node_id                   100
# author.avatar_url                100
# ...

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here

results = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents').json()

data = pd.DataFrame(results)

data
# Out:
#           name        path                                       sha  size  \
# 0   .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1        15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2        15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3        17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4        30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
# 5        40303       40303  30193d9cf62b07bcbb6366513ff03596861f2d29     0
# 6        44639       44639  22fc3d5c2db80822c351edb2248f3491c8ebda86     0
# 7        45525       45525  6a4a88cd9084110c8646c3cfd84dfe96b300a4a7     0
# 8        47222       47222  c7001604cdadc2fe7b82e0f6996690718cac6941     0
# 9        47830       47830  f84882ad7560fd2b8c6a0867bc707ce9009ef288     0
# 10       49418       49418  46bc658c09589d9023246b00e848ce97d30d4989     0
# ...

# %%
#This was my solution but it didn’t work

filter_col = [col for col in df if col.startswith('foo')]
filter_col

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
