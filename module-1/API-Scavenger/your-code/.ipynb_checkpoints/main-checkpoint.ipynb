# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
username = 'tsharma2020'
# %run "C:\Users\tusha\dataV2-labs\module-1\API-Scavenger\token\token_detail.ipynb"
#token = 'your token'

# %%
# import libraries here
import requests
import pandas as pd
import json

response = requests.get("https://api.github.com/repos/jmolendijk/dataV2-labs/forks", auth=('tsharma2020',token))
data = pd.DataFrame(response.json())
data
# Out:
#            id                           node_id         name  \
# 0   303425358  MDEwOlJlcG9zaXRvcnkzMDM0MjUzNTg=  dataV2-labs
# 1   303423312  MDEwOlJlcG9zaXRvcnkzMDM0MjMzMTI=  dataV2-labs
# 2   303422412  MDEwOlJlcG9zaXRvcnkzMDM0MjI0MTI=  dataV2-labs
# 3   303406441  MDEwOlJlcG9zaXRvcnkzMDM0MDY0NDE=  dataV2-labs
# 4   303403314  MDEwOlJlcG9zaXRvcnkzMDM0MDMzMTQ=  dataV2-labs
# 5   303399398  MDEwOlJlcG9zaXRvcnkzMDMzOTkzOTg=  dataV2-labs
# 6   303398603  MDEwOlJlcG9zaXRvcnkzMDMzOTg2MDM=  dataV2-labs
# 7   303398334  MDEwOlJlcG9zaXRvcnkzMDMzOTgzMzQ=  dataV2-labs
# 8   282919082  MDEwOlJlcG9zaXRvcnkyODI5MTkwODI=  dataV2-labs
# 9   282915736  MDEwOlJlcG9zaXRvcnkyODI5MTU3MzY=  dataV2-labs
# 10  282915688  MDEwOlJlcG9zaXRvcnkyODI5MTU2ODg=  dataV2-labs
# 11  282915261  MDEwOlJlcG9zaXRvcnkyODI5MTUyNjE=  dataV2-labs
# 12  282913803  MDEwOlJlcG9zaXRvcnkyODI5MTM4MDM=  dataV2-labs
#
#                        full_name  private  \
# 0    MichelleMartens/dataV2-labs    False
# ...

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
forks = requests.get("https://api.github.com/repos/jmolendijk/dataV2-labs/forks")
results = response.json()
forks = json_normalize(results)
forks
# Out:
# <ipython-input-13-77e69799b6d5>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   forks = json_normalize(results)
#                                         sha  \
# 0  732d41f99c3460826fc321566ca79cb2f8bfb2b3
# 1  80189cce124398781df93e115bf60755e3ed4d7b
# 2  820a60e936eb06c25271744ac773d41799501388
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjgyNjY1MjcyOjczMmQ0MWY5OWMzNDYwOD...
# 1  MDY6Q29tbWl0MjgyNjY1MjcyOjgwMTg5Y2NlMTI0Mzk4Nz...
# 2  MDY6Q29tbWl0MjgyNjY1MjcyOjgyMGE2MGU5MzZlYjA2Yz...
#
#                                                  url  \
# 0  https://api.github.com/repos/jmolendijk/dataV2...
# 1  https://api.github.com/repos/jmolendijk/dataV2...
# 2  https://api.github.com/repos/jmolendijk/dataV2...
#
#                                             html_url  \
# 0  https://github.com/jmolendijk/dataV2-labs/comm...
# 1  https://github.com/jmolendijk/dataV2-labs/comm...
# ...

# %%
from pandas.io.json import json_normalize

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
response = requests.get("https://api.github.com/repos/jmolendijk/dataV2-labs/languages", auth=('tsharma2020',token))
results = response.json()
data = json_normalize(results)
data
# Out:
# <ipython-input-16-e7a04bc7c695>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   data = json_normalize(results)
#    Jupyter Notebook    HTML  Python
# 0           2471626  510791    9907

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
response = requests.get("https://api.github.com/repos/jmolendijk/dataV2-labs/commits", auth=('tsharma2020',token))
results = response.json()
data = json_normalize(results)
data
#name of table[‘name of column’].reset_index()
data['committer.repos_url'].reset_index()
# Out:
# <ipython-input-23-2f82b85b9474>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   data = json_normalize(results)
#    index                            committer.repos_url
# 0      0  https://api.github.com/users/jmolendijk/repos
# 1      1  https://api.github.com/users/jmolendijk/repos
# 2      2    https://api.github.com/users/web-flow/repos

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
len(data)
# Out:
# 3

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
#response_c3 = requests.get("https://api.github.com/ironhack-datalabs/scavenger", auth=('tsharma2020',token))
# results1 = response.json()
# data = json_normalize(results1)
# response_c3 = requests.get("https://api.github.com/repos/ironhack-datalabs/scavenger/contents")
# data_c3 = pd.DataFrame(response_c3.json())
# data_c3.head

# %%
scavengers = requests.get("https://api.github.com/repos/ironhack-datalabs/scavenger").json()

# %%
scavengers
results = pd.DataFrame(scavengers)
results
# Out:
#                             id                           node_id       name  \
# login                162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# id                   162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# node_id              162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# avatar_url           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gravatar_id          162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# url                  162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# html_url             162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# followers_url        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# following_url        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gists_url            162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# starred_url          162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
#results.columns

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
