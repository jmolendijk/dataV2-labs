# %%
import requests
import pandas as pd

username = 'sebastieniron'
# %run './set_token.ipynb'
token = ''

response = requests.get('https://api.github.com/user/repos?page=1&per_page=100', auth=(username,token))
data = pd.DataFrame(response.json())
data
# Out:
#           id                           node_id               name  \
# 0  306386383  MDEwOlJlcG9zaXRvcnkzMDYzODYzODM=  Project-Amsterdam
# 1  296280011  MDEwOlJlcG9zaXRvcnkyOTYyODAwMTE=       data-prework
# 2  303403314  MDEwOlJlcG9zaXRvcnkzMDM0MDMzMTQ=        dataV2-labs
# 3  296048318  MDEwOlJlcG9zaXRvcnkyOTYwNDgzMTg=        hello-world
# 4  296288525  MDEwOlJlcG9zaXRvcnkyOTYyODg1MjU=      personal-data
# 5  306599763  MDEwOlJlcG9zaXRvcnkzMDY1OTk3NjM=  Project-Amsterdam
# 6  306385180  MDEwOlJlcG9zaXRvcnkzMDYzODUxODA=   ProjectAmsterdam
# 7  296247935  MDEwOlJlcG9zaXRvcnkyOTYyNDc5MzU=  super-duper-robot
#
#                          full_name  private  \
# 0    IrynaHorova/Project-Amsterdam    False
# 1       Sebastieniron/data-prework    False
# 2        Sebastieniron/dataV2-labs    False
# 3        Sebastieniron/hello-world    False
# 4      Sebastieniron/personal-data    False
# 5  Sebastieniron/Project-Amsterdam    False
# 6   Sebastieniron/ProjectAmsterdam    False
# 7  Sebastieniron/super-duper-robot    False
#
#                                                owner  \
# 0  {'login': 'IrynaHorova', 'id': 70847166, 'node...
# 1  {'login': 'Sebastieniron', 'id': 71374088, 'no...
# 2  {'login': 'Sebastieniron', 'id': 71374088, 'no...
# 3  {'login': 'Sebastieniron', 'id': 71374088, 'no...
# 4  {'login': 'Sebastieniron', 'id': 71374088, 'no...
# 5  {'login': 'Sebastieniron', 'id': 71374088, 'no...
# 6  {'login': 'Sebastieniron', 'id': 71374088, 'no...
# 7  {'login': 'Sebastieniron', 'id': 71374088, 'no...
#
#                                             html_url  \
# 0   https://github.com/IrynaHorova/Project-Amsterdam
# 1      https://github.com/Sebastieniron/data-prework
# 2       https://github.com/Sebastieniron/dataV2-labs
# 3       https://github.com/Sebastieniron/hello-world
# 4     https://github.com/Sebastieniron/personal-data
# 5  https://github.com/Sebastieniron/Project-Amste...
# 6  https://github.com/Sebastieniron/ProjectAmsterdam
# 7  https://github.com/Sebastieniron/super-duper-r...
#
#                                          description   fork  \
# 0         Project-Amsterdam DAFT Iryna and Sebastien  False
# 1                                               None   True
# 2  copy of the Ironhack data labs for use in JM's...   True
# 3                                               test  False
# 4                                               None  False
# 5         Project-Amsterdam DAFT Iryna and Sebastien   True
# 6                     AMS-DAFT-ProjectAmsterdam-Repo  False
# 7                                               None  False
#
#                                                  url  ... mirror_url archived  \
# 0  https://api.github.com/repos/IrynaHorova/Proje...  ...       None    False
# 1  https://api.github.com/repos/Sebastieniron/dat...  ...       None    False
# 2  https://api.github.com/repos/Sebastieniron/dat...  ...       None    False
# 3  https://api.github.com/repos/Sebastieniron/hel...  ...       None    False
# 4  https://api.github.com/repos/Sebastieniron/per...  ...       None    False
# 5  https://api.github.com/repos/Sebastieniron/Pro...  ...       None    False
# 6  https://api.github.com/repos/Sebastieniron/Pro...  ...       None    False
# 7  https://api.github.com/repos/Sebastieniron/sup...  ...       None    False
#
#   disabled open_issues_count license forks open_issues watchers  \
# 0    False                 0    None     1           0        1
# 1    False                 0    None     0           0        0
# 2    False                 0    None     0           0        0
# 3    False                 0    None     0           0        0
# 4    False                 0    None     0           0        0
# 5    False                 0    None     0           0        0
# 6    False                 0    None     0           0        0
# 7    False                 0    None     0           0        0
#
#   default_branch                                   permissions
# 0           main  {'admin': False, 'push': True, 'pull': True}
# 1         master   {'admin': True, 'push': True, 'pull': True}
# 2         master   {'admin': True, 'push': True, 'pull': True}
# 3         master   {'admin': True, 'push': True, 'pull': True}
# 4         master   {'admin': True, 'push': True, 'pull': True}
# 5           main   {'admin': True, 'push': True, 'pull': True}
# 6           main   {'admin': True, 'push': True, 'pull': True}
# 7         master   {'admin': True, 'push': True, 'pull': True}
#
# [8 rows x 74 columns]
