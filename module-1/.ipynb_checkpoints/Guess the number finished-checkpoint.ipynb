# %%
import random

guesses_taken = 0
as_string = str(guesses_taken)

print("""Welcome to my first self buid game! Hopefully you're just as excited as I'm!

What is your name?""")
name = input()

n = random.randint(1, 5)

print('\nWell, ' + name + ", I am thinking of a number between 1 and 100. \n\nDon't worry, I will tell you if you are close!")

guess = int(input("""Take a guess: """))

while guesses_taken < 7:
    guesses_taken = guesses_taken + 1
    print
    if guess > n:
        print("\nOh no! Your guess is too high!")
        if (guess - n) <= 10:
            print("You're very close, you can do this!")
            guess = int(input("\nHopefully you will guess again? \nTake a guess: "))
        else:
            guess = int(input("\nHopefully you will guess again? \nTake a guess: "))
    elif guess < n:
        print("\nOh no! Your guess is too low!")
        if (n - guess) <= 10:
            print("You're very close, you can do this!")
            guess = int(input("\nHopefully you will guess again? \nTake a guess: "))
        else:
            guess = int(input("\nHopefully you will guess again? \nTake a guess: "))
    elif guess == n:
        as_string = str(guesses_taken)
        print("\nYou did it " + name + "! You guessed the number in " + as_string + f" guesses! It was {n}")
        break
    else:
        pass
    
if guesses_taken >= 7:
        n = str(n)
        print("\nOh no, you didn't guess it. The number I was thinking of was " + n + ".")
        guess = int(input("\nWould you like to try again?"))
        if
# Out:
# Welcome to my first self buid game! Hopefully you're just as excited as I'm!
#
# What is your name?
# michelle
#
# Well, michelle, I am thinking of a number between 1 and 100.
#
# Don't worry, I will tell you if you are close!
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no! Your guess is too high!
# You're very close, you can do this!
#
# Hopefully you will guess again?
# Take a guess: 6
#
# Oh no, you didn't guess it. The number I was thinking of was 5.
#
# Would you like to try again?yes
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c46148e61a8d> in <module>()
#      42         n = str(n)
#      43         print("\nOh no, you didn't guess it. The number I was thinking of was " + n + ".")
# ---> 44         guess = int(input("\nWould you like to try again?"))
#      45
#
# ValueError: invalid literal for int() with base 10: 'yes'
