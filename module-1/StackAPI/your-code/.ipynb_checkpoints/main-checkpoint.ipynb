# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
from stackapi import StackAPI
from datetime import datetime
import pandas as pd
from pandas import json_normalize

# %%
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
#fetch questions and answers
questions = SITE.fetch('questions', fromdate = datetime(2020,9,1), todate=datetime(2020,9,30))
answers = SITE.fetch('answers', fromdate=datetime(2020,9,1), todate=datetime(2020,9,30))

# %%
#flatten questions
nested_columns = ['items']
questions_flat =  json_normalize(questions, nested_columns)
questions_flat.head()
# Out:
#                                                 tags  is_answered  view_count  \
# 0                      [node.js, typescript, nestjs]        False          54
# 1  [python, machine-learning, computer-vision, py...        False          38
# 2  [docker, nginx, gunicorn, nginx-reverse-proxy,...         True          35
# 3      [php, json, get, magento2, file-get-contents]         True          55
# 4  [recursion, functional-programming, division, ...         True          82
#
#    bounty_amount  bounty_closes_date  answer_count  score  last_activity_date  \
# 0           50.0        1.604484e+09             0      0          1603883619
# 1            NaN                 NaN             0      0          1603883287
# 2            NaN                 NaN             1      0          1603882967
# 3            NaN                 NaN             1      0          1603882626
# 4            NaN                 NaN             2      3          1603882528
#
# ...

# %%
#flatten answers
nested_columns = ['items']
answers_flat =  json_normalize(answers, nested_columns)
answers_flat.head()
# Out:
#    is_accepted  score  last_activity_date  last_edit_date  creation_date  \
# 0         True      1          1603882043      1603882043     1598964931
# 1         True      0          1603882016      1603882016     1599121107
# 2        False      0          1603881987      1603881987     1600267262
# 3        False      1          1603881496      1603881496     1600341212
# 4         True      1          1603877391      1603877391     1600649563
#
#    answer_id  question_id content_license  owner.reputation  owner.user_id  \
# 0   63688123     63687726    CC BY-SA 4.0                77        9095975
# 1   63719573     63719388    CC BY-SA 4.0                73       11928455
# 2   63922472     63903898    CC BY-SA 4.0               507        5381672
# 3   63936828     49781611    CC BY-SA 4.0              1918        3122378
# 4   63984951     63981315    CC BY-SA 4.0            157211       10676716
#
#   owner.user_type                                owner.profile_image  \
# ...

# %%
#pd.to_datetime(answers_flat['creation_date'], unit='s')

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questions_python = SITE.fetch(
    'questions', 
    min = 5, 
    sort = 'votes', 
    fromdate = datetime(2020,10,28), 
    todate = datetime(2020,10,29),
    tagged = 'python'
)

# %%
# there are no questions with a score of at least 5 today (2020-10-28)
nested_columns = ['items']
questions_python_flat =  json_normalize(questions_python, nested_columns)
questions_python_flat.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here

answers2 = SITE.fetch(
    'answers', 
    ids = [6784, 6473]
)

# %%
# there is only one answer from that id list
nested_columns = ['items']
answers2_flat =  json_normalize(answers2, nested_columns)
answers2_flat.head()
# Out:
#    is_accepted  score  last_activity_date  creation_date  answer_id  \
# 0        False      0          1218291583     1218291583       6784
#
#    question_id content_license  owner.reputation  owner.user_id  \
# 0         6778    CC BY-SA 2.5             29133            758
#
#   owner.user_type  owner.accept_rate  \
# 0      registered                 77
#
#                                  owner.profile_image owner.display_name  \
# 0  https://www.gravatar.com/avatar/0b4adc19284ed0...        Mark Renouf
#
#                                         owner.link
# 0  https://stackoverflow.com/users/758/mark-renouf
