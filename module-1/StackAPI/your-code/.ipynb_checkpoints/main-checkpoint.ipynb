# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
import pandas as pd
import json

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

1457136000

questions = SITE.fetch('questions', fromdate=1596240000, todate=1597190400)

#questions

q_data = pd.DataFrame(questions)
q_data
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['.net', 'pdfsharp'], 'owner': {'repu...
# 1    {'tags': ['windows', 'rust', 'ffi'], 'owner': ...
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
questions_two = SITE.fetch('questions', fromdate=1596240000, todate=1597190400, min=5, tagged='python', sort='votes')
q_data_2 = pd.DataFrame(questions_two)

q_data_2
# Out:
#     index  backoff  has_more  page  quota_max  quota_remaining  total  \
# 0       0        0     False     1        300              300      0
# 1       1        0     False     1        300              300      0
# 2       2        0     False     1        300              300      0
# 3       3        0     False     1        300              300      0
# 4       4        0     False     1        300              300      0
# 5       5        0     False     1        300              300      0
# 6       6        0     False     1        300              300      0
# 7       7        0     False     1        300              300      0
# 8       8        0     False     1        300              300      0
# 9       9        0     False     1        300              300      0
# 10     10        0     False     1        300              300      0
# 11     11        0     False     1        300              300      0
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
questions_3 = SITE.fetch('badges', ids=[6784, 6473])
questions_3

#q_data3 = pd.DataFrame(questions_3)
#q_data3
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 6784,
#    'link': 'https://stackoverflow.com/badges/6784/asterisk',
#    'name': 'asterisk'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 6473,
#    'link': 'https://stackoverflow.com/badges/6473/sql-server-2012',
#    'name': 'sql-server-2012'}]}
