# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
# Install a pip package in the current Jupyter kernel

import sys
# !{sys.executable} -m pip install stackapi

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

import pandas as pd

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
#Test
from datetime import date

d=1457136000
print (date.fromtimestamp(d))
# Out:
# 2016-03-05

# %%
# your code here

SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate='2020-09-01', todate='2020-09-30')

data = pd.DataFrame(questions)

data
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['node.js', 'typescript', 'nestjs'], ...
# 1    {'tags': ['python', 'machine-learning', 'compu...
# ...

# %%
data = flatten(data,['items'])

data
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                             items_tags  \
# 0                        [node.js, typescript, nestjs]
# 1    [python, machine-learning, computer-vision, py...
# ...

# %%
#Final answer:
data = flatten(data,['items_owner'])

data
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                             items_tags items_is_answered  \
# 0                        [node.js, typescript, nestjs]             False
# ...

# %%
#Final answer:

questions_data = pd.DataFrame(data['items_title'])

questions_data
# Out:
#                                            items_title
# 0    NestJS inject custom TypeOrm repository based ...
# 1    How to convert object detection model to binar...
# 2    Why do we must use nginx with gunicorn for fla...
# 3    Magento2/PHP - file_get_contents() returns dif...
# 4                            Integer division in Dhall
# ..                                                 ...
# 495  WordPress: Extend heading block in Gutenberg w...
# 496             BigDecimal Arithmatic in Jasper report
# 497  How do I change the CSS of an element based on...
# 498  Why is my Python loop functioning returning Na...
# 499  Jenkins - need JENKINS_HOME but missing the Ov...
#
# [500 rows x 1 columns]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
SITE = StackAPI('stackoverflow')
questions2 = SITE.fetch('questions', fromdate='2020-09-01', todate='2020-09-30',min=5, tagged='python', sort='votes')

data2 = pd.DataFrame(questions2)

data2 = flatten(data2, ['items'])
data2 = flatten(data2, ['items_owner'])
data2
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0     False     2        300              300      0
# 1          0     False     2        300              300      0
# 2          0     False     2        300              300      0
# 3          0     False     2        300              300      0
# 4          0     False     2        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 156        0     False     2        300              300      0
# 157        0     False     2        300              300      0
# 158        0     False     2        300              300      0
# 159        0     False     2        300              300      0
# 160        0     False     2        300              300      0
#
#                                             items_tags items_is_answered  \
# 0                 [python, python-3.x, string, quotes]              True
# ...

# %%
question2_score = pd.DataFrame(data2 ['items_score'])

question2_score
# Out:
#     items_score
# 0            64
# 1            42
# 2            41
# 3            24
# 4            19
# ..          ...
# 156           5
# 157           5
# 158           5
# 159           5
# 160           5
#
# [161 rows x 1 columns]

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here

answers = SITE.fetch('/answers/{ids}', ids=[6784, 6473])

ids_df = pd.DataFrame(answers)
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# <ipython-input-102-277b802bb15b> in <module>
#       1 # your code here
#       2
# ----> 3 answers = SITE.fetch('/answers/{ids}', ids=[6784, 6473])
#       4
#       5 ids_df = pd.DataFrame(answers)
#
# /usr/local/Cellar/jupyterlab/2.2.2/libexec/lib/python3.8/site-packages/stackapi/stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     196                 code = response["error_name"]
#     197                 message = response["error_message"]
# --> 198                 raise StackAPIError(self._previous_call, error, code, message)
#     199             except KeyError:
#     200                 pass  # This means there is no error
#
# StackAPIError: ('https://api.stackexchange.com/2.2//answers/6784;6473/?pagesize=100&page=1&filter=default&site=stackoverflow', 404, 'no_method', 'no method found with this name')
