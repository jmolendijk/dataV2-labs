# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
#import sys
#!{sys.executable} -m pip install pymysql

import pymysql
from sqlalchemy import create_engine
import pandas as pd

sqlstr = """SELECT titles.title_id as 'Title ID', titleauthor.au_id as 'Author ID', 
            ROUND(titles.advance * titleauthor.royaltyper / 100, 2) as 'Advance', 
            ROUND(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100, 2) as 'Sales_royalty'
            FROM titles
            LEFT JOIN titleauthor
            ON titles.title_id = titleauthor.title_id
            LEFT JOIN sales 
            ON titles.title_id = sales.title_id
            ORDER BY 1;
            """

engine = create_engine('mysql+pymysql://student:*********@34.77.233.175:3306/publications')

data_query_one = pd.read_sql_query(sqlstr, engine)

data_query_one
#I've made a print statement to see if anything was correct.
# Out:
#    Title ID    Author ID  Advance  Sales_royalty
# 0    BU1032  213-46-8915   2000.0           4.00
# 1    BU1032  213-46-8915   2000.0           8.00
# 2    BU1032  409-56-7008   3000.0           6.00
# 3    BU1032  409-56-7008   3000.0          11.99
# 4    BU1111  267-41-2394   2000.0          11.95
# 5    BU1111  724-80-9391   3000.0          17.93
# 6    BU2075  213-46-8915  10125.0          25.12
# 7    BU7832  274-80-9391   5000.0          29.99
# 8    MC2222  712-45-1867      0.0          23.99
# 9    MC3021  722-51-5454  11250.0          13.46
# 10   MC3021  722-51-5454  11250.0           8.07
# 11   MC3021  899-46-2035   3750.0           4.49
# 12   MC3021  899-46-2035   3750.0           2.69
# 13   MC3026         None      NaN            NaN
# 14   PC1035  238-95-7766   7000.0         110.16
# 15   PC8888  427-17-2319   4000.0          50.00
# 16   PC8888  846-92-7186   4000.0          50.00
# 17   PC9999  486-29-1786      NaN            NaN
# ...

# %% [markdown]
# # Challenge 2 - Working with JSON files
#
# Import the pandas library.

# %%
import pandas as pd
import os 
print(os.getcwd)
# Out:
# <built-in function getcwd>

# %% [markdown]
# In the next cell, load the data in `nasa.json` in the `data` folder and load it into a pandas dataframe. Name the dataframe `nasa`.

# %%
nasa = pd.read_json('/Users/bert/Desktop/dataV2-labs/module-1/Importing-Exporting-Data/data/nasa.json', orient='records')

#Here I need to use my complete path because otherwise it don't works.

# %% [markdown]
# Now that we have loaded the data, let's examine it using the `head()` function.

# %%
nasa.head(8)
#Instead of the default I have here select the first 8 rows
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
# 3                          NaN                          NaN  Fell
# 4                          NaN                          NaN  Fell
# 5                          NaN                          NaN  Fell
# 6                          NaN                          NaN  Fell
# 7                          NaN                          NaN  Fell
#
#                                          geolocation   id      mass  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0
# ...

# %% [markdown]
# #### The `value_counts()` function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the `value_counts()` function to determine the frequency of all types of asteroid landings by applying the function to the `fall` column.

# %%
nasa_one = nasa['fall']
print(type(nasa_one)) 

nasa_one.value_counts()

#First I turned the original nasa in a subdocument to turn in a serie. 
#Second make a printstatemnet to check that the new variable is a serie
#Third I used the value_counts()
# Out:
# <class 'pandas.core.series.Series'>
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the `orient=records` argument and name the file `nasa-output.json`. Remember to save the file inside the `data` folder.

# %%
nasa.to_json('/Users/bert/Desktop/dataV2-labs/module-1/Importing-Exporting-Data/data/nasa-output.json', orient='records')

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# CSV files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a CSV file into a dataframe directly from a URL without having to load the file first and then transform it. The dataset we will be using contains information about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class', 'test']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

#note to myself, i always need to check how many columns there are... 
#Thanks to Nelly to give me the solution to put in 'Test' as extra column_name.

# %%
#Step One: First get the files
shuttle = pd.read_csv(tst_url, sep=' ', names=cols)
shuttle
# Out:
#        time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 0        55         0         81         0    -6      11         25        88
# 1        56         0         96         0    52      -4         40        44
# 2        50        -1         89        -7    50       0         39        40
# 3        53         9         79         0    42      -2         25        37
# 4        55         2         82         0    54      -6         26        28
# ...     ...       ...        ...       ...   ...     ...        ...       ...
# 14495    80         0         84         0   -36     -29          4       120
# 14496    55         0         81         0   -20      25         26       102
# 14497    55         0         77         0    12     -22         22        65
# 14498    37         0        103         0    18     -16         66        85
# 14499    56         2         98         0    52       1         42        46
#
#        class  test
# ...

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
shuttle.head(7)

#Yes it works because now you can find it on top!
# Out:
#    time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 0    55         0         81         0    -6      11         25        88
# 1    56         0         96         0    52      -4         40        44
# 2    50        -1         89        -7    50       0         39        40
# 3    53         9         79         0    42      -2         25        37
# 4    55         2         82         0    54      -6         26        28
# 5    41         0         84         3    38      -4         43        45
# 6    37         0        100         0    36      -8         63        64
#
#    class  test
# 0     64     4
# 1      4     4
# 2      2     1
# 3     12     4
# 4      2     1
# 5      2     1
# 6      2     1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated, that we are not saving the index column and that the file is saved inside the `data` folder.

# %%
shuttle = shuttle.to_csv('/Users/bert/Desktop/dataV2-labs/module-1/Importing-Exporting-Data/data/shuttle.csv', index=False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the `data` folder. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
#import sys
#!{sys.executable} -m pip install xlrd
#libary was already installed.

astronaut = pd.read_excel('/Users/bert/Desktop/dataV2-labs/module-1/Importing-Exporting-Data/data/astronauts.xls')
astronaut
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active 1967-05-17
# 1           Loren W. Acton     NaN    NaN  Retired 1936-03-07
# 2         James C. Adamson  1984.0   10.0  Retired 1946-03-03
# 3          Thomas D. Akers  1987.0   12.0  Retired 1951-05-20
# 4              Buzz Aldrin  1963.0    3.0  Retired 1930-01-20
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired 1956-08-23
# 353  Neil W. Woodward III   1998.0   17.0  Retired 1962-07-26
# 354       Alfred M. Worden  1966.0    5.0  Retired 1932-02-07
# 355          John W. Young  1962.0    2.0  Retired 1930-09-24
# 356        George D. Zamka  1998.0   17.0  Retired 1962-06-29
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
astronaut.head(7)
# Out:
#                Name    Year  Group   Status Birth Date          Birth Place  \
# 0   Joseph M. Acaba  2004.0   19.0   Active 1967-05-17        Inglewood, CA
# 1    Loren W. Acton     NaN    NaN  Retired 1936-03-07         Lewiston, MT
# 2  James C. Adamson  1984.0   10.0  Retired 1946-03-03           Warsaw, NY
# 3   Thomas D. Akers  1987.0   12.0  Retired 1951-05-20        St. Louis, MO
# 4       Buzz Aldrin  1963.0    3.0  Retired 1930-01-20        Montclair, NJ
# 5   Andrew M. Allen  1987.0   12.0  Retired 1955-08-04     Philadelphia, PA
# 6   Joseph P. Allen  1967.0    6.0  Retired 1937-06-27  Crawsfordsville, IN
#
#   Gender                                         Alma Mater  \
# 0   Male  University of California-Santa Barbara; Univer...
# 1   Male   Montana State University; University of Colorado
# 2   Male          US Military Academy; Princeton University
# 3   Male                       University of Missouri-Rolla
# ...

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
astronauts_one = astronaut['Undergraduate Major']
astronauts_one.value_counts()

#Same strategy as before.
# Out:
# Physics                                          35
# Aerospace Engineering                            33
# Mechanical Engineering                           30
# Aeronautical Engineering                         28
# Electrical Engineering                           23
#                                                  ..
# Business Management; Aeronautical Engineering     1
# Physiology                                        1
# Molecular Biology                                 1
# Computer & Systems Engineering                    1
# Ecological Science                                1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a **tab separated file** using the `to_csv` function. Call the file `astronaut.csv`. Remember to remove the index column and save the file in the `data` folder.

# %%
astronaut = astronaut.to_csv('/Users/bert/Desktop/dataV2-labs/module-1/Importing-Exporting-Data/data/astronaut.csv', sep='\t', index=False)

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.
#
# Look in Google for a way to retrieve this data!

# %%
cols = ['Season', 'Age', 'Childish diseases', 'Accident/Trauma', 'Surgical intervention', 'High fevers', 'Frequency of alcohol', 'Smoking habit', 'Number Sitting', 'Diagnosis normal (N), altered (O) ']
fertility = pd.read_csv('/Users/bert/Desktop/dataV2-labs/module-1/Importing-Exporting-Data/data/fertility.txt', sep=",", names=cols)
fertility
# Out:
#     Season   Age  Childish diseases  Accident/Trauma  Surgical intervention  \
# 0    -0.33  0.69                  0                1                      1
# 1    -0.33  0.94                  1                0                      1
# 2    -0.33  0.50                  1                0                      0
# 3    -0.33  0.75                  0                1                      1
# 4    -0.33  0.67                  1                1                      0
# ..     ...   ...                ...              ...                    ...
# 95   -1.00  0.67                  1                0                      0
# 96   -1.00  0.61                  1                0                      0
# 97   -1.00  0.67                  1                1                      1
# 98   -1.00  0.64                  1                0                      1
# 99   -1.00  0.69                  0                1                      1
#
# ...
