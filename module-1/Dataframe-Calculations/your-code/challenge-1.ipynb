# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database

#I tried importing it directly from the Gdrive, but it gives me an error
# url = requests.get('https://drive.google.com/drive/folders/1hLuGokqZdS0yfXbiJs-VopLpOhoGEd0D')
# csv_raw = StringIO(url.text)
# pokemon = pd.read_csv(csv_raw)

# os.getcwd()
pokemon = pd.read_csv('/Users/ajiacovic/Documents/data/Pokemon.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
type1 = set(pokemon['Type 1'].unique())
type2 = set(pokemon['Type 2'].unique())

type1.union(type2)
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water',
#  nan}

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here

#I'm splitting the cell name by space (n=1 so, only one split, and expand the separation to another cell)
pokemon1= pokemon['Name'].str.split(' ',n=1,expand =True)

# %%
## I'm adding a column to the dataframe with the values extracted from the code before =this allows me to identify the cells to be changed
pokemon['dummieName'] = pokemon1[1]

# %%
pokemon['Name'] = pokemon1[0]

# %%
## Checking the types of data, and setting to string in order to make some modifications (Unsuccessful try with 'object' )
pokemon.dtypes
pokemon['Name'] = pokemon['Name'].astype('str')

# %%
pokemon['dummieName'] = pokemon['dummieName'].astype('str')

# %%
## Replacing the string 'nan' since no longer recognized as a NULL value
pokemon['dummieName'] = pokemon['dummieName'].replace('nan','')

# %%
## @Erin, These are the intermediary steps I did in order to get to understand the logic of it. I left it but commented it out.

## Sorting the dataframe by the values of the column 'dummieName'
# pokemon = pokemon.sort_values('dummieName',ascending=False)

## back up of the not_affected rows : this didn't work :( 
# not_affected = pokemon.loc[(pokemon['dummieName']=='')].index
# not_affected_rows

## Split and drop of the not_affected rows from Pokemon DF 
# tbdropped = (pokemon.loc[(pokemon['dummieName']=='')]).index
# pokemon = pokemon.drop(tbdropped, axis=0)

##Quick verification
# pokemon
# not_affected_rows

# %%
## Identifying affected rows:
## I tried several methods but ended creating a list with 1 and 0 that will help me achieve it

pokemon['Has Mega']=''
values = []

value = 0
for n in pokemon['Name']:
    if n[-4:]=='Mega':
        value = 1
        values.append(value) 
#         pokemon.loc[i].['Has Mega']=1 #this did't work 
#         pokemon['Has Mega'][i]= 1 #this did't work : filled 1 in some cells not all the affected ones
#         print(n)
#         print(i)
    else:
        value = 0
        values.append(value)        

    
#print(values)  

##Quick verification:
len(pokemon['Name'])==len(values)
# Out:
# True

# %%
##Adding list to column 'Has Mega':
pokemon['Has Mega'] = values #IT WORKS!
pokemon
# Out:
#        #          Name   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1     Bulbasaur    Grass  Poison    318  45      49       49       65
# 1      2       Ivysaur    Grass  Poison    405  60      62       63       80
# 2      3      Venusaur    Grass  Poison    525  80      82       83      100
# 3      3  VenusaurMega    Grass  Poison    625  80     100      123      122
# 4      4    Charmander     Fire     NaN    309  39      52       43       60
# ..   ...           ...      ...     ...    ...  ..     ...      ...      ...
# 795  719       Diancie     Rock   Fairy    600  50     100      150      100
# 796  719   DiancieMega     Rock   Fairy    700  50     160      110      160
# 797  720    HoopaHoopa  Psychic   Ghost    600  80     110       60      150
# 798  720    HoopaHoopa  Psychic    Dark    680  80     160       60      170
# 799  721     Volcanion     Fire   Water    600  80     110      120      130
#
# ...

# %%
## @ Erin, this is part of the previous try.is commented out on purpose

##intermediate step: taking the splitted but not affected names
# intermediate = pokemon.loc[(pokemon['Has Mega']== 0)]
# dropped = pokemon.loc[(pokemon['Has Mega']== 0)].index
# pokemon = pokemon.drop(dropped, axis=0)
# pokemon
# intermediate['Name']=intermediate['Name'].str.pad(1,side='right')
# intermediate

# %%
##working on the affected rows (added a space to "Mega " thinking of concatenating after)
intermediate = list(pokemon.loc[(pokemon['Has Mega']== 1)].index)

#changing name to 'Mega' to concatenate it later
pokemon.loc[intermediate,'Name']='Mega'

#adding white space on the right (preparing for concatenation)--> This didn't work (no space when concatenating)
# pokemon['Name']= pokemon['Name'].str.pad(1,side='right')

# %%
#concatenation and verification: IT WORKED!!!
pokemon['Name']= pokemon['Name'] + str(' ')+ pokemon['dummieName'].astype(str)

# %%
pokemon.pop('dummieName')
# Out:
# 0
# 1
# 2
# 3      Venusaur
# 4
#          ...
# 795
# 796     Diancie
# 797    Confined
# 798     Unbound
# 799
# Name: dummieName, Length: 800, dtype: object

# %%
pokemon.pop('Has Mega')
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 795    0
# 796    1
# 797    0
# 798    0
# 799    0
# Name: Has Mega, Length: 800, dtype: int64

# %%
# test transformed data
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1        Bulbasaur   Grass  Poison    318  45      49       49       65
# 1  2          Ivysaur   Grass  Poison    405  60      62       63       80
# 2  3         Venusaur   Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4       Charmander    Fire     NaN    309  39      52       43       60
# 5  5       Charmeleon    Fire     NaN    405  58      64       58       80
# 6  6        Charizard    Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7         Squirtle   Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# ...

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
pokemon['A/D Ratio'] = pokemon['Attack']/pokemon['Defense']
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1           Bulbasaur     Grass  Poison    318  45      49       49
# 1      2             Ivysaur     Grass  Poison    405  60      62       63
# 2      3            Venusaur     Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4          Charmander      Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719             Diancie      Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721           Volcanion      Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# ...

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
Name_only_max = pokemon['Name'].loc[(pokemon['A/D Ratio']== pokemon['A/D Ratio'].max())].reset_index() #--> this seems to be giving me the name only
Entire_row_max =pokemon.loc[(pokemon['A/D Ratio']== pokemon['A/D Ratio'].max())].reset_index()

print(Name_only_max)
Entire_row_max
# Out:
#    index                Name
# 0    429  DeoxysAttack Forme
#    index    #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 0    429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0      180       20    150           3       True        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
Name_only_min = pokemon['Name'].loc[(pokemon['A/D Ratio']== pokemon['A/D Ratio'].min())].reset_index()
Entire_row_min = pokemon.loc[(pokemon['A/D Ratio']== pokemon['A/D Ratio'].min())].reset_index()

print(Name_only_min)
Entire_row_min
# Out:
#    index      Name
# 0    230  Shuckle
#    index    #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    230  213  Shuckle     Bug   Rock    505  20      10      230       10
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0      230      5           2      False   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here
pokemon['Combo Type'] = pokemon['Type 1']+ str('-') + pokemon['Type 2']
pokemon['Combo Type'].reset_index()
# Out:
#   File "<ipython-input-28-e496cc8890e6>", line 4
#     pokemon[‘Combo Type’] = np.where((pokemon['Type 1'].isnull()==False & pokemon['Type 2'].isnull()==False), ['Type 1']+['Type 2'])
#                  ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
#To find the top 5 Ratios, I will sort the table by Ratio.
pokemon = pokemon.sort_values('A/D Ratio',ascending = False)
pokemon
# Out:
#        #                Name   Type 1   Type 2  Total   HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic      NaN    600   50     180       20
# 347  318           Carvanha     Water     Dark    305   45      90       20
# 19    15       Mega Beedrill      Bug   Poison    495   65     150       40
# 453  408           Cranidos      Rock      NaN    350   67     125       40
# 348  319           Sharpedo     Water     Dark    460   70     120       40
# ..   ...                 ...      ...      ...    ...  ...     ...      ...
# 616  555  DarmanitanZen Mode     Fire  Psychic    540  105      30      105
# 103   95               Onix      Rock   Ground    385   35      45      160
# 484  436            Bronzor     Steel  Psychic    300   57      24       86
# 139  129           Magikarp     Water      NaN    200   20      10       55
# 230  213            Shuckle       Bug     Rock    505   20      10      230
#
# ...

# %%
# 5th Highest ratio is 3 so:
among_highestADR = pokemon.loc[(pokemon['A/D Ratio']>= 3)].reset_index()
among_highestADR
# Out:
#    index    #                  Name   Type 1  Type 2  Total  HP  Attack  \
# 0    429  386    DeoxysAttack Forme  Psychic     NaN    600  50     180
# 1    347  318             Carvanha     Water    Dark    305  45      90
# 2     19   15         Mega Beedrill      Bug  Poison    495  65     150
# 3    453  408             Cranidos      Rock     NaN    350  67     125
# 4    348  319             Sharpedo     Water    Dark    460  70     120
# 5    428  386    DeoxysNormal Forme  Psychic     NaN    600  50     150
# 6    750  681  AegislashBlade Forme    Steel   Ghost    520  60     150
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  \
# 0       20      180       20    150           3       True      9.000
# 1       20       65       20     65           3      False      4.500
# 2       40       15       80    145           1      False      3.750
# 3       40       30       30     58           4      False      3.125
# ...

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here. The top5 Ratios gives 7 Pokemon, not5 because 3 Pokemons have the same Ratio of 3
pokemon.loc[(pokemon['A/D Ratio']>= 3)].agg('Combo Type').reset_index()
combotype_top5 = list(pokemon.loc[(pokemon['A/D Ratio']>= 3)].agg('Combo Type').unique())
print(combotype_top5)
# Out:
# [nan, 'Water-Dark', 'Bug-Poison', 'Steel-Ghost']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
#My output doesn't look the same at all.... :_(  
pokemon.groupby([pokemon.loc[(pokemon['A/D Ratio']>= 3)].agg('Combo Type')]).mean().reset_index()
# Out:
#     Combo Type      #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0   Bug-Poison   15.0  495.0  65.0   150.0     40.0     15.0     80.0  145.0
# 1  Steel-Ghost  681.0  520.0  60.0   150.0     50.0    150.0     50.0   60.0
# 2   Water-Dark  318.5  382.5  57.5   105.0     30.0     80.0     30.0   80.0
#
#    Generation  Legendary  A/D Ratio
# 0         1.0      False       3.75
# 1         6.0      False       3.00
# 2         3.0      False       3.75
