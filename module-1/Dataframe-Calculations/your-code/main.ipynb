# %% [markdown]
# # Mandatory Challenge
# ## Context
# You work in the data analysis team of a very important company. On Monday, the company shares some good news with you: you just got hired by a major retail company! So, let's get prepared for a huge amount of work!
#
# Then you get to work with your team and define the following tasks to perform:
# 1. You need to start your analysis using data from the past.
# 2. You need to define a process that takes your daily data as an input and integrates it.
#
# You are in charge of the second part, so you are provided with a sample file that you will have to read daily. To complete you task, you need the following aggregates:
# * One aggregate per store that adds up the rest of the values.
# * One aggregate per item that adds up the rest of the values.
#
# You can import the dataset `warehouse_and_retail_sales` from Ironhack's database.
#
# ## Your task
# Therefore, your process will consist of the following steps:
# 1. Read the sample file that a daily process will save in your folder.
# 2. Clean up the data.
# 3. Create the aggregates.
# 4. Write three tables in your local database:
#     - A table for the cleaned data.
#     - A table for the aggregate per supplier.
#     - A table for the aggregate per item.
#
# ## Instructions
# * Read the csv you can find in Ironhack's database.
# * Clean the data and create the aggregates as you consider.
# * Create the tables in your local database.
# * Populate them with your process.

# %%
# your code here
import numpy as np
import pandas as pd
import requests
from io import StringIO
from collections import Counter
import pymysql
from sqlalchemy import create_engine

# %%
orig_url = 'https://drive.google.com/file/d/1ZsHSCYciWkUd8y9mvEV5RZQiO1Qk0WLh/view?usp=sharing'

file_id = orig_url.split('/')[-2]
dwn_url = 'https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
raw_data = pd.read_csv(csv_raw)
raw_data.head()
# Out:
#    YEAR  MONTH                      SUPPLIER ITEM CODE  \
# 0  2017      4               ROYAL WINE CORP    100200
# 1  2017      4      SANTA MARGHERITA USA INC    100749
# 2  2017      4            JIM BEAM BRANDS CO     10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC     10120
# 4  2017      4               ROYAL WINE CORP    101664
#
#                         ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      GAMLA CAB - 750ML      WINE           0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML      WINE           0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML    LIQUOR           0.0
# 3          J W DANT BOURBON 100P - 1.75L    LIQUOR           0.0
# 4            RAMON CORDOVA RIOJA - 750ML      WINE           0.0
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               1.0              0.0
# 1               1.0              0.0
# 2               8.0              0.0
# 3               2.0              0.0
# 4               4.0              0.0

# %%
# Check if there are null values
raw_data.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# SUPPLIER            24
# ITEM CODE            0
# ITEM DESCRIPTION     0
# ITEM TYPE            1
# RETAIL SALES         0
# RETAIL TRANSFERS     0
# WAREHOUSE SALES      0
# dtype: int64

# %%
# Check why they may be null. Should they be removed or replaced?
check = raw_data.loc[raw_data['SUPPLIER'].isnull() == True]
check
'''These seems to be some internal technical records irrelevant to sales. In reall life I would ask owner of this data for
clarification but now I have to assume I'm right. This means I can remove these lines from the table.'''
clean_data = raw_data.loc[raw_data['SUPPLIER'].isnull() == False]
clean_data.head()
# Out:
#    YEAR  MONTH                      SUPPLIER ITEM CODE  \
# 0  2017      4               ROYAL WINE CORP    100200
# 1  2017      4      SANTA MARGHERITA USA INC    100749
# 2  2017      4            JIM BEAM BRANDS CO     10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC     10120
# 4  2017      4               ROYAL WINE CORP    101664
#
#                         ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      GAMLA CAB - 750ML      WINE           0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML      WINE           0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML    LIQUOR           0.0
# 3          J W DANT BOURBON 100P - 1.75L    LIQUOR           0.0
# 4            RAMON CORDOVA RIOJA - 750ML      WINE           0.0
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               1.0              0.0
# 1               1.0              0.0
# 2               8.0              0.0
# 3               2.0              0.0
# 4               4.0              0.0

# %%
# There was also one line where Item Type column had null value. Let's check if it's still there and what we can do about it.
check = clean_data[clean_data['ITEM TYPE'].isnull() == True]
check
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 66439  2017     10  REPUBLIC NATIONAL DISTRIBUTING CO    347939
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 66439  FONTANAFREDDA BAROLO SILVER LABEL 750 ML       NaN           0.0
#
#        RETAIL TRANSFERS  WAREHOUSE SALES
# 66439               0.0              1.0

# %%
'''I know that Barolo is a wine but it's also very easy to find this information in Google.'''
clean_data.loc[clean_data['ITEM TYPE'].isnull(), 'ITEM TYPE'] = 'WINE'
check = clean_data[clean_data['ITEM TYPE'].isnull() == True]
check
# Out:
# C:\Users\gruzd\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Empty DataFrame
# Columns: [YEAR, MONTH, SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE, RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES]
# Index: []

# %%
print(len(clean_data['ITEM CODE'].unique()))
print(len(clean_data['ITEM DESCRIPTION'].unique()))
print(len(clean_data['ITEM CODE'].unique()) - len(clean_data['ITEM DESCRIPTION'].unique()))
'''There are some items with the same code but different description'''
check = clean_data[['ITEM CODE', 'ITEM DESCRIPTION']]
check = check.groupby('ITEM CODE')['ITEM DESCRIPTION'].nunique()
item_code_list = check[check > 1].index.values.tolist()
item_code_list
# Out:
# 23553
# 23621
# -68
# ['10444',
#  '10491',
#  '10636',
#  '11088',
#  '11373',
#  '11562',
#  '11584',
#  '11592',
#  '11838',
#  '12134',
#  '12227',
#  '12375',
#  '12475',
#  '12646',
#  '12769',
#  '12785',
#  '13374',
#  '14737',
#  '181226',
#  '202410',
#  '22318',
#  '22921',
#  '23146',
#  '232492',
#  '232934',
#  '23528',
#  '23772',
#  '23805',
#  '24020',
#  '25555',
#  '25561',
#  '25961',
#  '25962',
#  '26282',
#  '26516',
#  '26841',
#  '27817',
#  '28226',
#  '28290',
#  '28331',
#  '28380',
#  '28462',
#  '28490',
#  '28533',
#  '28616',
#  '28649',
#  '28728',
#  '28741',
#  '28762',
#  '28770',
#  '28797',
#  '28851',
#  '28927',
#  '29017',
#  '29033',
#  '29050',
#  '29068',
#  '29147',
#  '29203',
#  '29394',
#  '29416',
#  '29530',
#  '29622',
#  '297468',
#  '300250',
#  '300644',
#  '300992',
#  '304922',
#  '304986',
#  '307412',
#  '30796',
#  '308170',
#  '30870',
#  '30878',
#  '30881',
#  '309762',
#  '31051',
#  '31056',
#  '31060',
#  '31069',
#  '31095',
#  '31098',
#  '311080',
#  '311120',
#  '31149',
#  '312298',
#  '313115',
#  '313879',
#  '313882',
#  '314006',
#  '317169',
#  '319177',
#  '322695',
#  '322923',
#  '326504',
#  '328745',
#  '332039',
#  '332919',
#  '334112',
#  '334127',
#  '33430',
#  '334353',
#  '33480',
#  '335882',
#  '337902',
#  '339182',
#  '340376',
#  '340837',
#  '341023',
#  '341968',
#  '342079',
#  '342150',
#  '342203',
#  '344326',
#  '345455',
#  '346093',
#  '346333',
#  '346461',
#  '347130',
#  '347277',
#  '349068',
#  '37451',
#  '37478',
#  '38180',
#  '404446',
#  '411876',
#  '41874',
#  '43228',
#  '43581',
#  '43597',
#  '43732',
#  '44359',
#  '45118',
#  '45360',
#  '47146',
#  '47176',
#  '47583',
#  '48102',
#  '48106',
#  '48777',
#  '50178',
#  '50188',
#  '50409',
#  '50752',
#  '54526',
#  '56065',
#  '56340',
#  '57452',
#  '67580',
#  '67598',
#  '67784',
#  '70110',
#  '70161',
#  '70523',
#  '70529',
#  '70595',
#  '70604',
#  '70806',
#  '70916',
#  '71061',
#  '71975',
#  '72069',
#  '72486',
#  '73137',
#  '73311',
#  '74365',
#  '74403',
#  '74749',
#  '75019',
#  '76773',
#  '77390',
#  '77904',
#  '78590',
#  '78757',
#  '79946',
#  '79979',
#  '79993',
#  '80077',
#  '81699',
#  '81777',
#  '82320',
#  '82681',
#  '82722',
#  '83119',
#  '83420',
#  '83786',
#  '84689',
#  '84695',
#  '84933',
#  '84984',
#  '85292',
#  '85560',
#  '91502',
#  '92452',
#  '94048',
#  '94722',
#  '97284',
#  '98558',
#  '99988']

# %%
check_dict = {}
for item in item_code_list:
    lst = clean_data.loc[clean_data['ITEM CODE'] == item]['ITEM DESCRIPTION'].unique().tolist()
    check_dict[item] = lst
'''The reason for having multiple descriptions for one code is various spelling, hense it can be aligned.
I will take first spelling option by default.'''
# Out:
# 'The reason for having multiple descriptions for one code is various spelling, hense it can be aligned.\nI will take first spelling option by default.'

# %%
codes = clean_data['ITEM CODE'].unique().tolist()
len(codes) # Self check that number of unique codes haven't changed since cell 7
code_dic = {}
for code in codes:
    code_dic[code] = clean_data.loc[clean_data['ITEM CODE'] == code]['ITEM DESCRIPTION'].tolist()[0]
code_dic
# Out:
# {'100200': 'GAMLA CAB - 750ML',
#  '100749': 'SANTA MARGHERITA P/GRIG ALTO - 375ML',
#  '10103': 'KNOB CREEK BOURBON 9YR - 100P - 375ML',
#  '10120': 'J W DANT BOURBON 100P - 1.75L',
#  '101664': 'RAMON CORDOVA RIOJA - 750ML',
#  '101680': 'MANISCHEWITZ CREAM WH CONCORD - 1.5L',
#  '101753': 'BARKAN CLASSIC PET SYR - 750ML',
#  '10197': 'KNOB CREEK BOURBON 9YR - 100P - 1.75L',
#  '101974': 'CH ST MICH P/GRIS - 750ML',
#  '102083': 'CH DE LA CHESNAIE MUSCADET - 750ML',
#  '10243': 'OLD GRAND DAD BOURBON 100P - 750ML',
#  '10246': 'HILLROCK DOUBLE CASK RYE - 750ML',
#  '10266': 'LA CHAYA MAL - 750ML',
#  '10268': 'LA CHAYA TORRONTES - 750ML',
#  '10269': 'FEW BOURBON - 750ML',
#  '10270': 'KOPPER KETTLE WHISKEY - 750ML',
#  '10271': 'ALLAGASH SAISON 6/4 NR 12.0Z',
#  '10274': 'KINSEY BOURBON - 750ML',
#  '10275': 'LOT 40 RYE - 750ML',
#  '10306': 'TROEGS SOLID SENDER PALE ALE - 4/6NR',
#  '10332': 'GREY GOOSE VODKA - 375ML',
#  '103608': 'VAJRA LANGHE NEBBIOLO DOC - 750ML',
#  '10370': 'BALTIMORE BEER WORKS DARK USHER - 4/6NR',
#  '10375': 'PALLINI LIMONCELLO 6/CS - 750ML',
#  '104': 'FOUR BOTTLE WINE TOTE',
#  '104060': 'LES CHAILLOUX SANCERRE CHERRIE - 750ML',
#  '10413': 'MURPHY GOODE CHARD - 750ML',
#  '10430': 'STONE IPA 4/6 NR - 12OZ',
#  '104302': 'EREDI LODALI BAROLO 6/CS - 750ML',
#  '10431': 'VICTORY GOLDEN MONKEY 4/6NR - 12OZ',
#  '10434': 'LAGUNITAS IPA 4/6 NR - 12OZ',
#  '10435': 'LAGUNITAS SUMPIN SUMPIN 4/6 NR - 12OZ',
#  '10436': 'OSKAR BLUES DALES PALE ALE 12.OZ 4/6 CAN',
#  '10437': 'CRISPIN CIDER ORIGINAL 4/6 NR - 12OZ',
#  '10438': 'BRECKENRIDGE VANILLA PORTER 4/6 NR - 12OZ',
#  '10439': 'CONCANNON FOUNDERS CAB - 750ML',
#  '10441': 'LOVE P/NOIR - 750ML',
#  '10442': 'OLMECA ALTOS TEQ - PLATA - 750ML',
#  '10443': 'OLMECA ALTOS TEQ - REPOSADO - 750ML',
#  '10444': 'JAMESON IRISH WHISKY CASK MATES - 750ML',
#  '10445': 'BRECKENRIDGE BOURBON - 750ML',
#  '104450': 'SEIFRIED S/BLC - 750ML',
#  '10472': 'MALIBU RUM - PASSION FRUIT - 750ML',
#  '10480': 'CHATEAU LAUBADE ARMAGNAC VSOP - 750ML',
#  '10499': 'CHATEAU LAUBADE ARMAGNAC XO - 750ML',
#  '10529': 'JOSE CUERVO GOLDEN MARGARITA - 1.75L',
#  '105490': 'HAKUTSURU SAKE - 720ML',
#  '1058': 'TROEGS HOPBACK ALE 4/6 NR - 12OZ',
#  '106': 'SIX BOTTLE WINE TOTE (NO LOGO)',
#  '10609': 'FIRESTONE LUPONIC DISTORTION - 4/6 CAN 12.0Z',
#  '10610': 'LAGUNITAS LIL SUMPIN - 2/12 NR 12.0Z',
#  '10634': 'SMIRNOFF VODKA - CHERRY - 1L',
#  '10636': 'HAKUSHU WHISKY 12 YR - 750ML',
#  '10637': 'CUPCAKE PROSECCO - 187 3PK',
#  '10645': 'OSKAR BLUES DEVIANT DALES - 4/6  CAN 12.OZ',
#  '10666': 'SAUZA HORNITOS REPOSATO - 375ML',
#  '10667': 'EFFEN VODKA - BLACK CHERRY - 375ML',
#  '10668': 'MAKERS MARK BOURBON - 375ML',
#  '10673': 'CINNABON CINNAMON CREAM LIQ - 750ML',
#  '106739': 'VEUVE CLICQUOT DEMI SEC - 375ML',
#  '10675': 'BRINLEY GOLD SHIPWRECK SPICED RUM - 750ML',
#  '10676': 'BRINLEY GOLD SHIPWRECK COCONUT RUM - 750ML',
#  '10677': 'BRINLEY GOLD SHIPWRECK VANILLA RUM - 750ML',
#  '10678': 'BRINLEY GOLD SHIPWRECK COCONUT RUM CREAM- 750ML',
#  '10693': 'TAYLOR LAKE COUNTRY RED - 3L',
#  '10696': 'FIRESTONE VARIETY - 2/12 12.OZ CAN',
#  '10697': 'UNION STEADY EDDIE - 4/6 12.OZ CAN',
#  '10711': 'ATLAS BREW WORKS PONZI - 4/6 12.OZ CAN',
#  '10714': 'SAM ADAMS PACK OF REBELS 2/12 CAN - 12OZ',
#  '10715': 'PORT CITY METRO RED - 12.OZ 4/6NR',
#  '10740': 'BERINGER FOUNDERS EST P/GRIG - 750ML',
#  '10758': 'CH ST JEAN CAL MER - 750ML',
#  '10772': 'DUCLAW BLOOD ORANGE GYPSY - 12.OZ 4/6NR',
#  '10790': 'VAMPIRE CAB - 750ML',
#  '342198': 'NICOLAS ROSE',
#  '10804': 'CH ST JEAN CAL CAB - 750ML',
#  '10820': 'JACOBS CREEK RIES - 750ML',
#  '108367': 'DOM CAVES DE PRIEURE SANCERRE - 750ML',
#  '108391': 'QUPE C/C SYR - 750ML',
#  '10847': 'MARKHAM CAB - 750ML',
#  '10850': 'OUR DAILY ZIN - 750ML',
#  '10855': 'AVION TEQ - SILVER - 1.75L',
#  '10856': 'MALIBU RUM- PINEAPPLE UPSIDE DOWN CAKE - 750ML',
#  '10859': 'TOM GORE CHARD - 750ML',
#  '10860': 'TOM GORE CAB - 750ML',
#  '10861': 'RAVAGE CAB - 750ML',
#  '10862': 'SERPENTS BITE WHISKEY - 750ML',
#  '108634': 'INDABA WESTERN CAPE CH/BLC - 750ML',
#  '10864': 'FORBIDDEN SECRET WH CHOCOLATE - 750ML',
#  '10866': 'GIN MARE - 750ML',
#  '10869': '99 SCHNAPPS - PINEAPPLE - 750ML',
#  '108790': 'CARTLIDGE & BROWN CAB - 750ML',
#  '10898': 'PICCINI CHIANTI - 1.5L',
#  '10907': 'SAGAMORE RYE - 750ML',
#  '10910': 'PRAGA PREMIUM PILS - 11.2OZ',
#  '10930': 'LAPHROAIG LORE SCOTCH - 750ML',
#  '10959': 'OLD LINE SINGLE MALT WHISKEY - 750ML',
#  '10979': 'J LOHR RIVERSTONE CHARD - 1.5L',
#  '10994': 'ABITA BIG EASY IPA - 12.OZ 4/6',
#  '110000': "SEAGRAM'S GIN - EXTRA DRY - 100ML",
#  '11002': 'ANCIENT AGE BOURBON - 1.75L',
#  '110132': 'R MONDAVI PRIVATE SEL CAB - 375ML',
#  '11019': 'CHLOE PROSECCO - 750ML',
#  '11029': 'EZRA BROOKS BOURBON - 1.75L',
#  '11037': 'EZRA BROOKS BOURBON - 750ML',
#  '11084': 'SHINSHU MARS IWAI JAPANESE WHISKY - 750ML',
#  '11085': 'SHINSHU MARS IWAI TRAD JAPANESE WHISKY - 750ML',
#  '11088': 'E WILLIAMS BLACK SOUR MASH 7YR - 750ML',
#  '11118': 'BULLEIT BOURBON - 750ML',
#  '11142': 'K JACKSON GRAND RES MER - 750ML',
#  '111708': 'DR PAULY BERG NOBLE HOUSE RIES - 750ML',
#  '112': 'CORKSCREW',
#  '11207': "MAKER'S MARK 90P - 1L",
#  '11215': 'BLACK BOX SHIRAZ 6/CS - 3L',
#  '11221': 'SVEDKA VODKA - 100P - 375ML',
#  '11229': 'OMMEGANG GREAT BEYOND - 12.OZ 6/4NR',
#  '11231': 'WILD TURKEY 101P - 1.75L',
#  '11266': 'MALIBU RUM - 1L',
#  '11274': 'BLACKSTONE CALIF MER - 1.5L',
#  '112771': 'RASHI LIGHT WHITE CONCORD - 750ML',
#  '11306': 'HILLBILLY 86 PROOF BOURBON WHISKEY - 750ML',
#  '11320': 'WENTE CHARLES WETMORE RES CAB - 750ML',
#  '11322': '4 HANDS DAKINE 4/6 CANS - 16OZ',
#  '11325': 'PEAK EVERGREEN/CRUSH VARIETY 4/6 - 12OZ',
#  '113441': 'SPY VALLEY MARLBOROUGH S/BLC - 750ML',
#  '11350': 'CRUZAN AGED RUM 151 PROOF - 1L',
#  '11371': 'MERIDIAN CAL MER - 750ML',
#  '11374': 'ETRUSCO AMARO - 750ML',
#  '11375': 'LA FOGATA TEQUILA - PLATINUM - 750ML',
#  '11376': "BOBBY'S GIN - 750ML",
#  '11380': 'FLOR DE CANA RUM - CENTENARIO - 750ML',
#  '11382': 'SKYY INFUSIONS HONEYCRISP APPLE - 750ML',
#  '11383': 'SKYY INFUSIONS TROPICAL MANGO - 750ML',
#  '11391': 'JUNIPERO GIN - 750ML',
#  '11392': 'THE GLENROTHES SHERRY CASK RES - 750ML',
#  '11398': 'MULDERBOSCH CHENIN BLANC - 750ML',
#  '114': 'WINE PAPER GIFT TOTE SINGLE BOTTLE',
#  '11418': 'WEST CORK IRISH WHISKEY 10 YEAR - 750ML',
#  '11436': 'SVEDKA VODKA - CITRON - 750ML',
#  '11446': 'NOBILO REGIONAL COLLECTION CHARD - 750ML',
#  '11447': 'DEEP EDDY PEACH VODKA - 1.75L',
#  '11449': 'DEEP EDDY RUBY RED GRAPEFRUIT VODKA - 50ML',
#  '11453': 'JACKSON MORGAN SALTED CARAMEL - 750ML',
#  '11462': 'JIM BEAM DOUBLE OAK BOURBON - 750ML',
#  '11463': 'EFFEN VODKA - BLOOD ORANGE - 750ML',
#  '11464': 'EFFEN VODKA - GREEN APPLE - 750ML',
#  '11487': 'SVEDKA VODKA - CLEMENTINE - 750ML',
#  '114936': 'VILLA JOLANDA PROSECCO - 750ML',
#  '115185': 'INDABA WESTERN CAPE MER - 750ML',
#  '11525': 'WILD TURKEY 81 - 1.75L',
#  '115290': 'INDABA S/BLC WESTERN CAPE - 750ML',
#  '11535': 'STONE GO TO IPA 4/6 16.OZ CAN',
#  '11536': 'STONE ARROGANT BASTARD 4/6 16.OZ CAN',
#  '11563': 'ARISTOCRAT 151 RUM GOLD - 1L',
#  '11584': 'E WILLIAMS GREEN BOURBON - 1.75L',
#  '11592': 'E WILLIAMS GREEN BOURBON - 750ML',
#  '11622': 'VAMPIRE MERLOT - 750ML',
#  '11649': 'BV COASTAL MERLOT - 375ML',
#  '11703': 'KENTUCKY GENTLEMAN - 1.75L',
#  '11711': 'EARLY TIMES KENTUCKY WHISKEY - 1.75L',
#  '11720': 'JIM BEAM BLACK - 1.75L',
#  '11738': 'JIM BEAM BLACK - 750ML',
#  '11746': "MAKER'S MARK 90P - 750ML",
#  '11762': 'JIM BEAM WHITE - 1.75L',
#  '11770': 'JIM BEAM WHITE - 750ML',
#  '11797': 'JIM BEAM WHITE - 200ML',
#  '11819': 'AMARULA FRUIT CREAM LIQUEUR - 750ML',
#  '118192': 'PLANETA LA SEGRETA ROSSO - 750ML',
#  '11835': 'JIM BEAM WHITE - 50ML',
#  '11837': 'CANE RUM WHITE RUM - 750ML',
#  '11838': 'RICH & RARE CANADIAN WHISKY - 1.75L',
#  '11841': 'PAUL MASSON BRANDY - APPLE - 750ML',
#  '11842': 'PAUL MASSON BRANDY - PINEAPPLE - 750ML',
#  '11843': 'KENTUCKY GENTLEMAN - 750ML',
#  '11844': 'SVEDKA VODKA STRAWBERRY LEMONADE - 1.75L',
#  '11851': 'HEAVEN HILL BOURBON 4YR - 1.75L',
#  '118516': 'COL DES VENTS CORBIERES ROUGE - 750ML',
#  '11860': 'ELIJAH CRAIG BOURBON  - 750ML',
#  '118680': 'WHITEHALL LANE NAPA VLY MER - 750ML',
#  '11876': 'PEAK HAPPY HOUR PILS - 4/6 CAN 12.OZ',
#  '11886': 'JIM BEAM WHITE - 375ML',
#  '11894': 'HEAVEN HILL BOURBON 4YR - 1L',
#  '11912': 'CAPTAIN LAWRENCE GF EFFORT - 2/12 CAN 12.OZ',
#  '11914': 'CAPTAIN LAWRENCE 6TH BORO PILS - 2/12 CAN 12.OZ',
#  '11927': 'ROCK TOWN ARKANSAS SM BATCH - 750ML',
#  '11940': 'WRAY & NEPHEW OVERPROOF - 750ML',
#  '119776': 'GIRARD CHARD RUSSIAN RIVER - 750ML',
#  '12017': 'OLD FORESTER BOURBON - 750ML',
#  '12045': 'WHISTLEPIG BOSS HOG THE INDEPENDANT - 750ML',
#  '12046': 'WHISTLEPIG BOSS HOG SPIRIT OF MORTIMER - 750ML',
#  '12068': 'OLD GRAND DAD BOURBON - 750ML',
#  '120960': 'YARDEN GALILEE MOSCATO 12/CS - 500ML',
#  '121134': 'CHARLES DE FERE RES BDB - 750ML',
#  '12134': 'DAVID NICHOLSON 1843 RESERVE BOURBON -750ML',
#  '12136': 'EZRA BROOKS RYE - 750ML',
#  '12138': 'AVA GRACE CHARD - 750ML',
#  '12139': 'AVA GRACE RED BLEND - 750ML',
#  '12141': 'CHAMPS DE PROVENCE ROSE - 750ML',
#  '12142': 'SUTTER HOME PINK MOSCATO - 187ML',
#  '12143': 'SUTTER HOME SANGRIA - 1.5L',
#  '12203': 'OLD CROW BOURBON - 1.75L',
#  '12204': 'OLD LINE AGED CARIBBEAN RUM - 750ML',
#  '12205': 'OLD LINE AGED CARIBBEAN RUM NAVY - 750ML',
#  '12212': 'PORT CITY COLOSSAL 6 - 12.OZ 6/4 NR',
#  '12220': 'OLD CROW BOURBON - 1L',
#  '12222': 'JEFFERSON CASK STRENGTH - 750ML',
#  '12223': 'JEFFERSON PRITCHARD CAB FINISH - 750ML',
#  '12224': 'KNAPPOGUE 16YR OLD - 750ML',
#  '12225': 'ONE EIGHT ROCK CREEK RYE - 750ML',
#  '12247': 'CAPTAIN LAWRENCE HOP COMMANDER - 12.OZ 4/6 NR',
#  '12285': 'WOLFBURN AURORA SINGLE MALT - 750ML',
#  '12327': 'CH ST MICH CANOE RIDGE MER 6/C - 750ML',
#  '12351': 'CH ST MICH COLD CREEK CAB 6/CS - 750ML',
#  '123765': 'SANCERRE COTES DE REIGNY ROSE - 750ML',
#  '12378': 'REBEL YELL - 1.75L',
#  '12394': 'REBEL YELL - 750ML',
#  '124028': 'MARQUIS DE LA TOUR BRUT NV - 750ML',
#  '12413': 'MCCLINTOCK FORAGER GIN - 750ML',
#  '12419': "WILD TURKEY MASTER'S KEEP DECADES - 750ML",
#  '12420': 'GLEN GRANT 18YR - 750ML',
#  '12424': 'TEN HIGH BOURBON - 1.75L',
#  '124672': 'SIMI MER - 750ML',
#  '124796': 'PRODUTTORI DEL BARBARESCO TOR - 750ML',
#  '12487': 'CAPTAIN LAWRENCE SEEKING ALPHA - 6/4 12.OZ',
#  '12526': 'SVEDKA VODKA CUCUMBER LIME - 1.75L',
#  '125261': 'MARQUES DE CACERAS RIOJA ROSE - 750ML',
#  '12530': 'WILD TURKEY 101 - 1L',
#  '12548': 'WILD TURKEY 101 - 750ML',
#  '12556': 'WILD TURKEY 81 - 750ML',
#  '12569': 'GIFFARD BANANE DU BRESIL - 750ML',
#  '12572': 'WILD TURKEY 101 - 375ML',
#  '12629': 'VIRGINIA GENTLEMAN - 1.75L',
#  '126578': 'CHRISTIAN BROTHERS BRANDY - 375ML',
#  '126691': 'CH DE SANCERRE VV - 750ML',
#  '126764': 'MANISCHEWITZ BLACKBERRY - 3L',
#  '126985': 'H BEAULIEU PICPOUL DE PINET BL - 1.5L',
#  '12769': 'E WILLIAMS BLACK SOUR MASH 7YR - 1.75L',
#  '12785': 'E WILLIAMS BLACK SOUR MASH 7YR - 1L',
#  '127922': 'FAMEGA VINHO VERDE - 750ML',
#  '128937': 'CHAPOUTIER BELLERUCHE BLC - 750ML',
#  '12904': 'DON EDUARDO TEQUILA - ANEJO - 750ML',
#  '129186': 'CAST BANFI BRUN MONTAL - 750ML',
#  '12920': 'GLENLIVET 18YR - 750ML',
#  '12947': 'WILD TURKEY RARE BREED - 750ML',
#  '12963': 'OLD GRAND DAD BOURBON - 1L',
#  '12971': 'TEN HIGH BOURBON - 1L',
#  '12998': 'JIM BEAM WHITE - 1L',
#  '13099': 'HEINEKEN LIGHT 4/6 NR - 12OZ',
#  '131172': 'SUTTER HOME P/GRIG 24/CS - 187ML',
#  '13145': 'STAGS LEAP S/BLC - 750ML',
#  '13153': 'SAINT M RIESLING - 750ML',
#  '13188': 'YELLOW TAIL SHZ/CAB - 750ML',
#  '13390': 'AMARETTO DI SARONNO - 1L',
#  '134015': 'CARTLIDGE & BROWN P/NOIR - 750ML',
#  '13420': 'STOLICHNAYA VODKA - VANILLA - 1L',
#  '13455': 'LAS ROCAS GARNACHA - 750ML',
#  '13501': 'SAUZA HORNITOS - 750ML',
#  '13552': 'DOM MICHEL THOMAS SANCERRE - 750ML',
#  '13560': 'GRGICH HILLS CHARD - 750ML',
#  '13587': 'BACARDI RUM - LIMON - 50ML',
#  '136409': "CH D'ARCINS HAUT MEDOC - 750ML",
#  '13650': 'DUCKHORN VYDS NAPA CAB - 750ML',
#  '136891': 'BADIOLI CHIANTI - 750ML',
#  '13692': 'FIGHTING COCK 103P - 750ML',
#  '137448': 'CAMPO VIEJO GRD RES - 750ML',
#  '13749': 'HOGUE J/RIES - 750ML',
#  '137510': 'LA PORTE DU CALLOU SAN BLC - 750ML',
#  '137537': 'ALSACE WILLIAM P/BLC - 750ML',
#  '138371': 'TRAPICHE OAK CASK CAB - 750ML',
#  '13862': 'ANTINORI TIGNANELLO 6/CS - 750ML',
#  '139025': 'TROIS FRERES MUSCADET - 750ML',
#  '13919': 'HENKELL TROCKEN - 750ML',
#  '13960': 'CASAL GARCIA VINHO VERDE BRANCO - 750ML',
#  '139890': 'SANTA JULIA OAK RES MAL - 750ML',
#  '14001': 'ESTANCIA P/NOIR - 750ML',
#  '14028': 'ELIJAH CRAIG BOURBON  - 1.75L',
#  '14036': 'BARKAN CLASSIC CHARD - 750ML',
#  '14044': 'BARKAN CLASSIC CAB - 750ML',
#  '14052': 'BARON HERZOG CAL MERLOT - 750ML',
#  '140570': 'CHAPOUTIER CDR BELLLRUCHE RGE - 750ML',
#  '1406': 'DOGFISH HEAD 120 MIN IPA 6/4 NR - 12OZ',
#  '140813': 'BARKAN CLAS S/BLC - 750ML',
#  '14087': 'GREY GOOSE VODKA - LE CITRON - 750ML',
#  '141135': 'VINA SAN ESTEBAN S/BLC - 750ML',
#  '14117': 'CHOPIN VODKA - 750ML',
#  '14133': 'CHOPIN VODKA - 1.75L',
#  '14176': 'BOLS SCHNAPPS - SOUR APPLE - 1L',
#  '14184': 'SAILOR JERRY RUM - SPICED - 750ML',
#  '14249': 'SMOKING LOON P/NOIR - 750ML',
#  '14265': "RASHI MOSCATO D'ASTI DOC - 750ML",
#  '14311': 'JOHNNIE WALKER BLUE - 750ML',
#  '143294': 'CH DES LEOTINS BORD - 750ML',
#  '14443': 'PEARL VODKA - 750ML',
#  '14516': "BANFI BELL'AGIO CHIANTI FLASK - 750ML",
#  '14575': 'LOUIS BERNARD CDR VIL - 750ML',
#  '14621': 'LOS VASCOS CAB RES - 750ML',
#  '14648': 'GRAND VENEUR CDR CHAMPAUVINS - 750ML',
#  '147222': 'BOGLE PET/SYR - 750ML',
#  '14737': 'CLINE CAL ZIN - 750ML',
#  '36358': 'SKYY VODKA - 1L',
#  '14753': 'CAHORS GOULEYANT GEO VIGOUROUX - 750ML',
#  '14818': 'SCHUG CARNEROS P/NOIR - 750ML',
#  '14834': 'CARMEL SACRAMENTAL KING DAVID - 750ML',
#  '148482': 'ERBES URZIGER WURZGARTEN KAB - 750ML',
#  '148610': 'CH PICAU PERNA ST EMIL - 750ML',
#  '14885': 'BV COASTAL CAB 12/CS - 375ML',
#  '14940': 'SCHUG CARNEROS CHARD - 750ML',
#  '14990': 'SCHUG SONOMA CHARD - 750ML',
#  '15008': 'MONTEZUMA TEQUILA - GOLD - 1L',
#  '15091': 'BV NAPA VLY MERLOT - 750ML',
#  '15105': 'TALISKER 10YR - 750ML',
#  '15130': 'GLENKINCHIE 12YR SCOTCH - 750ML',
#  '15156': 'DALWHINNIE 15YR SCOTCH - 750ML',
#  '15164': 'CRAGGANAMORE SCOTCH 12YR - 750ML',
#  '151769': 'KING EST P/GRIS - 375ML',
#  '152315': 'JOSE CUERVO GOLD TEQUILA - 200ML',
#  '15261': "BAKER'S BOURBON 107 PROOF - 750ML",
#  '15270': 'BASIL HAYDEN BOURBON 6/C - 750ML',
#  '15288': 'KNOB CREEK BOURBON 9YR - 100P - 750ML',
#  '153036': 'CARMEL CONCORD KING DAVID - 750ML',
#  '153125': 'BULLY HILL SWEET WALTER RED - 750ML',
#  '15318': 'CROWN ROYAL - 375ML',
#  '153346': 'YARDEN GALILEE MT HERMAN WH - 750ML',
#  '15342': 'BELVEDERE VODKA 12/C - 375ML',
#  '15385': 'CARAVELLA LIMONCELLO - 750ML',
#  '15407': 'BANFI ROSA REGALE BRACHETTO - 750ML',
#  '154466': 'SMIRNOFF VODKA - RASPBERRY TW - 375ML',
#  '1546': 'CUSQUENA BEER-PERU 4/6 NR - 12OZ',
#  '155837': 'FLOR DE CANA - GOLD - 750ML',
#  '156043': 'ALLEGRINI VALPOLICELLA CLASS - 750ML',
#  '15610': 'MARIETTA OV RED - 750ML',
#  '1562': 'TROEGS TROEGENATOR DOUBLE 4/6 NR - 12OZ',
#  '156426': 'REVERDY SANCERRE BLC - 750ML',
#  '156744': 'CH TOUR PUYBLANQUET ST EMIL - 750ML',
#  '15695': 'DOG POINT VYDS S/BLC - 750ML',
#  '15709': 'DOM CARNEROS BRUT CHAMP - 750ML',
#  '157805': 'LAZARIDIS AMETHYSTOS WH - 750ML',
#  '15881': 'COL DI SASSO SANG CAB - 750ML',
#  '15920': 'EDNA VALLEY CHARD - 750ML',
#  '15970': 'BRUGAL RUM - ANEJO - 750ML',
#  '159824': 'DANTE SP SEL CAB - 750ML',
#  '15989': 'CARLO ROSSI SANGRIA - 4L',
#  '160237': 'DOM THOMAS & FILS SAN CRELE - 750ML',
#  '160318': 'KEN FORRESTER PET P/TAGE - 750ML',
#  '16063': "MCCLELLAND'S SPEYSIDE - 750ML",
#  '161519': 'CH DAMANSE BORD SUP - 750ML',
#  '16209': 'WYNDHAM ESTATES BIN 555 SHZ - 750ML',
#  '16225': 'WILLEMETTE VLY W/CLSTER P/NOIR - 750ML',
#  '162639': 'HAKUSHIKA JUNMAI GINJO 12/CS - 300ML',
#  '162680': 'JOEL GOTT S/BLC - 750ML',
#  '1627': 'HEAVY SEAS POWDER MONKEY P/A 4/6 NR - 12OZ',
#  '163090': 'DUCK POND P/GRIS - 750ML',
#  '16314': 'DOMINO DE UGARTE RES RIOJA - 750ML',
#  '16330': 'PENFOLDS MAGIL EST SHZ - 750ML',
#  '163589': 'KSARA RES DU COUVENT RED - 750ML',
#  '16365': 'SAUZA TEQ - SILVER - 1L',
#  '16373': 'GOATS DO ROAM RED - 750ML',
#  '163775': 'NOZZOLE LE BRUNICHE CHARD - 750ML',
#  '16390': 'JOSE CUERVO GOLD TEQUILA - 50ML',
#  '16420': 'JAMESON IRISH WHISKEY - 375ML',
#  '164330': 'EL COTO RIOJA CRIANZA - 750ML',
#  '16519': 'SAUZA TRES GEN ANEJO - 750ML',
#  '165492': 'WRAY & NEPHEW RUM WHITE 126P - 375ML',
#  '16560': 'MARTIN CENDOYA RED RES - 750ML',
#  '166499': 'TERRA DE LOBOS RED - 750ML',
#  '166600': 'DROUHIN LAFORET BOURG P/NOIR - 750ML',
#  '16691': 'COPPOLA PRESENTS SHZ - 750ML',
#  '16705': 'HPNOTIQ LIQUEUR - 750ML',
#  '16721': 'SARTORI P/GRIG - 750ML',
#  '16756': 'FERRARI CARANO CHARD TRE TERRE - 750ML',
#  '16810': 'GEORGE DICKEL #8 SOUR MASH - 1.75L',
#  '16888': 'AGUARDIENTE CRISTAL - 750ML',
#  '169161': 'ARIEL CHARD NON ALCOHOLIC - 750ML',
#  '169722': 'CH FERRANDE GRAVES RED - 750ML',
#  '169765': 'CARTLIDGE & BROWN CHARD - 750ML',
#  '16985': "BUSHMILL'S MALT 16YR - 750ML",
#  '17000': 'K JACKSON GRAND RES CAB - 750ML',
#  '17027': 'PERRIN CDP VV - 750ML',
#  '17051': 'EROCIA RIESLING 6/CS - 750ML',
#  '17159': 'KINDZMARAULI RED TELAVI - 750ML',
#  '17353': 'BUFFALO TRACE BOURBON - 750ML',
#  '17361': 'BUFFALO TRACE - 1L',
#  '17515': 'SAINT HILAIRE SPARK BRUT - 750ML',
#  '175501': 'BOGLE CHARD - 750ML',
#  '17574': 'VEUVE CLICQUOT LA GRANDE DAME - 750ML',
#  '17582': 'BOMBAY GIN - SAPPHIRE - 1.75L',
#  '17590': 'BOMBAY GIN - SAPPHIRE - 1L',
#  '177334': 'DR PAULY BERG BERN BAD RIES KAB - 750ML',
#  '177741': 'PATIENT COTTAT S/BLC - 750ML',
#  '17817': 'SANDEMAN CHARACTER 6/CS - 750ML',
#  '17825': 'DON JULIO TEQUILA - "1942" - 750ML',
#  '17868': 'LINGANORE WH RAVEN - 750ML',
#  '17876': "BOODLE'S GIN - 1.75L",
#  '17892': "BOOKER NOE'S BOURBON - 750ML",
#  '17906': 'MONTEBELLO LONG ISLAND ICE TEA - 1.75L',
#  '17914': 'TIC TACK LIQUEUR - 750ML',
#  '17930': 'SKYY VODKA - 50ML',
#  '179426': 'CANYON ROAD CAB - 750ML',
#  '17957': 'ROMANA SAMBUCA - 375ML',
#  '17965': 'OLD FORESTER BOURBON - 1.75L',
#  '18007': 'OLD OVERHOLT RYE - 750ML',
#  '18015': 'JIM BEAM RYE WHISKEY - 750ML',
#  '18023': "BOODLE'S GIN - 1L",
#  '18031': 'J LOHR ESTATES CAB - 1.5L',
#  '18090': 'JAGERMEISTER LIQUEUR - 375ML',
#  '18104': 'BARENJAGER LIQUEUR - 750ML',
#  '18112': 'TOKAJI ASZU 5 PUTTONOS - 500ML',
#  '18139': 'LINGANORE SKIPJACK - 750ML',
#  '181552': 'SANCERRE WHITE SAUT - 375ML',
#  '181560': 'AVALON CAB - 750ML',
#  '181919': 'SANDEMAN FINE RICH MADEIRA - 750ML',
#  '182630': 'FREIXENET BDB - 750ML',
#  '182850': 'CARTLIDGE & BROWN MER - 750ML',
#  '183130': 'GRAHAM BECK CHARD - 750ML',
#  '18406': 'LAN RIOJA CRIANZA - 750ML',
#  '18449': 'LINGANORE MEDIEVAL MEADE - 750ML',
#  '18457': 'CLINE ACIENT VINES MOURVEDRE - 750ML',
#  '185264': 'LINGANORE MEDIEVAL MEAD',
#  '18546': 'PLOMARI OUZO - 750ML',
#  '185515': 'CIELO PINOT GRIG DEL VENETO - 750ML',
#  '18562': "L'ECOLE NO 41 COL VLY CAB - 750ML",
#  '18570': 'FRESCOBALDI REMOLE RED (SC) - 750ML',
#  '186031': 'CASTLE ROCK C/C CHARD - 750ML',
#  '18619': "BUSHMILL'S MALT 10YR - 750ML",
#  '186384': 'ZENATO P/GRIG - 750ML',
#  '18660': 'JOSE CUERVO LA RESERVA 3/CS - 750ML',
#  '186902': 'FRACCHIA VOULET CASARZO - 750ML',
#  '18694': 'DEANSTON SCOTCH - 750ML',
#  '18716': 'HAKATSURU SAKE - 1.8L',
#  '18783': 'KRIS P/GRIG - 750ML',
#  '1880': 'MIKES LEMONADE 4/6 NR - 11.2OZ',
#  '18821': 'BUCHANAN DELUXE 12YR - 750ML',
#  '18830': 'K JACKSON GRAND RES CHARD - 750ML',
#  '18856': 'FRESCOBALDI CASTIGLIANO CHN - 750ML',
#  '188700': 'CASTLE ROCK CAB - 750ML',
#  '18880': 'SANTA RITA SAUV BLC 120 - 750ML',
#  '189006': 'CH LAROCHE ST JEAN RED - 750ML',
#  '18910': 'SANTA RITA CAB 120 - 750ML',
#  '18937': 'SANTA RITA RESERVE CAB - 750ML',
#  '189545': 'SILVERADO CAB - 750ML',
#  '189715': 'BARON HERZOG CAL CHAMP - 750ML',
#  '19003': 'BLACKSTONE CALIF MER - 750ML',
#  '19011': 'BLACKSTONE MONTEREY CHARD - 750ML',
#  '19020': 'BLACKSTONE CALIF CAB - 750ML',
#  '19054': 'FRESCOBALDI NIP CHN RUFFINA - 750ML',
#  '19100': 'PAMPERO RUM - ANIVESARIO - 750ML',
#  '19119': 'SMOOKING LOON MER - 750ML',
#  '19135': 'COVEY RUN RIES - 750ML',
#  '191833': 'TOAD HOLLOW EYE/TOAD DRY ROSE - 750ML',
#  '36374': 'PLATINUM VODKA - 750ML',
#  '19194': 'RAVENSWOOD VINTNERS MER - 750ML',
#  '19224': 'RAVENSWOOD VINTNERS ZIN - 750ML',
#  '192767': 'TALBOTT KALI HART VYD CHARD - 750ML',
#  '19291': 'GENTLEMAN JACK - 750ML',
#  '192953': 'JUAN GIL WRONGO DONGO - 750ML',
#  '19321': 'SHAFER MERLOT - 750ML',
#  '193232': 'ORLEANS HILL OUR DAILY RED - 750ML',
#  '19356': 'RAVENSWOOD LODI ZIN - 750ML',
#  '19364': 'RAVENSWOOD VINTNERS CHARD - 750ML',
#  '19453': 'CALVERT EXTRA - 1.75L',
#  '19488': 'GEORGE DICKEL #12 - 1.75L',
#  '19496': 'BACARDI RUM - "8" - 750ML',
#  '195103': 'DOMINIO DE EGUREN PROTOCOLO RED - 750ML',
#  '195138': 'CH HAUT SURGET LALANDE POMEROL RED - 750ML',
#  '19518': 'CRUZAN RUM - PINEAPPLE - 750ML',
#  '19550': 'CRUZAN RUM - COCONUT - 750ML',
#  '19569': 'CRUZAN BANANA - 750ML',
#  '195839': 'STELLA P/GRIG - 750ML',
#  '19585': 'JIM BEAM BLACK - 1L',
#  '19615': 'BACARDI RUM RUNNER - 1.75L',
#  '19623': 'CARDHU 12Y SINGLE MALT - 750ML',
#  '19674': 'BLANDYS 5YR OLD MALMSEY- 750ML',
#  '19682': 'RON VIEJO RUM - DE CALDAS - 750ML',
#  '19690': 'CHIMNEY ROCK CAB - 750ML',
#  '1970': 'HEINEKEN DRAFT KEG CAN - 5L',
#  '19755': 'BACARDI RUM - BIG APPLE - 1L',
#  '19860': 'TURNING LEAF MER - 1.5L',
#  '19917': 'BV CARNEROS P/NOIR - 750ML',
#  '19933': '99 SCHNAPPS - BANANA - 750ML',
#  '19941': 'U MES U FAN TRES CAB ROSE - 750ML',
#  '199672': 'DI MAJO NORANTE SAN GORGI SANG - 750ML',
#  '19992': 'CHARTREUSE GREEN 110P - 750ML',
#  '200000': 'GOUGUENHEIM MAL - 750ML',
#  '20010': 'WAGNER OCKFENER BOCH RIES KAB - 750ML',
#  '20087': 'BULLY HILL LOVE MY GOAT RED - 750ML',
#  '20109': 'JAMESON IRISH WHISKEY - 1.75L',
#  '201308': 'MT TABOR MER - 750ML',
#  '201820': 'CH JOYLS JURANCON SEL - 750ML',
#  '20192': '99 SCHNAPPS - APPLE - 750ML',
#  '202088': 'SHO CHIKU BAI SAKE - 180ML',
#  '20214': 'SILVER OAK A/V CAB - 750ML',
#  '20265': "BEAM'S 8 STAR BLEND - 1.75L",
#  '20281': "BEAM'S 8 STAR BLEND - 1L",
#  '20311': 'DON Q RUM - CRISTAL - 1L',
#  '20389': 'INGLENOOK COPOLLA RUBICON 6/CS - 750ML',
#  '20419': 'SANDEMAN 20YR TAWNY PORT 6/CS - 750ML',
#  '20435': 'BROQUEL CAB - 750ML',
#  '20443': 'IMPERIAL WHISKEY - 1.75L',
#  '2046': 'GULDEN DRAAK DARK NR - 6/25.4OZ',
#  '20460': "SEAGRAM'S 7 CROWN - 1.75L",
#  '20613': "SEAGRAM'S 7 CROWN - 750ML",
#  '20621': 'FUKI PLUM WINE - 750ML',
#  '20630': "SEAGRAM'S 7 CROWN - 200ML",
#  '20656': "SEAGRAM'S 7 CROWN - 1L",
#  '20745': 'WOODBRIDGE P/GRIG - 1.5L',
#  '20826': 'WOODBRIDGE P/GRIG - 750ML',
#  '20877': 'INDABA WESTERN CAPE CHARD - 750ML',
#  '20990': 'BROQUEL MALBEC - 750ML',
#  '21032': 'RHUM BARBANCOURT - 3* 4YR - 750ML',
#  '21148': 'HOGUE CAB - 750ML',
#  '21164': 'BOGLE CAB - 750ML',
#  '21180': 'SANCERRE WHITE SAUTEREAU - 750ML',
#  '21199': 'CAVIT P/GRIG - 375ML',
#  '21202': 'TRAPICHE OAK CASK MALBEC - 750ML',
#  '21210': 'CANDONI PROSECCO BRUT 6/C - 750ML',
#  '21237': 'SANTA MARGHERITA CAB - 750ML',
#  '21326': 'FISH EYE CHARD - 750ML',
#  '21377': 'CANDONI P/GRIG - 750ML',
#  '21423': 'FISH EYE CAB - 750ML',
#  '21466': 'COTE DE REIGNY SAN ROSE - 750ML',
#  '21474': 'CH DES TOURS BROUILLY - 750ML',
#  '21482': 'DOM MARCEL LNG POUILLY FUME - 750ML',
#  '21504': 'FISH EYE MER - 750ML',
#  '21555': 'DOM TARIQUET S/BLC - 750ML',
#  '21563': 'FISH EYE P/GRIG - 750ML',
#  '21571': 'CHINON O/V RED DOM COLOMBIER - 750ML',
#  '21610': 'DON Q RUM - CRISTAL - 1.75L',
#  '21628': 'LUC PIRLET CHARD - 750ML',
#  '21652': 'CINZANO BIANCO VERM - 750ML',
#  '21679': 'MARTELL COGNAC VSOP - 750ML',
#  '21725': 'MONTE ANTICO ROSSO - 750ML',
#  '21792': 'DOM DE VAUFUGET VOUVRAY - 750ML',
#  '21806': 'FONSECA LBV PORT - 750ML',
#  '21903': 'ST SUPEREY NAPA CAB - 750ML',
#  '21920': 'CYT FRONTERA CARMENERE - 1.5L',
#  '21962': 'CATENA CHARD - 750ML',
#  '21989': 'CATENA CAB - 750ML',
#  '22004': "GREY GOOSE VODKA - L'ORANGE - 750ML",
#  '22012': 'GREY GOOSE VODKA - 750ML',
#  '22109': 'STONE ARROGANT BASTARD NR - 22OZ',
#  '22142': 'SOUTHERN TIER IPA 4/6 NR - 12OZ',
#  '22144': 'DON JULIO TEQUILA - ANEJO - 750ML',
#  '22179': 'LA CREMA SONOMA CHARD - 375ML',
#  '22284': 'CLOS DU BOIS RES CAB - 750ML',
#  '22310': 'OLD SPECKLED HEN 4/6 NR - 12OZ',
#  '2232': 'TWISTED TEA 4/6 NR - 12OZ',
#  '22322': 'LUKSUSOWA VODKA - 1L',
#  '22342': 'SEAGRAM JAMAICAN ME HAPPY 6/4 NR - 355ML',
#  '22348': 'DACHOUFFE LA CHOUFFE NR - 750ML',
#  '22359': 'UNIBROUE LA FIN DU MONDE 12/750',
#  '22382': 'TROEGS DREAMWEAVER WHEAT 4/6 NR - 12OZ',
#  '22414': 'ABITA STRAWBERRY 4/6 NR - 12OZ',
#  '22441': 'BEAR REPUBLIC RACER 5 IPA 4/6 NR - 12OZ',
#  '22470': 'CORAZON AGAVE - ANEJO - 750ML',
#  '22543': 'REX GOLIATH CAB - 750ML',
#  '22578': 'CORBETT CANYON CHARD - 3L',
#  '22586': 'CORBETT CANYON MER - 3L',
#  '22603': 'BROOKLYN LOCAL #2 NR - 750ML',
#  '22608': 'CASARSA CHARD - 1.5L',
#  '22616': 'CASARSA P/GRIG P/BLC - 1.5L',
#  '22632': 'CASARSA CAB - 1.5L',
#  '22647': 'ST GEORGE BEER ETHIOPIA 4/6 NR - 330ML',
#  '22683': 'CORBETT CANYON CAB - 3L',
#  '22691': 'CORBETT CANYON P/GRIG - 3L',
#  '22780': "GREY GOOSE VODKA - L'ORANGE - 1L",
#  '22837': 'ABSOLUT VODKA - MANDRIN - 1.75L',
#  '22904': 'WILD BLUE BLUEBERRY LAGER 4/6 NR - 12OZ',
#  '22917': 'FLYING DOG NUMERO UNO  4/6 NR - 12OZ',
#  '22918': 'BACARDI RUM - LIMON - 375ML',
#  '22921': 'BLUE MOON CAPPUCHNO OATML STOUT 4/6 NR',
#  '22935': 'BUD LIGHT LIME 4/6 NR - 12OZ',
#  '22940': '21ST AMENDMENT IPA 4/6 CAN - 12OZ',
#  '22944': '21ST AMENDMENT WATERMELON CAN 4/6 CANS 12.0Z',
#  '22982': 'LAGUNITAS PILS 4/6 NR - 12OZ',
#  '22993': 'RHUM BARBANCOURT 15 YR ES RS - 750ML',
#  '23004': 'HARPOON SMMR VACATION MIX  2/12 NR - 12OZ',
#  '23007': 'LEINENKUGEL BERRY WEISS 4/6 NR - 12OZ',
#  '23057': 'DOGFISH HD PALO SANTO BROWN 6/4 NR - 12OZ',
#  '23072': 'FLYING DOG GONZO IMP PORTER 4/6 NR - 12OZ',
#  '23074': 'SMIRNOFF STRAWBERRY 4/6 NR - 11.2OZ',
#  '23075': 'LANDSHARK LAGER 4/6 NR - 12OZ',
#  '23078': 'PLACIDO CHIANTI DOCG - 750ML',
#  '23080': 'FLYING DOG DBL DOG PALE ALE 4/6 NR - 12OZ',
#  '23083': 'BUD LIGHT LIME 18PK CAN - 12OZ',
#  '23111': 'LEINENKUGEL SUMMER SHANDY 4/6 NR - 12OZ',
#  '23112': 'SIERRA NEVADA SUMMERFEST 2/12 NR - 12OZ',
#  '23167': 'WELLER BOURBON 107P - 750ML',
#  '23178': 'TYSKIE GRONIE 4/6 NR - 11.2OZ',
#  '23181': 'MILLER 64 4/6 NR - 12OZ',
#  '23193': 'GUINNESS STOUT 2/12 NR - 12OZ',
#  '231968': 'OLARRA CLASICO RESA RIOJA - 750ML',
#  '231970': 'BODEGAS EGO MARIONETTE - 750ML',
#  '23206': 'DOMINION PIN-UP PACK 2/12 NR - 12OZ',
#  '232128': 'FAUST CAB - 750ML',
#  '23213': 'P MASSON BRANDY VS - 375ML',
#  '232138': 'MICHAEL DAVID FREAKSHOW RED',
#  '23221': 'JOHNNIE WALKER BLACK LABEL - 50ML',
#  '232384': 'VIGNAC BORD ROUGE KOS - 750ML',
#  '232422': 'ZENA CROWN SLOPE P/NOIR - 750ML',
#  '232824': 'LA CREMA MONTEREY P/NOIR ROSE - 750ML',
#  '23307': 'MICHELOB ULTRA 24/12 PREPRINT LSE-NR',
#  '23320': 'SIERRA NEVADA TORPEDO ALE 4/6 NR - 12OZ',
#  '23345': 'LINGANORE BLACK RAVEN - 750ML',
#  '23353': 'REX GOLIATH MER - 750ML',
#  '23357': 'KONA LONGBOARD 4/6 NR - 12OZ',
#  '23358': 'KONA FIREROCK 4/6 NR - 12OZ',
#  '23422': 'SMIRNOFF ICE MANGO 4/6 NR - 11.2OZ',
#  '23432': 'PABST 30 PACK CAN - 12OZ',
#  '23433': 'SMIRNOFF PARTY PACK 2/12 NR - 11.2OZ',
#  '23445': 'CORONA EXTRA LOOSE NR - 12OZ',
#  '23456': 'CORONA LIGHT LOOSE NR - 12OZ',
#  '23475': 'MILLER 64 30PK CAN - 12OZ',
#  '23481': 'STARR HILL THE LOVE 4/6 NR - 12OZ',
#  '23492': 'STARR HILL NORTHERN LIGHTS 4/6 NR - 12OZ',
#  '23523': 'TULLAMORE DEW IRISH - 750ML',
#  '23530': 'MIKES HARD MANGO PUNCH 4/6 NR - 11.2OZ',
#  '23533': 'ORION DRAFT BEER 3/4 NR - 21.4OZ',
#  '23537': 'BLUE MOON SMMR HONEY WHEAT NR',
#  '23558': 'COPPOLA PRESENTS BIANCO(P/GRIG) - 750ML',
#  '23560': 'BUTTERNUT PORKSLAP PALE 4/6 CANS - 12OZ',
#  '23566': 'COPPOLA PRESENTS ROSSO - 750ML',
#  '23590': 'WENTE VYDS RIVERBANK RIES - 750ML',
#  '23604': 'AGUARDIENTE CRISTAL - 1.75L',
#  '23612': 'SEQUOIA GROVE CAB - 750ML',
#  '23641': 'LAGUNITAS MAXIMUS 4/6 NR - 12OZ',
#  '23658': 'PEAK ORGANICS IPA 4/6 NR - 12OZ',
#  '23680': 'FERRARI CARANO RES NAPA CHARD - 750ML',
#  '23690': 'EVOLUTION LUCKY 7 PORTER 4/6 NR - 12OZ',
#  '23691': 'EVOLUTION PRIMAL PALE ALE 4/6 NR - 12OZ',
#  '23692': 'EVOLUTION EXILE RED ALE 4/6 NR',
#  '23730': 'SMIRNOFF PINEAPPLE 4/6 NR - 11.2OZ',
#  '23744': "CH L'ERMITAGE WHITE COSTIERES - 750ML",
#  '23763': "GOOSE ISLAND HONKER'S ALE 4/6 NR - 12OZ",
#  '23768': 'MIKES CLASSIC MARGARITA 4/6 NR - 11.2OZ',
#  '23772': 'FLYING DOG R B 20TH ANNIVER 4/6 NR - 12OZ',
#  '23773': 'GOOSE ISLAND IPA 4/6 NR - 12OZ',
#  '23790': 'MIKES STRAWBERRY MARGARITA 4/6 NR - 11.2OZ',
#  '23796': 'GOOSE ISLAND 312 URBAN WHEAT 4/6 NR - 12OZ',
#  '23804': 'S SMITH ORGANIC STRAWBERRY ALE NR - 18.7OZ',
#  '23805': 'SHINER BDAY BEER COFFEE ALE 4/6 NR - 12OZ',
#  '23812': 'LEINENKUGEL SUMMER SHANDY 2/12 CAN - 12OZ',
#  '23817': "BURNETT'S VODKA - VANILLA - 750ML",
#  '23841': 'PAUL MASSON BRANDY VS - 1.75L',
#  '23845': 'DOMINION GRAPEFRUIT PALE ALE 4/6 NR SEAS',
#  '23851': 'GUINNESS FOREIGN EXTRA STOUT 6/4 NR - 11.2OZ',
#  '23852': 'HEAVY SEAS ALPHA EFFECT 4/6 NR - 12OZ',
#  '23859': 'SELECT 55 30 PK CANS - 12OZ',
#  '23885': 'WOODCHUCK GUMPTION CIDER 4/6 NR - 355ML',
#  '23886': 'HEINEKEN LOOSE NR - 12OZ',
#  '23892': 'THREE OLIVES VODKA - CHERRY - 750ML',
#  '23905': 'MILLER LITE  HIGH GRAPHIC LOOSE NR - 12OZ',
#  '23930': 'LANDY COGNAC VS - 750ML',
#  '23933': 'SHINER FAMILY REUNION 4/6 NR - 12OZ',
#  '23939': 'COORS LIGHT HIGH GRAPHICS LOOSE NR - 12OZ',
#  '23957': 'BALVENIE PORTWOOD 21YR SM  - 750ML',
#  '23974': 'SHOCK TOP RUBY FRESH-NR',
#  '24007': 'SEBASTIANI SONOMA P/NOIR - 750ML',
#  '24074': 'ST REMY BRANDY XO - 750ML',
#  '24082': "SEAGRAM'S VODKA - EXTRA SMOOTH - 750ML",
#  '24090': 'JAMESON IRISH WHISKEY - 1L',
#  '24180': 'BRUGAL RUM - ANEJO - 1.75L',
#  '24187': 'LA TRAPPE QUADRUPLE NR - 750ML',
#  '24252': 'CHIVAS REGAL 18YR - 750ML',
#  '24333': 'WILD HORSE P/NOIR - 750ML',
#  '24376': 'THREE OLIVES VODKA - RASPBERRY - 750ML',
#  '24384': 'FETZER ANTHONYS HILL P/GRIG - 1.5L',
#  '24414': 'ESPOLON TEQUILA ANEJO - 750ML',
#  '24449': 'REMY MARTIN 1738 - 750ML',
#  '24487': 'SOUTHERN TIER 2X IPA 4/6 NR - 12OZ',
#  '24505': 'WEXFORD IRISH CREAN ALE 6/4 CANS - 14.9OZ',
#  '24528': 'HARPOON UFO WHITE 4/6 NR - 12OZ',
#  '24538': 'CYT FRONTERA CAB/MER 24/C - 187ML',
#  '24546': 'CYT FRONTERA CHARD 24/C - 187ML',
#  '24554': 'CASTELLO BANFI CUM LAUDE - 750ML',
#  '24573': 'MAGNERS PEAR CIDER 4/6 NR - 12OZ',
#  '24608': 'LA TRAPPE QUAD 6/4 NR - 11OZ',
#  '24635': 'SEQUOIA GROVE CHARD - 750ML',
#  '24678': 'DON Q RUM - GOLD - 1.75L',
#  '24686': 'RAMEY RR VLY CHARD - 750ML',
#  '24731': 'BALLAST POINT BIG EYE 4/6 NR - 12OZ',
#  '24733': 'BALLAST POINT SCULPIN 4/6 NR - 12OZ',
#  '24813': 'MILAGRO TEQUILA - ANEJO - 750ML',
#  '24856': 'FERNET BRANCA 6/CS - 750ML',
#  '24871': 'FULL SAIL SESSION LAGER 4/6 NR - 11OZ',
#  '24911': 'CRABBIES GINGER BEER 4/6 NR - 11.2OZ',
#  '24941': 'TROEGS PERPETUAL IPA 4/6 NR - 12OZ',
#  '24945': 'GROTH S/BLC - 750ML',
#  '24953': 'GROTH CAB - 750ML',
#  '24970': 'GROTH CHARD - 750ML',
#  '25003': 'HOGUE MER - 750ML',
#  '25040': 'BREWERS ART RESURRECTION CAN 4/6 NR - 12OZ',
#  '25092': 'ALLAGASH BLACK 6/4 NR - 12OZ',
#  '25135': 'RUFFINO LUMINA P/GRIG - 750ML',
#  '25151': "MICHELE CHIARLO BARB D'ASTI - 750ML",
#  '25222': 'UINTA HOP NOTCH IPA 4/6NR - 12OZ',
#  '25224': 'BV NAPA VLY CAB - 750ML',
#  '25303': 'SOUTHERN TIER AGED UNEARTHLY NR - 22OZ',
#  '25313': 'ALICE WHITE CHARD - 1.5L',
#  '25348': 'SAUZA EXTRA GOLD - 1L',
#  '25385': 'NATIONAL BOHEMIAN 30 PK CAN',
#  '25391': 'NB TRIPPEL BELGIAN STYLE ALE 4/6NR - 12OZ',
#  '25398': 'FLYING DOG PEARL NCKLCE CHESPKE ST NR',
#  '25399': 'CELTIC CROSSING LIQUEUR - 750ML',
#  '25405': 'NB FAT TIRE 4/6 NR - 12OZ',
#  '25407': 'NB VOODOO RANGER IMPERIAL IPA 4/6 NR',
#  '25411': 'OLD SPECKLED HEN 6/4 CANS - 14.9OZ',
#  '25415': 'NB VOODOO RANGER IPA 2/12 NR',
#  '25419': 'CORONA FAMILIAR NR - 32OZ',
#  '25424': 'NB VOODOO RANGER IPA 4/6 NR - 12OZ',
#  '25454': 'ANGRY ORCHARD CRISP APPLE 4/6NR - 355ML',
#  '25464': 'ANGRY ORCHARD STONE DRY 4/6NR - 355ML',
#  '25483': 'BLUE MOON SUMMER VARIETY 2/12 NR - 12OZ',
#  '25488': "BURNETT'S VODKA - 1L",
#  '2550': 'ABITA PURPLE HAZE 4/6 NR - 12OZ',
#  '25500': "BURNETT'S VODKA - COCONUT - 750ML",
#  '25544': 'SHOCK TOP SEASONAL SAMPLER 2/12NR - 12OZ',
#  '25546': 'FRANZISKANER WEISSBIER 4/6 NR 12OZ',
#  '25550': 'STOLI VODKA-CITROS - 1L',
#  '25563': 'BUD LT LM LIMEARITA 8OZ 12PK CAN',
#  '25577': 'STERLING VNT COLL CAB - 750ML',
#  '25585': 'STERLING VNT COLL CHARD - 750ML',
#  '25593': 'R BARBIER MED RED - 1.5L',
#  '25603': 'FLYING DOG THE TRUTH 4/6NR - 12OZ',
#  '25607': 'R BARBIER MED WHITE - 1.5L',
#  '25613': 'SMIRNOFF SCREWDRIVER 4/6NR - 11.2OZ',
#  '25625': 'LEFFE BRUNE 4/6NR - 11.2 OZ',
#  '25644': 'LAGUNITAS UNDERCOVER SHUT ALE 4/6NR - 12OZ',
#  '25670': 'VICTORY SUMMER LOVE 4/6NR - 12OZ',
#  '25682': 'SAAN SOJU - 375ML',
#  '2569': 'ABITA TURBO DOG 4/6 NR - 12OZ',
#  '25704': 'STERLING VNT COLL MERLOT - 750ML',
#  '25721': 'EVOLUTION LOT #3 IPA  4/6NR - 12OZ',
#  '25736': 'PORT CITY OPTIMAL WIT BEER 4/6NR - 12OZ',
#  '25737': 'PORT CITY ESSENTIAL PALE ALE 4/6NR - 12OZ',
#  '25738': 'PORT CITY MONUMENTAL IPA 4/6NR - 12OZ',
#  '25740': 'PORT CITY PORTER 4/6NR - 12OZ',
#  '25747': 'BACARDI RUM - COCO - 1.75L',
#  '2577': 'ABITA AMBER 4/6 NR - 12OZ',
#  '25844': 'ALOIS LAGEDER PINOT GRIGIO - 750ML',
#  '25883': 'MODELO ESPECIAL 24 LOOSE NR - 12OZ',
#  '25893': 'OMMISSION LAGER 4/6 NR - 11.2OZ',
#  '25896': 'WEINENSTEPHANER PILSNER 4/6NR - 11.2OZ',
#  '25921': 'HOFBRAU HEFE WEISS 4/6NR - 11.2OZ',
#  '25922': 'BUD LT LM STRAWBERITA 8OZ 12PK CAN',
#  '25928': 'KONA BIG WAVE GOLDEN ALE 4/6NR - 12OZ',
#  '25937': 'GOOSE ISLAND MATILDA 6/4 NR - 12OZ',
#  '25950': 'CABO WABO TEQUILA - ANEJO 6/CS - 750ML',
#  '25962': 'SAM ADAMS COLD SNAP NR',
#  '25980': 'FLYING DOG SNAKE DOG IPA 2/12 CANS - 12OZ',
#  '25983': 'OMMISSION PALE ALE 4/6 NR - 12OZ',
#  '25986': 'BLVD SIXTH GLASS 6/4 NR - 12OZ',
#  '25987': "REDD'S APPLE ALE 4/6NR - 12OZ",
#  '26015': 'BLVD DARK TRUTH 6/4 NR - 12OZ',
#  '26031': 'DOMINION DOUBLE D DOUBLE IPA 4/6 NR - 12OZ',
#  '26034': 'MONKEY BAY S/BLC - 750ML',
#  '26037': 'GOOSE ISLAND SOFIE 6/4 NR - 12OZ',
#  '26075': 'HOFBRAU ORIGINAL 4/6NR - 11.2OZ',
#  '26087': 'HOFBRAU DUNKEL 4/6NR - 11.2OZ',
#  '26093': 'BENZIGER MER - 750ML',
#  '26095': 'ANGRY ORCHARD CRISP APPLE 2/12 NR - 12OZ',
#  '26105': 'ANGRY ORCHARD MIX 2/12 NR - 12OZ',
#  '26114': 'BEST OF BELGIUM 2/12 NR - 12OZ',
#  '26116': 'HOFBRAU MAIBOCK 4/6 NR - 12OZ',
#  '26117': 'STARR HILL GRATEFUL 4/6 NR - 12OZ',
#  '26131': 'COLUMBIA CREST GR EST CHARD - 750ML',
#  '2615': 'HEAVY SEAS DOUBLE CANNON 4/6NR - 12OZ',
#  '26150': 'SCHLITZ MALT 2/12 CAN - 12OZ',
#  '26167': 'MAGNERS CIDER 4/6NR - 12OZ',
#  '26181': 'OMISSION IPA 4/6NR - 12OZ',
#  '26184': 'ANGRY ORCHARD GREEN APPLE 4/6NR - 12OZ',
#  '26186': 'ANGRY ORCHARD TAPPED MAPLE NR',
#  '26187': 'STELLA ARTOIS LOOSE NR - 11.2OZ',
#  '26202': 'FORDHAM GYPSY LAGER 4/6 NR - 12OZ',
#  '26205': 'NATURAL ICE CANS 15/CS - 25OZ',
#  '26206': 'SMITH & FORGE HARD CIDER 6/4 CANS - 16OZ',
#  '26248': 'REDDS STRAWBERRY ALE 4/6NR - 12OZ',
#  '26249': 'BUD LT LM STRAWBERITA 15/25OZ CAN',
#  '26252': 'DEVILS BACKBONE EIGHT POINT IPA 4/6NR - 12OZ',
#  '26260': 'BUD LT LM LIMEARITA 15/25OZ CAN',
#  '26262': 'DEVILS BACKBONE VIENNA LAGER 4/6NR - 12OZ',
#  '26267': 'INNUS AND GUNN ORIGINAL 6/4NR - 12OZ',
#  '26282': 'NB FOLLY MIX 2/12NR - 12OZ',
#  '26293': 'BUD CHELADA CANS 15/CS - 25OZ',
#  '26316': 'KONA ISLAND HOPPER VARIETY 2/12NR - 12OZ',
#  '26323': 'DOGFISH HEAD NAMASTE 4/6 NR - 12OZ',
#  '26354': 'SAM ADAMS REBEL IPA 4/6 NR - 12OZ',
#  '26358': 'SMIRNOFF PEACH BELLINI 4/6NR - 11.2OZ',
#  '2640': 'MOLSON XXX 4/6 NR - 12OZ',
#  '26512': 'BALTIMORE BEERWKS TELL TALE HEART 4/6NR - 12OZ',
#  '26556': 'PORT CITY DOWNRIGHT PILSNER 6/4NR - 12OZ',
#  '26565': 'JACK DANIELS BLACK - 750ML',
#  '26573': 'JACK DANIELS BLACK - 1L',
#  '2658': 'SARANAC PALE ALE 4/6 NR - 12OZ',
#  '26581': 'LANDMARK OVERLOOK CHARD - 750ML',
#  '26620': 'GEORGE DICKEL #8 SOUR MASH - 750ML',
#  '26637': 'DC BRAU PUBLIC PALE ALE 4/6 CANS - 12OZ',
#  '26638': 'GEORGE DICKEL #12 SOUR MASH - 750ML',
#  '26639': 'DC BRAU CORRUPTION IPA 4/6 CANS - 12OZ',
#  '26642': 'DC BRAU CITIZEN BELGIAN PALE 4/6 CANS - 12OZ',
#  '26644': 'DC BRAU PENN QUARTER PORT 4/6 CANS - 12OZ',
#  '26646': 'JACK DANIELS BLACK - 50ML',
#  '26647': 'DC BRAU EL HEFE SPKS GERM WHEA 4/6 CANS - 12OZ',
#  '26670': 'JACK DANIELS BLACK - 375ML',
#  '26681': 'UNION DUCKPIN PALE 4/6 CANS - 12OZ',
#  '26727': 'H BEAULIEU PICPOUL DE PINET BLC - 750ML',
#  '26735': 'JACK DANIELS BLACK - 1.75L',
#  '2674': 'SAM ADAMS SUMMER ALE 2/12NR - 12OZ',
#  '26751': 'JACK DANIELS BLACK - 200ML',
#  '26816': "SEAGRAM'S VODKA - EXTRA SMOOTH - 1.75L",
#  '26833': 'BALTIMORE BEER WORKS PEND PILS 4/6NR - 12OZ',
#  '26849': 'KENTUCKY BOURBON ALE 6/4NR - 12OZ',
#  '26863': 'DCHOUFFE HOUBLON 6/4NR - 11OZ',
#  '26867': 'EXCELSIOR ROBERTSON CAB - 750ML',
#  '26870': 'BALTIMORE BEER WORKS VARIETY 2/12NR - 12OZ',
#  '26883': 'DUCK POND P/NOIR - 750ML',
#  '26948': 'YELLOW TAIL MERLOT - 1.5L',
#  '26956': 'YELLOW TAIL SHZ - 1.5L',
#  '26964': 'YELLOW TAIL CHARD - 1.5L',
#  '26972': 'YELLOW TAIL SHZ/CAB - 1.5L',
#  '27006': "GRANT'S SCOTCH - 750ML",
#  '27014': 'MACALLAN 12YR SHERRY OAK - 750ML',
#  '2704': 'VERDI SPUMANTE MB NR - 25.4OZ',
#  '27049': "DEWAR'S SPECIAL RESERVE 12YR - 1L",
#  '27065': 'BALVENIE DOUBLEWOOD 12YR - 750ML',
#  '27073': 'CHIVAS REGAL 12YR - 1L',
#  '27081': 'FAMOUS GROUSE SCOTCH - 1.75L',
#  '27111': 'WHITE HORSE - 1.75L',
#  '27120': 'CLAN MACGREGOR SCOTCH - 1.75L',
#  '27146': 'GLENMORANGIE 10YR - 750ML',
#  '27154': 'REMY MARTIN VSOP - 50ML',
#  '27197': 'CHIVAS REGAL 12YR - 750ML',
#  '27200': 'CHIVAS REGAL 12YR - 50ML',
#  '27219': 'WHITE HORSE - 750ML',
#  '27235': 'CUTTY SARK SCOTCH - 750ML',
#  '27243': 'CHIVAS REGAL 12YR - 375ML',
#  '27260': 'LAPHROAIG 10YR - 750ML',
#  '27278': 'DEWAR\'S "WHITE LABEL" SCOTCH - 1.75L',
#  '27286': 'DEWAR\'S "WHITE LABEL" SCOTCH - 750ML',
#  '27294': "MCCLELLAND'S HIGHLAND SCOTCH - 1.75L",
#  '27308': 'FAMOUS GROUSE SCOTCH - 750ML',
#  '27324': 'CLUNY SCOTCH - 1L',
#  '27332': 'GLENFIDDICH 12YR - 750ML',
#  '27340': 'GLENLIVET 12YR - 750ML',
#  '27356': 'STRONGBOW GOLD CIDER 4/6NR - 11.2OZ',
#  '27358': 'STONE MIXED 1712 2/12NR - 12OZ',
#  '27359': 'GLENLIVET 12YR - 1.75L',
#  '27367': 'HIGHLAND PARK 12YR - 750ML',
#  '27383': "DUGGAN'S DEW SCOTCH - 1.75L",
#  '27391': "DUGGAN'S DEW SCOTCH - 750ML",
#  '27413': "DEWAR'S WHITE LABEL - 375ML",
#  '27430': 'BLACK & WHITE SCOTCH - 1.75L',
#  '27440': 'SHIPYARD SUMMER ALE 4/6 CANS - 12OZ',
#  '27448': "MCCLELLAND'S HIGHLAND SCOTCH - 750ML",
#  '27456': 'BOGLE S/BLC - 750ML',
#  '27464': 'J&B RARE - 750ML',
#  '27472': "MCCLELLAND'S ISLAY SCOTCH - 750ML",
#  '27474': 'DUCLAW BARE ASS BLONDE ALE 4/6NR - 12OZ',
#  '27482': 'DUCLAW SWEET BABY JESUS CHOC PB PORT 4/6NR - 12OZ',
#  '27485': 'LEFT HAND MILK STOUT NITRO 4/6NR - 12OZ',
#  '27499': 'JOHNNIE WALKER BLACK - 1L',
#  '27502': 'JOHNNIE WALKER BLACK - 750ML',
#  '27545': 'JOHNNIE WALKER RED - 750ML',
#  '27561': 'JOHNNIE WALKER BLACK - 375ML',
#  '27618': 'J&B RARE - 1.75L',
#  '27626': "DEWAR'S SPECIAL RESERVE 12YR - 1.75L",
#  '27642': "DEWAR'S SPECAIL RESRVE 12YR - 750ML",
#  '27646': 'SIXPOINT BENGALI TIGER 4/6 CANS - 12OZ',
#  '27650': 'ARGIOLAS CASTERA - 750ML',
#  '27656': 'DUCLAW NEON GYPSY IPA 4/6NR - 12OZ',
#  '27659': 'LEFT HAND MOUNTAIN MIX 12.0Z 2/12NR - 12OZ',
#  '27669': 'DIMPLE PINCH SCOTCH 15YR - 750ML',
#  '27685': "BALLANTINE'S SCOTCH - 1.75L",
#  '27700': 'DUCLAW DIRTY LITTLE FREAK COCONUT CHOCO ALE 4/6NR - 12OZ',
#  '27731': 'CUTTY SARK SCOTCH - 1L',
#  '27774': 'VAT 69 GOLD - 1.75L',
#  '27804': 'J W DANT SCOTCH - 1.75L',
#  '28002': 'JOHNNIE WALKER RED - 50ML',
#  '28045': 'CROWN ROYAL RESERVE - 750ML',
#  '28053': 'INVER HOUSE SCOTCH - 1.75L',
#  '28061': 'OMMEGANG GNOMEGANG 6/4 NR',
#  '28063': 'SIERRA NEVADA HOP HUNTER NR - 12OZ',
#  '28065': 'SIERRA NEVADA NOONER PILSNER NR -12OZ',
#  '28069': 'SAM ADAMS REBEL ROUSER NR',
#  '28088': 'CHIVAS REGAL 12YR - 1.75L',
#  '28094': 'SIXPOINT RESIN 4/6 CANS - 12OZ',
#  '2810': 'YUENGLING LAGER LOOSE NR - 12OZ',
#  '28100': 'FIRESTEED CELLARS P/NOIR - 750ML',
#  '28126': 'COINTREAU - 50ML',
#  '28201': 'BALLAST POINT EVEN KEEL 4/6 12Z CAN',
#  '28202': 'BALLAST POINT BIG EYE 4/6 12Z CAN',
#  '28203': 'BALLAST POINT SCULPIN 4/6 CANS',
#  '28215': "GRANT'S SCOTCH - 1.75L",
#  '28217': 'DUCLAW VARIETY PACK 2/12 12.0Z NR',
#  '28223': 'JOHNNIE WALKER BLACK - 1.75L',
#  '28226': 'STRONGBOW HONEY AND APPLE HARD CIDER -11.2',
#  '28227': 'STRONGBOW VARIETY 2/12 11.2OZ NR',
#  '28231': 'JOHNNIE WALKER RED - 1.75L',
#  '28304': 'CUTTY SARK SCOTCH - 1.75L',
#  '28308': 'BALTIMORE BEER WORKS THE CASK 6/4 NR',
#  '28319': 'NB VOODOO RNGR 8 HOP 4/6 NR',
#  '28365': 'HEAVY SEAS CROSSBONES 4/6 NR',
#  '28380': 'CANADIAN MIST WHISKY - 375ML',
#  '28388': 'GUINNESS AMERICAN BLONDE 4/6NR - 12OZ',
#  '28398': 'SCORESBY VERY RARE SCOTCH - 1.75L',
#  '28400': 'GOOSE ISLAND FLIGHT PACK SMPLR 12PK NR',
#  '28402': 'BLUE POINT TOASTED LAGER 4/6NR - 12OZ',
#  '28404': 'FLYING DOG BLOODLINE 4/6NR - 12OZ',
#  '28406': 'DUCLAW DEVILS MILK 4/6NR - 12OZ',
#  '28412': 'TERRAPIN HOPSECUTIONER 4/6NR - 12OZ',
#  '28414': 'BLUE POINT HOPTICAL ILLUSION 4/6NR - 12OZ',
#  '28425': 'BLUE POINT SUMMER ALE 4/6NR - 12OZ',
#  '28434': 'BUD LT LM MANGO RITA 2/12 CANS - 8OZ',
#  '2844': 'VERDI SPUMANTE MB 4/6NR - 187ML',
#  '28444': "BOWMORE'S 12YR ISLAY - 750ML",
#  '28451': 'DOMINION CANDI BELGIAN TRIPEL 4/6NR - 12OZ',
#  '28462': 'HARPOON UFO TWIST 4/6NR - 12OZ',
#  '28474': 'BUD LT LM MANGO RITA CANS 15/CS - 25OZ',
#  '28479': 'J W DANT SCOTCH - 1L',
#  '28487': 'HENRYS HARD ORANGE 4/6 NR',
#  '28490': 'HENRYS HARD GINGER ALE 4/6 NR',
#  '28511': 'LEINENKUGEL SHANDY SAMPLER 2/12 CAN - 12OZ',
#  '28514': 'SIERRA NEVADA 4-WAY IPA 2/12NR - 12OZ',
#  '28517': 'FLYING DOG TROPICAL BITCH IPA 4/6 NR',
#  '28533': 'CANADIAN MIST WHISKY - 200ML',
#  '28535': 'VICTORIA 4/6NR - 12OZ',
#  '28549': 'GOOSE ISLAND SUMMERTIME NR',
#  '28552': 'SMIRNOFF WATERMELON MIMOSA NR 12/CS - 24OZ',
#  '28557': 'STIEGL GRAPEFRUIT RADLER 4/6NR - 12OZ',
#  '28561': 'EVOLUTION SPRUNG NR',
#  '28577': 'TBC GRAPEFRUIT SHANDY NR',
#  '28579': "NOT YOUR FATHER'S ROOT BEER 4/6 NR",
#  '28582': 'BUD LT LM LEMONADERITA 15/25 CAN',
#  '28595': 'BUD LT LM LEMONADERITA 8OZ 12PK CAN',
#  '28602': 'DC BRAU PILS 4/6 CAN 12OZ',
#  '28605': 'STELLA ARTOIS 20/9.6OZ NR',
#  '28607': 'STELLA CIDRE 4/6 NR',
#  '28640': 'GOOSE ISLAND GREEN LINE PALE ALE 4/6 NR',
#  '28645': 'CONEY ISLAND MERMAID PILSNER 4/6 NR-12OZ',
#  '28649': 'CANADIAN MIST WHISKY - 750ML',
#  '28651': 'NOT YOUR FATHERS GINGER ALE 4/6 NR',
#  '28652': 'BEST DAMN ROOT BEER 4/6 NR',
#  '28653': 'GUINNESS NITRO IPA 4/6 CAN 11.2OZ',
#  '28673': 'CROWN ROYAL - 1L',
#  '28674': 'CROWN ROYAL RYE - 750ML',
#  '28681': 'CROWN ROYAL - 750ML',
#  '28682': 'DEVILS BACKBONE ADVENTURE PACK 12PK NR-12OZ',
#  '28687': 'ATLAS ROWDY 4/6 CAN',
#  '28690': 'MACALLAN 1OYR - FINE OAK - 750ML',
#  '28703': 'MACALLAN 15YR - FINE OAK - 750ML',
#  '28707': 'SMIRNOFF ICE WATERMELON MIMOSA 4/6 NR',
#  '28728': 'BLUE MOON WHITE IPA NR',
#  '28738': "SEAGRAM'S V.O. - 200ML",
#  '28741': 'NB JUICY WTRMLN LIME ALE 4/6 NR',
#  '28754': 'WINDSOR CANADIAN - 750ML',
#  '28761': 'LEINENKUGEL GRAPEFRUIT SHANDY NR',
#  '28762': 'CANADIAN CLUB WHISKY - 375ML',
#  '28765': 'TROEGS JOVIEL 6/4 12.7OZ NR',
#  '28770': 'NORTHERN LIGHT CANADIAN WHISKY - 1.75L',
#  '28797': 'CANADIAN MIST WHISKY - 1.75L',
#  '28827': 'DOGFISH HEAD HIGHER MATH 12OZ NR',
#  '28851': 'CANADIAN CLUB WHISKY - 1.75L',
#  '28886': 'BOLLINI P/GRIG - 750ML',
#  '28888': 'OSKAR BLUES PINNER IPA 4/6 12.OZ CAN',
#  '28894': 'GENTLEMAN JACK - 1.75L',
#  '28916': 'ABSOLUT VODKA - APEACH - 1L',
#  '28927': 'STONE ENJOY BY 4/6 12.OZ NR',
#  '28932': 'WOODFORD RESERVE 90.4P - 1L',
#  '28934': '21ST AMENDMENT DOWN TO EARTH IPA 4/6 12.OZ CAN',
#  '28945': 'BALLAST POINT GRAPEFRUIT SCULPIN 4/6 12.OZ NR',
#  '28955': 'FATTI BY STELZER BIO PERLE 20/16.9 NR',
#  '28956': 'FATTI BY STELZER EXPORT 20/16.9 NR',
#  '28957': 'FATTI BY STELZER RITTER TRUNK 20/16.9 NR',
#  '28958': 'FATTI BY STELZER URTYPHELL 20/16.OZ NR',
#  '28959': 'COUSINO MACUL SAUVIGNON GRIS - 750ML',
#  '28973': 'STOLI GINGER BEER NA 6/4 8.4.OZ CAN',
#  '28983': 'WINDSOR CANADIAN - 1.75L',
#  '29002': 'TROEGS SUNSHINE PILS 4/6 12.OZ NR',
#  '29006': 'STONE DELICIOUS 4/6 12.OZ NR',
#  '29008': 'SCHOFFERHOFER GRAPEFRUIT 6/4 16',
#  '29009': "SEAGRAM'S V.O. - 1.75L",
#  '29010': 'FIRESTONE UNION JACK IPA 4/6 12.OZ CAN',
#  '29012': 'FIRESTONE EASY JACK SESSION IPA4/6 12.OZ NR',
#  '29017': 'CANADIAN CLUB WHISKY - 750ML',
#  '29025': 'NB CITRADELIC TANGERINE IPA 4/6 NR',
#  '29033': 'BLACK VELVET CANADIAN WHISKY - 1.75L',
#  '29034': 'FIRESTONE PIVO PILS 4 /6/12.OZ CAN',
#  '29041': 'ATLAS DISTRICT COMMON 4/6 CAN',
#  '29050': 'BLACK VELVET CANADIAN WHISKY - 750ML',
#  '29071': 'UNION OLD PRO GOSE 12.OZ 4/6 CAN',
#  '2909': 'YUENGLING LAGER 4/6 NR - 12OZ',
#  '29092': 'PASSPORT SCOTCH - 1L',
#  '29098': 'STONE RUINATION DOUBLE IPA 2.0 4/6 12.OZ NR',
#  '29114': 'DON Q RUM - GOLD - 750ML',
#  '29122': 'INVERHOUSE SCOTCH (SC) - 1L',
#  '29149': 'DEWAR\'S "WHITE LABEL" SCOTCH - 50ML',
#  '2917': 'YUENGLING BLACK & TAN 4/6 NR - 12OZ',
#  '29201': 'SILLY SOUR ALE - 6/4 NR',
#  '29203': 'CANANDIAN CLUB WHISKY - 50ML',
#  '29220': 'BELVEDERE VODKA - 1L',
#  '29238': 'RAIN VODKA - 1.75L',
#  ...}

# %%
len(code_dic) # Self check again
# Out:
# 23553

# %%
clean_data['ITEM DESCRIPTION'] = clean_data['ITEM CODE'].map(code_dic)
clean_data.head()
# I also ran cell 7 to check that now item_code_list is empty as there are no multiple descriptions per one code anymore.
# Out:
# <ipython-input-11-73f11de231dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['ITEM DESCRIPTION'] = clean_data['ITEM CODE'].map(code_dic)
#    YEAR  MONTH                      SUPPLIER ITEM CODE  \
# 0  2017      4               ROYAL WINE CORP    100200
# 1  2017      4      SANTA MARGHERITA USA INC    100749
# 2  2017      4            JIM BEAM BRANDS CO     10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC     10120
# 4  2017      4               ROYAL WINE CORP    101664
#
#                         ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      GAMLA CAB - 750ML      WINE           0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML      WINE           0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML    LIQUOR           0.0
# 3          J W DANT BOURBON 100P - 1.75L    LIQUOR           0.0
# 4            RAMON CORDOVA RIOJA - 750ML      WINE           0.0
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               1.0              0.0
# 1               1.0              0.0
# 2               8.0              0.0
# 3               2.0              0.0
# 4               4.0              0.0

# %%
engine = create_engine('mysql+pymysql://Svetlana Gruzdeva:***@localhost/warehouse')
# I removed my real password and saved samples of sql tables below as a proof that my command did work.
clean_data.to_sql(con=engine, name='cleaned_data', if_exists='replace')
data = pd.read_sql_query('''SELECT * FROM cleaned_data LIMIT 10''', engine)
data
# Out:
#    index  YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      0  2017      4                    ROYAL WINE CORP    100200
# 1      1  2017      4           SANTA MARGHERITA USA INC    100749
# 2      2  2017      4                 JIM BEAM BRANDS CO     10103
# 3      3  2017      4       HEAVEN HILL DISTILLERIES INC     10120
# 4      4  2017      4                    ROYAL WINE CORP    101664
# 5      5  2017      4  REPUBLIC NATIONAL DISTRIBUTING CO    101680
# 6      6  2017      4                    ROYAL WINE CORP    101753
# 7      7  2017      4                 JIM BEAM BRANDS CO     10197
# 8      8  2017      4          STE MICHELLE WINE ESTATES    101974
# 9      9  2017      4          MONSIEUR TOUTON SELECTION    102083
#
#                         ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      GAMLA CAB - 750ML      WINE           0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML      WINE           0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML    LIQUOR           0.0
# 3          J W DANT BOURBON 100P - 1.75L    LIQUOR           0.0
# 4            RAMON CORDOVA RIOJA - 750ML      WINE           0.0
# 5   MANISCHEWITZ CREAM WH CONCORD - 1.5L      WINE           0.0
# 6         BARKAN CLASSIC PET SYR - 750ML      WINE           0.0
# 7  KNOB CREEK BOURBON 9YR - 100P - 1.75L    LIQUOR           0.0
# 8              CH ST MICH P/GRIS - 750ML      WINE           0.0
# 9     CH DE LA CHESNAIE MUSCADET - 750ML      WINE           0.0
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               1.0              0.0
# 1               1.0              0.0
# 2               8.0              0.0
# 3               2.0              0.0
# 4               4.0              0.0
# 5               1.0              0.0
# 6               1.0              0.0
# 7              32.0              0.0
# 8              26.0              0.0
# 9               1.0              0.0

# %%
col = ['RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES']
agg_supplier = clean_data.groupby('SUPPLIER')[col].sum().reset_index()
agg_supplier.to_sql(con=engine, name='aggregated_per_supplier', if_exists='replace')
data = pd.read_sql_query('''SELECT * FROM aggregated_per_supplier LIMIT 10''', engine)
data
# Out:
#    index                  SUPPLIER  RETAIL SALES  RETAIL TRANSFERS  \
# 0      0                8 VINI INC          2.78              2.00
# 1      1           A HARDY USA LTD          0.40              0.00
# 2      2      A I G WINE & SPIRITS         12.52              5.92
# 3      3     A VINTNERS SELECTIONS       8640.57           8361.10
# 4      4                   A&E INC         11.52              2.00
# 5      5           A&W BORDERS LLC          0.80              1.00
# 6      6       ADAMBA IMPORTS INTL         32.20             40.49
# 7      7        AIKO IMPORTERS INC         11.24             11.00
# 8      8  ALLAGASH BREWING COMPANY        304.09            339.00
# 9      9  ALLIED IMPORTERS USA LTD          7.63             11.00
#
#    WAREHOUSE SALES
# 0             1.00
# 1             0.00
# 2           134.00
# 3         29776.67
# 4             0.00
# 5             0.00
# 6             0.00
# 7             3.00
# 8          1742.92
# 9            18.00

# %%
agg_item = clean_data.groupby('ITEM CODE')[col].sum().reset_index()
agg_item.to_sql(con=engine, name='aggregated_per_item', if_exists='replace')
data = pd.read_sql_query('''SELECT * FROM aggregated_per_item LIMIT 10''', engine)
data
# Out:
#    index ITEM CODE  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 0      0    100003           0.0               0.0              1.0
# 1      1    100007           0.0               0.0              1.0
# 2      2    100008           0.0               0.0              1.0
# 3      3    100009           0.0               0.0             12.0
# 4      4    100011           0.0               0.0              3.0
# 5      5    100012           0.0               0.0             17.0
# 6      6     10004           0.0               0.0              1.0
# 7      7    100080           0.0               0.0              6.0
# 8      8      1001           0.0               0.0              9.0
# 9      9     10014           1.0               1.0             13.0
