# %%
import pandas as pd
import numpy as np 
import re

# %%
bevolking = pd.read_csv('/Users/bert/Desktop/Projecten/amsterdam_p/Data bevolking/bevolkingamsterdam.csv', sep=';')
bevolking
# Out:
#         City_Area      0-4      5-9    10-14    15-19    20-24     25-29  \
# 0      A  Centrum   2794.0   2274.0   2242.0   2921.0   7264.0   11399.0
# 1    B  Westpoort      4.0      1.0      3.0      5.0     13.0      12.0
# 2         E  West   7622.0   5664.0   5114.0   5317.0   9989.0   20599.0
# 3   F  Nieuw-West   9867.0   9309.0   8735.0   9335.0  13915.0   16619.0
# 4         K  Zuid   7179.0   5891.0   5119.0   5197.0   9830.0   19176.0
# 5         M  Oost   7463.0   6688.0   7229.0   7589.0  11181.0   16606.0
# 6        N  Noord   6145.0   5877.0   5456.0   5555.0   6538.0    7819.0
# 7     T  Zuidoost   4750.0   4704.0   4977.0   5604.0   8338.0    7913.0
# 8       Amsterdam  45824.0  40408.0  38875.0  41523.0  67068.0  100143.0
# 9             NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 10            NaN      NaN      NaN      NaN      NaN      NaN       NaN
#
#       30-34    35-39    40-44    45-49    50-54    55-59    60-64    65-69  \
# ...

# %%
#First I drop all the NaN values, they don't make sense. 

bevolking = bevolking.dropna()
bevolking
# Out:
#        City_Area      0-4      5-9    10-14    15-19    20-24     25-29  \
# 0     A  Centrum   2794.0   2274.0   2242.0   2921.0   7264.0   11399.0
# 1   B  Westpoort      4.0      1.0      3.0      5.0     13.0      12.0
# 2        E  West   7622.0   5664.0   5114.0   5317.0   9989.0   20599.0
# 3  F  Nieuw-West   9867.0   9309.0   8735.0   9335.0  13915.0   16619.0
# 4        K  Zuid   7179.0   5891.0   5119.0   5197.0   9830.0   19176.0
# 5        M  Oost   7463.0   6688.0   7229.0   7589.0  11181.0   16606.0
# 6       N  Noord   6145.0   5877.0   5456.0   5555.0   6538.0    7819.0
# 7    T  Zuidoost   4750.0   4704.0   4977.0   5604.0   8338.0    7913.0
# 8      Amsterdam  45824.0  40408.0  38875.0  41523.0  67068.0  100143.0
#
#      30-34    35-39    40-44    45-49    50-54    55-59    60-64    65-69  \
# 0   9504.0   6619.0   5321.0   5761.0   6188.0   6047.0   5400.0   4883.0
# 1     12.0      8.0      8.0      4.0      4.0      7.0     10.0     10.0
# ...

# %%
#Second we gonna take a look to the total population
#totale_bevolking = bevolking[['totaal']]

bevolking['0-24'] = bevolking['0-4']+bevolking['5-9']+bevolking['10-14']+bevolking['15-19']+bevolking['20-24']

bevolking['25-44'] = bevolking['25-29']+bevolking['30-34']+bevolking['35-39']+bevolking['40-44']

bevolking['45-69'] = bevolking['45-49']+bevolking['50-54']+bevolking['55-59']+bevolking['60-64']+bevolking['65-69']

bevolking['70+'] = bevolking['70-74']+bevolking['75-79']+bevolking['80+']

bevolking = bevolking.drop(['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80+'], axis=1)

bevolking
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
bevolking_percentage_jongeren = bevolking['0-24']/bevolking['totaal']*100
bevolking_percentage_jongeren
# Out:
# 0    20.037796
# 1    24.528302
# 2    22.863771
# 3    31.950863
# 4    22.705430
# 5    28.264895
# 6    29.798061
# 7    31.581349
# 8    26.788555
# dtype: float64

# %%
bevolking_percentage_volwassen = bevolking['25-44']/bevolking['totaal']*100
bevolking_percentage_volwassen
# Out:
# 0    37.616539
# 1    37.735849
# 2    44.385128
# 3    33.075616
# 4    39.335297
# 5    36.926694
# 6    29.939136
# 7    29.378569
# 8    36.381050
# dtype: float64

# %%
bevolking_percentage_babyboomers= bevolking['45-69']/bevolking['totaal']*100
bevolking_percentage_babyboomers
# Out:
# 0    32.389188
# 1    33.018868
# 2    26.484015
# 3    26.465739
# 4    27.047460
# 5    28.370492
# 6    29.634817
# 7    31.404370
# 8    28.339256
# dtype: float64

# %%
bevolking_percentage_ouderen= bevolking['70+']/bevolking['totaal']*100
bevolking_percentage_ouderen
# Out:
# 0     9.956477
# 1     4.716981
# 2     6.267085
# 3     8.507781
# 4    10.911813
# 5     6.437919
# 6    10.627985
# 7     7.635712
# 8     8.491139
# dtype: float64
