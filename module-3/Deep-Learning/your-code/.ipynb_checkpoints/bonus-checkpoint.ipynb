# %% [markdown]
# # Bonus Challenge: Spiral Data Classification
#
# Now that you completed Challenge 2, you know you can use the Tensorflow Playground to experiment the hyperparameters of your deep learning model. If you are brave enough to take on this challenge, we present you the spiral data generated by codes and you will replicate your model built visually in the Tensorflow Playground with Python codes.
#
# Below are the codes to generate the spiral dataset. Read the remarks and execute the codes.

# %%
from math import hypot, cos, sin
import numpy as np
import pandas as pd

"""
A function to generate X/Y data points that will form a spiral.
"""
def spiral(radius, step, resolution=.1, angle=0.0, start=0.0):
    dist = start
    coords=[]
    while dist*hypot(cos(angle),sin(angle))<radius:
        cord=[]
        cord.append(dist*cos(angle))
        cord.append(dist*sin(angle))
        coords.append(cord)
        dist+=step
        angle+=resolution
    return coords

# %%
# Generate two sets of spiral data points with opposite angles
data_1 = np.array(spiral(1000, 5, angle=0))
data_2 = np.array(spiral(1000, 5, angle=180))

# %%
# Plot the two datasets to visualize the spirals

import matplotlib.pyplot as plt

a, b = data_1.T
plt.scatter(a, b, s=5)

aa, bb = data_2.T
plt.scatter(aa, bb, s=5)

plt.show()

# %%
# Combine the two spiral datasets into one

df1 = pd.DataFrame(data=data_1, columns=["X", "Y"])
df1["CLASS"] = 0

df2 = pd.DataFrame(data=data_2, columns=["X", "Y"])
df2["CLASS"] = 1

df = df1.append(df2)
df['CLASS'].value_counts()
# Out:
# 0    201
# 1    200
# Name: CLASS, dtype: int64

# %% [markdown]
# Now, build a neural network with Tensorflow to classify `df`. See how low data loss and how high accuracy can you achieve!

# %%
# your code here

import tensorflow as tf
import tensorflow.keras as keras

# %%
X = df[['X', 'Y']]
y = df['CLASS']

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(200, activation=tf.nn.tanh))
model.add(tf.keras.layers.Dense(200, activation=tf.nn.tanh))
model.add(tf.keras.layers.Dense(200, activation=tf.nn.tanh))
model.add(tf.keras.layers.Dense(200, activation=tf.nn.tanh))
model.add(tf.keras.layers.Dense(5, activation=tf.nn.softmax))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X, y, epochs=200)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Layer flatten is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 13/13 [==============================] - 0s 2ms/step - loss: 1.7576 - accuracy: 0.2818
# Epoch 2/200
# 13/13 [==============================] - 0s 2ms/step - loss: 1.5500 - accuracy: 0.2943
# Epoch 3/200
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2656 - accuracy: 0.4040
# Epoch 4/200
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0296 - accuracy: 0.5137
# Epoch 5/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8075 - accuracy: 0.5436
# Epoch 6/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7415 - accuracy: 0.4813
# Epoch 7/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7031 - accuracy: 0.5187
# Epoch 8/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7121 - accuracy: 0.4938
# Epoch 9/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7131 - accuracy: 0.5287
# Epoch 10/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7178 - accuracy: 0.5162
# Epoch 11/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7350 - accuracy: 0.4813
# Epoch 12/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7147 - accuracy: 0.5137
# Epoch 13/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7251 - accuracy: 0.5087
# Epoch 14/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7212 - accuracy: 0.5287
# Epoch 15/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7136 - accuracy: 0.5212
# Epoch 16/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.5362
# Epoch 17/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7072 - accuracy: 0.5012
# Epoch 18/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7288 - accuracy: 0.5012
# Epoch 19/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7106 - accuracy: 0.5087
# Epoch 20/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7226 - accuracy: 0.5012
# Epoch 21/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7116 - accuracy: 0.5187
# Epoch 22/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7022 - accuracy: 0.5387
# Epoch 23/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6860 - accuracy: 0.5287
# Epoch 24/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.5411
# Epoch 25/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6881 - accuracy: 0.5387
# Epoch 26/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7076 - accuracy: 0.5137
# Epoch 27/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7008 - accuracy: 0.4913
# Epoch 28/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7000 - accuracy: 0.5012
# Epoch 29/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6823 - accuracy: 0.5436
# Epoch 30/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5112
# Epoch 31/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.5411
# Epoch 32/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7034 - accuracy: 0.5287
# Epoch 33/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6964 - accuracy: 0.5287
# Epoch 34/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6687 - accuracy: 0.5436
# Epoch 35/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6874 - accuracy: 0.5137
# Epoch 36/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6706 - accuracy: 0.5237
# Epoch 37/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.5411
# Epoch 38/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6649 - accuracy: 0.5511
# Epoch 39/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.5436
# Epoch 40/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.5262
# Epoch 41/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5486
# Epoch 42/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.5287
# Epoch 43/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6653 - accuracy: 0.5536
# Epoch 44/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6870 - accuracy: 0.5212
# Epoch 45/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.5411
# Epoch 46/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6746 - accuracy: 0.5810
# Epoch 47/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6885 - accuracy: 0.5062
# Epoch 48/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6548 - accuracy: 0.5786
# Epoch 49/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6970 - accuracy: 0.4963
# Epoch 50/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7048 - accuracy: 0.5536
# Epoch 51/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6949 - accuracy: 0.5362
# Epoch 52/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7039 - accuracy: 0.5411
# Epoch 53/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7108 - accuracy: 0.5362
# Epoch 54/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6682 - accuracy: 0.5162
# Epoch 55/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.5461
# Epoch 56/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6574 - accuracy: 0.5461
# Epoch 57/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.5586
# Epoch 58/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6443 - accuracy: 0.5835
# Epoch 59/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6571 - accuracy: 0.5686
# Epoch 60/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.5312
# Epoch 61/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7040 - accuracy: 0.4963
# Epoch 62/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5636
# Epoch 63/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7002 - accuracy: 0.5362
# Epoch 64/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.5436
# Epoch 65/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6829 - accuracy: 0.5262
# Epoch 66/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6621 - accuracy: 0.5661
# Epoch 67/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6755 - accuracy: 0.5337
# Epoch 68/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6557 - accuracy: 0.5461
# Epoch 69/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.5885
# Epoch 70/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6340 - accuracy: 0.5885
# Epoch 71/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6355 - accuracy: 0.5736
# Epoch 72/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6390 - accuracy: 0.5661
# Epoch 73/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6607 - accuracy: 0.5436
# Epoch 74/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6718 - accuracy: 0.5761
# Epoch 75/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6568 - accuracy: 0.5810
# Epoch 76/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6983 - accuracy: 0.5337
# Epoch 77/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7013 - accuracy: 0.4963
# Epoch 78/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.5137
# Epoch 79/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6628 - accuracy: 0.5511
# Epoch 80/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.5461
# Epoch 81/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6532 - accuracy: 0.5686
# Epoch 82/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6565 - accuracy: 0.5761
# Epoch 83/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6649 - accuracy: 0.5511
# Epoch 84/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6706 - accuracy: 0.5511
# Epoch 85/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.5910
# Epoch 86/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6772 - accuracy: 0.5611
# Epoch 87/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6808 - accuracy: 0.5312
# Epoch 88/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6795 - accuracy: 0.5661
# Epoch 89/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.5337
# Epoch 90/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6618 - accuracy: 0.5436
# Epoch 91/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6616 - accuracy: 0.5611
# Epoch 92/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5561
# Epoch 93/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5287
# Epoch 94/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6746 - accuracy: 0.5436
# Epoch 95/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6757 - accuracy: 0.5162
# Epoch 96/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6705 - accuracy: 0.5387
# Epoch 97/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6634 - accuracy: 0.5586
# Epoch 98/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6582 - accuracy: 0.5661
# Epoch 99/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6484 - accuracy: 0.5661
# Epoch 100/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6359 - accuracy: 0.5761
# Epoch 101/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6652 - accuracy: 0.5411
# Epoch 102/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6741 - accuracy: 0.5362
# Epoch 103/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6687 - accuracy: 0.5511
# Epoch 104/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6506 - accuracy: 0.5661
# Epoch 105/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6457 - accuracy: 0.5860
# Epoch 106/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6550 - accuracy: 0.5187
# Epoch 107/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6445 - accuracy: 0.5511
# Epoch 108/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6619 - accuracy: 0.5486
# Epoch 109/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.5511
# Epoch 110/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6723 - accuracy: 0.5237
# Epoch 111/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6405 - accuracy: 0.5661
# Epoch 112/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6524 - accuracy: 0.5786
# Epoch 113/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6415 - accuracy: 0.5486
# Epoch 114/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6546 - accuracy: 0.5611
# Epoch 115/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.5461
# Epoch 116/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6784 - accuracy: 0.5312
# Epoch 117/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6701 - accuracy: 0.4938
# Epoch 118/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6395 - accuracy: 0.5810
# Epoch 119/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6347 - accuracy: 0.5786
# Epoch 120/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6231 - accuracy: 0.5985
# Epoch 121/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.5387
# Epoch 122/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6606 - accuracy: 0.5611
# Epoch 123/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7013 - accuracy: 0.5137
# Epoch 124/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6765 - accuracy: 0.5511
# Epoch 125/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.5162
# Epoch 126/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.5387
# Epoch 127/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6652 - accuracy: 0.5337
# Epoch 128/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6618 - accuracy: 0.5387
# Epoch 129/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.5486
# Epoch 130/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.5661
# Epoch 131/200
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6416 - accuracy: 0.6060
# Epoch 132/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6325 - accuracy: 0.5835
# Epoch 133/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6260 - accuracy: 0.5860
# Epoch 134/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6613 - accuracy: 0.5511
# Epoch 135/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6484 - accuracy: 0.5636
# Epoch 136/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6469 - accuracy: 0.5586
# Epoch 137/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6384 - accuracy: 0.6010
# Epoch 138/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.5636
# Epoch 139/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.5686
# Epoch 140/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.5860
# Epoch 141/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7080 - accuracy: 0.5037
# Epoch 142/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.5137
# Epoch 143/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6826 - accuracy: 0.5411
# Epoch 144/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6886 - accuracy: 0.5137
# Epoch 145/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5711
# Epoch 146/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5636
# Epoch 147/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6756 - accuracy: 0.5237
# Epoch 148/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5337
# Epoch 149/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6743 - accuracy: 0.5536
# Epoch 150/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.5436
# Epoch 151/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6732 - accuracy: 0.5362
# Epoch 152/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6564 - accuracy: 0.5411
# Epoch 153/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.6035
# Epoch 154/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.5711
# Epoch 155/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.5511
# Epoch 156/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6501 - accuracy: 0.5536
# Epoch 157/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6341 - accuracy: 0.6035
# Epoch 158/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6440 - accuracy: 0.5486
# Epoch 159/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6270 - accuracy: 0.5910
# Epoch 160/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.5586
# Epoch 161/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6240 - accuracy: 0.5885
# Epoch 162/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6356 - accuracy: 0.5486
# Epoch 163/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6524 - accuracy: 0.5686
# Epoch 164/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6520 - accuracy: 0.5262
# Epoch 165/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.5885
# Epoch 166/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6294 - accuracy: 0.5935
# Epoch 167/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6355 - accuracy: 0.5387
# Epoch 168/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6241 - accuracy: 0.5885
# Epoch 169/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6129 - accuracy: 0.5910
# Epoch 170/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6170 - accuracy: 0.5960
# Epoch 171/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6130 - accuracy: 0.5711
# Epoch 172/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.5885
# Epoch 173/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6132 - accuracy: 0.6135
# Epoch 174/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6413 - accuracy: 0.5835
# Epoch 175/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6111 - accuracy: 0.5960
# Epoch 176/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6083 - accuracy: 0.6259
# Epoch 177/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6069 - accuracy: 0.6010
# Epoch 178/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6300 - accuracy: 0.5860
# Epoch 179/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6201 - accuracy: 0.5810
# Epoch 180/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6215 - accuracy: 0.6060
# Epoch 181/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6222 - accuracy: 0.5910
# Epoch 182/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6111 - accuracy: 0.6010
# Epoch 183/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6085 - accuracy: 0.6135
# Epoch 184/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.6085
# Epoch 185/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6058 - accuracy: 0.5960
# Epoch 186/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.5187
# Epoch 187/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6844 - accuracy: 0.5062
# Epoch 188/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6653 - accuracy: 0.5212
# Epoch 189/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6503 - accuracy: 0.5736
# Epoch 190/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6421 - accuracy: 0.5611
# Epoch 191/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.5835
# Epoch 192/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.5611
# Epoch 193/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6616 - accuracy: 0.5362
# Epoch 194/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6290 - accuracy: 0.5910
# Epoch 195/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6246 - accuracy: 0.5885
# Epoch 196/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6198 - accuracy: 0.5885
# Epoch 197/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6287 - accuracy: 0.5761
# Epoch 198/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6078 - accuracy: 0.6060
# Epoch 199/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6201 - accuracy: 0.5810
# Epoch 200/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6298 - accuracy: 0.5761

# %%
yy = np.round(model.predict(X).T[0])

# %%
df_check = X.copy()

# %%
df_check['class'] = yy

# %%
df_check1 = df_check.drop(df_check.loc[df_check['class'] == 1].index, axis=0)
df_check1.drop('class', axis=1, inplace=True)
df_check2 = df_check.drop(df_check.loc[df_check['class'] == 0].index, axis=0)
df_check2.drop('class', axis=1, inplace=True)
# Out:
# C:\Users\gruzd\anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\gruzd\anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
a, b = df_check1.to_numpy().T
plt.scatter(a, b, s=5)

aa, bb = df_check2.to_numpy().T
plt.scatter(aa, bb, s=5)

plt.show()

# %%
# The pefrormance of the model is very bad and doesn't improve significantly with increase of layers or epochs.
