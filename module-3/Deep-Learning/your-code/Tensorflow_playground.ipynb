# %% [markdown]
# # Tensorflow Hyperparameter Tuning
#
#
#
# Neural network analysis of *learning rate*, *epoch*, *optimizer*, *loss function* to optimize the neural network model.
#
# [Exercise](https://developers.google.com/machine-learning/crash-course/introduction-to-neural-networks/playground-exercises) on tuning the Tensorflow hyperpamameters in the [Tensorflow Playground](https://playground.tensorflow.org/).
#
# Goal : tuning the hyperparameters for the spiral dataset in order to reach training and test loss <0.05

# %%
from IPython.display import Image
Image("TensorFlow_challenge_results.png")
