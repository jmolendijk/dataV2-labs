# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Challenge 1 - Import and Describe the Dataset
#
# In this lab, we will use a dataset containing information about customer preferences. We will look at how much each customer spends in a year on each subcategory in the grocery store and try to find similarities using clustering.
#
# The origin of the dataset is [here](https://archive.ics.uci.edu/ml/datasets/wholesale+customers).

# %%
# loading the data:
customers = pd.read_csv('../data/Wholesale customers data.csv')
customers.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
customers.shape
# Out:
# (440, 8)

# %% [markdown]
# #### Explore the dataset with mathematical and visualization techniques. What do you find?
#
# Checklist:
#
# * What does each column mean?
# * Any categorical data to convert?
# * Any missing data to remove?
# * Column collinearity - any high correlations?
# * Descriptive statistics - any outliers to remove?
# * Column-wise data distribution - is the distribution skewed?
# * Etc.
#
# Additional info: Over a century ago, an Italian economist named Vilfredo Pareto discovered that roughly 20% of the customers account for 80% of the typical retail sales. This is called the [Pareto principle](https://en.wikipedia.org/wiki/Pareto_principle). Check if this dataset displays this characteristic.

# %%
par = customers.copy()
par['Total'] = par.iloc[:,2:].sum(axis = 1)

# %%
par = par.sort_values(by='Total', ascending=False)
par.reset_index(inplace=True)

# %%
par['cum_count'] = list(par.index)
par['sales_pct'] = par['Total'].cumsum()/par['Total'].sum()*100
par['customers_pct'] = (par['cum_count']+1)/len(par) * 100

# %%
par[par['customers_pct'] >=20].head()
# Out:
#     index  Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 87    406        1       3  25066   5010     5026    9806              1092
# 88    426        1       3  13134   9347    14316    3141              5079
# 89      9        2       3   6006  11093    18881    1159              7425
# 90    276        1       3  27901   3749     6964    4479               603
# 91     43        2       3    630  11095    23998     787              9529
#
#     Delicassen  Total  cum_count  sales_pct  customers_pct
# 87         960  46960         87  42.904839      20.000000
# 88        1894  46911         88  43.225719      20.227273
# 89        2098  46662         89  43.544896      20.454545
# 90        2503  46199         90  43.860905      20.681818
# 91          72  46111         91  44.176312      20.909091

# %%
par[par['sales_pct'] >=80].head()
# Out:
#      index  Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 251    310        1       2   7034  1492     2405   12569               299
# 252    178        1       3  11002  7075     4945    1152               120
# 253    243        1       1  11210  3576     5119     561              1682
# 254    162        1       3  15177  2024     3810    2665               232
# 255     59        1       3   6137  5360     8040     129              3084
#
#      Delicassen  Total  cum_count  sales_pct  customers_pct
# 251        1117  24916        251  80.144143      57.272727
# 252         395  24689        252  80.313020      57.500000
# 253        2398  24546        253  80.480919      57.727273
# 254         610  24518        254  80.648627      57.954545
# 255        1603  24353        255  80.815206      58.181818

# %% [markdown]
# The Pareto principle does not hold - 80% of sales are generated by 57% of customers

# %% [markdown]
# #### What does each column mean?

# %% [markdown]
# >- Fresh: annual spending (m.u.) on fresh products (Continuous);
# >- Milk: annual spending (m.u.) on milk products (Continuous);
# >- Grocery: annual spending (m.u.)on grocery products (Continuous);
# >- Frozen: annual spending (m.u.)on frozen products (Continuous)
# >- Detergents_Paper: annual spending (m.u.) on detergents and paper products (Continuous)
# >- Delicassen: annual spending (m.u.)on and delicatessen products (Continuous);
# >- Channel: customers Channel - Horeca (Hotel/Restaurant/Caf̩) or Retail channel (Nominal)
# >- Region: customers Region : Lisbon, Oporto or Other (Nominal)

# %% [markdown]
# #### Plotting variables

# %%
#there are some extreme values that need to be investigated later
customers.hist(figsize=(13,8))
plt.show()

# %%
customers[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].boxplot(figsize=(10,5))
plt.show()

# %% [markdown]
# #### Let us remove few very extreme outliers

# %%
customers = customers[(customers['Fresh']<80000) & (customers['Milk']<60000) & (customers['Grocery']<80000) & (customers['Frozen']<40000) & (customers['Delicassen']<20000)]
customers.reset_index(inplace=True)
customers.shape
# Out:
# (435, 9)

# %%
customers.head()
# Out:
#    index  Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0      0        2       3  12669  9656     7561     214              2674
# 1      1        2       3   7057  9810     9568    1762              3293
# 2      2        2       3   6353  8808     7684    2405              3516
# 3      3        1       3  13265  1196     4221    6404               507
# 4      4        2       3  22615  5410     7198    3915              1777
#
#    Delicassen
# 0        1338
# 1        1776
# 2        7844
# 3        1788
# 4        5185

# %% [markdown]
# #### Any categorical data to convert?

# %%
#all data typesa are int, as expected
customers.dtypes
# Out:
# index               int64
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
#We need to recode Region to dummy variables
customers = pd.get_dummies(customers, columns=['Region','Channel'], drop_first=True)

# %% [markdown]
# #### Any missing data to remove?

# %%
#no missing avlues
customers.isnull().sum()
# Out:
# index               0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# Region_2            0
# Region_3            0
# Channel_2           0
# dtype: int64

# %% [markdown]
# #### Column collinearity - any high correlations?

# %%
plt.figure(figsize=(8,6))
sns.heatmap(customers.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# >There are two highly correlated columns `Detergents_Paper` and `Grocery`, but lest us keep the `Detergents_Paper`

# %%
cols = ['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']

# %%
customers[cols].hist(figsize=(8,8))
plt.show()

# %% [markdown]
# #### Describe the data

# %%
customers.describe()
# Out:
#             index         Fresh          Milk       Grocery        Frozen  \
# count  435.000000    435.000000    435.000000    435.000000    435.000000
# mean   220.045977  11630.744828   5380.002299   7636.147126   2840.204598
# std    127.440626  11654.374150   5971.679533   8524.526125   3613.604752
# min      0.000000      3.000000     55.000000      3.000000     25.000000
# 25%    110.500000   3100.000000   1520.500000   2146.500000    728.500000
# 50%    221.000000   8258.000000   3610.000000   4740.000000   1517.000000
# 75%    330.500000  16718.000000   7086.000000  10431.000000   3512.500000
# max    439.000000  76237.000000  54259.000000  67298.000000  35009.000000
#
#        Detergents_Paper    Delicassen    Region_2    Region_3   Channel_2
# count        435.000000    435.000000  435.000000  435.000000  435.000000
# mean        2759.772414   1390.790805    0.105747    0.717241    0.321839
# std         4353.065698   1704.203121    0.307868    0.450859    0.467720
# ...

# %%
customers[cols].boxplot(figsize=(9,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# > There are few extreme outliers in all subproduct categories

# %% [markdown]
# #### Transform the data to mitigate outliers issue further

# %%
customers_scale = customers.copy()
customers_scale.shape
# Out:
# (435, 10)

# %%
scaler = RobustScaler(quantile_range=(10, 90))
transformer = scaler.fit(customers[cols])
customers_scale[cols] = transformer.transform(customers[cols])

# %%
#customers_scale[cols] = np.log(customers_scale[cols])

# %%
customers_scale[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].hist(figsize=(8,8))
plt.show()

# %%
customers_scale[cols].boxplot(figsize=(9,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Challenge 2 - Data Cleaning and Transformation
#
# If your conclusion from the previous challenge is the data need cleaning/transformation, do it in the cells below. However, if your conclusion is the data need not be cleaned or transformed, feel free to skip this challenge. But if you do choose the latter, please provide rationale.

# %% [markdown]
# > **Made my changes above. I corrected the skewness of the data by log transformation, this also partially solved the outliers**

# %% [markdown]
# # Challenge 3 - Data Preprocessing
#
# One problem with the dataset is the value ranges are remarkably different across various categories (e.g. `Fresh` and `Grocery` compared to `Detergents_Paper` and `Delicassen`). If you made this observation in the first challenge, you've done a great job! This means you not only completed the bonus questions in the previous Supervised Learning lab but also researched deep into [*feature scaling*](https://en.wikipedia.org/wiki/Feature_scaling). Keep on the good work!
#
# Diverse value ranges in different features could cause issues in our clustering. The way to reduce the problem is through feature scaling. We'll use this technique again with this dataset.
#
# #### We will use the `StandardScaler` from `sklearn.preprocessing` and scale our data. Read more about `StandardScaler` [here](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler).
#
# *After scaling your data, assign the transformed data to a new variable `customers_scale`.*

# %%
customers_scale[cols].isnull().sum()
# Out:
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
X = customers_scale.loc[:,cols].to_numpy()
customers_scale[cols] = pd.DataFrame(StandardScaler().fit(X).transform(X))
customers_scale[cols].shape
# Out:
# (435, 6)

# %%
customers_scale[cols].hist(figsize=(8,8))
plt.show()

# %%
customers_scale.shape
# Out:
# (435, 10)

# %% [markdown]
# # Challenge 3 - Data Clustering with K-Means
#
# Now let's cluster the data with K-Means first. Initiate the K-Means model, then fit your scaled data. In the data returned from the `.fit` method, there is an attribute called `labels_` which is the cluster number assigned to each data record. What you can do is to assign these labels back to `customers` in a new column called `customers['labels']`. Then you'll see the cluster results of the original data.

# %%
cols_class = ['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']

# %%
customers['labels_km5'] = KMeans(n_clusters=5).fit(customers_scale[cols_class]).labels_

# %% [markdown]
# Count the values in `labels`.

# %%
# Your code here:
customers.labels_km5.value_counts()
# Out:
# 1    241
# 0    109
# 2     64
# 3     18
# 4      3
# Name: labels_km5, dtype: int64

# %% [markdown]
# # Challenge 4 - Data Clustering with DBSCAN
#
# Now let's cluster the data using DBSCAN. Use `DBSCAN(eps=0.5)` to initiate the model, then fit your scaled data. In the data returned from the `.fit` method, assign the `labels_` back to `customers['labels_DBSCAN']`. Now your original data have two labels, one from K-Means and the other from DBSCAN.

# %%
# Your code here
customers['labels_DBSCAN'] = DBSCAN(eps = 0.5, min_samples = 5).fit(customers_scale[cols_class]).labels_

# %% [markdown]
# Count the values in `labels_DBSCAN`.

# %%
# Your code here
customers['labels_DBSCAN'].value_counts()
# Out:
# -1    244
#  1    169
#  2     11
#  0      7
#  3      4
# Name: labels_DBSCAN, dtype: int64

# %%
customers.head()
# Out:
#    index  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0      0  12669  9656     7561     214              2674        1338
# 1      1   7057  9810     9568    1762              3293        1776
# 2      2   6353  8808     7684    2405              3516        7844
# 3      3  13265  1196     4221    6404               507        1788
# 4      4  22615  5410     7198    3915              1777        5185
#
#    Region_2  Region_3  Channel_2  labels_km5  labels_DBSCAN
# 0         0         1          1           0             -1
# 1         0         1          1           0              2
# 2         0         1          1           0             -1
# 3         0         1          0           1             -1
# 4         0         1          1           2             -1

# %% [markdown]
# # Challenge 5 - Compare K-Means with DBSCAN
#
# Now we want to visually compare how K-Means and DBSCAN have clustered our data. We will create scatter plots for several columns. For each of the following column pairs, plot a scatter plot using `labels` and another using `labels_DBSCAN`. Put them side by side to compare. Which clustering algorithm makes better sense?
#
# Columns to visualize:
#
# * `Detergents_Paper` as X and `Milk` as y
# * `Grocery` as X and `Fresh` as y
# * `Frozen` as X and `Delicassen` as y

# %% [markdown]
# Visualize `Detergents_Paper` as X and `Milk` as y by `labels` and `labels_DBSCAN` respectively

# %%
def chrt(x,y, lab1, lab2):
    fig, ax = plt.subplots(ncols = 2, figsize=(14,5))
    ax[0].scatter(x = customers[x], y = customers[y], c = customers[lab1])
    ax[0].set_title(lab1)
    ax[0].set_xlabel(x)
    ax[0].set_ylabel(y)
    ax[1].scatter(x = customers[x], y = customers[y], c = customers[lab2])
    ax[1].set_title(lab2)
    ax[1].set_xlabel(x)
    ax[1].set_ylabel(y)
    plt.show()
    return None

# %%
# Your code here:

# %% [markdown]
# Visualize `Grocery` as X and `Fresh` as y by `labels` and `labels_DBSCAN` respectively

# %%
# Your code here:

# %% [markdown]
# Visualize `Frozen` as X and `Delicassen` as y by `labels` and `labels_DBSCAN` respectively

# %%
chrt('Detergents_Paper', 'Milk', 'labels_km5', 'labels_DBSCAN')
chrt('Grocery', 'Fresh', 'labels_km5', 'labels_DBSCAN')
chrt('Frozen', 'Delicassen', 'labels_km5', 'labels_DBSCAN')

# %% [markdown]
# Let's use a groupby to see how the mean differs between the groups. Group `customers` by `labels` and `labels_DBSCAN` respectively and compute the means for all columns.

# %%
# Your code here:
customers.groupby('labels_km5')[cols].mean()
# Out:
#                    Fresh          Milk       Grocery       Frozen  \
# labels_km5
# 0            6501.211009   9209.458716  14051.651376  1521.082569
# 1            9269.302905   2637.124481   3415.070539  1999.062241
# 2           28671.359375   3833.593750   4506.875000  8273.375000
# 3           10774.666667  22936.611111  34858.000000  2310.111111
# 4           29309.666667  14238.000000  17059.333333  5613.000000
#
#             Detergents_Paper    Delicassen
# labels_km5
# 0                5903.761468   1562.431193
# 1                 827.141079    909.248963
# 2                 629.437500   1817.281250
# 3               17070.944444   2994.888889
# 4                3363.000000  15115.333333

# %%
# Your code here:
customers.groupby('labels_DBSCAN')[cols].mean()
# Out:
#                       Fresh         Milk       Grocery       Frozen  \
# labels_DBSCAN
# -1             13848.352459  7861.397541  11240.491803  3431.909836
#  0             10491.571429  3295.285714   7213.428571   887.428571
#  1              8814.071006  1863.591716   2464.041420  2049.000000
#  2              4158.727273  6915.272727   9301.181818  1185.090909
#  3             17902.750000  2009.500000   2453.500000  8143.500000
#
#                Detergents_Paper   Delicassen
# labels_DBSCAN
# -1                  4339.241803  1897.901639
#  0                  3200.428571   443.428571
#  1                   443.668639   690.142012
#  2                  3880.181818  1666.727273
#  3                   415.250000   958.500000

# %% [markdown]
# Which algorithm appears to perform better?

# %% [markdown]
# >**Answer**: Kmeans does a better job at separting the classes, hwever both algorythms suffer from outliers in our dataset

# %% [markdown]
# # Bonus Challenge 2 - Changing K-Means Number of Clusters
#
# As we mentioned earlier, we don't need to worry about the number of clusters with DBSCAN because it automatically decides that based on the parameters we send to it. But with K-Means, we have to supply the `n_clusters` param (if you don't supply `n_clusters`, the algorithm will use `8` by default). You need to know that the optimal number of clusters differs case by case based on the dataset. K-Means can perform badly if the wrong number of clusters is used.
#
# In advanced machine learning, data scientists try different numbers of clusters and evaluate the results with statistical measures (read [here](https://en.wikipedia.org/wiki/Cluster_analysis#External_evaluation)). We are not using statistical measures today but we'll use our eyes instead. In the cells below, experiment with different number of clusters and visualize with scatter plots. What number of clusters seems to work best for K-Means?

# %%
customers['labels_km4'] = KMeans(n_clusters=4).fit(customers_scale[cols]).labels_
customers['labels_km6'] = KMeans(n_clusters=6).fit(customers_scale[cols]).labels_

# %%
chrt('Detergents_Paper', 'Milk', 'labels_km4', 'labels_km6')
chrt('Grocery', 'Fresh', 'labels_km4', 'labels_km6')
chrt('Frozen', 'Delicassen', 'labels_km4', 'labels_km6')

# %%
customers.labels_km4.value_counts()
# Out:
# 1    272
# 0     97
# 2     57
# 3      9
# Name: labels_km4, dtype: int64

# %%
customers.labels_km6.value_counts()
# Out:
# 0    239
# 1     93
# 2     47
# 3     45
# 4      8
# 5      3
# Name: labels_km6, dtype: int64

# %% [markdown]
# >**Answer** Further increase or decrease in number of clusters might not be the best as it separates some very small groups

# %% [markdown]
# # Bonus Challenge 3 - Changing DBSCAN `eps` and `min_samples`
#
# Experiment changing the `eps` and `min_samples` params for DBSCAN. See how the results differ with scatter plot visualization.

# %%
customers['labels_DBSCAN06n5'] = DBSCAN(eps = 0.6, min_samples = 5).fit(customers_scale[cols]).labels_
customers['labels_DBSCAN07n5'] = DBSCAN(eps = 0.7, min_samples = 5).fit(customers_scale[cols]).labels_

# %%
chrt('Detergents_Paper', 'Milk', 'labels_DBSCAN06n5', 'labels_DBSCAN07n5')
chrt('Grocery', 'Fresh', 'labels_DBSCAN06n5', 'labels_DBSCAN07n5')
chrt('Frozen', 'Delicassen', 'labels_DBSCAN06n5', 'labels_DBSCAN07n5')

# %%
customers['labels_DBSCAN05n4'] = DBSCAN(eps = 0.5, min_samples = 4).fit(customers_scale[cols]).labels_
customers['labels_DBSCAN05n6'] = DBSCAN(eps = 0.5, min_samples = 6).fit(customers_scale[cols]).labels_

# %%
chrt('Detergents_Paper', 'Milk', 'labels_DBSCAN05n4', 'labels_DBSCAN05n6')
chrt('Grocery', 'Fresh', 'labels_DBSCAN05n4', 'labels_DBSCAN05n6')
chrt('Frozen', 'Delicassen', 'labels_DBSCAN05n4', 'labels_DBSCAN05n6')

# %% [markdown]
# >**Answer** DBSCAN remains quite noisy

# %% [markdown]
# > **Comment:** The potential solution to create a better cluster solution is to transform the features, e.g. instead of categories use share of spend and total spend as additional feature.
