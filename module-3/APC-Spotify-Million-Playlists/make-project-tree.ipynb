# %%
import os

# %%
from pathlib import Path

class DisplayablePath(object):
    display_filename_prefix_middle = '├──'
    display_filename_prefix_last = '└──'
    display_parent_prefix_middle = '    '
    display_parent_prefix_last = '│   '

    def __init__(self, path, parent_path, is_last):
        self.path = Path(str(path))
        self.parent = parent_path
        self.is_last = is_last
        if self.parent:
            self.depth = self.parent.depth + 1
        else:
            self.depth = 0

    @property
    def displayname(self):
        if self.path.is_dir():
            return self.path.name + '/'
        return self.path.name

    @classmethod
    def make_tree(cls, root, parent=None, is_last=False, criteria=None):
        root = Path(str(root))
        criteria = criteria or cls._default_criteria

        displayable_root = cls(root, parent, is_last)
        yield displayable_root

        children = sorted(list(path
                               for path in root.iterdir()
                               if criteria(path)),
                          key=lambda s: str(s).lower())
        count = 1
        for path in children:
            is_last = count == len(children)
            if path.is_dir():
                yield from cls.make_tree(path,
                                         parent=displayable_root,
                                         is_last=is_last,
                                         criteria=criteria)
            else:
                yield cls(path, displayable_root, is_last)
            count += 1

    @classmethod
    def _default_criteria(cls, path):
        return True

    @property
    def displayname(self):
        if self.path.is_dir():
            return self.path.name + '/'
        return self.path.name

    def displayable(self):
        if self.parent is None:
            return self.displayname

        _filename_prefix = (self.display_filename_prefix_last
                            if self.is_last
                            else self.display_filename_prefix_middle)

        parts = ['{!s} {!s}'.format(_filename_prefix,
                                    self.displayname)]

        parent = self.parent
        while parent and parent.parent is not None:
            parts.append(self.display_parent_prefix_middle
                         if parent.is_last
                         else self.display_parent_prefix_last)
            parent = parent.parent

        return ''.join(reversed(parts))

# %%
p = os.getcwd()

# %%
ignore = ['data-processed',  'dataset', 'Kaggle-RecSys-101', 'dataset-original']
paths = DisplayablePath.make_tree(
    Path(p), 
    criteria=lambda path: True if path.name not in (ignore) else False)
for path in paths:
    print(path.displayable())
# Out:
# RecSys-Spotify-Million-Playlists/
# ├── .gitignore
# ├── .ipynb_checkpoints/
# │   └── make-project-tree-checkpoint.ipynb
# ├── credentials/
# │   ├── .ipynb_checkpoints/
# │   │   └── credentials-checkpoint.ipynb
# │   └── credentials.ipynb
# ├── data-processing-notebooks/
# │   ├── .ipynb_checkpoints/
# │   │   ├── collaborative-filtering-data-preparation-checkpoint.ipynb
# │   │   ├── collaborative-filtering-data-preparation-scale-down-checkpoint.ipynb
# │   │   ├── dictionaries_tracks_desc_pids-checkpoint.ipynb
# │   │   ├── explore-with-provided-scripts-checkpoint.ipynb
# │   │   ├── mpd-slice-combine-checkpoint.ipynb
# │   │   ├── spotify-api-genre-checkpoint.ipynb
# │   │   ├── spotify-api-track-checkpoint.ipynb
# │   │   └── track-uri-combine-checkpoint.ipynb
# │   ├── collaborative-filtering-data-preparation-scale-down.ipynb
# │   ├── collaborative-filtering-data-preparation.ipynb
# │   ├── dictionaries_tracks_desc_pids.ipynb
# │   ├── explore-with-provided-scripts.ipynb
# │   ├── mpd-slice-combine.ipynb
# │   ├── spotify-api-genre.ipynb
# │   ├── spotify-api-track.ipynb
# │   └── track-uri-combine.ipynb
# ├── evaluation/
# │   ├── ALS_binary_topn_500_10000.csv
# │   ├── ALS_pos_topn_500_10000.csv
# │   ├── CB_audio_features_1000.csv
# │   ├── summary.csv
# │   ├── SVD_binary100_10000.csv
# │   ├── SVD_binary50_10000.csv
# │   ├── SVD_pos100_10000.csv
# │   └── SVD_pos50_10000.csv
# ├── make-project-tree.ipynb
# ├── modeling-notebooks/
# │   ├── .ipynb_checkpoints/
# │   │   ├── CB00_audio_features-checkpoint.ipynb
# │   │   ├── CB01_Audio_features_genres_data_preparation-checkpoint.ipynb
# │   │   ├── CB01_Audio_features_genres_model-checkpoint.ipynb
# │   │   ├── CF00_Memory_based_scaled_down-checkpoint.ipynb
# │   │   ├── CF01_Model_Surprise_50pct_sample-checkpoint.ipynb
# │   │   ├── CF01_Model_Surprise_scaled_down-checkpoint.ipynb
# │   │   ├── CF02_Model_ALS_Implicit_binary-checkpoint.ipynb
# │   │   ├── CF02_Model_ALS_Implicit_pos-checkpoint.ipynb
# │   │   ├── CF02_Model_ALS_Implicit_pos_full_data-checkpoint.ipynb
# │   │   ├── CF03_Model_SVD_sparse_matrix_binary_ratings -checkpoint.ipynb
# │   │   ├── CF03_Model_SVD_sparse_matrix_pos_ratings-checkpoint.ipynb
# │   │   ├── evaluation-checkpoint.ipynb
# │   │   └── evaluation-summary-checkpoint.ipynb
# │   ├── CB00_audio_features.ipynb
# │   ├── CB01_Audio_features_genres_data_preparation.ipynb
# │   ├── CB01_Audio_features_genres_model.ipynb
# │   ├── CF00_Memory_based_scaled_down.ipynb
# │   ├── CF01_Model_Surprise_50pct_sample.ipynb
# │   ├── CF01_Model_Surprise_scaled_down.ipynb
# │   ├── CF02_Model_ALS_Implicit_binary.ipynb
# │   ├── CF02_Model_ALS_Implicit_pos.ipynb
# │   ├── CF02_Model_ALS_Implicit_pos_full_data.ipynb
# │   ├── CF03_Model_SVD_sparse_matrix_binary_ratings .ipynb
# │   ├── CF03_Model_SVD_sparse_matrix_pos_ratings.ipynb
# │   ├── evaluation-summary.ipynb
# │   ├── evaluation.ipynb
# │   └── tenor.gif
# ├── README.md
# └── src/
#     ├── .ipynb_checkpoints/
#     └── __pycache__/
#         └── imp.cpython-38.pyc
