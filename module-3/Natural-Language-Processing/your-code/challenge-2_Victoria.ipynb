# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located in the lab directory named `Sentiment140.csv.zip`. You need to unzip it into a `.csv` file. Then in the cell below, load and explore the data.
#
# *Notes:*
#
# * The dataset was downloaded from [Kaggle](https://www.kaggle.com/kazanova/sentiment140). We made a slight change on the original data so that each column has a label.
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here
import pandas as pd
data = pd.read_csv('/Users/victoria/Downloads/Sentiment140.csv')

# %%
short = data.sample(n=20000)

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# your code here
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords

def clean_up(s):
    new = s.lower()
    new1 = re.sub(r'http\S+', '', new)
    new2 = re.sub(r'[^a-z]', ' ', new1)
    return (new2.lstrip().rstrip())

def tokenize(s):
    words = word_tokenize(s)
    return words

def stem_and_lemmatize(l):
    stem = [PorterStemmer().stem(w) for w in l]
    lem = [WordNetLemmatizer().lemmatize(w) for w in stem]
    return lem

def remove_stopwords(l):
    stop_words = set(stopwords.words('english'))
    filtered = [w for w in l if not w in stop_words]
    return filtered


short['text_processed'] = short['text'].apply(clean_up)

# %%
short['text_processed'] = short['text_processed'].apply(tokenize)
short['text_processed'] = short['text_processed'].apply(stem_and_lemmatize)
short['text_processed'] = short['text_processed'].apply(remove_stopwords)

# %%
short
# Out:
#          target         ids                          date      flag  \
# 1556844       4  2185465848  Mon Jun 15 17:25:25 PDT 2009  NO_QUERY
# 1108152       4  1971692164  Sat May 30 07:41:02 PDT 2009  NO_QUERY
# 761817        0  2297457105  Tue Jun 23 10:27:56 PDT 2009  NO_QUERY
# 1042779       4  1957241217  Thu May 28 23:55:27 PDT 2009  NO_QUERY
# 184943        0  1967842177  Fri May 29 20:18:31 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 24658         0  1558071614  Sun Apr 19 07:09:38 PDT 2009  NO_QUERY
# 1006061       4  1880572256  Fri May 22 01:43:15 PDT 2009  NO_QUERY
# 1395427       4  2053723487  Sat Jun 06 05:30:20 PDT 2009  NO_QUERY
# 909896        4  1751395180  Sat May 09 19:20:57 PDT 2009  NO_QUERY
# 1495539       4  2069955050  Sun Jun 07 16:50:17 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 1556844         kinslley      can NOT wait for jilll &amp; jojo to come up
# 1108152  classicromantic                back from devon  the sheep loved us
# 761817       LeahBraemel  @VictoriaDahl personally I find it a hard sell...
# 1042779        Mhowell68  Morning all. What a gorgeous day. Far too good...
# 184943          natycake  @KhloeKardashian: I wish I had long distance s...
# ...                  ...                                                ...
# 24658            spcshp1                                  Long travel day.
# 1006061         bridugan  @brianlogandales I love Rock-a-Doodle!!! That ...
# 1395427        donnybrat  @rking27 http://twitpic.com/6qlzf - where's my...
# 909896          intanzie  Happy Mothers May to my Mak   Love you always!...
# 1495539      KimberScott  @ericmeerkamper I don't think you have to worr...
#
#                                             text_processed
# 1556844                     [wait, jilll, amp, jojo, come]
# 1108152                      [back, devon, sheep, love, u]
# 761817   [victoriadahl, person, find, hard, sell, unles...
# 1042779              [morn, gorgeou, day, far, good, work]
# 184943   [khloekardashian, wish, long, distanc, could, ...
# ...                                                    ...
# 24658                                  [long, travel, day]
# 1006061  [brianlogandal, love, rock, doodl, movi, amazi...
# 1395427                                [rking, place, set]
# 909896        [happi, mother, may, mak, love, alway, xoxo]
# 1495539  [ericmeerkamp, think, worri, sinc, ipod, sing,...
#
# [20000 rows x 7 columns]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here
all_words = []
for line in short.text_processed:
    for x in line:
        all_words.append(x)
len(all_words)
# Out:
# 155489

# %%
# all_words = nltk.FreqDist(all_words)
# all_words = dict(all_words)
# popular = list(dict(sorted(all_words.items(), key=lambda x: x[1], reverse=True)).keys())
# popular = popular[:5000]

# %%
all_words1 = nltk.FreqDist(all_words)
#Get 3000 most common words
word_tuples = all_words1.most_common(5000)
word_features = [x[0] for x in word_tuples]

# %%
len(all_words)
# Out:
# 155489

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

test = short[['text_processed','target']]
documents = [(row[1]['text_processed'], row[1]['target']) for row in test.iterrows()]

def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)
        
    return features

featuresets = [(find_features(tweet),category) for (tweet,category) in documents]

# %%
featuresets[0]
# Out:
# ({'go': False,
#   'day': False,
#   'get': False,
#   'wa': False,
#   'thi': False,
#   'good': False,
#   'work': False,
#   'love': False,
#   'like': False,
#   'quot': False,
#   'got': False,
#   'u': False,
#   'today': False,
#   'time': False,
#   'miss': False,
#   'know': False,
#   'thank': False,
#   'lol': False,
#   'one': False,
#   'want': False,
#   'back': False,
#   'feel': False,
#   'see': False,
#   'im': False,
#   'realli': False,
#   'amp': True,
#   'think': False,
#   'make': False,
#   'hope': False,
#   'well': False,
#   'watch': False,
#   'need': False,
#   'night': False,
#   'na': False,
#   'ha': False,
#   'still': False,
#   'look': False,
#   'oh': False,
#   'home': False,
#   'new': False,
#   'come': True,
#   'morn': False,
#   'wish': False,
#   'last': False,
#   'much': False,
#   'twitter': False,
#   'tomorrow': False,
#   'haha': False,
#   'wait': True,
#   'great': False,
#   'sad': False,
#   'week': False,
#   'follow': False,
#   'right': False,
#   'sleep': False,
#   'would': False,
#   'whi': False,
#   'fun': False,
#   'tonight': False,
#   'tri': False,
#   'hi': False,
#   'happi': False,
#   'hate': False,
#   'bad': False,
#   'onli': False,
#   'say': False,
#   'way': False,
#   'veri': False,
#   'friend': False,
#   'even': False,
#   'tweet': False,
#   'thing': False,
#   'sorri': False,
#   'nice': False,
#   'gon': False,
#   'though': False,
#   'could': False,
#   'guy': False,
#   'play': False,
#   'take': False,
#   'better': False,
#   'weekend': False,
#   'bed': False,
#   'school': False,
#   'hour': False,
#   'start': False,
#   'ye': False,
#   'x': False,
#   'peopl': False,
#   'final': False,
#   'soon': False,
#   'yeah': False,
#   'show': False,
#   'awesom': False,
#   'littl': False,
#   'next': False,
#   'never': False,
#   'dont': False,
#   'let': False,
#   'lt': False,
#   'sick': False,
#   'long': False,
#   'bore': False,
#   'hey': False,
#   'cant': False,
#   'life': False,
#   'movi': False,
#   'tire': False,
#   'year': False,
#   'head': False,
#   'plea': False,
#   'anoth': False,
#   'find': False,
#   'wan': False,
#   'use': False,
#   'girl': False,
#   'cool': False,
#   'call': False,
#   'alway': False,
#   'done': False,
#   'someth': False,
#   'everyon': False,
#   'man': False,
#   'eat': False,
#   'hurt': False,
#   'sure': False,
#   'ani': False,
#   'read': False,
#   'leav': False,
#   'game': False,
#   'rain': False,
#   'ok': False,
#   'live': False,
#   'phone': False,
#   'best': False,
#   'keep': False,
#   'suck': False,
#   'help': False,
#   'n': False,
#   'first': False,
#   'readi': False,
#   'alreadi': False,
#   'sound': False,
#   'guess': False,
#   'befor': False,
#   'pretti': False,
#   'made': False,
#   'ever': False,
#   'talk': False,
#   'song': False,
#   'ur': False,
#   'becaus': False,
#   'b': False,
#   'excit': False,
#   'enjoy': False,
#   'babi': False,
#   'went': False,
#   'hous': False,
#   'pic': False,
#   'summer': False,
#   'omg': False,
#   'lot': False,
#   'earli': False,
#   'mayb': False,
#   'someon': False,
#   'bit': False,
#   'amaz': False,
#   'ya': False,
#   'yay': False,
#   'tell': False,
#   'noth': False,
#   'yet': False,
#   'left': False,
#   'lost': False,
#   'check': False,
#   'finish': False,
#   'r': False,
#   'hot': False,
#   'old': False,
#   'listen': False,
#   'hear': False,
#   'two': False,
#   'give': False,
#   'late': False,
#   'mom': False,
#   'away': False,
#   'later': False,
#   'stuff': False,
#   'parti': False,
#   'also': False,
#   'birthday': False,
#   'car': False,
#   'meet': False,
#   'thought': False,
#   'damn': False,
#   'stay': False,
#   'w': False,
#   'wonder': False,
#   'mean': False,
#   'saw': False,
#   'might': False,
#   'wow': False,
#   'big': False,
#   'glad': False,
#   'actual': False,
#   'end': False,
#   'ta': False,
#   'stop': False,
#   'put': False,
#   'th': False,
#   'sinc': False,
#   'happen': False,
#   'run': False,
#   'sunday': False,
#   'weather': False,
#   'com': False,
#   'doe': False,
#   'world': False,
#   'sun': False,
#   'anyth': False,
#   'hard': False,
#   'monday': False,
#   'yesterday': False,
#   'kid': False,
#   'friday': False,
#   'busi': False,
#   'poor': False,
#   'cri': False,
#   'mani': False,
#   'beauti': False,
#   'die': False,
#   'shop': False,
#   'around': False,
#   'p': False,
#   'shit': False,
#   'woke': False,
#   'dinner': False,
#   'exam': False,
#   'video': False,
#   'gone': False,
#   'food': False,
#   'studi': False,
#   'ugh': False,
#   'tho': False,
#   'fuck': False,
#   'iphon': False,
#   'job': False,
#   'famili': False,
#   'said': False,
#   'everyth': False,
#   'music': False,
#   'lunch': False,
#   'luck': False,
#   'move': False,
#   'must': False,
#   'okay': False,
#   'plan': False,
#   'anyon': False,
#   'believ': False,
#   'post': False,
#   'may': False,
#   'dream': False,
#   'sweet': False,
#   'ill': False,
#   'funni': False,
#   'god': False,
#   'outsid': False,
#   'forward': False,
#   'cold': False,
#   'win': False,
#   'mine': False,
#   'updat': False,
#   'place': False,
#   'far': False,
#   'seem': False,
#   'total': False,
#   'boy': False,
#   'room': False,
#   'found': False,
#   'class': False,
#   'chang': False,
#   'drink': False,
#   'almost': False,
#   'ask': False,
#   'person': False,
#   'buy': False,
#   'turn': False,
#   'hair': False,
#   'without': False,
#   'welcom': False,
#   'el': False,
#   'aw': False,
#   'c': False,
#   'hahaha': False,
#   'till': False,
#   'everi': False,
#   'brother': False,
#   'xx': False,
#   'book': False,
#   'aww': False,
#   'onc': False,
#   'free': False,
#   'month': False,
#   'gt': False,
#   'eye': False,
#   'probabl': False,
#   'rememb': False,
#   'coffe': False,
#   'rest': False,
#   'wrong': False,
#   'idea': False,
#   'dog': False,
#   'pictur': False,
#   'mother': False,
#   'walk': False,
#   'didnt': False,
#   'hehe': False,
#   'send': False,
#   'alon': False,
#   'caus': False,
#   'drive': False,
#   'write': False,
#   'clean': False,
#   'hit': False,
#   'real': False,
#   'dad': False,
#   'bring': False,
#   'hug': False,
#   'sooo': False,
#   'half': False,
#   'beach': False,
#   'wake': False,
#   'word': False,
#   'money': False,
#   'tv': False,
#   'train': False,
#   'pain': False,
#   'sit': False,
#   'kinda': False,
#   'text': False,
#   'link': False,
#   'cute': False,
#   'fail': False,
#   'super': False,
#   'news': False,
#   'rock': False,
#   'blog': False,
#   'mind': False,
#   'part': False,
#   'came': False,
#   'forgot': False,
#   'either': False,
#   'name': False,
#   'heart': False,
#   'headach': False,
#   'seen': False,
#   'ladi': False,
#   'pas': False,
#   'ago': False,
#   'whole': False,
#   'comput': False,
#   'least': False,
#   'hell': False,
#   'offic': False,
#   'stupid': False,
#   'worri': False,
#   'sometim': False,
#   'crazi': False,
#   'danc': False,
#   'anyway': False,
#   'sister': False,
#   'e': False,
#   'enough': False,
#   'minut': False,
#   'trip': False,
#   'btw': False,
#   'g': False,
#   'awww': False,
#   'fan': False,
#   'hang': False,
#   'shower': False,
#   'problem': False,
#   'open': False,
#   'l': False,
#   'kill': False,
#   'break': False,
#   'interest': False,
#   'www': False,
#   'goin': False,
#   'st': False,
#   'true': False,
#   'hello': False,
#   'saturday': False,
#   'ice': False,
#   'stuck': False,
#   'k': False,
#   'site': False,
#   'took': False,
#   'face': False,
#   'visit': False,
#   'citi': False,
#   'add': False,
#   'boo': False,
#   'pay': False,
#   'fine': False,
#   'pick': False,
#   'homework': False,
#   'serious': False,
#   'close': False,
#   'anymor': False,
#   'foot': False,
#   'concert': False,
#   'spend': False,
#   'v': False,
#   'kind': False,
#   'told': False,
#   'pm': False,
#   'quit': False,
#   'care': False,
#   'dear': False,
#   'abl': False,
#   'repli': False,
#   'full': False,
#   'cuz': False,
#   'email': False,
#   'nite': False,
#   'heard': False,
#   'ipod': False,
#   'ah': False,
#   'lmao': False,
#   'til': False,
#   'cours': False,
#   'wont': False,
#   'photo': False,
#   'vote': False,
#   'soo': False,
#   'le': False,
#   'congrat': False,
#   'sunni': False,
#   'fb': False,
#   'onlin': False,
#   'cut': False,
#   'tea': False,
#   'goodnight': False,
#   'cook': False,
#   'learn': False,
#   'asleep': False,
#   'tour': False,
#   'decid': False,
#   'graduat': False,
#   'join': False,
#   'sign': False,
#   'fall': False,
#   'forget': False,
#   'facebook': False,
#   'answer': False,
#   'hand': False,
#   'internet': False,
#   'june': False,
#   'team': False,
#   'store': False,
#   'sigh': False,
#   'breakfast': False,
#   'xd': False,
#   'side': False,
#   'set': False,
#   'stori': False,
#   'definit': False,
#   'coupl': False,
#   'awak': False,
#   'second': False,
#   'hungri': False,
#   'f': False,
#   'favorit': False,
#   'agre': False,
#   'togeth': False,
#   'bout': False,
#   'cat': False,
#   'dead': False,
#   'min': False,
#   'goe': False,
#   'ride': False,
#   'sing': False,
#   'bye': False,
#   'scare': False,
#   'nd': False,
#   'mum': False,
#   'season': False,
#   'instead': False,
#   'h': False,
#   'drop': False,
#   'usual': False,
#   'download': False,
#   'lil': False,
#   'catch': False,
#   'fli': False,
#   'tommcfli': False,
#   'ticket': False,
#   'save': False,
#   'sore': False,
#   'mileycyru': False,
#   'short': False,
#   'test': False,
#   'red': False,
#   'complet': False,
#   'jealou': False,
#   'lucki': False,
#   'film': False,
#   'ahh': False,
#   'bought': False,
#   'yea': False,
#   'pool': False,
#   'list': False,
#   'annoy': False,
#   'point': False,
#   'mr': False,
#   'offici': False,
#   'vacat': False,
#   'wed': False,
#   'wear': False,
#   'laptop': False,
#   'reason': False,
#   'soooo': False,
#   'chocol': False,
#   'nope': False,
#   'fix': False,
#   'dude': False,
#   'mad': False,
#   'broke': False,
#   'high': False,
#   'moment': False,
#   'la': False,
#   'em': False,
#   'white': False,
#   'window': False,
#   'black': False,
#   'star': False,
#   'episod': False,
#   'tuesday': False,
#   'nap': False,
#   'worth': False,
#   'park': False,
#   'differ': False,
#   'suppos': False,
#   'yo': False,
#   'ive': False,
#   'ppl': False,
#   'ate': False,
#   'revis': False,
#   'smile': False,
#   'rather': False,
#   'upload': False,
#   'afternoon': False,
#   'support': False,
#   'leg': False,
#   'laugh': False,
#   'bet': False,
#   'bodi': False,
#   'realiz': False,
#   'hmm': False,
#   'date': False,
#   'messag': False,
#   'air': False,
#   'mood': False,
#   'beer': False,
#   'order': False,
#   'town': False,
#   'figur': False,
#   'co': False,
#   'hr': False,
#   'fell': False,
#   'sadli': False,
#   'comment': False,
#   'crap': False,
#   'uk': False,
#   'bike': False,
#   'youtub': False,
#   'english': False,
#   'chill': False,
#   'slow': False,
#   'app': False,
#   'pack': False,
#   'album': False,
#   'gym': False,
#   'type': False,
#   'terribl': False,
#   'shall': False,
#   'cake': False,
#   'relax': False,
#   'cream': False,
#   'weird': False,
#   'math': False,
#   'appl': False,
#   'holiday': False,
#   'power': False,
#   'page': False,
#   'chat': False,
#   'green': False,
#   'moon': False,
#   'lose': False,
#   'water': False,
#   'lie': False,
#   'ddlovato': False,
#   'websit': False,
#   'church': False,
#   'perfect': False,
#   'knew': False,
#   'share': False,
#   'special': False,
#   'freak': False,
#   'apart': False,
#   'fit': False,
#   'juli': False,
#   'beat': False,
#   'possibl': False,
#   'cheer': False,
#   'throat': False,
#   'garden': False,
#   'broken': False,
#   'absolut': False,
#   'award': False,
#   'age': False,
#   'account': False,
#   'horribl': False,
#   'chanc': False,
#   'sent': False,
#   'unfortun': False,
#   'depress': False,
#   'dress': False,
#   'art': False,
#   'count': False,
#   'forev': False,
#   'search': False,
#   'fight': False,
#   'state': False,
#   'sat': False,
#   'bless': False,
#   'da': False,
#   'wtf': False,
#   'radio': False,
#   'band': False,
#   'insid': False,
#   'sunshin': False,
#   'storm': False,
#   'due': False,
#   'isnt': False,
#   'son': False,
#   'mommi': False,
#   'small': False,
#   'present': False,
#   'bbq': False,
#   'shoot': False,
#   'understand': False,
#   'boyfriend': False,
#   'luv': False,
#   'question': False,
#   'shot': False,
#   'fast': False,
#   'touch': False,
#   'shame': False,
#   'drunk': False,
#   'track': False,
#   'current': False,
#   'road': False,
#   'alot': False,
#   'except': False,
#   'bill': False,
#   'david': False,
#   'fair': False,
#   'cancel': False,
#   'appar': False,
#   'stand': False,
#   'warm': False,
#   'thx': False,
#   'bum': False,
#   'stress': False,
#   'mac': False,
#   'front': False,
#   'huge': False,
#   'spent': False,
#   'j': False,
#   'connect': False,
#   'disappoint': False,
#   'record': False,
#   'celebr': False,
#   'wat': False,
#   'arriv': False,
#   'cloth': False,
#   'matter': False,
#   'wash': False,
#   'past': False,
#   'paper': False,
#   'googl': False,
#   'number': False,
#   'bro': False,
#   'addict': False,
#   'dure': False,
#   'notic': False,
#   'wors': False,
#   'chicken': False,
#   'sleepi': False,
#   'pray': False,
#   'pizza': False,
#   'project': False,
#   'doctor': False,
#   'paint': False,
#   'card': False,
#   'shirt': False,
#   'club': False,
#   'line': False,
#   'kick': False,
#   'french': False,
#   'breath': False,
#   'cousin': False,
#   'longer': False,
#   'whatev': False,
#   'yep': False,
#   'xxx': False,
#   'load': False,
#   'thursday': False,
#   'gorgeou': False,
#   'surpris': False,
#   'yummi': False,
#   'pop': False,
#   'myspac': False,
#   'especi': False,
#   'low': False,
#   'kiss': False,
#   'camera': False,
#   'screen': False,
#   'pc': False,
#   'gave': False,
#   'product': False,
#   'fact': False,
#   'bday': False,
#   'singl': False,
#   'via': False,
#   'remind': False,
#   'lame': False,
#   'group': False,
#   'tast': False,
#   'sim': False,
#   'although': False,
#   'travel': False,
#   'earlier': False,
#   'followfriday': False,
#   'choic': False,
#   'jona': False,
#   'swear': False,
#   'fri': False,
#   'gut': False,
#   'seriou': False,
#   'tan': False,
#   'pull': False,
#   'upset': False,
#   'peac': False,
#   'jonasbroth': False,
#   'exhaust': False,
#   'safe': False,
#   'vega': False,
#   'exactli': False,
#   'london': False,
#   'expect': False,
#   'hmmm': False,
#   'husband': False,
#   'vip': False,
#   'doesnt': False,
#   'mail': False,
#   'hospit': False,
#   'ear': False,
#   'ball': False,
#   'angel': False,
#   'parent': False,
#   'dm': False,
#   'san': False,
#   'along': False,
#   'twilight': False,
#   'kate': False,
#   'bar': False,
#   'market': False,
#   'pink': False,
#   'bu': False,
#   'top': False,
#   'dvd': False,
#   'goodby': False,
#   'plu': False,
#   'glass': False,
#   'wit': False,
#   'manag': False,
#   'return': False,
#   'shoe': False,
#   'begin': False,
#   'flight': False,
#   'colleg': False,
#   'mention': False,
#   'box': False,
#   'design': False,
#   'easi': False,
#   'fish': False,
#   'becom': False,
#   'blue': False,
#   'wine': False,
#   'bag': False,
#   'tom': False,
#   'releas': False,
#   'jon': False,
#   'normal': False,
#   'mess': False,
#   'taken': False,
#   'servic': False,
#   'hubbi': False,
#   'roll': False,
#   'father': False,
#   'hold': False,
#   'crash': False,
#   'view': False,
#   'ju': False,
#   'jump': False,
#   'issu': False,
#   'worst': False,
#   'wasnt': False,
#   'inde': False,
#   'gettin': False,
#   'sort': False,
#   'recommend': False,
#   'sell': False,
#   'huh': False,
#   'magic': False,
#   'smell': False,
#   'rip': False,
#   'yr': False,
#   'havent': False,
#   'finger': False,
#   'miley': False,
#   'idk': False,
#   'dark': False,
#   'extra': False,
#   'mcfli': False,
#   'block': False,
#   'stomach': False,
#   'fire': False,
#   'ff': False,
#   'confus': False,
#   'memori': False,
#   'bloodi': False,
#   'proud': False,
#   'pre': False,
#   'felt': False,
#   'tummi': False,
#   'yum': False,
#   'chicago': False,
#   'guitar': False,
#   'bitch': False,
#   'round': False,
#   'mtv': False,
#   'light': False,
#   'mall': False,
#   'yup': False,
#   'death': False,
#   'swim': False,
#   'silli': False,
#   'schedul': False,
#   'chees': False,
#   'buddi': False,
#   'laker': False,
#   'race': False,
#   'compani': False,
#   'lay': False,
#   'major': False,
#   'woman': False,
#   'profil': False,
#   'result': False,
#   'si': False,
#   'countri': False,
#   'door': False,
#   'three': False,
#   'daddi': False,
#   'arm': False,
#   'wife': False,
#   'limit': False,
#   'gosh': False,
#   'quiet': False,
#   'copi': False,
#   'watchin': False,
#   'ad': False,
#   'hotel': False,
#   'ahhh': False,
#   'lone': False,
#   'mate': False,
#   'flu': False,
#   'interview': False,
#   'expens': False,
#   'tear': False,
#   'delet': False,
#   'throw': False,
#   'cd': False,
#   'island': False,
#   'babe': False,
#   'studio': False,
#   'quick': False,
#   'nose': False,
#   'blood': False,
#   'assign': False,
#   'disney': False,
#   'fantast': False,
#   'milk': False,
#   'meant': False,
#   'speak': False,
#   'met': False,
#   'near': False,
#   'airport': False,
#   'taylor': False,
#   'nobodi': False,
#   'wast': False,
#   'coz': False,
#   'blast': False,
#   'drama': False,
#   'adam': False,
#   'plane': False,
#   'fml': False,
#   'daughter': False,
#   'alright': False,
#   'piss': False,
#   'energi': False,
#   'prob': False,
#   'prepar': False,
#   'men': False,
#   'de': False,
#   'behind': False,
#   'cover': False,
#   'ran': False,
#   'ouch': False,
#   'entir': False,
#   'xo': False,
#   'ohh': False,
#   'danni': False,
#   'machin': False,
#   'fever': False,
#   'appreci': False,
#   'impress': False,
#   'jame': False,
#   'cooki': False,
#   'bummer': False,
#   'fat': False,
#   'kno': False,
#   'nick': False,
#   'jb': False,
#   'jordanknight': False,
#   'doin': False,
#   'hangov': False,
#   'hah': False,
#   'germani': False,
#   'spam': False,
#   'web': False,
#   'child': False,
#   'network': False,
#   'random': False,
#   'grow': False,
#   'cross': False,
#   'heh': False,
#   'info': False,
#   'ruin': False,
#   'kati': False,
#   'often': False,
#   'lazi': False,
#   'australia': False,
#   'joke': False,
#   'thanx': False,
#   'note': False,
#   'everybodi': False,
#   'imisscath': False,
#   'bird': False,
#   'raini': False,
#   'west': False,
#   'burn': False,
#   'cup': False,
#   'ca': False,
#   'delici': False,
#   'entertain': False,
#   'sexi': False,
#   'john': False,
#   'color': False,
#   'holi': False,
#   'ooh': False,
#   'stick': False,
#   'practic': False,
#   'voic': False,
#   'slept': False,
#   'burnt': False,
#   'lead': False,
#   'dang': False,
#   'mike': False,
#   'cough': False,
#   'toe': False,
#   'hero': False,
#   'paid': False,
#   'shut': False,
#   'egg': False,
#   'crack': False,
#   'board': False,
#   ...},
#  4)

# %%
len(featuresets)
# Out:
# 20000

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# mistake
training_set = featuresets[:4000]
testing_set = featuresets[4000:]
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                     sick = True                0 : 4      =     16.9 : 1.0
#                      ugh = True                0 : 4      =     16.9 : 1.0
#                      cri = True                0 : 4      =     14.2 : 1.0
#                      sad = True                0 : 4      =     12.6 : 1.0
#                     gone = True                0 : 4      =     12.3 : 1.0
#                   welcom = True                4 : 0      =     11.7 : 1.0
#                     hate = True                0 : 4      =      9.8 : 1.0
#                  congrat = True                4 : 0      =      9.1 : 1.0
#                  headach = True                0 : 4      =      8.9 : 1.0
#                     hurt = True                0 : 4      =      8.5 : 1.0
#                      yay = True                4 : 0      =      8.5 : 1.0
#                      eye = True                0 : 4      =      8.3 : 1.0
#                     poor = True                0 : 4      =      8.2 : 1.0
#                      boo = True                0 : 4      =      7.6 : 1.0
#                     math = True                0 : 4      =      7.6 : 1.0

# %%
#right one, but eternity to process
training_set = featuresets[:15000]
testing_set = featuresets[15000:]

# %%
#used a trick
training_set = featuresets[:4000]
testing_set = featuresets[4000:5000]
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here
print(nltk.classify.accuracy(classifier, testing_set))
# Out:
# 0.705

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
