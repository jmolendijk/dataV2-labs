# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located in the lab directory named `Sentiment140.csv.zip`. You need to unzip it into a `.csv` file. Then in the cell below, load and explore the data.
#
# *Notes:*
#
# * The dataset was downloaded from [Kaggle](https://www.kaggle.com/kazanova/sentiment140). We made a slight change on the original data so that each column has a label.
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here

import pandas as pd

cols_to_use = ['target','id','date','flag','user','text']

tweets = pd.read_csv('training.1600000.processed.noemoticon.csv',  encoding='latin-1', names=cols_to_use)


tweets = tweets.sample(n=20000, random_state=0)

tweets.shape
# Out:
# (20000, 6)

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
import re

def clean_up(s):
    s = s.lower()
    cleanString = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*'," ", s )
    cleanString2 = re.sub(r"[^a-z]", " ", cleanString) 
    return (cleanString2.lstrip().rstrip()) 


from nltk.tokenize import word_tokenize

def tokenize(s):
    wordList = word_tokenize(s)
    return wordList

from nltk.stem import PorterStemmer , WordNetLemmatizer

#import nltk
#nltk.download()
def stem_and_lemmatize(lst):
    stem = [ PorterStemmer().stem(w) for w in lst]
    lem = [ WordNetLemmatizer().lemmatize(w) for w in stem] 
    return lem


from nltk.corpus import stopwords

def remove_stopwords(lst):
    stop_words = set(stopwords.words('english'))
    word_tokens = lst
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return filtered_sentence

# %%
def big_function(df):
    one = clean_up(df['text'])
    two = tokenize(one)
    three = stem_and_lemmatize(two)
    four = remove_stopwords(three)
    return four

# %%
tweets['text_processed'] = tweets.apply(lambda x: big_function(x), axis=1 )

# %%
# your code here

tweets.head()
# Out:
#          target          id                          date      flag  \
# 557138        0  2204444171  Wed Jun 17 02:14:00 PDT 2009  NO_QUERY
# 349381        0  2017152437  Wed Jun 03 07:56:34 PDT 2009  NO_QUERY
# 182051        0  1967043408  Fri May 29 18:52:13 PDT 2009  NO_QUERY
# 571236        0  2208721054  Wed Jun 17 09:32:48 PDT 2009  NO_QUERY
# 1339637       4  2018731586  Wed Jun 03 10:25:27 PDT 2009  NO_QUERY
#
#                   user                                               text  \
# 557138       einmensch  wants to compete! i want hard competition! i w...
# 349381   keithmorrison  It seems we are stuck on the ground in Amarill...
# 182051      PunkieDory  where the f are my pinking shears? rarararrrar...
# 571236      DYkEY_tYPE  0ff t0 tHE MEEtiN..  i HAtE WhEN PPl V0lUNtEER...
# 1339637  BlueSmartiies                                    @ reply me pls
#
#                                             text_processed
# 557138   [want, compet, want, hard, competit, want, ral...
# 349381   [seem, stuck, ground, amarillo, put, ground, s...
# 182051   [f, pink, shear, rarararrrarararr, babyproof, ...
# 571236   [ff, meetin, hate, ppl, v, lunteer, free, time...
# 1339637                                        [repli, pl]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here

all_words = []

for line in tweets.text_processed:
    for x in line:
        all_words.append(x)
len(all_words)
# Out:
# 156302

# %%
all_words = nltk.FreqDist(all_words)
all_words = dict(all_words)
popular = list(dict(sorted(all_words.items(), key=lambda x: x[1], reverse=True)).keys())
popular = popular[:5000]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

word_features= popular

test = tweets[['text_processed','target']]

documents = [(row[1]['text_processed'], row[1]['target']) for row in test.iterrows()]’

def find_features(document):
    #print(document)
    words = set(document)
    features = {}
    for w in word_features:
     features[w] = (w in words)
    return features  


featuresets = [(find_features(tweet),category) for (tweet,category) in documents]

# %%
featuresets[1]
# Out:
# ({'go': False,
#   'get': False,
#   'day': False,
#   'wa': False,
#   'thi': False,
#   'good': False,
#   'work': False,
#   'like': False,
#   'love': False,
#   'got': False,
#   'quot': False,
#   'u': False,
#   'today': False,
#   'time': False,
#   'thank': False,
#   'want': False,
#   'one': False,
#   'know': False,
#   'lol': False,
#   'back': False,
#   'see': False,
#   'feel': False,
#   'miss': False,
#   'realli': False,
#   'think': False,
#   'im': False,
#   'still': False,
#   'amp': False,
#   'night': False,
#   'hope': False,
#   'need': False,
#   'well': False,
#   'make': False,
#   'watch': False,
#   'home': False,
#   'ha': False,
#   'come': False,
#   'oh': False,
#   'look': False,
#   'new': False,
#   'na': False,
#   'twitter': False,
#   'morn': False,
#   'last': False,
#   'much': False,
#   'tomorrow': False,
#   'haha': False,
#   'wish': False,
#   'great': False,
#   'wait': False,
#   'sleep': False,
#   'whi': False,
#   'week': False,
#   'sad': False,
#   'tri': False,
#   'veri': False,
#   'right': False,
#   'bad': False,
#   'tonight': False,
#   'would': False,
#   'happi': False,
#   'fun': False,
#   'onli': False,
#   'follow': False,
#   'friend': False,
#   'sorri': False,
#   'hi': False,
#   'better': False,
#   'hate': False,
#   'way': False,
#   'thing': False,
#   'nice': False,
#   'gon': False,
#   'though': False,
#   'say': False,
#   'take': False,
#   'bed': False,
#   'show': False,
#   'could': False,
#   'even': False,
#   'start': False,
#   'yeah': False,
#   'tweet': False,
#   'school': False,
#   'peopl': False,
#   'ye': False,
#   'hour': True,
#   'rain': False,
#   'plea': False,
#   'weekend': False,
#   'tire': False,
#   'guy': False,
#   'play': False,
#   'dont': False,
#   'lt': False,
#   'next': False,
#   'awesom': False,
#   'never': False,
#   'hey': False,
#   'x': False,
#   'let': False,
#   'use': False,
#   'sick': False,
#   'long': False,
#   'life': False,
#   'ok': False,
#   'soon': False,
#   'movi': False,
#   'find': False,
#   'cant': False,
#   'phone': False,
#   'call': False,
#   'everyon': False,
#   'final': False,
#   'first': False,
#   'wan': False,
#   'cool': False,
#   'best': False,
#   'girl': False,
#   'head': False,
#   'read': False,
#   'suck': False,
#   'anoth': False,
#   'ani': False,
#   'live': False,
#   'year': False,
#   'littl': False,
#   'alway': False,
#   'help': False,
#   'keep': False,
#   'talk': False,
#   'becaus': False,
#   'sure': False,
#   'n': False,
#   'leav': True,
#   'man': False,
#   'done': False,
#   'hurt': False,
#   'thought': False,
#   'lot': False,
#   'eat': False,
#   'alreadi': False,
#   'bore': False,
#   'made': False,
#   'yay': False,
#   'readi': False,
#   'enjoy': False,
#   'someth': False,
#   'hous': False,
#   'omg': False,
#   'went': False,
#   'yet': False,
#   'amaz': False,
#   'guess': False,
#   'summer': False,
#   'check': False,
#   'befor': False,
#   'tell': False,
#   'finish': False,
#   'wow': False,
#   'give': False,
#   'sound': False,
#   'mean': False,
#   'lost': False,
#   'damn': False,
#   'ur': False,
#   'earli': False,
#   'song': False,
#   'b': False,
#   'ever': False,
#   'babi': False,
#   'excit': False,
#   'late': False,
#   'bit': False,
#   'hear': False,
#   'away': False,
#   'left': False,
#   'big': False,
#   'end': False,
#   'mayb': False,
#   'actual': False,
#   'hot': False,
#   'someon': False,
#   'pic': False,
#   'yesterday': False,
#   'pretti': False,
#   'w': False,
#   'parti': False,
#   'wonder': False,
#   'game': False,
#   'happen': False,
#   'p': False,
#   'music': False,
#   'doe': False,
#   'listen': False,
#   'glad': False,
#   'stop': True,
#   'stuff': False,
#   'god': False,
#   'boy': False,
#   'saw': False,
#   'two': False,
#   'found': False,
#   'old': False,
#   'r': False,
#   'ya': False,
#   'exam': False,
#   'seem': True,
#   'mom': False,
#   'stay': False,
#   'th': False,
#   'noth': False,
#   'com': False,
#   'mani': False,
#   'car': False,
#   'job': False,
#   'hard': False,
#   'weather': False,
#   'kid': False,
#   'later': False,
#   'move': False,
#   'world': False,
#   'sun': False,
#   'said': True,
#   'cold': False,
#   'birthday': False,
#   'put': True,
#   'ta': False,
#   'beauti': False,
#   'also': False,
#   'shop': False,
#   'may': False,
#   'updat': True,
#   'busi': False,
#   'meet': False,
#   'studi': False,
#   'book': False,
#   'post': False,
#   'around': False,
#   'month': False,
#   'fuck': False,
#   'famili': False,
#   'must': False,
#   'everyth': False,
#   'poor': False,
#   'buy': False,
#   'total': False,
#   'friday': False,
#   'cri': False,
#   'luck': False,
#   'least': False,
#   'free': False,
#   'aww': False,
#   'run': False,
#   'sunday': False,
#   'video': False,
#   'monday': False,
#   'sinc': False,
#   'dad': False,
#   'chang': False,
#   'might': False,
#   'funni': False,
#   'class': False,
#   'anyon': False,
#   'die': False,
#   'win': False,
#   'enough': False,
#   'place': False,
#   'pictur': False,
#   'gone': False,
#   'ugh': False,
#   'anyth': False,
#   'shit': False,
#   'room': False,
#   'far': False,
#   'welcom': False,
#   'lunch': False,
#   'repli': False,
#   'stupid': False,
#   'dinner': False,
#   'woke': False,
#   'plan': False,
#   'everi': False,
#   'till': False,
#   'forward': False,
#   'drink': False,
#   'tho': False,
#   'caus': False,
#   'iphon': False,
#   'hell': False,
#   'name': False,
#   'cute': False,
#   'didnt': False,
#   'write': False,
#   'text': False,
#   'face': False,
#   'believ': False,
#   'idea': False,
#   'tv': False,
#   'fan': False,
#   'food': False,
#   'probabl': False,
#   'ask': False,
#   'walk': False,
#   'minut': False,
#   'gt': False,
#   'kill': False,
#   'ill': False,
#   'whole': False,
#   'pain': False,
#   'send': False,
#   'anymor': False,
#   'eye': False,
#   'heart': False,
#   'alon': False,
#   'person': False,
#   'rock': False,
#   'brother': False,
#   'crazi': False,
#   'almost': False,
#   'coffe': False,
#   'hang': False,
#   'c': False,
#   'rest': False,
#   'fail': False,
#   'quit': False,
#   'hair': False,
#   'mine': False,
#   'clean': False,
#   'turn': False,
#   'without': False,
#   'wrong': False,
#   'kinda': False,
#   'blog': False,
#   'money': False,
#   'xx': False,
#   'el': False,
#   'awww': False,
#   'dream': False,
#   'goodnight': False,
#   'sweet': False,
#   'ah': False,
#   'hello': False,
#   'drive': False,
#   'open': False,
#   'ice': False,
#   'beach': False,
#   'real': False,
#   'link': False,
#   'boo': False,
#   'sit': False,
#   'ticket': False,
#   'ago': False,
#   'sooo': False,
#   'true': False,
#   'comput': False,
#   'e': False,
#   'mind': False,
#   'smile': False,
#   'either': False,
#   'outsid': False,
#   'dude': False,
#   'rememb': False,
#   'part': False,
#   'www': False,
#   'close': False,
#   'g': False,
#   'pay': False,
#   'full': False,
#   'abl': False,
#   'mother': False,
#   'k': False,
#   'pm': False,
#   'break': False,
#   'train': False,
#   'learn': False,
#   'wake': False,
#   'okay': False,
#   'dog': False,
#   'half': False,
#   'saturday': False,
#   'reason': False,
#   'problem': False,
#   'danc': False,
#   'pack': False,
#   'super': False,
#   'hit': False,
#   'heard': False,
#   'shower': False,
#   'came': False,
#   'onc': False,
#   'la': False,
#   'aw': False,
#   'email': False,
#   'interest': False,
#   'hug': False,
#   'definit': False,
#   'visit': False,
#   'btw': False,
#   'wont': False,
#   'season': False,
#   'stuck': True,
#   'bring': False,
#   'offic': False,
#   'sometim': False,
#   'headach': False,
#   'goe': False,
#   'worri': False,
#   'sister': False,
#   'pas': False,
#   'onlin': False,
#   'graduat': False,
#   'join': False,
#   'facebook': False,
#   'forgot': False,
#   'anyway': False,
#   'sign': False,
#   'messag': False,
#   'kind': False,
#   'fine': False,
#   'hehe': False,
#   'fix': False,
#   'breakfast': False,
#   'news': False,
#   'hahaha': False,
#   'ppl': False,
#   'add': False,
#   'til': False,
#   'test': False,
#   'word': False,
#   'drop': False,
#   'cuz': False,
#   'complet': False,
#   'dress': False,
#   'internet': False,
#   'congrat': False,
#   'relax': False,
#   'catch': False,
#   'cours': False,
#   'photo': False,
#   'star': False,
#   'suppos': False,
#   'ladi': False,
#   'citi': False,
#   'pick': False,
#   'site': False,
#   'dead': False,
#   'st': False,
#   'question': False,
#   'spend': False,
#   'cat': False,
#   'took': False,
#   'lucki': False,
#   'dear': False,
#   'care': False,
#   'fall': False,
#   'lmao': False,
#   'f': False,
#   'nite': False,
#   'concert': False,
#   'broke': False,
#   'page': False,
#   'bought': False,
#   'cut': False,
#   'seen': False,
#   'sigh': False,
#   'point': False,
#   'trip': False,
#   'save': False,
#   'min': False,
#   'laugh': False,
#   'vote': False,
#   'red': False,
#   'bout': False,
#   'cream': False,
#   'town': False,
#   'gym': False,
#   'le': False,
#   'mr': False,
#   'bye': False,
#   'hungri': False,
#   'fb': False,
#   'favorit': False,
#   'coupl': False,
#   'worst': False,
#   'june': False,
#   'tommcfli': False,
#   'serious': False,
#   'age': False,
#   'ride': False,
#   'fli': False,
#   'goin': False,
#   'soo': False,
#   'load': False,
#   'mileycyru': False,
#   'date': False,
#   'v': False,
#   'holiday': False,
#   'asleep': False,
#   'beat': False,
#   'knew': False,
#   'websit': False,
#   'flu': False,
#   'l': False,
#   'water': False,
#   'list': False,
#   'high': False,
#   'via': False,
#   'line': False,
#   'set': False,
#   'cook': False,
#   'sunshin': False,
#   'stori': False,
#   'sunni': False,
#   'tea': False,
#   'sing': False,
#   'cheer': False,
#   'told': False,
#   'sore': False,
#   'afternoon': False,
#   'stress': False,
#   'agre': False,
#   'decid': False,
#   'myspac': False,
#   'woman': False,
#   'second': False,
#   'sat': False,
#   'wear': False,
#   'tour': False,
#   'differ': False,
#   'air': False,
#   'youtub': False,
#   'yea': False,
#   'plu': False,
#   'perfect': False,
#   'nap': False,
#   'unfortun': False,
#   'special': False,
#   'pool': False,
#   'co': False,
#   'top': False,
#   'peac': False,
#   'hand': False,
#   'weird': False,
#   'window': False,
#   'fell': False,
#   'mad': False,
#   'bike': False,
#   'shirt': False,
#   'horribl': False,
#   'xd': False,
#   'parent': False,
#   'mess': False,
#   'ahh': False,
#   'nd': False,
#   'blue': False,
#   'cloth': False,
#   'instead': False,
#   'ate': False,
#   'sim': False,
#   'hr': False,
#   'togeth': False,
#   'wed': False,
#   'three': False,
#   'yo': False,
#   'lil': False,
#   'appar': False,
#   'sleepi': False,
#   'flight': True,
#   'met': False,
#   'warm': False,
#   'bet': False,
#   'realiz': False,
#   'share': False,
#   'download': False,
#   'lose': False,
#   'store': False,
#   'ipod': False,
#   'account': False,
#   'annoy': False,
#   'thx': False,
#   'fit': False,
#   'moment': False,
#   'figur': False,
#   'awak': False,
#   'revis': False,
#   'garden': False,
#   'kick': False,
#   'ive': False,
#   'wtf': False,
#   'crap': False,
#   'offici': False,
#   'jealou': False,
#   'chat': False,
#   'boyfriend': False,
#   'soooo': False,
#   'laptop': False,
#   'comment': False,
#   'em': False,
#   'googl': False,
#   'shoe': False,
#   'math': False,
#   'sent': False,
#   'gave': False,
#   'j': False,
#   'juli': False,
#   'band': False,
#   'green': False,
#   'memori': False,
#   'foot': False,
#   'fair': False,
#   'sadli': False,
#   'pc': False,
#   'understand': False,
#   'short': False,
#   'slow': False,
#   'album': False,
#   'servic': False,
#   'doesnt': False,
#   'usual': False,
#   'scare': False,
#   'road': False,
#   'longer': False,
#   'small': False,
#   'da': False,
#   'safe': False,
#   'app': False,
#   'leg': False,
#   'lazi': False,
#   'depress': False,
#   'homework': False,
#   'earlier': False,
#   'broken': False,
#   'chocol': False,
#   'spent': False,
#   'answer': False,
#   'paper': False,
#   'freak': False,
#   'babe': False,
#   'worth': False,
#   'white': False,
#   'english': False,
#   'proud': False,
#   'moon': False,
#   'forget': False,
#   'record': False,
#   'lie': False,
#   'chill': False,
#   'order': False,
#   'upload': False,
#   'mac': False,
#   'eh': False,
#   'box': False,
#   'terribl': False,
#   'fact': False,
#   'side': False,
#   'possibl': False,
#   'appl': False,
#   'arriv': False,
#   'past': False,
#   'episod': False,
#   'begin': False,
#   'david': False,
#   'block': False,
#   'bday': False,
#   'chanc': False,
#   'pray': False,
#   'jona': False,
#   'throat': False,
#   'fast': False,
#   'burn': False,
#   'mention': False,
#   'cup': False,
#   'round': False,
#   'alot': False,
#   'due': False,
#   'profil': False,
#   'celebr': False,
#   'version': False,
#   'lone': False,
#   'support': False,
#   'church': False,
#   'paint': False,
#   'countri': False,
#   'uk': False,
#   'son': False,
#   'current': False,
#   'bu': False,
#   'xoxo': False,
#   'ff': False,
#   'mood': False,
#   'camera': False,
#   'wife': False,
#   'ddlovato': False,
#   'dunno': False,
#   'vacat': False,
#   'xxx': False,
#   'airport': False,
#   'vega': False,
#   'project': False,
#   'colleg': False,
#   'scari': False,
#   'yr': False,
#   'film': False,
#   'yum': False,
#   'london': False,
#   'woo': False,
#   'father': False,
#   'nope': False,
#   'singl': False,
#   'idk': False,
#   'note': False,
#   'cancel': False,
#   'mum': False,
#   'h': False,
#   'finger': False,
#   'xo': False,
#   'surpris': False,
#   'yep': False,
#   'tuesday': False,
#   'shall': False,
#   'award': False,
#   'delet': False,
#   'remind': False,
#   'twilight': False,
#   'number': False,
#   'bodi': False,
#   'market': False,
#   'pizza': False,
#   'stomach': False,
#   'ach': False,
#   'cousin': False,
#   'wat': False,
#   'tast': False,
#   'wit': False,
#   'followfriday': False,
#   'sort': False,
#   'normal': False,
#   'wash': False,
#   'isnt': False,
#   'act': False,
#   'invit': False,
#   'shame': False,
#   'manag': False,
#   'event': False,
#   'near': False,
#   'gut': False,
#   'addict': False,
#   'cd': False,
#   'bless': False,
#   'present': False,
#   'dm': False,
#   'bug': False,
#   'exactli': False,
#   'swim': False,
#   'becom': False,
#   'hold': False,
#   'case': False,
#   'huge': False,
#   'shot': False,
#   'raini': False,
#   'type': False,
#   'random': False,
#   'slept': False,
#   'light': False,
#   'ear': False,
#   'hill': False,
#   'deal': False,
#   'ahead': False,
#   'angel': False,
#   'issu': False,
#   'team': False,
#   'camp': False,
#   'hmm': False,
#   'bbq': False,
#   'mark': False,
#   'park': False,
#   'sell': False,
#   'child': False,
#   'power': False,
#   'thursday': False,
#   'club': False,
#   'vid': False,
#   'crash': False,
#   'etc': False,
#   'rd': False,
#   'whatev': False,
#   'web': False,
#   'card': False,
#   'wednesday': False,
#   'price': False,
#   'behind': False,
#   'except': False,
#   'rather': False,
#   'laker': False,
#   'absolut': False,
#   'ad': False,
#   'ohh': False,
#   'pull': False,
#   'teeth': False,
#   'mtv': False,
#   'roll': False,
#   'lame': False,
#   'beer': False,
#   'front': False,
#   'allow': False,
#   'bum': False,
#   'grow': False,
#   'ball': False,
#   'bar': False,
#   'storm': False,
#   'cross': False,
#   'tweetdeck': False,
#   'confus': False,
#   'state': False,
#   'low': False,
#   'huh': False,
#   'appreci': False,
#   'chicken': False,
#   'vip': False,
#   'fresh': False,
#   'ouch': False,
#   'swine': False,
#   'art': False,
#   'black': False,
#   'pop': False,
#   'doctor': False,
#   'coz': False,
#   'somebodi': False,
#   'ahhh': False,
#   'interview': False,
#   'wors': False,
#   'rip': False,
#   'nah': False,
#   'talent': False,
#   'recommend': False,
#   'glass': False,
#   'epic': False,
#   'mile': False,
#   'instal': False,
#   'hmmm': False,
#   'radio': False,
#   'buddi': False,
#   'street': False,
#   'cake': False,
#   'tom': False,
#   'voic': False,
#   'matt': False,
#   'everybodi': False,
#   'ruin': False,
#   'nyc': False,
#   'especi': False,
#   'upset': False,
#   'impress': False,
#   'edit': False,
#   'dvd': False,
#   'design': False,
#   'bro': False,
#   'festiv': False,
#   'gorgeou': False,
#   'blah': False,
#   'disappoint': False,
#   'french': False,
#   'smoke': False,
#   'product': False,
#   'drunk': False,
#   'outta': False,
#   'cooki': False,
#   'stick': False,
#   'fight': False,
#   'bitch': False,
#   'mate': False,
#   'ton': False,
#   'somewher': False,
#   'shoot': False,
#   'puppi': False,
#   'meant': False,
#   'tip': False,
#   'nearli': False,
#   'ng': False,
#   'silli': False,
#   'insid': False,
#   'color': False,
#   'nick': False,
#   'brain': False,
#   'self': False,
#   'felt': False,
#   'id': False,
#   'easi': False,
#   'ooh': False,
#   'compani': False,
#   'fill': False,
#   'hospit': False,
#   'miley': False,
#   'si': False,
#   'yummi': False,
#   'stand': False,
#   'view': False,
#   'guitar': False,
#   'pink': False,
#   'board': False,
#   'fish': False,
#   'medium': False,
#   'forev': False,
#   'file': False,
#   'heat': False,
#   'taylor': False,
#   'tear': False,
#   'plane': False,
#   'certain': False,
#   'realis': False,
#   'build': False,
#   'goodby': False,
#   'cover': False,
#   'troubl': False,
#   'sen': False,
#   'match': False,
#   'nobodi': False,
#   'fml': False,
#   'joke': False,
#   'daughter': False,
#   'race': False,
#   'custom': False,
#   'couldnt': False,
#   'ju': False,
#   'jon': False,
#   'fam': False,
#   'screw': False,
#   'husband': False,
#   'nose': False,
#   'count': False,
#   'return': False,
#   'mall': False,
#   'taken': False,
#   'lay': False,
#   'expect': False,
#   'marri': False,
#   'group': False,
#   'piss': False,
#   'havent': False,
#   'sky': False,
#   'freez': False,
#   'matter': False,
#   'john': False,
#   'gig': False,
#   'doubl': False,
#   'door': False,
#   'bloodi': False,
#   'milk': False,
#   'bag': False,
#   'releas': False,
#   'gettin': False,
#   'channel': False,
#   'ignor': False,
#   'peep': False,
#   'push': False,
#   'apart': False,
#   'tonit': False,
#   'kate': False,
#   'arm': False,
#   'afford': False,
#   'librari': False,
#   'drag': False,
#   'gay': False,
#   'track': False,
#   'badli': False,
#   'shut': False,
#   'exhaust': False,
#   'chri': False,
#   'watchin': False,
#   'smell': False,
#   'expens': False,
#   'prepar': False,
#   'trek': False,
#   'code': False,
#   'mail': False,
#   'doubt': False,
#   'mommi': False,
#   'goodmorn': False,
#   'wine': False,
#   'screen': False,
#   'throw': False,
#   'girlfriend': False,
#   'practic': False,
#   'american': False,
#   'brown': False,
#   'entir': False,
#   'limit': False,
#   'msn': False,
#   'everywher': False,
#   'search': False,
#   'blackberri': False,
#   'jonathanrknight': False,
#   'mouth': False,
#   'dri': False,
#   'choic': False,
#   'kiss': False,
#   'dark': False,
#   'although': False,
#   'fever': False,
#   ...},
#  0)

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

train_set = featuresets[:4000]
test_set = featuresets[4000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
classifier.show_most_informative_features(20)
# Out:
# Most Informative Features
#                      sad = True                0 : 4      =     13.9 : 1.0
#                   stupid = True                0 : 4      =     13.6 : 1.0
#                goodnight = True                4 : 0      =     11.7 : 1.0
#                      www = True                4 : 0      =     11.0 : 1.0
#                  comment = True                4 : 0      =      8.4 : 1.0
#                 unfortun = True                0 : 4      =      7.7 : 1.0
#                     suck = True                0 : 4      =      7.6 : 1.0
#                     fail = True                0 : 4      =      7.4 : 1.0
#                      ugh = True                0 : 4      =      6.7 : 1.0
#                    point = True                4 : 0      =      6.3 : 1.0
#                  project = True                4 : 0      =      6.3 : 1.0
#                     sing = True                4 : 0      =      6.3 : 1.0
#                      act = True                0 : 4      =      6.3 : 1.0
#                    weird = True                0 : 4      =      6.3 : 1.0
#                   anymor = True                0 : 4      =      6.2 : 1.0
#                     wish = True                0 : 4      =      6.0 : 1.0
#                      box = True                4 : 0      =      5.7 : 1.0
#                      web = True                4 : 0      =      5.7 : 1.0
#                  horribl = True                0 : 4      =      5.7 : 1.0
#                     slow = True                0 : 4      =      5.7 : 1.0

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.702

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
