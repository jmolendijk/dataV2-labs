# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located in the lab directory named `Sentiment140.csv.zip`. You need to unzip it into a `.csv` file. Then in the cell below, load and explore the data.
#
# *Notes:*
#
# * The dataset was downloaded from [Kaggle](https://www.kaggle.com/kazanova/sentiment140). We made a slight change on the original data so that each column has a label.
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here
import pandas as pd

data = pd.read_csv('../data/Sentiment140.csv/Sentiment140.csv')
data2 = data.head(20000)

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# # your code here
# import sys
# !{sys.executable} -m pip install ipynb
from ipynb.fs.full.challenge1 import clean_up,tokenize,stem_and_lemmatize,remove_stopwords

data2['text_processed'] = data2['text'].apply(lambda row: clean_up(row))
data2['text_processed'] = data2['text_processed'].apply(lambda row: tokenize(row))
data2['text_processed'] = data2['text_processed'].apply(lambda row: stem_and_lemmatize(row))
data2['text_processed'] = data2['text_processed'].apply(lambda row: remove_stopwords(row))
# Out:
# <ipython-input-48-61b3448e4553>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['text_processed'] = data2['text'].apply(lambda row: clean_up(row))
# <ipython-input-48-61b3448e4553>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['text_processed'] = data2['text_processed'].apply(lambda row: tokenize(row))
# <ipython-input-48-61b3448e4553>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['text_processed'] = data2['text_processed'].apply(lambda row: stem_and_lemmatize(row))
# <ipython-input-48-61b3448e4553>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['text_processed'] = data2['text_processed'].apply(lambda row: remove_stopwords(row))

# %%
data2
# Out:
#        target         ids                          date      flag  \
# 0           0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1           0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2           0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3           0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4           0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19995       0  1556975331  Sun Apr 19 01:19:14 PDT 2009  NO_QUERY
# 19996       0  1556976068  Sun Apr 19 01:19:30 PDT 2009  NO_QUERY
# 19997       0  1556976167  Sun Apr 19 01:19:32 PDT 2009  NO_QUERY
# 19998       0  1556976222  Sun Apr 19 01:19:34 PDT 2009  NO_QUERY
# 19999       0  1556976246  Sun Apr 19 01:19:34 PDT 2009  NO_QUERY
#
#                   user                                               text  \
# 0      _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1        scotthamilton  is upset that he can't update his Facebook by ...
# 2             mattycus  @Kenichan I dived many times for the ball. Man...
# 3              ElleCTF    my whole body feels itchy and like its on fire
# 4               Karoli  @nationwideclass no, it's not behaving at all....
# ...                ...                                                ...
# 19995  TOMurdockPapers  Not much time off this weekend, work trip to M...
# 19996        nikibennn                          One more day of holidays
# 19997     eifflesummer  feeling so down right now .. i hate you DAMN H...
# 19998        lomobabes  geez,i hv to READ the whole book of personalit...
# 19999      thatsblue2u  I threw my sign at donnie and he bent over to ...
#
#                                           text_processed
# 0      [switchfoot, awww, bummer, shoulda, got, david...
# 1      [upset, updat, facebook, text, might, cri, res...
# 2      [kenichan, dive, mani, time, ball, manag, save...
# 3                 [whole, bodi, feel, itchi, like, fire]
# 4        [nationwideclass, behav, mad, whi, becaus, see]
# ...                                                  ...
# 19995  [much, time, weekend, work, trip, malm, fri, s...
# 19996                                [one, day, holiday]
# 19997                 [feel, right, hate, damn, humprey]
# 19998  [geez, hv, read, whole, book, person, type, be...
# 19999  [threw, sign, donni, bent, get, wa, thinge, ma...
#
# [20000 rows x 7 columns]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here
from nltk import FreqDist

wordfreq = FreqDist(sum(data2['text_processed'], []))

# %%
test = set(list(wordfreq.keys()))
test
# Out:
# {'chutney',
#  'ammm',
#  'von',
#  'mj',
#  'mdsteelerg',
#  'communic',
#  'stress',
#  'horrors_wench',
#  'gato',
#  'sarahlsharp',
#  'youd',
#  'underground',
#  'entr',
#  'hahahahaha',
#  'formal',
#  'reunit',
#  'budget',
#  'wah',
#  'philipin',
#  'blargh',
#  'advanc',
#  'rl',
#  'socalvixen',
#  'indyank',
#  'ke_ai_cuti',
#  'discipl',
#  'allll',
#  'chocolatedrop',
#  'put',
#  'pingin',
#  'desperat',
#  'sandal',
#  'editor',
#  'unc',
#  'transit',
#  'windless',
#  'goddamnit',
#  'cucumb',
#  'foxbroadcast',
#  'jake',
#  'excus',
#  'medium',
#  'sassydani',
#  'afew',
#  'dondria',
#  'haircut',
#  'len',
#  'viabl',
#  'pregnanc',
#  'misschrii',
#  'evolut',
#  'sweati',
#  'duchess_rebecca',
#  'hngntuff',
#  'hub',
#  'stupido',
#  'vertic',
#  'nextt',
#  'hassl',
#  'coachi',
#  'alexfost',
#  'kimkardashian',
#  'aeroplan',
#  'bdiflip',
#  'jennatar',
#  'bend',
#  'ambeanosc',
#  'agenda',
#  'tenny_id',
#  'jonathanrhi',
#  'fiddi',
#  'mehhhhhh',
#  'laratron',
#  'applepear',
#  'balboa',
#  'cleder',
#  'friendi',
#  'mainten',
#  'rachelkvinc',
#  'tm',
#  'briantruong',
#  'bcoz',
#  'kaiser_wilhelm',
#  'ronald',
#  'iamcheerbear',
#  'marcus',
#  'diari',
#  'camiluvsflow',
#  'bagel',
#  'alexlumley',
#  'domain',
#  'njoku',
#  'loveketurah',
#  'nuff',
#  'missabab',
#  'velcro',
#  'michalabana',
#  'geekstev',
#  'gaultier',
#  'jamilla',
#  'itsallgoood',
#  'lancelot',
#  'citrin',
#  'djr',
#  'yobeeon',
#  'packetdienst',
#  'formula',
#  'usin',
#  'geico',
#  'alllllllll',
#  'shescap',
#  'chip',
#  'ninadutchess',
#  'foget',
#  'solo',
#  'iphon',
#  'twenty_',
#  'mikeyzito',
#  'land',
#  'machiiiii',
#  'sumwher',
#  'heykimmi',
#  'swellvintag',
#  'mokshjuneja',
#  'shakin',
#  'bustout',
#  'zelda',
#  'caz',
#  'haddow',
#  'uuuu',
#  'firefox',
#  'temper',
#  'cincinnati',
#  'bullcrap',
#  'iont',
#  'mccainblogett',
#  'bootleg',
#  'hmph',
#  'aww',
#  'injuri',
#  'techi',
#  'accompani',
#  'phpnw',
#  'albums_but',
#  'aparty',
#  'kschocolat',
#  'jjs',
#  'recon',
#  'digg',
#  'tbaoina',
#  'loath',
#  'las_vegas_grl',
#  'hv',
#  'drafthous',
#  'file',
#  'gina',
#  'dougrea',
#  'sunk',
#  'pan',
#  'avalanch',
#  'bomber',
#  'blondekati',
#  'pretend',
#  'keelybin',
#  'ckv',
#  'vase',
#  'extraordinari',
#  'return',
#  'mehhh',
#  'monday',
#  'peachfuzz_uk',
#  'birdsal',
#  'brew',
#  'cerr',
#  'tkam',
#  'arbi',
#  'sianllewellyn',
#  'leash',
#  'earthtoryann',
#  'flatt',
#  'mela_lyn',
#  'tak',
#  'mcflyrul',
#  'jungl',
#  'marvel',
#  'aaliyahlov',
#  'anthoni',
#  'mommytoaprinc',
#  'raymondroman',
#  'sociallycub',
#  'byllicrayon',
#  'warrnambool',
#  'jacvanek',
#  'fundrais',
#  'galway',
#  'nigel',
#  'sophiamar',
#  'scare',
#  'oregon',
#  'roundhay',
#  'zeist',
#  'zackdft',
#  'cobi',
#  'angry_barista',
#  'tagalong',
#  'lil_shortcak',
#  'squishi',
#  'chel',
#  'palli',
#  'ahaa',
#  'r',
#  'slash',
#  'roundabout',
#  'prejudic',
#  'cassieventura',
#  'mercygrl',
#  'bhargavkapadia',
#  'tessaschraven',
#  'bball',
#  'musik',
#  'chibi',
#  'cec',
#  'zinziii',
#  'peepz',
#  'parad',
#  'ultraviolet__x',
#  'spi',
#  'vicoden',
#  'labellasim',
#  'cronotrigg',
#  'adam_brodi',
#  'vmware',
#  'erinmckenna',
#  'ellen',
#  'wsh',
#  'adavi',
#  'tomorroooowwwwwwwwww',
#  'stperfect',
#  'flamit',
#  'sternum',
#  'joeynigro',
#  'hawk',
#  'saragarth',
#  'checksid',
#  'cgiridhar',
#  'blend',
#  'alter',
#  'spite',
#  'crusad',
#  'verryyyyi',
#  'thale',
#  'famousrichard',
#  'decod',
#  'justinsx',
#  'jassonc',
#  'hcg',
#  'florenc',
#  'kevin',
#  'trophi',
#  'bellenoirmag',
#  'drool',
#  'sssh',
#  'frumiousm',
#  'spider',
#  'witch',
#  'mr_dread',
#  'wnt',
#  'midbreak',
#  'mea',
#  'infinit',
#  'rockergirl',
#  'procedur',
#  'wha',
#  'wale',
#  'mine',
#  'bittenappl',
#  'sundberg',
#  'sail',
#  'dweeman',
#  'gingha',
#  'spare',
#  'ayla_f',
#  'bep',
#  'rerun',
#  'ignor',
#  'eurorockradio',
#  'graduat',
#  'ubertwitt',
#  'noordinarygrl',
#  'xoxoxo',
#  'filiocht',
#  'onslaught',
#  'theviperroom',
#  'unbread',
#  'pollen',
#  'brow',
#  'galaxi',
#  'rockinrita',
#  'vns',
#  'cohen',
#  'alessandrod',
#  'officialdylan',
#  'cansada',
#  'airwanderor',
#  'slc',
#  'vanessa_blu',
#  'artygirlr',
#  'starrahpenzhitz',
#  'walthamstowemd',
#  'pomad',
#  'nicola',
#  'cupcak',
#  'goodlaura',
#  'rowdi',
#  'alliter',
#  'awesom',
#  'nancypr',
#  'toll',
#  'kcinwpb',
#  'abit',
#  'forehead',
#  'roxa',
#  'mesh',
#  'wiper',
#  'craftjuic',
#  'damnit',
#  'lollyjay',
#  'hamstr',
#  'mistak',
#  'nirvanaarch',
#  'niffti',
#  'gamet',
#  'syd',
#  'frank',
#  'gemma',
#  'actulli',
#  'hamilton',
#  'submit',
#  'bracelet',
#  'pkr',
#  'kickin',
#  'wenrichcap',
#  'getti',
#  'vain',
#  'anyway',
#  'evil',
#  'pukey',
#  'gut',
#  'eryn',
#  'ninkompoop',
#  'gerardway',
#  'ya',
#  'efron',
#  'ewpopwatch',
#  'scarier',
#  'poooooor',
#  'joyann',
#  'oberst',
#  'heygorg',
#  'hoopyfrood',
#  'pride',
#  'zoe',
#  'carpent',
#  'poach',
#  'burnsrodney',
#  'michaelgio',
#  'gloucest',
#  'tnmchris',
#  'pft',
#  'hedydd',
#  'odannygirl',
#  'thay',
#  'forest',
#  'aquila',
#  'jamieharrop',
#  'davidt',
#  'call',
#  'racket',
#  'pix',
#  'jeorgina',
#  'stab',
#  'savour',
#  'femal',
#  'appdizzl',
#  'brigidemili',
#  'koh',
#  'breakdown',
#  'upperbowl',
#  'lucy_moor',
#  'coyoteontherun',
#  'burt',
#  'slessard',
#  'blackpearl',
#  'booohoooo',
#  'briannack',
#  'jaylnn',
#  'dailycomplain',
#  'broke',
#  'pshhh',
#  'unburn',
#  'girlz',
#  'ago',
#  'bcos',
#  'daria',
#  'keyr',
#  'wrestler',
#  'luya',
#  'yochevet',
#  'envo',
#  'abl',
#  'booo',
#  'carpal',
#  'prismaticjul',
#  'spf',
#  'seattlefutbol',
#  'allig',
#  'thaa',
#  'awwwwww',
#  'vivalariaa',
#  'robgold',
#  'kevn',
#  'lmaoo',
#  'simba',
#  'superneej',
#  'esp',
#  'princesssuperc',
#  'tiredddd',
#  'angeltalk',
#  'moriesbel',
#  'goast',
#  'celticgirl',
#  'lend',
#  'devist',
#  'hitokyri',
#  'meesh',
#  'princedavey',
#  'tired',
#  'undefin',
#  'kevo',
#  'fantasia',
#  'misunderstood',
#  'anitacochran',
#  'tiredofbeinsexi',
#  'haue',
#  'kirstiekalam',
#  'nightttt',
#  'tisdal',
#  'ohble',
#  'reavel',
#  'knob',
#  'yarn',
#  'tatiana_k',
#  'toi',
#  'ravin',
#  'yiew',
#  'releg',
#  'enjoyin',
#  'honeybeetoy',
#  'frighten',
#  'excel',
#  'withdrawel',
#  'pure',
#  'bglr',
#  'html',
#  'vandal',
#  'fring',
#  'zydeco',
#  'ranger',
#  'mominisrael',
#  'taiheartshbk',
#  'quinpark',
#  'form',
#  'criminalrecord',
#  'lorrainka',
#  'vbscript',
#  'cantbdeal',
#  'festiv',
#  'david',
#  'harrddd',
#  'jessdubb',
#  'blockparti',
#  'frangipani',
#  'kuraihim',
#  'shall',
#  'expload',
#  'exacerb',
#  'doubleshot',
#  'jsparson',
#  'retreat',
#  'wdpoa',
#  'crabbi',
#  'appear',
#  'kathi',
#  'arnt',
#  'solen',
#  'checkd',
#  'twitch',
#  'nocturn',
#  'butterfli',
#  'arggg',
#  'cushion',
#  'knowww',
#  'biscuti',
#  'missi',
#  'imit',
#  'hey',
#  'acm',
#  'magicbartend',
#  'glogowerpow',
#  'trishzw',
#  'canadien',
#  'madaudm',
#  'surveil',
#  'skank',
#  'dadi_iy',
#  'hormiguero',
#  'tent',
#  'ane',
#  'alan',
#  'coursework',
#  'williamstodd',
#  'impress',
#  'nike',
#  'gurn',
#  'catq',
#  'noooooooooooo',
#  'cool',
#  'recreat',
#  'hippychick',
#  'roach',
#  'kuhn',
#  'rad_chick_',
#  'vfactori',
#  'deliap',
#  'alyssaspear',
#  'jwmayer',
#  'turducken',
#  'leftov',
#  'dj_reev',
#  'darkrai',
#  'ahbl',
#  'hire',
#  'warriorwoman',
#  'taub',
#  'wid',
#  'strip',
#  'bounder',
#  'gv',
#  'logyourrun',
#  'ikr',
#  'chelserlynn',
#  'keyboard',
#  'dhughesi',
#  'annoy',
#  'cutestmidget',
#  'tmrw',
#  'driver',
#  'paddl',
#  'janetdamitajo',
#  'borinnggg',
#  'grimmi',
#  'rmaz',
#  'supplier',
#  'tracitoguchi',
#  'ever',
#  'bergenlarsen',
#  'aack',
#  'dryer',
#  'octob',
#  'biz',
#  'ladygaga',
#  'dozc',
#  'park',
#  'aug',
#  'serotonin',
#  'kennel',
#  'savicev',
#  'ahhhhh',
#  'wknds',
#  'straw',
#  'kimmel',
#  'kg',
#  'sugarbank',
#  'lye',
#  'snarl',
#  'masha',
#  'brian_g',
#  'eek',
#  'skinnylatt',
#  'bloati',
#  'third',
#  'hawker',
#  'prompt',
#  'gald',
#  'chequ',
#  'paperweight',
#  'iam',
#  'chrisett',
#  'electronica',
#  'exahust',
#  'veneer',
#  'offlin',
#  'liamwong',
#  'goldfish',
#  'maddyva',
#  'open',
#  'afaik',
#  'cupcakin',
#  'java',
#  'whoa',
#  'loyal',
#  'xosophietweet',
#  'tablecoth',
#  'legallybuy',
#  'misterskul',
#  'missloki',
#  'abiban',
#  'mothsandlac',
#  'licenc',
#  'lamb',
#  'uur',
#  'disk',
#  'wy',
#  'yayfuckbuddi',
#  'songz',
#  'buggi',
#  'krystynchong',
#  'wrt',
#  'helpp',
#  'felic',
#  'opposit',
#  'fistynut',
#  'gibb',
#  'uniqu',
#  'citibank',
#  'astronaut',
#  'sexism',
#  'animorph',
#  'remodel',
#  'summais',
#  'profess',
#  'someonetel',
#  'techathead',
#  'uuughhhh',
#  'shoulda',
#  'mear',
#  'signup',
#  'xm',
#  'sioux',
#  'rpm',
#  'teddy_j',
#  'kusasi',
#  'franciscoiv',
#  'brewrey',
#  'empir',
#  'entwin',
#  'ahleesonn',
#  'use',
#  'brock',
#  'stark',
#  'dsn',
#  'radioros',
#  'vagina',
#  'waaahhh',
#  'cruel',
#  'bluepet',
#  'elledel',
#  'deviantart',
#  'tropic',
#  'charlott',
#  'rubicund',
#  'twxtd',
#  'stressin',
#  'erardo',
#  'dumbest',
#  'bebe',
#  'relief',
#  'kaytedixon',
#  'flossin',
#  'billipip',
#  'trevieno',
#  'mtnh',
#  'iii',
#  'mtb',
#  'nytim',
#  'lot',
#  'lene',
#  'karimjebari',
#  'bimbot',
#  'nam',
#  'thehoosiersuk',
#  'truli',
#  'earlyy',
#  'elitist',
#  'speakeasi',
#  'arrrggghhh',
#  'agenc',
#  'chello',
#  'recov',
#  'oooo',
#  'xovinc',
#  'sumwer',
#  'sting',
#  'icarusmalfoy',
#  'disapptin',
#  'staticxag',
#  'boygenius',
#  'dl',
#  'confessionsmom',
#  'chrissak',
#  'britneyspear',
#  'carolrainbow',
#  'involv',
#  'thirsti',
#  'approv',
#  'va',
#  'cking',
#  'peteee',
#  'whatdamnnick',
#  'voluptuousgir',
#  'lincoln',
#  'timvansa',
#  'yike',
#  'williamhstraf',
#  'unexpect',
#  'tomashast',
#  'snowboard',
#  'avacado',
#  'iiiit',
#  'intermitt',
#  'puzzl',
#  'band',
#  'soundcheck',
#  'peel',
#  'contin',
#  'wen',
#  'msoft',
#  'mixup',
#  'bal',
#  'selsun',
#  'terryfre',
#  'fallenstar_',
#  'smash',
#  'merman',
#  'announc',
#  'krm_bia',
#  'awman',
#  'static',
#  'gern',
#  'rhook',
#  'extinguish',
#  'luishandshak',
#  'gna',
#  'dashkdot',
#  'seem',
#  'random',
#  'jglynn',
#  'franklero',
#  'alw',
#  'delawar',
#  'tokyofan',
#  'regyat',
#  'bsb',
#  'ddubsbostongirl',
#  'montaaaaaaag',
#  'waaaayi',
#  'trashi',
#  'charact',
#  'sharethi',
#  'diegosecond',
#  'badass',
#  'nap',
#  'footag',
#  'server',
#  'schaeferj',
#  'hillsong',
#  'vemana',
#  'ryann',
#  'macbook',
#  'outbound',
#  'djedub',
#  'beefi',
#  'edbehren',
#  'xxmarypoppinsxx',
#  'appreci',
#  'afford',
#  'hough',
#  'cancer',
#  'lovelifeforev',
#  'graham',
#  'michaelfidl',
#  'snorkel',
#  'kimone_isher',
#  'order',
#  'emperor',
#  'freefal',
#  'nathnaelb',
#  'twitterrif',
#  'sherri',
#  'graz',
#  'mind',
#  'core',
#  'glue',
#  'olga_bondarev',
#  'kthnx',
#  'mellieebellie',
#  'aargh',
#  'pyroroux',
#  'stasia',
#  'grungi',
#  'bitsyfest',
#  'saracen',
#  'follw',
#  'willbat',
#  'dnwallac',
#  'powerpool',
#  'royalbluestuey',
#  'cheapest',
#  'trisaraht',
#  'warfar',
#  'korea',
#  'tti',
#  'scottavenu',
#  'chop',
#  'anticip',
#  'twice',
#  'hannahindi',
#  'pgreenb',
#  'chant',
#  'natybabi',
#  '_laertesgirl',
#  'pass',
#  'rank',
#  'confedswht',
#  'suce',
#  'someth',
#  'oww',
#  'flannel',
#  'absolutley',
#  'nawal',
#  'usuali',
#  'tale',
#  'forthcom',
#  'austgr',
#  'laterz',
#  'thepistol',
#  'kendellrene',
#  'vicker',
#  'bernes',
#  'knacker',
#  'dreamweav',
#  'decaf',
#  'disapprov',
#  'bethel',
#  'tipsgirl',
#  'guy',
#  'yfemammabear',
#  'hjc',
#  'crystaljordan',
#  'trackstar',
#  'farrow',
#  'sato',
#  'carrier',
#  'fr',
#  'uva',
#  'maria',
#  'bleachin',
#  'sharneselani',
#  'jamsandwich',
#  'heartbreakerzen',
#  'doubl',
#  'neurofen',
#  'practic',
#  'holydueg',
#  'dy',
#  'absorb',
#  'cpu',
#  'postman',
#  'cset',
#  'woodgrain',
#  'missio',
#  'edwin',
#  'gourgeous',
#  'forex',
#  'taylor',
#  'detail',
#  'martinaronsen',
#  'naominanashi',
#  'sandwhich',
#  'penn',
#  'estrellabonita',
#  'biolif',
#  'lauder',
#  'keza',
#  'tinier',
#  'ramen',
#  'bryci',
#  'million',
#  'aldrichjc',
#  'sih',
#  'chriselian',
#  'vocal',
#  'diag',
#  'abruzzo',
#  'penelop',
#  'vertebra',
#  'blurrgghh',
#  'huen',
#  'bueller',
#  'braveri',
#  'ofantast',
#  'michellev',
#  'nati',
#  'station',
#  'darkest',
#  'cherri',
#  'ii',
#  'nettl',
#  'jessv',
#  'proud',
#  'halfpastoctob',
#  'dunk',
#  'massiv',
#  'xbreathexgx',
#  'frikkin',
#  'cherylmckinnon',
#  'tallk',
#  'knihe',
#  'stopin',
#  'sfmta',
#  'crooner',
#  'tromp',
#  'commer',
#  'dora',
#  'melt',
#  'veryyi',
#  'mtva',
#  'chipper',
#  'rebroadcast',
#  'poxa',
#  'hasta',
#  'jayx',
#  'gmpr',
#  'afwif',
#  'lisiepeasi',
#  'madamrosmerta',
#  'ker',
#  'andrewmyork',
#  'hack',
#  'noe',
#  'jessi',
#  'presid',
#  'bunac',
#  'fma',
#  'wigan',
#  'ahh',
#  'niko',
#  'nod',
#  'unlucki',
#  'hillman',
#  'trenchcoat',
#  'defeat',
#  'promis',
#  'popcorn',
#  'teenag',
#  'destinyjoy',
#  'kvaina',
#  'cusack',
#  'unfortunat',
#  'rod',
#  'cadenc',
#  'lava',
#  'dindl',
#  'master',
#  'cruddi',
#  'soooooooo',
#  'afriad',
#  'hawkey',
#  'hungri',
#  'youngec',
#  'grill',
#  'uniquelymo',
#  'ty',
#  'b',
#  'reaper',
#  'malayalam',
#  'youu',
#  'rezki',
#  'oakley',
#  'heikem',
#  'innoc',
#  'day',
#  'derailleur',
#  'marilyn',
#  'theengteach',
#  'britney',
#  'revesdoux',
#  'theis',
#  'torrent',
#  'bai',
#  ...}

# %%
import operator

sorted_wordfreq = dict( sorted(wordfreq.items(), key=operator.itemgetter(1),reverse=True))
top5000 = list(sorted_wordfreq)[:5000]
top5000
# Out:
# ['go',
#  'work',
#  'get',
#  'wa',
#  'day',
#  'miss',
#  'like',
#  'got',
#  'want',
#  'today',
#  'feel',
#  'back',
#  'time',
#  'still',
#  'realli',
#  'wish',
#  'good',
#  'one',
#  'sad',
#  'im',
#  'quot',
#  'need',
#  'think',
#  'know',
#  'night',
#  'u',
#  'ha',
#  'home',
#  'sleep',
#  'last',
#  'hope',
#  'sorri',
#  'love',
#  'bad',
#  'na',
#  'make',
#  'lol',
#  'oh',
#  'whi',
#  'much',
#  'see',
#  'watch',
#  'well',
#  'come',
#  'hate',
#  'onli',
#  'twitter',
#  'sick',
#  'look',
#  'amp',
#  'tomorrow',
#  'tri',
#  'morn',
#  'bed',
#  'though',
#  'new',
#  'would',
#  'week',
#  'veri',
#  'tonight',
#  'could',
#  'right',
#  'even',
#  'thing',
#  'hour',
#  'school',
#  'friend',
#  'wait',
#  'tire',
#  'start',
#  'cant',
#  'suck',
#  'way',
#  'hurt',
#  'bore',
#  'peopl',
#  'find',
#  'gon',
#  'better',
#  'never',
#  'fun',
#  'play',
#  'take',
#  'dont',
#  'cold',
#  'show',
#  'lost',
#  'rain',
#  'wan',
#  'long',
#  'say',
#  'ani',
#  'ugh',
#  'phone',
#  'yeah',
#  'year',
#  'keep',
#  'thank',
#  'follow',
#  'yet',
#  'becaus',
#  'earli',
#  'poor',
#  'tweet',
#  'hous',
#  'damn',
#  'great',
#  'anoth',
#  'away',
#  'guy',
#  'soon',
#  'littl',
#  'someth',
#  'head',
#  'snow',
#  'life',
#  'someon',
#  'call',
#  'next',
#  'man',
#  'nice',
#  'befor',
#  'alreadi',
#  'let',
#  'use',
#  'leav',
#  'late',
#  'guess',
#  'game',
#  'help',
#  'haha',
#  'noth',
#  'first',
#  'weekend',
#  'ok',
#  'done',
#  'hard',
#  'went',
#  'left',
#  'hear',
#  'talk',
#  'stop',
#  'weather',
#  'girl',
#  'end',
#  'pleas',
#  'cri',
#  'break',
#  'thought',
#  'read',
#  'lt',
#  'alway',
#  'n',
#  'made',
#  'ever',
#  'car',
#  'readi',
#  'mean',
#  'happen',
#  'old',
#  'fuck',
#  'final',
#  'finish',
#  'live',
#  'outsid',
#  'x',
#  'eat',
#  'class',
#  'seem',
#  'woke',
#  'sure',
#  'run',
#  'gone',
#  'lot',
#  'omg',
#  'happi',
#  'yesterday',
#  'stay',
#  'doe',
#  'b',
#  'babi',
#  'sinc',
#  'ta',
#  'pretti',
#  'everyon',
#  'die',
#  'sound',
#  'stupid',
#  'mayb',
#  'mani',
#  'bit',
#  'stuck',
#  'tell',
#  'studi',
#  'two',
#  'didnt',
#  'around',
#  'movi',
#  'lone',
#  'put',
#  'anyon',
#  'actual',
#  'best',
#  'hot',
#  'clean',
#  'anymor',
#  'meet',
#  'may',
#  'stuff',
#  'move',
#  'must',
#  'yes',
#  'headach',
#  'give',
#  'pain',
#  'tho',
#  'updat',
#  'almost',
#  'anyth',
#  'saturday',
#  'wonder',
#  'sun',
#  'enough',
#  'busi',
#  'might',
#  'wow',
#  'believ',
#  'dog',
#  'r',
#  'hey',
#  'parti',
#  'sit',
#  'found',
#  'god',
#  'also',
#  'wake',
#  'big',
#  'th',
#  'without',
#  'shop',
#  'spring',
#  'kid',
#  'monday',
#  'room',
#  'later',
#  'ur',
#  'boo',
#  'kill',
#  'aww',
#  'c',
#  'till',
#  'homework',
#  'drive',
#  'check',
#  'close',
#  'write',
#  'job',
#  'said',
#  'turn',
#  'w',
#  'saw',
#  'fail',
#  'probabl',
#  'shit',
#  'awak',
#  'caus',
#  'ill',
#  'plan',
#  'p',
#  'alon',
#  'total',
#  'walk',
#  'wrong',
#  'sunday',
#  'eye',
#  'music',
#  'crap',
#  'month',
#  'post',
#  'serious',
#  'test',
#  'world',
#  'dream',
#  'boy',
#  'least',
#  'video',
#  'comput',
#  'minut',
#  'famili',
#  'money',
#  'mom',
#  'beauti',
#  'listen',
#  'compani',
#  'everyth',
#  'throat',
#  'food',
#  'far',
#  'buy',
#  'drink',
#  'enjoy',
#  'chang',
#  'everi',
#  'els',
#  'yay',
#  'hell',
#  'broke',
#  'awesom',
#  'coffe',
#  'mine',
#  'okay',
#  'forgot',
#  'open',
#  'abl',
#  'suppos',
#  'idea',
#  'unfortun',
#  'aw',
#  'sore',
#  'lose',
#  'hair',
#  'either',
#  'internet',
#  'ago',
#  'fix',
#  'asot',
#  'luck',
#  'pictur',
#  'holiday',
#  'hit',
#  'book',
#  'song',
#  'depress',
#  'amaz',
#  'gt',
#  'dinner',
#  'rest',
#  'ya',
#  'hungri',
#  'real',
#  'cool',
#  'tv',
#  'sigh',
#  'send',
#  'kinda',
#  'dead',
#  'pic',
#  'fall',
#  'name',
#  'f',
#  'cat',
#  'awww',
#  'repli',
#  'easter',
#  'hang',
#  'site',
#  'sooo',
#  'place',
#  'femal',
#  'dad',
#  'ask',
#  'birthday',
#  'face',
#  'anyway',
#  'ticket',
#  'laptop',
#  'forward',
#  'half',
#  'april',
#  'season',
#  'excit',
#  'pm',
#  'exam',
#  'onlin',
#  'pick',
#  'seen',
#  'iphon',
#  'worst',
#  'paper',
#  'took',
#  'hand',
#  'super',
#  'came',
#  'problem',
#  'page',
#  'horribl',
#  'upset',
#  'rememb',
#  'tuesday',
#  'brother',
#  'friday',
#  'lunch',
#  'bum',
#  'kind',
#  'foot',
#  'store',
#  'instead',
#  'text',
#  'glad',
#  'messag',
#  'email',
#  'mad',
#  'heart',
#  'news',
#  'offic',
#  'jealous',
#  'word',
#  'person',
#  'set',
#  'care',
#  'til',
#  'whole',
#  'hug',
#  'min',
#  'quit',
#  'sometim',
#  'asleep',
#  'broken',
#  'fan',
#  'win',
#  'crazi',
#  'wont',
#  'com',
#  'sweet',
#  'spend',
#  'complet',
#  'disappoint',
#  'beach',
#  'worri',
#  'trip',
#  'appar',
#  'due',
#  'part',
#  'xx',
#  'ate',
#  'told',
#  'onc',
#  'catch',
#  'cut',
#  'ive',
#  'realiz',
#  'reason',
#  'wear',
#  'link',
#  'doesnt',
#  'sleepi',
#  'wtf',
#  'summer',
#  'ride',
#  'photo',
#  'train',
#  'understand',
#  'near',
#  'usual',
#  'account',
#  'figur',
#  'project',
#  'drop',
#  'load',
#  'soo',
#  'dude',
#  'wors',
#  'full',
#  'hr',
#  'red',
#  'ah',
#  'sunni',
#  'le',
#  'sister',
#  'stomach',
#  'slow',
#  'insid',
#  'cancel',
#  'heard',
#  'annoy',
#  'soooo',
#  'fell',
#  'fight',
#  'ach',
#  'episod',
#  'true',
#  'vacat',
#  'park',
#  'pay',
#  'terribl',
#  'v',
#  'window',
#  'dear',
#  'shower',
#  'stori',
#  'short',
#  'shame',
#  'hahaha',
#  'moment',
#  'bought',
#  'citi',
#  'st',
#  'cuz',
#  'g',
#  'download',
#  'e',
#  'mind',
#  'cours',
#  'l',
#  'record',
#  'top',
#  'second',
#  'water',
#  'upload',
#  'town',
#  'mess',
#  'bring',
#  'fast',
#  'scare',
#  'offici',
#  'coupl',
#  'finger',
#  'dress',
#  'hi',
#  'flight',
#  'band',
#  'shoe',
#  'sent',
#  'stress',
#  'parent',
#  'pack',
#  'learn',
#  'visit',
#  'kick',
#  'mood',
#  'ppl',
#  'lmao',
#  'cute',
#  'breakfast',
#  'danc',
#  'agre',
#  'nite',
#  'team',
#  'ipod',
#  'past',
#  'slept',
#  'bar',
#  'nick_cart',
#  'definit',
#  'mum',
#  'point',
#  'answer',
#  'save',
#  'chanc',
#  'bus',
#  'nd',
#  'doctor',
#  'sat',
#  'hold',
#  'order',
#  'sign',
#  'k',
#  'death',
#  'crash',
#  'tummi',
#  'co',
#  'block',
#  'uni',
#  'tweetdeck',
#  'ruin',
#  'rock',
#  'drunk',
#  'essay',
#  'pass',
#  'issu',
#  'blog',
#  'bug',
#  'bummer',
#  'free',
#  'weird',
#  'nap',
#  'bout',
#  'argh',
#  'btw',
#  'airport',
#  'fair',
#  'blue',
#  'decid',
#  'dentist',
#  'togeth',
#  'mileycyrus',
#  'hospit',
#  'concert',
#  'facebook',
#  'manag',
#  'spent',
#  'lay',
#  'side',
#  'power',
#  'lame',
#  'mac',
#  'isnt',
#  'goodnight',
#  'coachella',
#  'line',
#  'ouch',
#  'interest',
#  'bodi',
#  'three',
#  'tea',
#  'leg',
#  'sing',
#  'websit',
#  'dure',
#  'funni',
#  'yea',
#  'thursday',
#  'tour',
#  'cough',
#  'ahh',
#  'afternoon',
#  'behind',
#  'piss',
#  'shoot',
#  'confus',
#  'chocol',
#  'flu',
#  'huge',
#  'fact',
#  'revis',
#  'batteri',
#  'colleg',
#  'idk',
#  'puppi',
#  'glass',
#  'longer',
#  'goin',
#  'english',
#  'instal',
#  'none',
#  'burn',
#  'traffic',
#  'road',
#  'raini',
#  'loss',
#  'hill',
#  'hmm',
#  'rip',
#  'nobodi',
#  'nose',
#  'wast',
#  'uk',
#  'warm',
#  'googl',
#  'ice',
#  'bike',
#  'high',
#  'search',
#  'gut',
#  'freak',
#  'expect',
#  'gym',
#  'em',
#  'star',
#  'deal',
#  'list',
#  'knew',
#  'taken',
#  'camera',
#  'kitti',
#  'small',
#  'la',
#  'web',
#  'havent',
#  'servic',
#  'club',
#  'race',
#  'air',
#  'low',
#  'pizza',
#  'lucki',
#  'delet',
#  'fb',
#  'son',
#  'wed',
#  'possibl',
#  'gave',
#  'date',
#  'scari',
#  'pull',
#  'invit',
#  'joke',
#  'london',
#  'box',
#  'goodby',
#  'shot',
#  'exhaust',
#  'film',
#  'cover',
#  'easi',
#  'hello',
#  'hubbi',
#  'boyfriend',
#  'light',
#  'itali',
#  'empti',
#  'white',
#  'ladi',
#  'allergi',
#  'h',
#  'mr',
#  'nope',
#  'yr',
#  'ad',
#  'favorit',
#  'rather',
#  'app',
#  'dvd',
#  'chat',
#  'ring',
#  'troubl',
#  'dang',
#  'earlier',
#  'garden',
#  'mile',
#  'connect',
#  'except',
#  'notic',
#  'round',
#  'youtub',
#  'sold',
#  'wet',
#  'speak',
#  'winter',
#  'door',
#  'fine',
#  'stand',
#  'pc',
#  'arm',
#  'gah',
#  'age',
#  'quiet',
#  'bloodi',
#  'anywher',
#  'plus',
#  'report',
#  'tommcfli',
#  'yep',
#  'xd',
#  'houston',
#  'file',
#  'tax',
#  'forev',
#  'design',
#  'although',
#  'gosh',
#  'fit',
#  'sort',
#  'assign',
#  'freez',
#  'tast',
#  'sell',
#  'cook',
#  'support',
#  'differ',
#  'cream',
#  'knee',
#  'cake',
#  'fli',
#  'chicken',
#  'random',
#  'smell',
#  'comment',
#  'felt',
#  'lazi',
#  'librari',
#  'card',
#  'germani',
#  'state',
#  'street',
#  'present',
#  'tree',
#  'cup',
#  'return',
#  'four',
#  'singl',
#  'event',
#  'brain',
#  'blah',
#  'ball',
#  'bye',
#  'babe',
#  'laugh',
#  'current',
#  'album',
#  'mail',
#  'dunno',
#  'matter',
#  'dark',
#  'peac',
#  'version',
#  'exact',
#  'cell',
#  'ran',
#  'itun',
#  'egg',
#  'share',
#  'caught',
#  'texa',
#  'note',
#  'da',
#  'case',
#  'shirt',
#  'expens',
#  'question',
#  'lie',
#  'type',
#  'especi',
#  'perfect',
#  'math',
#  'cheer',
#  'neck',
#  'wife',
#  'daughter',
#  'fire',
#  'count',
#  'prob',
#  'feed',
#  'degre',
#  'black',
#  'fml',
#  'wednesday',
#  'pray',
#  'roll',
#  'number',
#  'appl',
#  'somewher',
#  'add',
#  'realis',
#  'shut',
#  'yanke',
#  'bag',
#  'spam',
#  'entir',
#  'chuck',
#  'ear',
#  'fat',
#  'voic',
#  'radio',
#  'hero',
#  'bird',
#  'screw',
#  'arriv',
#  'art',
#  'bet',
#  'wide',
#  'chees',
#  'worth',
#  'quick',
#  'green',
#  'button',
#  'beat',
#  'aint',
#  'screen',
#  'infect',
#  'paint',
#  'darn',
#  'group',
#  'lil',
#  'gorgeous',
#  'tear',
#  'burnt',
#  'forget',
#  'blood',
#  'smoke',
#  'kutner',
#  'mention',
#  'direct',
#  'chicago',
#  'macbook',
#  'couldnt',
#  'bc',
#  'tom',
#  'mouth',
#  'nick',
#  'meant',
#  'absolut',
#  'coz',
#  'memori',
#  'cuddl',
#  'area',
#  'vet',
#  'mother',
#  'normal',
#  'holi',
#  'cd',
#  'dm',
#  'bitch',
#  'san',
#  'ala',
#  'system',
#  'perform',
#  'track',
#  'hmmm',
#  'clear',
#  'middl',
#  'tonit',
#  'canada',
#  'becom',
#  'afraid',
#  'dread',
#  'fish',
#  'uh',
#  'twilight',
#  'beer',
#  'contact',
#  'mobil',
#  'given',
#  'special',
#  'bday',
#  'ng',
#  'replac',
#  'stream',
#  'front',
#  'prepar',
#  'apart',
#  'jonathanrknight',
#  'experi',
#  'bill',
#  'edit',
#  'histori',
#  'child',
#  'code',
#  'tough',
#  'bro',
#  'men',
#  'copi',
#  'silli',
#  'doubt',
#  'camp',
#  'ahead',
#  'alarm',
#  'law',
#  'afford',
#  'proper',
#  'migrain',
#  'shitti',
#  'profil',
#  'self',
#  'land',
#  'error',
#  'mark',
#  'fault',
#  'bowl',
#  'shift',
#  'charg',
#  'starbuck',
#  'awwww',
#  'laundri',
#  'teeth',
#  'price',
#  'pair',
#  'evil',
#  'act',
#  'wasnt',
#  'clock',
#  'angel',
#  'xxx',
#  'remind',
#  'fill',
#  'reach',
#  'product',
#  'attempt',
#  'dammit',
#  'cousin',
#  'honey',
#  'chill',
#  'gross',
#  'machin',
#  'cabl',
#  'forc',
#  'xoxo',
#  'imagin',
#  'hip',
#  'ignor',
#  'major',
#  'soup',
#  'husband',
#  'twit',
#  'wine',
#  'coursework',
#  'result',
#  'guitar',
#  'paid',
#  'ny',
#  'woman',
#  'interview',
#  'key',
#  'bank',
#  'access',
#  '_',
#  'net',
#  'weight',
#  'vega',
#  'accid',
#  ...]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here
words1 = list(wordfreq.keys())
def find_features(words1):
    
    words = set(words1)
    features = {}
    for w in top5000:
        features[w] = (w in words)
        
    return features

# %%
df = data2['text_processed'].apply(lambda row: find_features(row))

# %%
print(df)
# Out:
# 0        {'go': False, 'work': False, 'get': False, 'wa...
# 1        {'go': False, 'work': False, 'get': False, 'wa...
# 2        {'go': True, 'work': False, 'get': False, 'wa'...
# 3        {'go': False, 'work': False, 'get': False, 'wa...
# 4        {'go': False, 'work': False, 'get': False, 'wa...
#                                ...
# 19995    {'go': True, 'work': True, 'get': False, 'wa':...
# 19996    {'go': False, 'work': False, 'get': False, 'wa...
# 19997    {'go': False, 'work': False, 'get': False, 'wa...
# 19998    {'go': False, 'work': False, 'get': False, 'wa...
# 19999    {'go': False, 'work': False, 'get': True, 'wa'...
# Name: text_processed, Length: 20000, dtype: object

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
