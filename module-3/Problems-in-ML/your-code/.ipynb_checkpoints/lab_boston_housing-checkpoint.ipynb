# %% [markdown]
# # Understanding Over & Underfitting
# ## Predicting Boston Housing Prices

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %% [markdown]
# ---
# ## Data Exploration
# Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %%
# Your code here
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
boston = pd.read_csv('../data/boston_data.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 1  0.10328  25.0   5.13   0.0  0.453  5.927  47.2  6.9320  8.0  284.0
# 2  0.34940   0.0   9.90   0.0  0.544  5.972  76.7  3.1025  4.0  304.0
# 3  2.73397   0.0  19.58   0.0  0.871  5.597  94.9  1.5257  5.0  403.0
# 4  0.04337  21.0   5.64   0.0  0.439  6.115  63.0  6.8147  4.0  243.0
#
#    ptratio   black  lstat  medv
# 0     19.2  376.94   9.88  21.7
# 1     19.7  396.90   9.22  19.6
# 2     18.4  396.24   9.97  20.3
# 3     14.7  351.85  21.45  15.4
# 4     16.8  393.97   9.43  20.5

# %%
boston.info
# Out:
# <bound method DataFrame.info of          crim    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0     0.15876   0.0  10.81   0.0  0.413  5.961   17.5  5.2873   4.0  305.0
# 1     0.10328  25.0   5.13   0.0  0.453  5.927   47.2  6.9320   8.0  284.0
# 2     0.34940   0.0   9.90   0.0  0.544  5.972   76.7  3.1025   4.0  304.0
# 3     2.73397   0.0  19.58   0.0  0.871  5.597   94.9  1.5257   5.0  403.0
# 4     0.04337  21.0   5.64   0.0  0.439  6.115   63.0  6.8147   4.0  243.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 399   9.32909   0.0  18.10   0.0  0.713  6.185   98.7  2.2616  24.0  666.0
# 400  51.13580   0.0  18.10   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 401   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850   1.0  198.0
# 402   0.02055  85.0   0.74   0.0  0.410  6.383   35.7  9.1876   2.0  313.0
# 403   0.08244  30.0   4.93   0.0  0.428  6.481   18.5  6.1899   6.0  300.0
#
#      ptratio   black  lstat  medv
# ...

# %%
#checking data for missing values
boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
# There are 14 attributes in each case of the dataset. They are:
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's

# %%
# to visualize and to check for outliers
boston.hist(bins=15, figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A9AF813220>,
# ...
#       dtype=object)

# %%
boston.boxplot(figsize=(20,10), color='blue')

# %%
boston.boxplot (column= ['crim', 'black'],color='blue')

# %% [markdown]
# ### Next, we want to explore the data. Pick several varibables you think will be ost correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %%
# Your plots here
import seaborn as sns
corr = boston.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot=True)

# %% [markdown]
# parameteres most correlated with price:
#
# positively correlated  : tax, rad, rm
#  are negatively correlated : CRim,lstat,zn

# %%
x = boston['tax']
y = boston['medv']
m, b = np. polyfit(x, y, 1) #m = slope, b = intercept.
plt. plot(x, y, 'o') #create scatter plot.
plt. plot(x, m*x + b) #add line of best fit.
plt.title('TAX VS. MEDV')
# Out:
# Text(0.5, 1.0, 'TAX VS. MEDV')

# %%
x = boston['crim']
y = boston['medv']
m, b = np. polyfit(x, y, 1) #m = slope, b = intercept.
plt. plot(x, y, 'o') #create scatter plot.
plt. plot(x, m*x + b) #add line of best fit.
plt.title('CRIME VS. MEDV')
# Out:
# Text(0.5, 1.0, 'CRIME VS. MEDV')

# %%
x = boston['zn']
y = boston['medv']
m, b = np. polyfit(x, y, 1) #m = slope, b = intercept.
plt. plot(x, y, 'o') #create scatter plot.
plt. plot(x, m*x + b) #add line of best fit.
plt.title('Zone VS. MEDV')
# Out:
# Text(0.5, 1.0, 'Zone VS. MEDV')

# %%
x = boston['lstat']
y = boston['medv']
m, b = np. polyfit(x, y, 1) #m = slope, b = intercept.
plt. plot(x, y, 'o') #create scatter plot.
plt. plot(x, m*x + b) #add line of best fit.
plt.title('lstat VS. MEDV')
# Out:
# Text(0.5, 1.0, 'lstat VS. MEDV')

# %%
x = boston['age']
y = boston['medv']
m, b = np. polyfit(x, y, 1) #m = slope, b = intercept.
plt. plot(x, y, 'o') #create scatter plot.
plt. plot(x, m*x + b) #add line of best fit.
plt.title('AGE VS. MEDV')
# Out:
# Text(0.5, 1.0, 'AGE VS. MEDV')

# %%
x = boston['rm']
y = boston['medv']
m, b = np. polyfit(x, y, 1) #m = slope, b = intercept.
plt. plot(x, y, 'o') #create scatter plot.
plt. plot(x, m*x + b) #add line of best fit.
plt.title('Room VS. MEDV')
# Out:
# Text(0.5, 1.0, 'Room VS. MEDV')

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?

# %%
# Your response here

# Several Series have direct correlation with MEDV :
#- the number of room generates a straight linear correlation with MEDV
# as well the ZN - proportion of residential land zoned for lots over 25,000 sq.ft.

#Several Series have negative correlation with MEDV :
# Crim (which seems logical, the less crime in an area, the higher the price of a house)
#

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
# Your response here

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
# Your code here

boston['medv'].describe()
# Out:
# count    404.000000
# mean      22.312376
# std        8.837019
# min        5.000000
# 25%       17.100000
# 50%       21.400000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %% [markdown]
# ----
#
# ## Developing a Model

# %% [markdown]
# ### Implementation: Define a Performance Metric
# What is the performance meteric with which you will determine the performance of your model? Create a function that calculates this performance metric, and then returns the score.

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    # Your code here:
    R2D2 = r2_score(y_true, y_predict)
    
    return R2D2

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the traing and test.

# %%
# Your code here
from sklearn.model_selection import train_test_split

# %%
medv_target = boston['medv']
features_boston = boston.drop(columns='medv')
X_train, X_test, y_train, y_test = train_test_split(features_boston, medv_target, test_size=0.2, shuffle=True)

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
# Five separate RFR here with the given max depths
list_depth = [2, 4, 6, 8, 10]

# %%
#training both on X_Train & X_Test

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
# Produce a plot with the score for the testing and training for the different max depths
# Creating a for loop for each elem in list_depth to test the RandomForest on each max_depth parameter (for train & test sets)
# then appending the results to 2 different lists to then compare & plot their differences in performance score
# X, y = make_regression(n_features=4, n_informative=2,
# ...                        random_state=0, shuffle=False)
# >>> regr = RandomForestRegressor(max_depth=2, random_state=0)
# >>> regr.fit(X, y)
# RandomForestRegressor(...)
# >>> print(regr.predict([[0, 0, 0, 0]]))



rf_X_train_score = []
rf_X_test_score = []

for i in list_depth:
    rf_train = RandomForestRegressor(max_depth = i , random_state=42)
    rf_train.fit(X_train, y_train)
    ytrain_predict = rf_train.predict(X_train)
    print(f'the accuracy of the RF Train with a max depth of {rf_train.max_depth} is of',performance_metric(y_train, ytrain_predict))
    rf_X_train_score.append(performance_metric(y_train, ytrain_predict))

    rf_test = RandomForestRegressor(max_depth = i , random_state=42)
    rf_test.fit(X_test, y_test)
    ytest_predict = rf_train.predict(X_test)
    print(f'the accuracy of the RF Test with a max depth of {rf_test.max_depth} is of',performance_metric(y_test, ytest_predict))
    rf_X_test_score.append(performance_metric(y_test, ytest_predict))
    print('-------------')
# Out:
# the accuracy of the RF Train with a max depth of 2 is of 0.7705062790804585
# the accuracy of the RF Test with a max depth of 2 is of 0.8059263662746597
# -------------
# the accuracy of the RF Train with a max depth of 4 is of 0.9063173482390435
# the accuracy of the RF Test with a max depth of 4 is of 0.8660319004778037
# -------------
# the accuracy of the RF Train with a max depth of 6 is of 0.9504302895339669
# the accuracy of the RF Test with a max depth of 6 is of 0.8861826890633686
# -------------
# the accuracy of the RF Train with a max depth of 8 is of 0.9658958781622873
# the accuracy of the RF Test with a max depth of 8 is of 0.8931946993913276
# -------------
# the accuracy of the RF Train with a max depth of 10 is of 0.9706787101349729
# the accuracy of the RF Test with a max depth of 10 is of 0.8958668919802799
# -------------

# %%
rf_X_train_score
# Out:
# [0.7705062790804585,
#  0.9063173482390435,
#  0.9504302895339669,
#  0.9658958781622873,
#  0.9706787101349729]

# %%
plt.figure(figsize=(20,10))
plt.plot(list_depth, rf_X_train_score, c='b', label='perf score train model')
plt.plot(list_depth, rf_X_test_score, c='r' ,label='perf score test model')

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %% [markdown]
# # Your response here
# # Up to 4 in max_depth, there is an important difference between the two models ; after 4 levels of depth, the test set RF
# #reached a plateau in performance, which indicates that adding more depth does not increase the accuracy
#
# # the train set RF keeps increasing its accuracy past 4 levels of depth, which seems to indicate overfitting for the train set RF

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %%
# Your response here
rf1 = RandomForestRegressor(max_depth=1)
rf1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=1)

# %%
y_predict1 = rf1.predict(X_test)
print (f'the accuracy of the random forest for  {rf1.max_depth} is of',performance_metric(y_test, y_predict1))
# Out:
# the accuracy of the random forest for  1 is of 0.605952150536368

# %%
rf10 = RandomForestRegressor(max_depth=10)
rf10.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10)

# %%
y_predict10 = rf10.predict(X_test)
print (f'the accuracy of the random forest for {rf10.max_depth} is of',performance_metric(y_test, y_predict10))
# Out:
# the accuracy of the random forest for 10 is of 0.8909502745559229

# %% [markdown]
# The performance metrics is much higher when the Random forest is tested with 10 max_depth

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Run your model and explain its performance.

# %%
# Your response here

rf_i = []
for i in range(1,13):
    rf = RandomForestRegressor(max_depth=i)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    perf = performance_metric(y_test, y_pred)
    print(f'the performance with of the RFR with a max_depth of {rf.max_depth} is of', perf)
    rf_i.append(perf)
# Out:
# the performance with of the RFR with a max_depth of 1 is of 0.5866699818630808
# the performance with of the RFR with a max_depth of 2 is of 0.8045320656973918
# the performance with of the RFR with a max_depth of 3 is of 0.855399410173727
# the performance with of the RFR with a max_depth of 4 is of 0.8578336559921349
# the performance with of the RFR with a max_depth of 5 is of 0.8816022762510168
# the performance with of the RFR with a max_depth of 6 is of 0.8884499618563992
# the performance with of the RFR with a max_depth of 7 is of 0.8874868698565657
# the performance with of the RFR with a max_depth of 8 is of 0.9017309630132785
# the performance with of the RFR with a max_depth of 9 is of 0.8884081831677832
# the performance with of the RFR with a max_depth of 10 is of 0.8817250327338001
# the performance with of the RFR with a max_depth of 11 is of 0.890638382850022
# the performance with of the RFR with a max_depth of 12 is of 0.8986257325694781

# %%
#Top performer is max depth 8

# %% [markdown]
# ### Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %%
# Your response here

#How relevant today is data that was collected from 1978?
#Probably the dats is not too relevant as a lot of time has passed and economic, social parameteres have changed a lot

# Are the features present in the data sufficient to describe a home?

# Several other features would be appreciated to make the model more robust, e.g. number of services nearby,
# quality of schools, distance to city centre, size of living areas


# the predictions scores are no higher than 75, which does not make it a total errorless model, 
# but it is quite reliable to make predictions

# Would data collected in an urban city like Boston be applicable in a rural city?
# Each city may need its own parameters to make predictions. Rrural cities would certainly have different
# criteria & features needed to predict its housing prices
