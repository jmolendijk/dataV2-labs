# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# %%
standdata = pd.read_csv('standarddata.csv')
standdata
# Out:
#         month      FFMC       DMC        DC       ISI      temp        RH  \
# 0   -1.321897 -0.805959 -1.323326 -1.830477 -0.860946 -1.842640  0.411724
# 1    1.042880 -0.008102 -1.179541  0.488891 -0.509688 -0.153278 -0.692456
# 2    1.042880 -0.008102 -1.049822  0.560715 -0.509688 -0.739383 -0.692456
# 3   -1.321897  0.191362 -1.212361 -1.898266 -0.004756 -1.825402  3.233519
# 4   -1.321897 -0.243833 -0.931043 -1.798600  0.126966 -1.291012  3.356206
# ..        ...       ...       ...       ...       ...       ...       ...
# 512 -0.139508 -1.640083 -0.846648  0.474768 -1.563460  1.536084 -0.753800
# 513 -0.139508 -1.640083 -0.846648  0.474768 -1.563460  0.519019  1.638592
# 514 -0.139508 -1.640083 -0.846648  0.474768 -1.563460  0.398350  1.577248
# 515 -0.139508  0.680957  0.549003  0.269382  0.500176  1.156839 -0.140366
# 516  1.042880 -2.020879 -1.685913 -1.780442 -1.739089 -1.222058 -0.815143
#
#          wind      rain  MeanFire  IQRFire  day
# ...

# %%
# Taken from https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60

x = standdata.drop(columns=['MeanFire','IQRFire'])

pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2', 'principal component 3'])

finalDF = pd.concat([principalDf, standdata[['IQRFire']]], axis = 1)
finalDF
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                 3.550571              -0.578462               0.670867
# 1                -0.341843               0.561231              -1.860818
# 2                -0.127387               0.712793              -1.554706
# 3                 3.184722               0.741173               2.025246
# 4                 2.789602               1.248458               1.060036
# ..                     ...                    ...                    ...
# 512               0.339597               0.575153              -2.078221
# 513               1.451509               1.618613               0.190045
# 514               1.563289               1.465669               0.451903
# 515              -1.196006              -0.558827               0.130355
# 516               2.709289               0.373327              -1.585073
#
#      IQRFire
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.35879713, 0.15236413, 0.13590213])
