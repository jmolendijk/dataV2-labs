# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Data1.csv')
data
# Out:
#      month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain      area
# 0        2    1  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0  0.000000
# 1        4    0  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0  0.000000
# 2        4    1  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0  0.000000
# 3        2    1  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2  0.000000
# 4        2    1  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0  0.000000
# ..     ...  ...   ...    ...    ...   ...   ...  ..   ...   ...       ...
# 512      3    1  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0  2.006871
# 513      3    1  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  4.012592
# 514      3    1  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  2.498152
# 515      3    1  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0  0.000000
# 516      4    0  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0  0.000000
#
# [517 rows x 11 columns]

# %%
dataoutput = data['area']
datainput = data.drop(columns=['area'])
normalized_input = tf.keras.utils.normalize(datainput)

# %%
X = normalized_input
y = dataoutput

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(8, activation=tf.nn.softmax)) #8 different sizes of fire.

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Layer flatten_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 13/13 [==============================] - 0s 2ms/step - loss: 1.8002 - accuracy: 0.4843
# Epoch 2/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.3527 - accuracy: 0.4843
# Epoch 3/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2836 - accuracy: 0.4843
# Epoch 4/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2716 - accuracy: 0.4843
# Epoch 5/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2730 - accuracy: 0.4843
# Epoch 6/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2562 - accuracy: 0.4843
# Epoch 7/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2591 - accuracy: 0.4843
# Epoch 8/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2592 - accuracy: 0.4843
# Epoch 9/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2508 - accuracy: 0.4843
# Epoch 10/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2508 - accuracy: 0.4843
# Epoch 11/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2537 - accuracy: 0.4843
# Epoch 12/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2520 - accuracy: 0.4843
# Epoch 13/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2498 - accuracy: 0.4843
# Epoch 14/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2531 - accuracy: 0.4843
# Epoch 15/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2567 - accuracy: 0.4843
# Epoch 16/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2526 - accuracy: 0.4843
# Epoch 17/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2494 - accuracy: 0.4843
# Epoch 18/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2526 - accuracy: 0.4770
# Epoch 19/20
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2426 - accuracy: 0.4843
# Epoch 20/20
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2427 - accuracy: 0.4843

# %%
val_loss, val_acc = model.evaluate(X_test, y_test)
# Out:
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2233 - accuracy: 0.3438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 962us/step - loss: 1.2999 - accuracy: 0.4423
