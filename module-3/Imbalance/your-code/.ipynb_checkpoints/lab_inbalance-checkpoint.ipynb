# %% [markdown]
# # Inbalanced Classes
# ## In this lab, we are going to explore a case of imbalanced classes.
#
#
# Like we disussed in class, when we have noisy data, if we are not careful, we can end up fitting our model to the noise in the data and not the 'signal'-- the factors that actually determine the outcome. This is called overfitting, and results in good results in training, and in bad results when the model is applied to real data. Similarly, we could have a model that is too simplistic to accurately model the signal. This produces a model that doesnt work well (ever).

# %% [markdown]
# ### First, download the data from: https://www.kaggle.com/ntnu-testimon/paysim1. Import the dataset and provide some discriptive statistics and plots. What do you think will be the important features in determining the outcome?

# %%
# Your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../dataset.csv')

# %%
data
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
data_corr = data.corr()
fix , ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(data_corr, annot=True)

# All columns are verly lowly correlated so this does not give us any insight in what variable will play an important role
# in determining fraud or not. Out of intuition I would guess the Type & Name destination of money will play a big role in
# determining fraud.

# %% [markdown]
# ### What is the distribution of the outcome?

# %%
# Your response here
data['isFraud'].value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
data['isFlaggedFraud'].value_counts()

# We can already see here that very little transactions are flagged as fraud.
# Out:
# 0    6362604
# 1         16
# Name: isFlaggedFraud, dtype: int64

# %%
data.dtypes

# Type as categorical value we can deal with since there are only 4 possible types.
# NameOrig and Namedest we will have to drop for our models since there are way too many possibilities.
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %% [markdown]
# ### Clean the dataset. How are you going to integrate the time variable? Do you think the step (integer) coding in which it is given is appropriate?

# %%
# Your code here
# Checking for null values
data.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
# Checking for outliers & NOT deleting outliers since financial wise it is normal there are outliers (very rich & poor)

# Q1 = data.quantile(0.25)
# Q3 = data.quantile(0.75)
# IQR = Q3 - Q1

# data_new = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]
# data_new
# Out:
#          step     type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1  PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1           1  PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 4           1  PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5           1  PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6           1  PAYMENT   7107.77   C154988899      183195.00       176087.23
# ...       ...      ...       ...          ...            ...             ...
# 6259906   601  PAYMENT      3.04   C960748220       25287.00        25283.96
# 6259907   601  PAYMENT  13232.49   C737614907       25283.96        12051.47
# 6259908   601  PAYMENT   2221.70  C2025555227         496.00            0.00
# 6259910   601  PAYMENT   5542.37  C1586821392         465.00            0.00
# 6259911   601    DEBIT   4205.96  C1666975703       10856.00         6650.04
#
# ...

# %%
data['type'].value_counts()
# Out:
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: type, dtype: int64

# %%
# We are dropping categorical columns nameOrig & nameDest since they have too many possibilities. We could try to delete all
# the numbers and keep the letters in front of them and convert it to a dummy variabel (m=1 no m=0) but since we don't know
# what these letters mean we are opting to drop them.

data = data.drop(columns=['nameOrig','nameDest'])

# %%
# For the categorical column 'Type' we will make a distinction between cash and no cash transfers, because my intuition tells me
# cash is the most sketchy form of payment when it comes to trying to detect fraud.

def cash_function(string):
    cashcount = 0
    if "CASH" in (string):
        cashcount =+ 1
    
    return cashcount

data['type'] = data['type'].apply(lambda row: cash_function(row))
data
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1     0     9839.64      170136.00       160296.36
# 1           1     0     1864.28       21249.00        19384.72
# 2           1     0      181.00         181.00            0.00
# 3           1     1      181.00         181.00            0.00
# 4           1     0    11668.14       41554.00        29885.86
# ...       ...   ...         ...            ...             ...
# 6362615   743     1   339682.13      339682.13            0.00
# 6362616   743     0  6311409.28     6311409.28            0.00
# 6362617   743     1  6311409.28     6311409.28            0.00
# 6362618   743     0   850002.52      850002.52            0.00
# 6362619   743     1   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                  0.00            0.00        0               0
# 1                  0.00            0.00        0               0
# ...

# %%
data['type'].value_counts()
# Out:
# 1    3636784
# 0    2725836
# Name: type, dtype: int64

# %% [markdown]
# ### Run a logisitc regression classifier and evaluate its accuracy.

# %%
# Your code here

# https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = data.drop(columns=['isFraud'])
y = data['isFraud']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

model.score(X_train, y_train)

# Accuracy is way too big due to the imbalance.
# Out:
# 0.9983078249735696

# %%
# import sys
# !{sys.executable} -m pip install imblearn
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from collections import Counter

X = data.drop(columns=['isFraud'])
y = data['isFraud']

oversample = SMOTE()
X, y = oversample.fit_resample(X,y)

counter = Counter(y)
print(counter) # Now we created extra examples of the minority case, so risk of overfitting.

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

model_smote = LogisticRegression()
model_smote.fit(X_train, y_train)

model_smote.score(X_train, y_train)

# %%
model_smote.score(X_test, y_test)
# Out:
# 0.9066216711297103

# %%
X = data.drop(columns=['isFraud'])
y = data['isFraud']

undersample = NearMiss()
X, y = undersample.fit_resample(X,y)

counter = Counter(y)
print(counter) # Now we removed a lot of the majority cases, risk of losing a lot of information.

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

model_nearmiss = LogisticRegression()
model_nearmiss.fit(X_train, y_train)

model_nearmiss.score(X_train, y_train)
# Out:
# Counter({0: 8213, 1: 8213})
# C:\Users\svvan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9818978813215359

# %%
model_nearmiss.score(X_test, y_test)
# Out:
# 0.9819819819819819

# %% [markdown]
# ### Now pick a model of your choice and evaluate its accuracy.

# %%
# Your code here

# %% [markdown]
# ### Which model worked better and how do you know?

# %%
# Your response here

# The undersampling worked way better we can deduce that out of the scores.
# We must keep in mind that undersampling involves giving up a lot of information, we went from 6.000.000+ records to 8200.
