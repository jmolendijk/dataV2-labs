# %%
import pandas as pd
import numpy as np

# %%
density = pd.read_csv('population_density.csv')
density
# Out:
#     Country/Region                Province/State  density mostdensecity
# 0        Australia         From Diamond Princess  26604.0             -
# 1           Canada                Grand Princess  26604.0             -
# 2            China                     Hong Kong   6659.0             -
# 3            China                         Macau  21340.0             -
# 4      Cruise Ship              Diamond Princess  26604.0             -
# ..             ...                           ...      ...           ...
# 279             US                      Kentucky    910.0    Louisville
# 280             US                        Oregon   1874.0      Portland
# 281             US                  South Dakota    881.0   Sioux Falls
# 282             US  United States Virgin Islands   1878.9    Frenchtown
# 283             US                Virgin Islands   1878.9    Frenchtown
#
# [284 rows x 4 columns]

# %%
density = density.loc[density['Country/Region'] == 'US']
density.sort_values(by=['density'], ascending=False)
# Out:
#     Country/Region                Province/State  density      mostdensecity
# 249             US                      New York  27799.0          Manhattan
# 18              US              Diamond Princess  26604.0                  -
# 19              US                Grand Princess  26604.0                  -
# 240             US                    New Jersey  23394.0         Guttenberg
# 236             US                        Hawaii  15989.1         Mōʻiliʻili
# 230             US                   Puerto Rico  11907.4     Santa Teresita
# 255             US                    California   7286.0      San Francisco
# 232             US                      Delaware   6269.3    Cleland Heights
# 263             US                 Massachusetts   5472.0             Boston
# 237             US                       Florida   4969.0              Miami
# 259             US                      Illinois   4612.0            Chicago
# ...
