# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# # UNDERSTANDING THE DUTCH BEER-DRINKING PATTERN

# %% [markdown]
# ## DATASETS
#
# ### In .csv
# - BeerPCT in TOTAL alcohol consumption per person per year per country (1964-1984-2014
# - Beer consumption per person per country(in liters of pure alcohol: 1L of beer = 0.05L of pure alcohol)(1961-2013)
# - Weather in NL per year(1960-2014)
# - Happiness indicator per share (of people self declaring it)
# - Unemploymentrate NL (1960-2013)
# - Consumer index prices for : Beer, Cheese, Milk, Bread 2000-2018
# - Average price of goods for : beer, cheese, bread, potatoes
#
# - Gender Ratio (adulthood) per country
# - Beer consumption per gender per country but only for 2010
#
#
# ### Extra Info NL
# - Tax info on alcoholic beverages NL: 0.03% since 1992
# - 1980 Queen Beatrix reign starts => disturbances in the country
# - 1973,79,2018 Oil crisis affecting the country --> does it shows
# - Worldcups:
#     - runners-up in 1974,1978,2010--> does it show?
#     - 1980 The Dutch football team qualified for the euro cup, and one of the best games against Germany (so it seems)
#     - 1988 winners of UEFA--> does it show?

# %% [markdown]
# ## CREATING A MySQL DB

# %%
#I created one in SequelPRO

# %% [markdown]
# ### Summary of Tables Created:
#     -SHARE_BEERNL : % total alcohol consumption in the NL
#     -BEERNL: Beer comsumption of beer in Liters (of pure alcohol = 0.05/L)
#     -WEATHERNL: AVG per Year, AVG per summer/Winter, Precipitation
#     -HAPPYNL : Share of the people, in NL that self proclaim to be happy
#     -UNEMPLOYMENTNL : unemployment rate in NL
#     -INDEX_PRICESNL : index price change of Beer, Milk/Cheese, Bread
#     -PRICENL : AVG price of Beer, Potatoes, Milk/Cheese
#     -GENDERNL :
#
# #### To create
#
# In SQLITE
# Import Sqlite
#
# c.execute('CREATE TABLE WEATHERNL ([generated_id] integer primary key, [Entity text], [Year] text, [Wine_pct_total_alcohol] number, [Beer_pct_total_alcohol] number, [Spirits_pct_total_alcohol] number)')
# conn.commit()
#
# In SequelPRO
# import pymysql
# from sqlalchemy import create_engine
#
# #### To add(if SqLite is used:
# In SqLite
# share_beer.to_sql('SHARE_BEERNL', conn, if_exists='append', index = False)
#
# In SequelPRO
# data6.to_sql('authors2', engine, if_exists='replace', index=False)
#
# #### To read
#
# In SequelPRO
# import pymysql
# from sqlalchemy import create_engine
#
# engine = create_engine('mysql+pymysql://student:IHisCool!@34.77.233.175:3306/publications')
# fromsql = '''select au_id, au_lname, au_fname
# from authors
# '''
# authors = pd.read_sql_query(fromsql,engine)
# authors

# %%
engine = create_engine('mysql+pymysql://root:     @127.0.0.1:3306/M2_StoryTelling_Beer') 
connection = engine.raw_connection()

# %% [markdown]
# ## CLEANING DATA

# %% [markdown]
# ### SHARE OF BEER IN TOTAL ALCOHOL CONSUMPTION

# %%
#0_ BeerPCT in TOTAL alcohol consumption

alcohol_pct = pd.read_csv('data/alcohol-by-type-1890.csv')
alcohol_pct
alcohol_pct = alcohol_pct.loc[alcohol_pct['Year']>1960]
share_beer = alcohol_pct.loc[alcohol_pct['Entity']=='Netherlands']
share_beer.index = share_beer.Entity

# %%
share_beer = share_beer.drop(['Code','Entity'], axis=1)

# %%
share_beer = share_beer.reset_index()
share_beer.columns = ['Entity','Year','Wine_pct_total_alcohol','Beer_pct_total_alcohol','Spirits_pct_total_alcohol']
share_beer
# Out:
#         Entity  Year  Wine_pct_total_alcohol  Beer_pct_total_alcohol  \
# 0  Netherlands  1964                       9                      48
# 1  Netherlands  1984                      22                      49
# 2  Netherlands  2014                      35                      48
#
#    Spirits_pct_total_alcohol
# 0                         43
# 1                         29
# 2                         17

# %%
#Saving .csv

share_beer.to_csv('data/share_beer.csv', index=False)

# %%
#Insert the DF in the Table:

share_beer.to_sql('SHARE_BEER',engine, if_exists='append', index = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-458-fc282745335b> in <module>
#       1 #Insert the DF in the Table:
#       2
# ----> 3 share_beer.to_sql('SHARE_BEER',engine, if_exists='append', index = False)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# /usr/local/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# /usr/local/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1825             dtype=dtype,
#    1826         )
# -> 1827         table.create()
#    1828         table.insert(chunksize, method)
#    1829
#
# /usr/local/lib/python3.9/site-packages/pandas/io/sql.py in create(self)
#     719
#     720     def create(self):
# --> 721         if self.exists():
#     722             if self.if_exists == "fail":
#     723                 raise ValueError(f"Table '{self.name}' already exists.")
#
# /usr/local/lib/python3.9/site-packages/pandas/io/sql.py in exists(self)
#     706
#     707     def exists(self):
# --> 708         return self.pd_sql.has_table(self.name, self.schema)
#     709
#     710     def sql_schema(self):
#
# /usr/local/lib/python3.9/site-packages/pandas/io/sql.py in has_table(self, name, schema)
#    1836         query = f"SELECT name FROM sqlite_master WHERE type='table' AND name={wld};"
#    1837
# -> 1838         return len(self.execute(query, [name]).fetchall()) > 0
#    1839
#    1840     def get_table(self, table_name, schema=None):
#
# /usr/local/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1677             cur = self.con
#    1678         else:
# -> 1679             cur = self.con.cursor()
#    1680         try:
#    1681             cur.execute(*args, **kwargs)
#
# AttributeError: 'Engine' object has no attribute 'cursor'

# %% [markdown]
# #### Plotting this with a pie chart

# %%
# years = [1964,1984,2014]

# my_labels = ['Wine (% total alcohol)','Beer (% total alcohol)','Spirits (% total alcohol)']
# plt.pie(my_data, labels= my_labels, autopct='%1.1f%%')
# plt.title('beer consumption share in the Total consumption of alcoholic beverages in',i)
# plt.axis('equal')
# plt.show()

# %% [markdown]
# ### BEER CONSUMPTION PER CAPITAL (in L of pure alcohol=0.05)

# %%
#1- Beer consumption in liters for type beer

beer = pd.read_csv('data/beer-consumption-per-person.csv')
beer

beer_NL = beer.loc[(beer['Entity']=='Netherlands')]
beer_NL = beer_NL.drop('Code', axis=1)
beer_NL.columns =('Entity','Year','Consumption')
beer_NL.head()

# BNL = list(beer_NL['Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Beer'])
# len(BNL)
# Missing_values = [0]
# BNL = Missing_values+BNL+Missing_values
# Out:
#            Entity  Year  Consumption
# 5561  Netherlands  1961         1.88
# 5562  Netherlands  1962         1.96
# 5563  Netherlands  1963         2.20
# 5564  Netherlands  1964         2.45
# 5565  Netherlands  1965         2.59

# %%
#Saving .csv

beer_NL.to_csv('data/beer_NL.csv', index=False)

# %%
#To SQL DB

# %% [markdown]
# ### WEATHER IN NL -AVG PER YEAR

# %%
#2 Weather in NL per year
weather = pd.read_csv('data/Climate_data_NL.csv',sep=';')

# %%
#creating a column with the data on previous dataset 
weather['Entity']='Netherlands'
# weather['Beer_consumptionNL'] = BNL
weather.reset_index()
#Periods column was displayed in a bizarre way
weather['Periods'] = weather['Periods'].astype(str).str[:4]
weather = weather.loc[weather['Periods']>'1959']

weather.head()
# Out:
#       ID Periods  YearAverage_1  WinterAverage_2  SummerAverage_3  \
# 0      0    1971            9.8              3.3             16.6
# 1      1    1981           10.1              3.4             17.0
# 162  162    1960            9.6              3.2             15.6
# 163  163    1961            9.8              3.7             15.6
# 164  164    1962            8.1              2.7             14.7
#
#      WinterAverageMinimumTemperature_4  SummerAverageMaximumTemperature_5  \
# 0                                  0.4                               21.4
# 1                                  0.5                               21.9
# 162                                NaN                                NaN
# 163                                NaN                                NaN
# 164                                NaN                                NaN
#
#      IceDays_6  FrostDays_7  SummeryDays_8  ...  QuantityOfPrecipitation_11  \
# 0          8.0         58.0           22.0  ...                       827.0
# 1          8.0         58.0           26.0  ...                       887.0
# 162        5.0         44.0           10.0  ...                       928.0
# 163        9.0         42.0           16.0  ...                       912.0
# 164       13.0         72.0            4.0  ...                       765.0
#
#      DaysWithPrecipitation_12  SnowDays_13  DryDays_14  DaysWithFog_15  \
# 0                       131.0         25.0       109.0            65.0
# 1                       131.0         25.0       122.0            63.0
# 162                       NaN          NaN         NaN             NaN
# 163                       NaN          NaN         NaN             NaN
# 164                       NaN          NaN         NaN             NaN
#
#      Evaporation_16  RelativeHumidity_17  HoursOfSunshine_18  SunlessDays_19  \
# 0             543.0                 82.0              1524.0            76.0
# 1             559.0                 82.0              1602.0            61.0
# 162             NaN                  NaN              1355.0             NaN
# 163             NaN                  NaN              1435.0             NaN
# 164             NaN                  NaN              1398.0             NaN
#
#           Entity
# 0    Netherlands
# 1    Netherlands
# 162  Netherlands
# 163  Netherlands
# 164  Netherlands
#
# [5 rows x 22 columns]

# %%
weather = weather.drop('ID', axis=1)
weather = weather.drop([0,1],axis=0)

# %%
weather.shape
# Out:
# (55, 21)

# %%
#Renaming column for clarity
weather.columns=([
                'Year',
                'AVGTemp_Year',
                'AVGTemp_Winter',
                'AVGTemp_Summer',
                'Winter_min',
                'Summer_max',
                'Nb_IceDays',
                'Nb_FrostDays',
                'Nb_SummerDays',
                'Nb_TropicalDays',
                'Temp_HeatingDegDays',
                'Qty_precipitation',
                'Days_precipitation',
                'Nb_SnowDays',
                'Nb_DryDays',
                'Nb_FoggyDays',
                'Evaporation',
                'PCT_Relative_humidity',
                'Hours_Sunshine',
                'Sunless_days',
                'Entity',
                ])

weather.head()
# Out:
#      Year  AVGTemp_Year  AVGTemp_Winter  AVGTemp_Summer  Winter_min  \
# 162  1960           9.6             3.2            15.6         NaN
# 163  1961           9.8             3.7            15.6         NaN
# 164  1962           8.1             2.7            14.7         NaN
# 165  1963           7.8            -3.1            15.8         NaN
# 166  1964           8.9             1.1            15.8         NaN
#
#      Summer_max  Nb_IceDays  Nb_FrostDays  Nb_SummerDays  Nb_TropicalDays  \
# 162         NaN         5.0          44.0           10.0              NaN
# 163         NaN         9.0          42.0           16.0              NaN
# 164         NaN        13.0          72.0            4.0              NaN
# 165         NaN        42.0          92.0           25.0              NaN
# 166         NaN        11.0          71.0           23.0              NaN
#
#      ...  Qty_precipitation  Days_precipitation  Nb_SnowDays  Nb_DryDays  \
# 162  ...              928.0                 NaN          NaN         NaN
# 163  ...              912.0                 NaN          NaN         NaN
# 164  ...              765.0                 NaN          NaN         NaN
# 165  ...              777.0                 NaN          NaN         NaN
# 166  ...              748.0                 NaN          NaN         NaN
#
#      Nb_FoggyDays  Evaporation  PCT_Relative_humidity  Hours_Sunshine  \
# 162           NaN          NaN                    NaN          1355.0
# 163           NaN          NaN                    NaN          1435.0
# 164           NaN          NaN                    NaN          1398.0
# 165           NaN          NaN                    NaN          1425.0
# 166           NaN          NaN                    NaN          1531.0
#
#      Sunless_days       Entity
# 162           NaN  Netherlands
# 163           NaN  Netherlands
# 164           NaN  Netherlands
# 165           NaN  Netherlands
# 166           NaN  Netherlands
#
# [5 rows x 21 columns]

# %%
#checking types -making sure I will be able to make calculations on the data
weather.dtypes
# Out:
# Year                      object
# AVGTemp_Year             float64
# AVGTemp_Winter           float64
# AVGTemp_Summer           float64
# Winter_min               float64
# Summer_max               float64
# Nb_IceDays               float64
# Nb_FrostDays             float64
# Nb_SummerDays            float64
# Nb_TropicalDays          float64
# Temp_HeatingDegDays      float64
# Qty_precipitation        float64
# Days_precipitation       float64
# Nb_SnowDays              float64
# Nb_DryDays               float64
# Nb_FoggyDays             float64
# Evaporation              float64
# PCT_Relative_humidity    float64
# Hours_Sunshine           float64
# Sunless_days             float64
# Entity                    object
# dtype: object

# %%
#Checking Null values
weather.isnull().sum()
# Out:
# Year                      0
# AVGTemp_Year              0
# AVGTemp_Winter            0
# AVGTemp_Summer            0
# Winter_min               20
# Summer_max               20
# Nb_IceDays                0
# Nb_FrostDays              0
# Nb_SummerDays             0
# Nb_TropicalDays          20
# Temp_HeatingDegDays       0
# Qty_precipitation         0
# Days_precipitation       11
# Nb_SnowDays              20
# Nb_DryDays               21
# Nb_FoggyDays             20
# Evaporation              20
# PCT_Relative_humidity    20
# Hours_Sunshine            0
# Sunless_days             11
# Entity                    0
# dtype: int64

# %%
#Dropping what I don't need and what has too many missing values (compared to rows)
weather = weather.drop(['Temp_HeatingDegDays',
              'Evaporation',
              'Nb_IceDays',
              'Nb_FrostDays',
              'Nb_SnowDays',
              'Nb_DryDays',
              'Nb_TropicalDays',
              'Nb_FoggyDays',
              'PCT_Relative_humidity'
             ], axis=1)

#rearranging columns:
weather = weather[['Entity',
                   'Year',
                   'AVGTemp_Year',
                   'AVGTemp_Winter',
                   'AVGTemp_Summer',
                   'Winter_min',
                   'Summer_max',
                   'Nb_SummerDays',
                   'Hours_Sunshine',
                   'Qty_precipitation',
                   'Days_precipitation',
                   ]]
weather.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-442-6827068be8fc> in <module>
#       1 #Dropping what I don't need and what has too many missing values (compared to rows)
# ----> 2 weather = weather.drop(['Temp_HeatingDegDays',
#       3               'Evaporation',
#       4               'Nb_IceDays',
#       5               'Nb_FrostDays',
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165                 weight  1.0     0.8
#    4166         """
# -> 4167         return super().drop(
#    4168             labels=labels,
#    4169             axis=axis,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "['Temp_HeatingDegDays' 'Evaporation' 'Nb_IceDays' 'Nb_FrostDays'\n 'Nb_SnowDays' 'Nb_DryDays' 'Nb_TropicalDays' 'Nb_FoggyDays'\n 'PCT_Relative_humidity'] not found in axis"

# %%
#I had previously downloaded data with the wrong format, hence commenting the following out

# weather.apply(lambda x: x.str.replace('','.'))
#I need to change the type of the following
# weather['Days_precipitation'].astype('int64')
# weather['Nb_SnowDays'].astype('int')
# weather['Nb_FoggyDays'].astype('int')
# weather['Nb_DryDays'].astype('int')
# weather['PCT_Relative_humidity'].astype('float')
# weather['Sunless_days'].astype('int')

# %%
weather.dtypes
# Out:
# Entity                 object
# Year                   object
# AVGTemp_Year          float64
# AVGTemp_Winter        float64
# AVGTemp_Summer        float64
# Winter_min            float64
# Summer_max            float64
# Nb_SummerDays         float64
# Hours_Sunshine        float64
# Qty_precipitation     float64
# Days_precipitation    float64
# dtype: object

# %%
#Saving .csv

weather.to_csv('data/weather_NL.csv', index=False)

# %%
#Adding info to the MySQL table

# %% [markdown]
# ## GATHERING INFO IN A NEW DATAFRAME

# %%
#creating my data table

dataNL = weather[['Entity',
                  'Year',
                   'AVGTemp_Year',
                   'AVGTemp_Winter',
                   'AVGTemp_Summer',
                   'Winter_min',
                   'Summer_max',
                   'Nb_SummerDays',
                   'Hours_Sunshine',
                   'Qty_precipitation',
                   'Days_precipitation',
                 ]]

dataNL['BeerConsumption'] = BNL

# %%
dataNL['Year'] = pd.to_datetime(dataNL['Year'])
dataNL

dataNL.head()
# Out:
#           Entity       Year  AVGTemp_Year  AVGTemp_Winter  AVGTemp_Summer  \
# 162  Netherlands 1960-01-01           9.6             3.2            15.6
# 163  Netherlands 1961-01-01           9.8             3.7            15.6
# 164  Netherlands 1962-01-01           8.1             2.7            14.7
# 165  Netherlands 1963-01-01           7.8            -3.1            15.8
# 166  Netherlands 1964-01-01           8.9             1.1            15.8
#
#      Winter_min  Summer_max  Nb_SummerDays  Hours_Sunshine  Qty_precipitation  \
# 162         NaN         NaN           10.0          1355.0              928.0
# 163         NaN         NaN           16.0          1435.0              912.0
# 164         NaN         NaN            4.0          1398.0              765.0
# 165         NaN         NaN           25.0          1425.0              777.0
# 166         NaN         NaN           23.0          1531.0              748.0
#
#      Days_precipitation  BeerConsumption
# 162                 NaN             0.00
# 163                 NaN             1.88
# 164                 NaN             1.96
# 165                 NaN             2.20
# 166                 NaN             2.45

# %%
# Out:
#           Entity       Year  AVGTemp_Year  AVGTemp_Winter  AVGTemp_Summer  \
# 183  Netherlands 1981-01-01           9.2             2.6            15.8
#
#      Winter_min  Summer_max  Nb_SummerDays  Hours_Sunshine  Qty_precipitation  \
# 183        -0.2        20.0           14.0          1308.0              992.0
#
#      Days_precipitation  BeerConsumption
# 183               146.0             5.72

# %%
# Out:
#           Entity       Year  AVGTemp_Year  AVGTemp_Winter  AVGTemp_Summer  \
# 216  Netherlands 2014-01-01          11.7             6.0            17.4
#
#      Winter_min  Summer_max  Nb_SummerDays  Hours_Sunshine  Qty_precipitation  \
# 216         3.3        22.0           23.0          1787.0              952.0
#
#      Days_precipitation  BeerConsumption
# 216               124.0              0.0

# %%
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
dataNL.set_index('Year')['AVGTemp_Summer'].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ## DRINK GENDER RATIO

# %%
drink_ratio = pd.read_csv('data/males-vs-females-who-drank-alcohol-in-last-year.csv')
drink_ratio2010 = ratio.loc[(ratio['Entity']=='Netherlands')&(ratio['Year']==2010)]
drink_ratio2010
# Out:
#             Entity Code  Year  Total population (Gapminder, HYDE & UN)  \
# 29172  Netherlands  NLD  2010                               16683000.0
#
#       Continent  Indicator:Alcohol, consumers past 12 months (%) - Sex:Female  \
# 29172       NaN                                               83.6
#
#        Indicator:Alcohol, consumers past 12 months (%) - Sex:Male
# 29172                                               92.9

# %%
ratio_age = pd.read_csv('data/sex-ratio-by-age.csv')
ratio_age
# Out:
#             Entity Code  Year  Sex ratio by age (15 year olds) (UNWPP, 2017)  \
# 0      Afghanistan  AFG  1950                                     110.725960
# 1      Afghanistan  AFG  1951                                     110.239836
# 2      Afghanistan  AFG  1952                                     109.217998
# 3      Afghanistan  AFG  1953                                     108.646649
# 4      Afghanistan  AFG  1954                                     108.700272
# ...            ...  ...   ...                                            ...
# 15901     Zimbabwe  ZWE  2011                                     100.027344
# 15902     Zimbabwe  ZWE  2012                                      99.931326
# 15903     Zimbabwe  ZWE  2013                                      99.923038
# 15904     Zimbabwe  ZWE  2014                                      99.971532
# 15905     Zimbabwe  ZWE  2015                                     100.061274
#
#        Sex ratio by age (20 year olds) (UNWPP, 2017)  \
# 0                                         115.678881
# 1                                         114.390486
# 2                                         112.674319
# 3                                         111.340221
# 4                                         110.692684
# ...                                              ...
# 15901                                      97.947110
# 15902                                      98.144598
# 15903                                      98.270087
# 15904                                      98.312325
# 15905                                      98.386791
#
#        Sex ratio by age (30 year olds) (UNWPP, 2017)  \
# 0                                         118.566663
# 1                                         118.288218
# 2                                         117.518995
# 3                                         117.060109
# 4                                         117.101741
# ...                                              ...
# 15901                                      91.633517
# 15902                                      91.292345
# 15903                                      91.092513
# 15904                                      91.082905
# 15905                                      91.166891
#
#        Sex ratio by age (40 year olds) (UNWPP, 2017)  \
# 0                                         119.636455
# 1                                         119.375972
# 2                                         118.787630
# 3                                         118.236943
# 4                                         117.753065
# ...                                              ...
# 15901                                      92.367246
# 15902                                      93.047464
# 15903                                      93.105930
# 15904                                      92.469114
# 15905                                      91.570857
#
#        Sex ratio by age (50 year olds) (UNWPP, 2017)  \
# 0                                         124.993101
# 1                                         124.586307
# 2                                         123.710621
# 3                                         122.198021
# 4                                         119.957057
# ...                                              ...
# 15901                                      76.861300
# 15902                                      77.717715
# 15903                                      78.739122
# 15904                                      79.989064
# 15905                                      81.394156
#
#        Sex ratio by age (60 year olds) (UNWPP, 2017)  \
# 0                                         130.460824
# 1                                         130.063446
# 2                                         129.190856
# 3                                         127.650155
# 4                                         125.267577
# ...                                              ...
# 15901                                      71.714321
# 15902                                      70.976913
# 15903                                      70.414498
# 15904                                      70.020986
# 15905                                      69.803147
#
#        Sex ratio by age (70 year olds) (UNWPP, 2017)  \
# 0                                         130.004055
# 1                                         129.302326
# 2                                         127.946743
# 3                                         126.501222
# 4                                         125.063549
# ...                                              ...
# 15901                                      77.211796
# 15902                                      76.394269
# 15903                                      75.484262
# 15904                                      74.428774
# 15905                                      73.224739
#
#        Sex ratio by age (80 year olds) (UNWPP, 2017)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 15901                                      71.063352
# 15902                                      71.046431
# 15903                                      71.119331
# 15904                                      71.422764
# 15905                                      71.741453
#
#        Sex ratio by age (90 year olds) (UNWPP, 2017)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 15901                                      61.622992
# 15902                                      61.962693
# 15903                                      61.863743
# 15904                                      60.981496
# 15905                                      59.220146
#
#        Sex ratio by age (100 year olds) (UNWPP, 2017)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 15901                                       39.622642
# 15902                                       38.181818
# 15903                                       36.842105
# 15904                                       37.288136
# 15905                                       37.096774
#
# [15906 rows x 13 columns]

# %%
# Save to .csv

# %%
# Save to MySQL

# %% [markdown]
# # share-of-people-who-say-they-are-happy

# %%
happypeople = pd.read_csv('data/Happiness-Eurobarometer.csv')
happypeople = happypeople.loc[happypeople['Entity']=='Netherlands']
happypeople.head()
# Out:
#           Entity Code  Year  \
# 554  Netherlands  NLD  1973
# 555  Netherlands  NLD  1975
# 556  Netherlands  NLD  1976
# 557  Netherlands  NLD  1977
# 558  Netherlands  NLD  1978
#
#      Share of people who are happy (Eurobarometer 2017)
# 554                                          93.000000
# 555                                          86.175941
# 556                                          90.539238
# 557                                          91.697433
# 558                                          93.160416

# %%
happypeople =happypeople.drop('Code', axis=1)

# %%
happypeople.columns = ['Entity',
                       'Year',
                       'Share_of_happy']
hapypeople.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-462-795a5d28dbe6> in <module>
#       2                        'Year',
#       3                        'Share_of_happy']
# ----> 4 hapypeople.head()
#
# NameError: name 'hapypeople' is not defined

# %%
#Saving .csv

happypeople.to_csv('data/weather_NL.csv', index=False)

# %%
#To MySQL

# %% [markdown]
# # INDEX Price

# %%
#Price level indicesEUR 28 =100
#Exporting from .csv
PxIndex = pd.read_csv('data/Pricelevel_beer.csv')
#cleaning unnecessary data out (keeping only the data on aloholic beverages)
Price_index = PxIndex.loc[PxIndex['PPP_CAT']=='Alcoholic beverages']
Price_index.drop('Flag and Footnotes', axis=1)
# Out:
#       TIME                                                GEO  \
# 5     1995          European Union - 28 countries (2013-2020)
# 14    1995                                            Belgium
# 23    1995                                           Bulgaria
# 32    1995                                            Czechia
# 41    1995                                            Denmark
# ...    ...                                                ...
# 8960  2019                                            Albania
# 8969  2019                                             Serbia
# 8978  2019                                             Turkey
# 8987  2019                             Bosnia and Herzegovina
# 8996  2019  Kosovo (under United Nations Security Council ...
#
#                              NA_ITEM              PPP_CAT  Value
# 5     Price level indices (EU28=100)  Alcoholic beverages      :
# 14    Price level indices (EU28=100)  Alcoholic beverages      :
# 23    Price level indices (EU28=100)  Alcoholic beverages      :
# 32    Price level indices (EU28=100)  Alcoholic beverages      :
# 41    Price level indices (EU28=100)  Alcoholic beverages      :
# ...                              ...                  ...    ...
# 8960  Price level indices (EU28=100)  Alcoholic beverages  103.7
# 8969  Price level indices (EU28=100)  Alcoholic beverages   84.4
# 8978  Price level indices (EU28=100)  Alcoholic beverages  184.6
# 8987  Price level indices (EU28=100)  Alcoholic beverages   71.9
# 8996  Price level indices (EU28=100)  Alcoholic beverages      :
#
# [1000 rows x 5 columns]
