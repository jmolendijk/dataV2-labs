# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA BASES
#
# ### In .csv
# - BeerPCT in TOTAL alcohol consumption per person per year per country
# - Beer consumption per person per country
# - Weather in NL per year
# - Gender Ratio (adulthood) per country
# - Beer consumption per gender per country but only for 2010
# - Happiness indicator per share (of people self declaring it)
#
# ### Manual
# - Tax info on alcoholic beverages NL

# %%
#0_ BeerPCT in TOTAL alcohol consumption

alcohol_pct = pd.read_csv('data/alcohol-by-type-1890.csv')
alcohol_pct
alcohol_pct.loc[alcohol_pct['Year']>1960]
# Out:
#             Entity Code  Year  Wine (% total alcohol)  Beer (% total alcohol)  \
# 2        Australia  AUS  1964                      12                      75
# 3        Australia  AUS  1984                      24                      64
# 4        Australia  AUS  2014                      40                      46
# 5          Austria  AUT  1964                      30                      55
# 6          Austria  AUT  1984                      37                      49
# 7          Austria  AUT  2014                      35                      51
# 10         Belgium  BEL  1964                      13                      77
# 11         Belgium  BEL  1984                      21                      61
# 12         Belgium  BEL  2014                      35                      51
# 13          Canada  CAN  1964                       6                      60
# 14          Canada  CAN  1984                      14                      48
# ...

# %%
#1- Beer consumption in liters for type beer

beer = pd.read_csv('data/beer-consumption-per-person.csv')
beer

beer_NL = beer.loc[(beer['Entity']=='Netherlands')]
beer_NL

BNL = list(beer_NL['Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Beer'])
len(BNL)
Missing_values = [0]
BNL = Missing_values+BNL+Missing_values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-1a7411be40d5> in <module>
#      11 Missing_values = [0]
#      12 BNL = Missing_values+BNL+Missing_values
# ---> 13 BNL = BNL.DataFrame()
#      14
#
# AttributeError: 'list' object has no attribute 'DataFrame'

# %%
#Tool to SQL command

# %%
#2 Weather in NL per year
weather = pd.read_csv('data/Climate_data_NL.csv',sep=';')

weather['Entity']='Netherlands'


# weather.drop(['Temperature/Winter average minimum temperature (degree Celsius)','Temperature/Summer average maximum temperature (degree Celsius)','Precipitation/Evaporation (mm)'],axis=1)
weather['Beer_consumptionNL'] = BNL
weather.head()

weather.dtypes
weather['Temperature/Year average (degree Celsius)'].astype('float')
# weather['Temperature/Winter average (degree Celsius)'].astype(float)
# weather['Temperature/Summer average (degree Celsius)'].astype(float)
# weather['Temperature/Winter average minimum temperature (degree Celsius)'].astype(float)
# weather['Temperature/Summer average maximum temperature (degree Celsius)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-12810e1c73e7> in <module>
#      10
#      11 weather.dtypes
# ---> 12 weather['Temperature/Year average (degree Celsius)'].astype('float')
#      13 # weather['Temperature/Winter average (degree Celsius)'].astype(float)
#      14 # weather['Temperature/Summer average (degree Celsius)'].astype(float)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...

# %%
weather['Temperature/Year average (degree Celsius)'].corr(weather['Beer_consumptionNL'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-1687e0d2a62d> in <module>
# ----> 1 weather['Temperature/Year average (degree Celsius)'].corr(weather['Beer_consumptionNL'])
#
# /usr/local/lib/python3.9/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2331
#    2332         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2333             return nanops.nancorr(
#    2334                 this.values, other.values, method=method, min_periods=min_periods
#    2335             )
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
# ...

# %%
drink_ratio = pd.read_csv('data/males-vs-females-who-drank-alcohol-in-last-year.csv')
drink_ratio2010 = ratio.loc[(ratio['Entity']=='Netherlands')&(ratio['Year']==2010)]
drink_ratio2010
# Out:
#             Entity Code  Year  Total population (Gapminder, HYDE & UN)  \
# 29172  Netherlands  NLD  2010                               16683000.0
#
#       Continent  Indicator:Alcohol, consumers past 12 months (%) - Sex:Female  \
# 29172       NaN                                               83.6
#
#        Indicator:Alcohol, consumers past 12 months (%) - Sex:Male
# 29172                                               92.9

# %%
ratio_age = pd.read_csv('data/sex-ratio-by-age.csv')
ratio_age
# Out:
#             Entity Code  Year  Sex ratio by age (15 year olds) (UNWPP, 2017)  \
# 0      Afghanistan  AFG  1950                                     110.725960
# 1      Afghanistan  AFG  1951                                     110.239836
# 2      Afghanistan  AFG  1952                                     109.217998
# 3      Afghanistan  AFG  1953                                     108.646649
# 4      Afghanistan  AFG  1954                                     108.700272
# ...            ...  ...   ...                                            ...
# 15901     Zimbabwe  ZWE  2011                                     100.027344
# 15902     Zimbabwe  ZWE  2012                                      99.931326
# 15903     Zimbabwe  ZWE  2013                                      99.923038
# 15904     Zimbabwe  ZWE  2014                                      99.971532
# 15905     Zimbabwe  ZWE  2015                                     100.061274
#
# ...

# %%
# share-of-people-who-say-they-are-happy

# %%
happypeople = pd.read_csv('data/Happiness-Eurobarometer.csv')
happypeople.loc[happypeople['Entity']=='Netherlands']
# Out:
#           Entity Code  Year  \
# 554  Netherlands  NLD  1973
# 555  Netherlands  NLD  1975
# 556  Netherlands  NLD  1976
# 557  Netherlands  NLD  1977
# 558  Netherlands  NLD  1978
# 559  Netherlands  NLD  1979
# 560  Netherlands  NLD  1980
# 561  Netherlands  NLD  1981
# 562  Netherlands  NLD  1982
# 563  Netherlands  NLD  1983
# 564  Netherlands  NLD  1984
# 565  Netherlands  NLD  1985
# 566  Netherlands  NLD  1986
# 567  Netherlands  NLD  1987
# 568  Netherlands  NLD  1988
# 569  Netherlands  NLD  1989
# 570  Netherlands  NLD  1990
# 571  Netherlands  NLD  1991
# 572  Netherlands  NLD  1992
# 573  Netherlands  NLD  1993
# 574  Netherlands  NLD  1994
# 575  Netherlands  NLD  1996
# 576  Netherlands  NLD  1997
# 577  Netherlands  NLD  1998
# 578  Netherlands  NLD  1999
# 579  Netherlands  NLD  2000
# 580  Netherlands  NLD  2001
# 581  Netherlands  NLD  2002
# 582  Netherlands  NLD  2003
# 583  Netherlands  NLD  2004
# 584  Netherlands  NLD  2005
# 585  Netherlands  NLD  2006
# ...

# %%
#Price level indicesEUR 28 =100
#Exporting from .csv
PxIndex = pd.read_csv('data/Pricelevel_beer.csv')
#cleaning unnecessary data out (keeping only the data on aloholic beverages)
Price_index = PxIndex.loc[PxIndex['PPP_CAT']=='Alcoholic beverages']
Price_index.drop('Flag and Footnotes', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-228eb1b340f5> in <module>
#       6 Price_index.drop('Flag and Footnotes', axis=1)
#       7
# ----> 8 Price_index.npwhere(Price_index['Value']==':',NaN)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'npwhere'
