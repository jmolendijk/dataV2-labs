# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA BASES
#
# ### In .csv
# - BeerPCT in TOTAL alcohol consumption per person per year per country
# - Beer consumption per person per country
# - Weather in NL per year
# - Gender Ratio (adulthood) per country
# - Beer consumption per gender per country but only for 2010
# - Happiness indicator per share (of people self declaring it)
#
# ### Manual
# - Tax info on alcoholic beverages NL

# %%
#0_ BeerPCT in TOTAL alcohol consumption

alcohol_pct = pd.read_csv('/Users/ajiacovic/Documents/data/miniprojectStory telling/alcohol-by-type-1890.csv')
alcohol_pct
# Out:
#            Entity Code  Year  Wine (% total alcohol)  Beer (% total alcohol)  \
# 0       Australia  AUS  1890                      10                      47
# 1       Australia  AUS  1929                      19                      62
# 2       Australia  AUS  1964                      12                      75
# 3       Australia  AUS  1984                      24                      64
# 4       Australia  AUS  2014                      40                      46
# ..            ...  ...   ...                     ...                     ...
# 61  United States  USA  1890                       4                      47
# 62  United States  USA  1929                       0                       0
# 63  United States  USA  1964                       8                      48
# 64  United States  USA  1984                      13                      51
# 65  United States  USA  2014                      18                      49
#
#     Spirits (% total alcohol)
# 0                          43
# 1                          20
# 2                          13
# 3                          12
# 4                          14
# ..                        ...
# 61                         49
# 62                          0
# 63                         44
# 64                         36
# 65                         34
#
# [66 rows x 6 columns]

# %%
#1- Beer consumption in liters for type beer

beer = pd.read_csv('/Users/ajiacovic/Documents/data/miniprojectStory telling/beer-consumption-per-person.csv')
beer
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1961
# 1     Afghanistan  AFG  1962
# 2     Afghanistan  AFG  1963
# 3     Afghanistan  AFG  1964
# 4     Afghanistan  AFG  1965
# ...           ...  ...   ...
# 8947     Zimbabwe  ZWE  2010
# 8948     Zimbabwe  ZWE  2011
# 8949     Zimbabwe  ZWE  2012
# 8950     Zimbabwe  ZWE  2013
# 8951     Zimbabwe  ZWE  2014
#
#       Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Beer
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 8947                                               1.67
# 8948                                               2.05
# 8949                                               2.07
# 8950                                               2.12
# 8951                                               2.23
#
# [8952 rows x 4 columns]

# %%
#Tool to SQL command

# %%
#2 Weather in NL per year
weather = pd.read_csv('/Users/ajiacovic/Documents/data/miniprojectStory telling/Climate_data_De_Bilt__temperature__precipitation__sunshine_1800_2014_16112020_200849.csv')
