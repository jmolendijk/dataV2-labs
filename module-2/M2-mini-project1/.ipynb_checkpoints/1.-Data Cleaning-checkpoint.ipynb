# %% [markdown]
# # Descriptive Statistics Review

# %% [markdown]
# ## Before you start:
#
# - Read the README.md file
# - Comment as much as you can
# - Happy learning!

# %% [markdown]
# ## Context

# %% [markdown]
# ![img](./diamonds.jpg)

# %% [markdown]
# In this lab we are going to work with data to understand the characteristics of a diamond that are most likely to influence its price. In this first part of the lab, we will explore and clean our data.
#
# The dataset we will be using is comprised of approximately 54k rows and 11 different columns. As always, a row represents a single observation (in this case a diamond) and each of the columns represent a different feature of a diamond.
#
# The following codebook was provided together with the dataset to clarify what each column represents:

# %% [raw]
# | Column  | Description  |
# |---|---|
# | Price  | Price in US dollars (326-18,823)  |
# | Carat  | Weight of the diamond (0.2--5.01)  |
# | Cut  | Quality of the cut (Fair, Good, Very Good, Premium, Ideal)  |
# | Color  | Diamond colour, from J (worst) to D (best)  |
# | Clarity  | A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))   |
# | x  | Length in mm (0--10.74)  |
# | y  | Width in mm (0--58.9)  |
# | z  | Depth in mm (0--31.8)  |
# | Depth  | Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)  |
# | Table  | Width of top of diamond relative to widest point (43--95)  |

# %% [markdown]
# ## Libraries
# Pandas and numpy will be needed for the analysis of the data. Don't worry about the seaborn and matplotlib import at the moment, you will learn more about them next week, but we will be using some of their functionalities.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# First import the data from the .csv file provided and assign it to a variable named `diamonds` and drop the column with the index.

# %%
#your code here
os.getcwd()
diamonds = pd.read_csv('diamonds.csv')
diamonds.head(20)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1            2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2            3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3            4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4            5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5            6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6            7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7            8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8            9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9           10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 11          12   0.23      Ideal     J     VS1   62.8   56.0    340  3.93
# ...

# %% [markdown]
# # 1. Taking the first look at the data.
# Let's see how the data looks by using pandas methods like `head()`, `info()` and `describe()`.
#
# **First, use the `head` method.**

# %%
#your code here
diamonds.info()
diamonds.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB
#               count          mean           std    min       25%       50%  \
# Unnamed: 0  53940.0  26970.500000  15571.281097    1.0  13485.75  26970.50
# carat       53940.0      0.797940      0.474011    0.2      0.40      0.70
# ...

# %% [markdown]
# We can see the first 5 rows of the dataset using the `head` method. This by itself doesn't tell us much about the data that we have, but we can have a first look at the features (columns) and some of the values that each one takes.
#
# **What do you see? Make some comments about the values you see in each column, comparing them with the codebook. Is that what you would expect for these variables?**

# %%
#your code here
diamonds.head(5)
#Most of the diamonds its carats seem to be lower than 1 and their price & depth are about equal as well.
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# It is very important to know the amount of data we have, because everything will depend on that, from the quality of the analysis to the choice of our infrastracture.
#
# **Check the shape of the data**

# %%
#your code here
diamonds.shape
# Out:
# (53940, 11)

# %% [markdown]
# The `clarity` column is confusing because we are not diamond experts. Let's create a new column with a new scale that is more understandable for us.
#
# **Create a new column with numbers from 0 to 7. The lowest would be 0 with value `I1` and the greatest 7 with value `IF`**

# %%
#your code here
diamonds = diamonds.set_index('clarity')
diamonds = diamonds.rename(index={"I1": "0", "SI2": "1", "SI1" : "2", "VS2" : "3", "VS1" : "4", "VVS2" : "5", "VVS1": "6", "IF" : "7"})
diamonds = diamonds.reset_index()
diamonds = diamonds.drop(columns=['Unnamed: 0'])
diamonds
# Out:
#       clarity  carat        cut color  depth  table  price     x     y     z
# 0           1   0.23      Ideal     E   61.5   55.0    326  3.95  3.98  2.43
# 1           2   0.21    Premium     E   59.8   61.0    326  3.89  3.84  2.31
# 2           4   0.23       Good     E   56.9   65.0    327  4.05  4.07  2.31
# 3           3   0.29    Premium     I   62.4   58.0    334  4.20  4.23  2.63
# 4           1   0.31       Good     J   63.3   58.0    335  4.34  4.35  2.75
# ...       ...    ...        ...   ...    ...    ...    ...   ...   ...   ...
# 53935       2   0.72      Ideal     D   60.8   57.0   2757  5.75  5.76  3.50
# 53936       2   0.72       Good     D   63.1   55.0   2757  5.69  5.75  3.61
# 53937       2   0.70  Very Good     D   62.8   60.0   2757  5.66  5.68  3.56
# 53938       1   0.86    Premium     H   61.0   58.0   2757  6.15  6.12  3.74
# 53939       1   0.75      Ideal     D   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# It makes sense to do the same with the `color` column.
#
# **Do the same with values from 0 to 6. Read the codebook to see the match**

# %%
#your code here
# Diamond colour, from J (worst) to D (best)
diamonds = diamonds.set_index('color')
diamonds = diamonds.rename(index={"J": "0", "I" : "1", "H" : "2", "G" : "3", "F" : "4", "E" : "5", "D": "6"})
diamonds = diamonds.reset_index()
# diamonds = diamonds.drop(columns=['Unnamed: 0'])
diamonds
# Out:
#       color clarity  carat        cut  depth  table  price     x     y     z
# 0         5       1   0.23      Ideal   61.5   55.0    326  3.95  3.98  2.43
# 1         5       2   0.21    Premium   59.8   61.0    326  3.89  3.84  2.31
# 2         5       4   0.23       Good   56.9   65.0    327  4.05  4.07  2.31
# 3         1       3   0.29    Premium   62.4   58.0    334  4.20  4.23  2.63
# 4         0       1   0.31       Good   63.3   58.0    335  4.34  4.35  2.75
# ...     ...     ...    ...        ...    ...    ...    ...   ...   ...   ...
# 53935     6       2   0.72      Ideal   60.8   57.0   2757  5.75  5.76  3.50
# 53936     6       2   0.72       Good   63.1   55.0   2757  5.69  5.75  3.61
# 53937     6       2   0.70  Very Good   62.8   60.0   2757  5.66  5.68  3.56
# 53938     2       1   0.86    Premium   61.0   58.0   2757  6.15  6.12  3.74
# 53939     6       1   0.75      Ideal   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# With the `info` method, we can see the features of the dataset, and the amount of observations (rows) that have a non-null value and the types of the features.
#
# **Now use the `info` method and comparing with the shape, comment on what you see**

# %%
#your code here
diamonds.info()
diamonds.shape
#There are no NULL entries which is good and allows us to do calculations on the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   color    53940 non-null  object
#  1   clarity  53940 non-null  object
#  2   carat    53940 non-null  float64
#  3   cut      53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB
# (53940, 10)

# %% [markdown]
# In the last line of the info output, you have some information about the types of the columns. As you know, it is a good idea to check if the types of each column is what you expect. If a column has the right type, we will be able to do all the operations that we want to do.
#
# For instance, if we have a column that is a `date` with a `string` format, we will have the data but we won't be able to do a simple operation, such as format the date the way that we would like.
#
# Changing the data type to the one we needs can help us to solve a lot of problems in our data.
#
# **Check the types of each column and comment if it matches with the expected**

# %%
#your code here
#From the info() command we can see that our transformed columns 'color' & 'clarity' are still object type columns.
#We need to change that to int type.
diamonds[["color", "clarity"]] = diamonds[["color", "clarity"]].apply(pd.to_numeric)
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   color    53940 non-null  int64
#  1   clarity  53940 non-null  int64
#  2   carat    53940 non-null  float64
#  3   cut      53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 4.1+ MB

# %% [markdown]
# # 2. A deeper look: checking the basic statistics.
#
# The `describe` method gives us an overview of our data. From here we can see all the descriptive metrics for our variables.
#
# **Use the `describe` method and comment on what you see**

# %%
#your code and comments here
diamonds.describe().transpose()
# Out:
#            count         mean          std    min     25%      50%      75%  \
# color    53940.0     3.405803     1.701105    0.0    2.00     3.00     5.00
# clarity  53940.0     3.051020     1.647136    0.0    2.00     3.00     4.00
# carat    53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth    53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table    53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price    53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x        53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y        53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z        53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#               max
# color        6.00
# clarity      7.00
# carat        5.01
# depth       79.00
# table       95.00
# price    18823.00
# x           10.74
# y           58.90
# z           31.80

# %% [markdown]
# You have probably noticed that the columns x, y and z have a minimum value of 0. This means that there are one or more rows (or observations) in our dataset that are supposedly representing a diamond that has lenght, width or depth of 0. Considering that we're talking about a physical object, this is impossible!
#
# Now let's proceed to check the rows that have a value of 0 in any of the x, y or z columns. By doing this we want to check if the data we are missing can be obtained using the data that we do have.
#
# **Check the columns with `x`, `y` and `z` with value 0 in all of them and comment what you see**

# %%
#your code here
diamonds0 = diamonds.loc[(diamonds['x']==0) | (diamonds['y']==0) | (diamonds['z']==0)]
diamonds0
# Depth  | Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# | z  | Depth in mm (0--31.8)  |

#For some reason the correct values for the x,y,z columns were not noted everywhere.
#By looking at the formula of the depth column we can reverse engineer the values for some of them.
# Out:
#        color  clarity  carat        cut  depth  table  price     x     y    z
# 2207       3        1   1.00    Premium   59.1   59.0   3142  6.55  6.48  0.0
# 2314       2        0   1.01    Premium   58.1   59.0   3167  6.66  6.60  0.0
# 4791       3        1   1.10    Premium   63.0   59.0   3696  6.50  6.47  0.0
# 5471       4        1   1.01    Premium   59.2   58.0   3837  6.50  6.47  0.0
# 10167      3        0   1.50       Good   64.0   61.0   4731  7.15  7.04  0.0
# 11182      4        1   1.07      Ideal   61.6   56.0   4954  0.00  6.62  0.0
# 11963      2        3   1.00  Very Good   63.3   53.0   5139  0.00  0.00  0.0
# 13601      3        3   1.15      Ideal   59.2   56.0   5564  6.88  6.83  0.0
# 15951      3        4   1.14       Fair   57.5   67.0   6381  0.00  0.00  0.0
# 24394      2        1   2.18    Premium   59.4   61.0  12631  8.49  8.45  0.0
# 24520      3        3   1.56      Ideal   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %% [markdown]
# As you can see, we have 20 rows that have a value of 0 in some or all the aforementioned columns.
# Most of them (12) are missing the z value, which we can obtain using the columns depth, x and y.
#
# 20 rows with issues represent just 0.03% of our data (20 out of 53940) so it wouldn't be a big deal to remove them. Still, lets try to keep all the data we have.
#
# For those 12 rows, we will create a function that applies the formula given in the codebook and get the value of z. We will drop the other rows (8), since they are missing all 3 values or 2 of them.
#
# **Create a function named `calculate_z` that applies the function in the codebook to one single row you give to the function**

# %%
#your code here
def calculate_z(row):

    if row.z==0:
        return ((row.depth*(row.x+row.y))/200)
    else:
        return row.z

# %% [markdown]
# **Apply it just to the rows with incorrect values**

# %%
#your code here
diamonds['z'] = diamonds.apply(lambda row: calculate_z(row), axis=1)
diamonds0 = diamonds.loc[(diamonds['x']==0) | (diamonds['y']==0) | (diamonds['z']==0)]
diamonds0
# Out:
#        color  clarity  carat        cut  depth  table  price    x     y  \
# 11182      4        1   1.07      Ideal   61.6   56.0   4954  0.0  6.62
# 11963      2        3   1.00  Very Good   63.3   53.0   5139  0.0  0.00
# 15951      3        4   1.14       Fair   57.5   67.0   6381  0.0  0.00
# 24520      3        3   1.56      Ideal   62.2   54.0  12800  0.0  0.00
# 26243      6        6   1.20    Premium   62.1   59.0  15686  0.0  0.00
# 27429      2        1   2.25    Premium   62.8   59.0  18034  0.0  0.00
# 49556      4        1   0.71       Good   64.1   60.0   2130  0.0  0.00
# 49557      4        1   0.71       Good   64.1   60.0   2130  0.0  0.00
#
#              z
# 11182  2.03896
# 11963  0.00000
# 15951  0.00000
# 24520  0.00000
# 26243  0.00000
# 27429  0.00000
# 49556  0.00000
# 49557  0.00000

# %% [markdown]
# If we leave the other 8 values as they are, it would negatively affect our analysis, because these are data that do not make logical sense. Therefore it is better to consider those values as NaN values, since they are probably the result of a mistake or error during process of measuring and storing these values in a dataset.
#
# To replace them we can use the pandas .replace() method and np.NaN.
#
# **Replace the zero values in the `z` column for a NaN**

# %%
#your code here
diamonds['z'].replace({0: np.nan})
# Out:
# 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# 4        2.75
#          ...
# 53935    3.50
# 53936    3.61
# 53937    3.56
# 53938    3.74
# 53939    3.64
# Name: z, Length: 53940, dtype: float64

# %% [markdown]
# ----
# # Bonus: check the new z values
# Since we need to be 100% sure of our data, let's create a function that validates our z. To do so, we will use the same formula, but this time we will calculate the value of depth with the new value assigned to z.
#
# **Create a function named `validate_z` that compares the `z`  in cells above with the one thrown by the formula and run it with the rows you changed in the cells above**

# %%
#your code here

# %% [markdown]
# Let's check the data again with the `describe()` method.

# %% [markdown]
# The minimum value for x, y and z should now be a positive number, as it should be for the physical measurements of an object.

# %% [markdown]
# Let's finish by checking for NaN values in the data. Since we introduced them ourselves using 'replace', we will surely find some, but there may be more that are unrelated to the x, y and z columns. Checking NaNs is a fundamental part of data cleaning and it's always better to do this kind of operations before proceeding with analysis.
#
# **Check how many NaNs do you have, comment what you would do with those values, and then do so**

# %%
#your code here

# %% [markdown]
# # 3. Checking for outliers
# Now we are going to revisit the summary table to check for outliers.
#
# **Use the `describe` method again and comment on what you see. After that, check if you have any outliers**

# %%
#your code here
diamonds.describe()
# Out:
#               color       clarity         carat         depth         table  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       3.405803      3.051020      0.797940     61.749405     57.457184
# std        1.701105      1.647136      0.474011      1.432621      2.234491
# min        0.000000      0.000000      0.200000     43.000000     43.000000
# 25%        2.000000      2.000000      0.400000     61.000000     56.000000
# 50%        3.000000      3.000000      0.700000     61.800000     57.000000
# 75%        5.000000      4.000000      1.040000     62.500000     59.000000
# max        6.000000      7.000000      5.010000     79.000000     95.000000
#
#               price             x             y             z
# count  53940.000000  53940.000000  53940.000000  53940.000000
# mean    3932.799722      5.731157      5.734526      3.539778
# std     3989.439738      1.121761      1.142135      0.703801
# ...

# %%
#your comments here
# We can see that the mean of z has gone up.

# %% [markdown]
# To manage these outliers, we are going to filter our DataFrame, we're going to take all the values that have a price higher than the 75th percentile.
#
# **Look for that quantile and filter the dataframe to clearly see the outliers. What do you think?**

# %%
#your code here
diamonds['price'].quantile(q=0.75)
diamondsQ = diamonds.loc[(diamonds['price']>5324.25)]
diamondsQ
# There is a big gap between the max price & the 75th percentile price. So this means that in a boxplot the Q2 line would lie
# closer to the Q1 line than to the Q3 line.
# Out:
#        color  clarity  carat        cut  depth  table  price     x     y     z
# 12765      5        1   1.07      Ideal   62.2   55.0   5325  6.54  6.58  4.08
# 12766      2        2   1.11      Ideal   60.6   59.0   5325  6.75  6.71  4.08
# 12767      3        2   1.14    Premium   62.2   58.0   5326  6.64  6.70  4.15
# 12768      2        3   1.07    Premium   62.1   59.0   5327  6.52  6.56  4.06
# 12769      0        2   1.33  Very Good   64.0   53.0   5327  6.93  7.01  4.46
# ...      ...      ...    ...        ...    ...    ...    ...   ...   ...   ...
# 27745      2        2   2.00  Very Good   62.8   57.0  18803  7.95  8.00  5.01
# 27746      3        1   2.07      Ideal   62.5   55.0  18804  8.20  8.13  5.11
# 27747      3        7   1.51      Ideal   61.7   55.0  18806  7.37  7.41  4.56
# 27748      3        2   2.00  Very Good   63.5   56.0  18818  7.90  7.97  5.04
# 27749      1        3   2.29    Premium   60.8   60.0  18823  8.50  8.47  5.16
#
# ...

# %% [markdown]
# Our dataset is really big and the outliers are really far apart from the rest of the values. To see this more clearly we will use a boxplot, which plots the median, 25th and 75th quartile, the maximum and minimum, as well as any outliers.

# %%
#Run this code
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds.y, ax=ax[0])
sns.boxplot(y=diamonds.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# Now we can see that all the values are within an acceptable range, but we have 2 big outliers in y and 1 in z. Now we know that our max values for y should be around 10 and the values for z should be around 6, so let's filter our dataset to find values higher than 10 in it.

# %%
#your code here
outlier = diamonds.loc[(diamonds['y']>20) | (diamonds['z']>20)]
outlier
# Out:
#        color  clarity  carat        cut  depth  table  price     x      y  \
# 24067      2        1   2.00    Premium   58.9   57.0  12210  8.09  58.90
# 48410      5        4   0.51  Very Good   61.8   54.7   1970  5.12   5.15
# 49189      5        4   0.51      Ideal   61.8   55.0   2075  5.15  31.80
#
#            z
# 24067   8.06
# 48410  31.80
# 49189   5.12

# %% [markdown]
# Now that we have found the outlier, let's use the function we defined earlier to correct this value. First, we need to change the value to 0 (because that's how we defined the function before) and then we will apply it.
#
# **Apply `calculate_z` for the row with the outlier**

# %%
#your code here
# diamonds['z'] = 0
diamonds['z'] = diamonds.apply(lambda row: calculate_z(row), axis=1)
diamonds
# Out:
#        color  clarity  carat        cut  depth  table  price     x     y  \
# 0          5        1   0.23      Ideal   61.5   55.0    326  3.95  3.98
# 1          5        2   0.21    Premium   59.8   61.0    326  3.89  3.84
# 2          5        4   0.23       Good   56.9   65.0    327  4.05  4.07
# 3          1        3   0.29    Premium   62.4   58.0    334  4.20  4.23
# 4          0        1   0.31       Good   63.3   58.0    335  4.34  4.35
# ...      ...      ...    ...        ...    ...    ...    ...   ...   ...
# 53935      6        2   0.72      Ideal   60.8   57.0   2757  5.75  5.76
# 53936      6        2   0.72       Good   63.1   55.0   2757  5.69  5.75
# 53937      6        2   0.70  Very Good   62.8   60.0   2757  5.66  5.68
# 53938      2        1   0.86    Premium   61.0   58.0   2757  6.15  6.12
# 53939      6        1   0.75      Ideal   62.2   55.0   2757  5.83  5.87
#
#               z
# 0      2.438475
# 1      2.311270
# 2      2.310140
# 3      2.630160
# ...

# %% [markdown]
# Let's check if we actually corrected the outlier.

# %%
diamonds.loc[48410]
# Out:
# color              5
# clarity            4
# carat           0.51
# cut        Very Good
# depth           61.8
# table           54.7
# price           1970
# x               5.12
# y               5.15
# z            3.17343
# Name: 48410, dtype: object

# %% [markdown]
# Cool! Now let's validate our new `z`. We will check if we obtain the same value of depth using our validate function. If the formula applies, this means could approximate the real value of `z`.
#
# **Apply `validate_z` to the row used earlier**

# %%
#your code here

# %% [markdown]
# Now let's do the same for `y`. First, let's filter the DataFrame to find the outliers. We said that the maximum values should be around 10, so let's check what are the values above 10.
#
# **Check the values greater than 10 in the `y` column**

# %%
#your code here
diamonds.loc[(diamonds['y']>10)]
# Out:
#        color  clarity  carat      cut  depth  table  price      x      y  \
# 24067      2        1   2.00  Premium   58.9   57.0  12210   8.09  58.90
# 25998      1        0   4.01  Premium   61.0   61.0  15223  10.14  10.10
# 27415      0        0   5.01     Fair   65.5   59.0  18018  10.74  10.54
# 27630      0        0   4.50     Fair   65.8   58.0  18531  10.23  10.16
# 49189      5        4   0.51    Ideal   61.8   55.0   2075   5.15  31.80
#
#                z
# 24067  19.728555
# 25998   6.173200
# 27415   6.969200
# 27630   6.708310
# 49189  11.417550

# %% [markdown]
# We can clearly see that the 31.8 in row 49189 is an outlier for the y value. Also, we can see that the 58.9 value for `y` in row 24067 is actually its depth, so it was a mistake when they introduced the data. Let's create a function to fix these outliers.
#
# **Create a function named `calculate_y` to calculate `y` using `z` and `x` the same way you did above**

# %%
#your code here

def calculate_y(row):
    
    if row.y>30:
        return (((200*row.z)/row.depth)-row.x)

    else:
        return row.y

diamonds['y'] = diamonds.apply(lambda row: calculate_y(row), axis=1)
diamonds.loc[(diamonds['y']>10)]
diamonds.loc[(diamonds['y']>30)]
# diamonds.describe()
#Maybe define if y<0 y=0?
# Out:
#        color  clarity  carat      cut  depth  table  price     x     y  \
# 24067      2        1   2.00  Premium   58.9   57.0  12210  8.09  58.9
# 49189      5        4   0.51    Ideal   61.8   55.0   2075  5.15  31.8
#
#                z
# 24067  19.728555
# 49189  11.417550

# %%
#Dropped the outliers since I didn't manage to fix them.
diamonds = diamonds.drop([24067,49189])
#dropping rows with zeroes.
diamonds = diamonds.drop([11963,15951,24520,26243,27429,49556,49557])
# Out:
#               color       clarity         carat         depth         table  \
# count  53938.000000  53938.000000  53938.000000  53938.000000  53938.000000
# mean       3.405799      3.051040      0.797923     61.749457     57.457238
# std        1.701112      1.647138      0.473990      1.432595      2.234506
# min        0.000000      0.000000      0.200000     43.000000     43.000000
# 25%        2.000000      2.000000      0.400000     61.000000     56.000000
# 50%        3.000000      3.000000      0.700000     61.800000     57.000000
# 75%        5.000000      4.000000      1.040000     62.500000     59.000000
# max        6.000000      7.000000      5.010000     79.000000     95.000000
#
#               price             x             y             z
# count  53938.000000  53938.000000  53938.000000  53938.000000
# mean    3932.680707      5.731124      5.733057      3.539106
# std     3989.346482      1.121733      1.113336      0.692394
# ...

# %% [markdown]
# We will check the rows that had an outlier in `y`, to check that the values were changed.
#
# **Check those rows (also validating with your function) and comment what you see**

# %% [markdown]
# Now that we have corrected or dropped all of our outliers, lets plot another box plot to double check.

# %%
#Run this code
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds.y, ax=ax[0])
sns.boxplot(y=diamonds.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# **What do you think? Are these values more reasonable?**

# %%
#your thoughts here
#These values do seem more reasonable, more consistent as a group of data.
os.getcwd()
# Out:
# 'C:\\Users\\svvan\\Desktop\\dataV2-labs\\module-2\\M2-mini-project1'

# %% [markdown]
# **Once you are happy with your cleaning, save the cleaned data and continue to csv. Your new csv should be named ``diamonds_clean``**

# %%
#your code here
diamonds.to_csv('diamonds_clean.csv', index=True)
