# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
diamonds = pd.read_csv('/Users/nelly/dataV2-labs/module-2/M2-mini-project1/diamonds_clean1.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

diamonds.head()
# Out:
#    carat      cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    Ideal      5        1   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium      5        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good      5        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium      1        3   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good      0        1   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here

diamonds.describe().transpose()
# Out:
#            count         mean          std     min     25%      50%      75%  \
# carat    53938.0     0.797923     0.473990    0.20    0.40     0.70     1.04
# color    53938.0     3.405799     1.701112    0.00    2.00     3.00     5.00
# clarity  53938.0     3.051040     1.647138    0.00    2.00     3.00     4.00
# depth    53938.0    61.749457     1.432595   43.00   61.00    61.80    62.50
# table    53938.0    57.457238     2.234506   43.00   56.00    57.00    59.00
# price    53938.0  3932.680707  3989.346482  326.00  950.00  2401.00  5324.00
# x        53938.0     5.731124     1.121733    0.00    4.71     5.70     6.54
# y        53938.0     5.733057     1.113336    0.00    4.72     5.71     6.54
# z        53931.0     3.539594     0.691780    1.07    2.91     3.53     4.04
#
#               max
# carat        5.01
# color        6.00
# clarity      7.00
# depth       79.00
# table       95.00
# price    18823.00
# x           10.74
# y           10.54
# z            6.98

# %%
#your comments here

# The column with the most variability is the price since we cleaned the outlilers for the other numeric values.

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here

# In general people think that the bigger the diamond (carat) the more expensive.
# But when we have the same carat and different prices we should see the rarity (color & clarity) and quality of the cut.

diamonds.corr()
# Out:
#             carat     color   clarity     depth     table     price         x  \
# carat    1.000000 -0.291410 -0.352804  0.028321  0.181628  0.921585  0.975093
# color   -0.291410  1.000000 -0.025661 -0.047313 -0.026450 -0.172481 -0.270261
# clarity -0.352804 -0.025661  1.000000 -0.067434 -0.160324 -0.146756 -0.371967
# depth    0.028321 -0.047313 -0.067434  1.000000 -0.295800 -0.010571 -0.025213
# table    0.181628 -0.026450 -0.160324 -0.295800  1.000000  0.127139  0.195352
# price    0.921585 -0.172481 -0.146756 -0.010571  0.127139  1.000000  0.884425
# x        0.975093 -0.270261 -0.371967 -0.025213  0.195352  0.884425  1.000000
# y        0.974439 -0.270087 -0.366852 -0.028356  0.189178  0.886226  0.998339
# z        0.976401 -0.275041 -0.376472  0.096665  0.155971  0.882072  0.990999
#
#                 y         z
# carat    0.974439  0.976401
# color   -0.270087 -0.275041
# clarity -0.366852 -0.376472
# depth   -0.028356  0.096665
# table    0.189178  0.155971
# price    0.886226  0.882072
# x        0.998339  0.990999
# y        1.000000  0.990650
# z        0.990650  1.000000

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
diamonds.pivot_table(index=["color"])
# Out:
#           carat   clarity      depth        price      table         x  \
# color
# 0      1.162137  2.776353  61.887215  5323.818020  57.812393  6.519338
# 1      1.026927  2.964035  61.846385  5091.874954  57.577278  6.222826
# 2      0.911668  2.933879  61.837203  4485.739010  57.517873  5.983081
# 3      0.771190  3.463425  61.757111  3999.135671  57.288629  5.677543
# 4      0.736538  3.133934  61.694582  3724.886397  57.433536  5.614961
# 5      0.657882  2.969784  61.662076  3076.854737  57.491456  5.411607
# 6      0.657795  2.691513  61.698125  3169.954096  57.404590  5.417051
#
#               y         z
# color
# 0      6.518105  4.033251
# 1      6.222730  3.846369
# 2      5.978442  3.698622
# 3      5.680192  3.507966
# 4      5.619456  3.465788
# 5      5.416336  3.337585
# 6      5.421128  3.343320

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
# your thoughts here

# I thought with better color the more expensive the diamond, but:

# The mean price for the best color is 3169
# The mean price for the worst color is 5323
# We set the values to : D:6 (BEST) , E=5 , F=4 ,G=3 , H=2 , I=1  , J=0 (WORSE) 


diamonds['color'].corr(diamonds['price'])
# Out:
# -0.17248077500702869

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here

diamonds['color'].hist()
# Out:
# <AxesSubplot:>

# %%
#your comments here

# The most common color is 3 , then 5 and 4

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here

diamonds.groupby('carat', as_index=False)['clarity','color','depth','price','table','x','y','z'].mean()
# Out:
# <ipython-input-10-3e67eaae6c5a>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   diamonds.groupby('carat', as_index=False)['clarity','color','depth','price','table','x','y','z'].mean()
#      carat   clarity     color      depth         price      table          x  \
# 0     0.20  2.833333  5.166667  61.100000    365.166667  59.333333   3.786667
# 1     0.21  2.666667  5.444444  60.511111    380.222222  58.444444   3.874444
# 2     0.22  2.600000  4.800000  61.620000    391.400000  60.400000   3.898000
# 3     0.23  4.901024  4.518771  61.426621    486.143345  58.034130   3.946382
# 4     0.24  4.972441  4.185039  61.599213    505.185039  57.488189   3.990157
# ..     ...       ...       ...        ...           ...        ...        ...
# 268   4.00  0.000000  1.000000  63.300000  15984.000000  58.000000  10.010000
# 269   4.01  0.000000  0.500000  61.750000  15223.000000  61.500000  10.080000
# 270   4.13  0.000000  2.000000  64.800000  17329.000000  61.000000  10.000000
# 271   4.50  0.000000  0.000000  65.800000  18531.000000  58.000000  10.230000
# 272   5.01  0.000000  0.000000  65.500000  18018.000000  59.000000  10.740000
#
#              y         z
# 0     3.753333  2.303333
# 1     3.837778  2.332222
# 2     3.848000  2.386000
# 3     3.973379  2.431468
# 4     4.019331  2.465591
# ..         ...       ...
# 268   9.940000  6.310000
# 269  10.020000  6.205000
# 270   9.850000  6.430000
# 271  10.160000  6.720000
# 272  10.540000  6.980000
#
# [273 rows x 9 columns]

# %%
#your comments

# We know that the maximum price for a diamond in the data set is 18823
# Carats go from 0.2 to 5.01

# We seea a tendecy here : The more carats the more expensive

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here

# The most common diamonds are relatively small, in other words: 
# The most common carats are between .2 and 1

diamonds['carat'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here

print(diamonds['table'].corr(diamonds['clarity']))

diamonds.pivot_table(index=["table"])
# Out:
# -0.16032447595387642
#         carat  clarity  color  depth    price      x      y      z
# table
# 43.0   1.0400     4.00    1.0  62.90   4997.0  6.450  6.410  4.040
# 44.0   0.2900     4.00    5.0  62.80    474.0  4.200  4.240  2.650
# 49.0   0.6500     3.00    3.0  64.25   2290.5  5.355  5.320  3.425
# 50.0   1.5100     2.00    3.0  61.50   8995.5  7.380  7.295  4.510
# 50.1   0.9400     1.00    2.0  66.00   3353.0  6.130  6.170  4.060
# ...       ...      ...    ...    ...      ...    ...    ...    ...
# 71.0   0.6800     2.00    3.0  58.00   1633.0  5.850  5.700  3.350
# 73.0   0.6025     3.25    4.5  68.90   2406.5  5.520  5.465  3.745
# 76.0   0.7900     2.00    3.0  65.30   2362.0  5.520  5.130  3.350
# 79.0   0.8100     1.00    4.0  68.80   2301.0  5.260  5.200  3.580
# 95.0   2.0100     2.00    4.0  58.60  13387.0  8.320  8.310  4.870
#
# [127 rows x 8 columns]

# %%
#your comments here

# Table values are between 43 and 95
# Clarity goes from 0 (worst) to 7 (best)

# The calrity doen not have a real close relation with the table , it varies a lot. 
# Ex: big table 75 with medium clarity 3.25 or smaller table 43 with better clarity 4

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here

diamonds.pivot_table(index=["clarity"])
# Out:
#             carat     color      depth        price      table         x  \
# clarity
# 0        1.283846  2.968961  62.734278  3924.168691  58.303779  6.761093
# 1        1.077548  3.470140  61.772479  5062.251169  57.927282  6.401187
# 2        0.850482  3.448450  61.853042  3996.001148  57.662541  5.888383
# 3        0.763935  3.494208  61.724417  3924.989395  57.417401  5.657709
# 4        0.727185  3.161567  61.667442  3839.671359  57.315435  5.572230
# 5        0.596202  3.569483  61.663778  3283.737071  57.024990  5.218454
# 6        0.503321  3.351573  61.624651  2523.114637  56.884460  4.960364
# 7        0.505123  3.101676  61.510615  2864.839106  56.507207  4.968402
#
#                 y         z
# clarity
# 0        6.709379  4.224688
# 1        6.392115  3.951987
# 2        5.888256  3.640636
# 3        5.658859  3.492788
# 4        5.578619  3.437719
# 5        5.232118  3.221465
# 6        4.975075  3.062132
# 7        4.989827  3.061659

# %%
#your comments here

# We can see here that clarity does not relly influence the price since:
# The mean price for the best clarity is 3924
# The mean price for the worst clarity is 2864

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here

# Yes the size(carats) is one of the most important factor for the price

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# The relationship between: carats, x, y , z and price they have almost the same shape!

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here

# As seen before the plots with the same shape have  a high correlation

# price - carat = .92
# price - x = .88
# price - y = .89
# price - z = .88

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493193353459509

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# I think it would be good to take in account external factor like the source of the diamond.

# Add a feature like : Blockchain technology for mineral traceability
# 2003Kimberley Process, international certification system for diamonds conflict-free.

# New Yort Times artice "Blood diamonds": https://www.nytimes.com/2006/12/17/weekinreview/17mcneil.html
# Times article: https://time.com/blood-diamonds/
# $81.4 billion-a-year industry ( Africa is home to 65% of the world’s diamonds).

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
