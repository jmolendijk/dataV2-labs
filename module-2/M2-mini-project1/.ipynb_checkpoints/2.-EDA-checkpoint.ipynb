# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('../M2-mini-project1/diamonds_clean.csv')
# diamonds = diamonds.drop('Unnamed: 0', axis=1)
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53927   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53928   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53929   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53930   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53931   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        clarity values  color values  verif_z  verif_y
# 0                   1             5    False    False
# 1                   2             5     True     True
# 2                   4             5     True     True
# 3                   3             1     True     True
# 4                   1             0     True     True
# ...               ...           ...      ...      ...
# 53927               2             6     True     True
# 53928               2             6     True     True
# 53929               2             6     True     True
# 53930               1             2     True     True
# 53931               1             6     True     True
#
# [53932 rows x 14 columns]

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879     61.749336     57.457029   3932.136079      5.732007
# std        0.473986      1.432514      2.234064   3988.734835      1.119670
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity values  color values
# count  53932.000000  53932.000000    53932.000000  53932.000000
# mean       5.734141      3.539735        3.051101      3.405789
# std        1.113272      0.692051        1.647109      1.701165
# min        3.680000      1.070000        0.000000      0.000000
# 25%        4.720000      2.910000        2.000000      2.000000
# 50%        5.710000      3.530000        3.000000      3.000000
# 75%        6.540000      4.040000        4.000000      5.000000
# max       19.278421      8.060000        7.000000      6.000000

# %% [markdown]
# ### your comments here
#
# When checking at the std of the price, I can see that the value is closed to the mean. This shows a very high variability, indicating that the price of the diamonds is quite volatile.
#
# The same observation can be done for the caratage. If I divide the std of carats by the average I see that the variability represent around 60% of the mean value (quite high)
#
# Color is also a factor showing a hight variability (around 50%).Color, as well as caratage, could be having a significant influence in price (so far).
#
# Concerning the clarity values, I see that the variability is lower (30%) which could indicate tha the clarity doesn't change as much as the previous 3 factors.
#
# For the depth and table, I see that the the variability is much lower that all 3 above, below 5% of the average each.

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %% [markdown]
# ### your hypotheses here
#    Based on the above, I believe that carats,color and clarity will have a bigger influence in price.

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby(['color', 'color values'])
color_diamonds
# Out:
#                        carat  clarity values      depth        price  \
# color color values
# D     6             0.657715        2.691025  61.698066  3168.106436
# E     5             0.657867        2.969889  61.662090  3076.752475
# F     4             0.736509        3.134605  61.694087  3725.091938
# G     3             0.771088        3.463419  61.757449  3998.145173
# H     2             0.911627        2.933871  61.836557  4484.958805
# I     1             1.026927        2.964035  61.846385  5091.874954
# J     0             1.162137        2.776353  61.887215  5323.818020
#
#                         table   verif_y   verif_z         x         y  \
# color color values
# D     6             57.404355  0.966047  0.946265  5.417851  5.421928
# E     5             57.491201  0.951822  0.948352  5.411580  5.416949
# F     4             57.433148  0.919488  0.949471  5.616727  5.620529
# G     3             57.288060  0.917449  0.946236  5.678549  5.681198
# H     2             57.518176  0.913876  0.947001  5.984776  5.981484
# I     1             57.577278  0.917005  0.941903  6.222826  6.222730
# J     0             57.812393  0.925926  0.946225  6.519338  6.518105
#
#                            z
# color color values
# D     6             3.343320
# E     5             3.337767
# F     4             3.465938
# G     3             3.507966
# H     2             3.699147
# I     1             3.846369
# J     0             4.033251

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %% [markdown]
# ### your thoughts here
#
#    I notice that for a higher-value of color (D= value 6) the average price is not equally highest.
#    On the contrary. If we only compare these 2 columns, we could think that the higher value for color would also be the 'cheaper'. On the other hand,I also notice that the average caratage is, as the price, negatively correlated with color.
#    One could make the hipothesis that carats have a bigger influence (at this stage of the analisis) than color

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
diamonds['color values'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### your comments here
#
# The histogram help us understand that the highest number of diamonds bought have a color value between 2 and 5.
# Knowing that the color has also a certain 'value' (6 being a highest quality of color -colorless) we could then deduce that the the lowest frequency is not linked to the price directly, and that if the price is higher for this particular range of color, then the reason needs to be sourced in another parameter.

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
#Somehow, I could not display the table with groupby.
diamonds.pivot_table(index='carat')
# Out:
#        clarity values  color values      depth         price      table  \
# carat
# 0.20         2.833333      5.166667  61.100000    365.166667  59.333333
# 0.21         2.666667      5.444444  60.511111    380.222222  58.444444
# 0.22         2.600000      4.800000  61.620000    391.400000  60.400000
# 0.23         4.901024      4.518771  61.426621    486.143345  58.034130
# 0.24         4.972441      4.185039  61.599213    505.185039  57.488189
# ...               ...           ...        ...           ...        ...
# 4.00         0.000000      1.000000  63.300000  15984.000000  58.000000
# 4.01         0.000000      0.500000  61.750000  15223.000000  61.500000
# 4.13         0.000000      2.000000  64.800000  17329.000000  61.000000
# 4.50         0.000000      0.000000  65.800000  18531.000000  58.000000
# 5.01         0.000000      0.000000  65.500000  18018.000000  59.000000
#
#         verif_y   verif_z          x          y         z
# carat
# 0.20   1.000000  0.916667   3.786667   3.753333  2.303333
# 0.21   1.000000  0.888889   3.874444   3.837778  2.332222
# 0.22   1.000000  1.000000   3.898000   3.848000  2.386000
# 0.23   0.911263  0.928328   3.946382   3.973379  2.431468
# 0.24   0.814961  0.929134   3.990157   4.019331  2.465591
# ...         ...       ...        ...        ...       ...
# 4.00   1.000000  1.000000  10.010000   9.940000  6.310000
# 4.01   1.000000  0.500000  10.080000  10.020000  6.205000
# 4.13   1.000000  1.000000  10.000000   9.850000  6.430000
# 4.50   0.000000  1.000000  10.230000  10.160000  6.720000
# 5.01   0.000000  1.000000  10.740000  10.540000  6.980000
#
# [273 rows x 10 columns]

# %% [markdown]
# ### your comments
#    Here we see a more direct relation with price. for most of the diamonds of my table, the carats and the price seem to be positively correlated. There are some exceptions for ex. for category  of diamonds with 4 to 5 carats, where the price is going down. For this group I check the rest of parameters and noticed that the clarity is 0, the lowest.

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds.carat.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.pivot_table(index='table')
# Out:
#         carat  clarity values  color values  depth    price  verif_y  verif_z  \
# table
# 43.0   1.0400            4.00           1.0  62.90   4997.0      0.0      1.0
# 44.0   0.2900            4.00           5.0  62.80    474.0      1.0      1.0
# 49.0   0.6500            3.00           3.0  64.25   2290.5      1.0      1.0
# 50.0   1.5100            2.00           3.0  61.50   8995.5      1.0      1.0
# 50.1   0.9400            1.00           2.0  66.00   3353.0      1.0      1.0
# ...       ...             ...           ...    ...      ...      ...      ...
# 71.0   0.6800            2.00           3.0  58.00   1633.0      1.0      1.0
# 73.0   0.6025            3.25           4.5  68.90   2406.5      0.5      1.0
# 76.0   0.7900            2.00           3.0  65.30   2362.0      0.0      0.0
# 79.0   0.8100            1.00           4.0  68.80   2301.0      0.0      0.0
# 95.0   2.0100            2.00           4.0  58.60  13387.0      1.0      1.0
#
#            x      y      z
# table
# 43.0   6.450  6.410  4.040
# 44.0   4.200  4.240  2.650
# 49.0   5.355  5.320  3.425
# 50.0   7.380  7.295  4.510
# 50.1   6.130  6.170  4.060
# ...      ...    ...    ...
# 71.0   5.850  5.700  3.350
# 73.0   5.520  5.465  3.745
# 76.0   5.520  5.130  3.350
# 79.0   5.260  5.200  3.580
# 95.0   8.320  8.310  4.870
#
# [127 rows x 10 columns]

# %% [markdown]
# ### your comments here
# Furthermore, and based on the observation of table, I see no direct relation with price.

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.pivot_table(index ='clarity values')
# Out:
#                    carat  color values      depth        price      table  \
# clarity values
# 0               1.283846      2.968961  62.734278  3924.168691  58.303779
# 1               1.077602      3.469967  61.771567  5062.267356  57.926823
# 2               0.850482      3.448450  61.853042  3996.001148  57.662541
# 3               0.763850      3.494370  61.724249  3924.166204  57.418040
# 4               0.727108      3.161812  61.667968  3839.144308  57.313966
# 5               0.596202      3.569483  61.663778  3283.737071  57.024990
# 6               0.503131      3.350848  61.624521  2519.512315  56.883881
# 7               0.505123      3.101676  61.510615  2864.839106  56.507207
#
#                  verif_y   verif_z         x         y         z
# clarity values
# 0               0.755735  0.950067  6.761093  6.709379  4.224688
# 1               0.923286  0.939173  6.404157  6.395579  3.952642
# 2               0.948718  0.945809  5.888383  5.888256  3.640636
# 3               0.947128  0.950718  5.658633  5.659782  3.492788
# 4               0.916524  0.951652  5.572860  5.580017  3.437925
# 5               0.909001  0.946309  5.218454  5.232118  3.221465
# 6               0.920909  0.940339  4.961721  4.976437  3.062132
# 7               0.922346  0.959777  4.968402  4.989827  3.061659

# %% [markdown]
# ### your comments here
# The variation of clarity vs. price doesn't seem to follow a concise path alone, but when compared to the carats, it makes more sense.

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %% [markdown]
# ### your thoughts here
# I believe carats then color seem to be the 2 parameters that have the biggest influence in the price of diamonds

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %% [markdown]
# ### your thoughts here
# Carats and price, carats and lenght/witdh/depth
# Price and x/y/z

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %% [markdown]
# ### your thoughts here
# Carat and price have a correlation of .92! and almost a 1 on the measures.
# The correlation with the mearsures is intuitive because the weight has a direct link with the physical measures
# of the rock

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804612

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
