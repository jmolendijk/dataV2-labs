# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# diamonds.head()
# Out:
#               carat         color       clarity         depth         table  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879      3.405789      3.051101     61.749336     57.457029
# std        0.473986      1.701165      1.647109      1.432514      2.234064
# min        0.200000      0.000000      0.000000     43.000000     43.000000
# 25%        0.400000      2.000000      2.000000     61.000000     56.000000
# 50%        0.700000      3.000000      3.000000     61.800000     57.000000
# 75%        1.040000      5.000000      4.000000     62.500000     59.000000
# max        5.010000      6.000000      7.000000     79.000000     95.000000
#
#               price             x             y             z
# count  53932.000000  53932.000000  53932.000000  53932.000000
# mean    3932.136079      5.732007      5.734142      3.539735
# std     3988.734835      1.119670      1.113276      0.692051
# min      326.000000      3.730000      3.680000      1.070000
# 25%      949.750000      4.710000      4.720000      2.910000
# 50%     2401.000000      5.700000      5.710000      3.530000
# 75%     5324.000000      6.540000      6.540000      4.040000
# max    18823.000000     10.740000     19.278421      8.060000

# %%
#your comments here
"""
looking at the std at price it is really big, it acutally is almost the same as the mean, meaning that the difference
within price is really big, so the price really varies
"""

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
# your hypotheses here

"""
probably carat, color, clarity
depth & table are having a much larger value, hower the std is almost the same as carat, color, clarity, 
therefore i think it will have less impact on the price than the others
"""

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby('color').mean()

"""
the mean value of price, is also at the middlest color(3)
however, what is strange that the mean price at color 0 is 20000 higher, which is quite an increase, but if you
see the describe tabel, the std only is almost 40000, and e.g. also the lowest price comes not even close to the 
mean value of color 6, so I expected the difference to be a lot bigger, this might shows that color is not of such
a big impact on price
"""
# Out:
#           carat   clarity      depth      table        price         x  \
# color
# 0      1.162137  2.776353  61.887215  57.812393  5323.818020  6.519338
# 1      1.026927  2.964035  61.846385  57.577278  5091.874954  6.222826
# 2      0.911627  2.933871  61.836557  57.518176  4484.958805  5.984776
# 3      0.771088  3.463419  61.757449  57.288060  3998.145173  5.678549
# 4      0.736509  3.134605  61.694087  57.433148  3725.091938  5.616727
# 5      0.657867  2.969889  61.662090  57.491201  3076.752475  5.411580
# 6      0.657715  2.691025  61.698066  57.404355  3168.106436  5.417851
#
#               y         z  validate_z
# color
# 0      6.518130  4.033251    0.946225
# 1      6.222728  3.846369    0.941903
# 2      5.981484  3.699147    0.947001
# 3      5.681198  3.507966    0.946236
# 4      5.620529  3.465938    0.949471
# 5      5.416949  3.337767    0.948352
# 6      5.421928  3.343320    0.946265

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here

"""
that color 0 is most expensive, and color 6 is cheapest,
what I don't understand is that the table stated J is worst and D is best, in this case D: 6 and J:0, so this means
it actually is the other way around 

# the price difference is around 2000, as I already mentioned above, I expected a larger value here
# if you look at the other columns, carat is also decreasing (same as price), 

# depth and table are staying around the same (as expected),
# clarity also has values from 0 to 6, just like color, and it looks like everything is around 3, which is the middle 
# of these numbers, therefore, there probably is not (as expected) especially a lot of clarity 6 in color 6, and 0
# in color 0, 

so probably the relation between color and clarity is independent?

"""

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here

freq_color = diamonds.color.value_counts().sort_index()
freq_color.plot.bar()

# %%
#your comments here

"""
you see that the color 3 is the most frequent, is it skewed to the right, meaning that the higher numbered colors
are more frequent, as color 0 is of best quality, this means that the less quality colored diamonds occur more often
"""

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('carat').mean().head()
# Out:
#           color   clarity      depth      table       price         x  \
# carat
# 0.20   5.166667  2.833333  61.100000  59.333333  365.166667  3.786667
# 0.21   5.444444  2.666667  60.511111  58.444444  380.222222  3.874444
# 0.22   4.800000  2.600000  61.620000  60.400000  391.400000  3.898000
# 0.23   4.518771  4.901024  61.426621  58.034130  486.143345  3.946382
# 0.24   4.185039  4.972441  61.599213  57.488189  505.185039  3.990157
#
#               y         z  validate_z
# carat
# 0.20   3.753333  2.303333    0.916667
# 0.21   3.837778  2.332222    0.888889
# 0.22   3.848000  2.386000    1.000000
# 0.23   3.973379  2.431468    0.928328
# 0.24   4.019331  2.465591    0.929134

# %%
#your comments

"""
there are many values for carat, which makes it more difficult to see, but in general for the price, this does 
increase, it starts with 3000 and ends with 18000, 

however, it is not the same as for color, where it increases step by step, in the beginning it does, 
but once the carat gets a higher value its more varied

both color, clarity really decrease (so they get better values if the carat increases)

table and depth stay around the same value again

x, y, z change with increase of the carat (makes sense as the length, width, and depth will definitely impact the 
weight of the diamond)
"""

# %%
diamonds.carat.mean()
# Out:
# 0.7978793666097885

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds.carat.hist(bins=30)
mean = 0.7978793666097885
plt.axvline(x=mean, color='r', linestyle='dashed', linewidth=2)

# %%
diamonds.carat.hist()
mean = 0.7978793666097885
plt.axvline(x=mean, color='r', linestyle='dashed', linewidth=2)

"""
making more bins I think you beter see the difference at the beginning at the column (as most carat values are
at this side of the histogram, you see that it is definitely skewed to the left)
so diamonds with less carat are occuring more often 
this could explain why the mean price if the value of the carat increases, is more varied, as there are less data 
points, so makes sense that the mean if more impacted by outliers
"""

# %%
import seaborn as sns
ax = sns.boxplot(x='carat', y='price', data=diamonds, showmeans=True)

# %%
ax = sns.boxplot(x='color', y='price', data=diamonds, showmeans=True)

"""
this plot shows that the price does increase slightly with colors, but it especially shows a lot of outliers
and each color has outliers at the highest prices (which shouldn't be if color change has a very big impact 
on the price)
"""

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('table').mean().head()
# Out:
#        carat  color  clarity  depth   price      x      y      z  validate_z
# table
# 43.0    1.04    1.0      4.0  62.90  4997.0  6.450  6.410  4.040         1.0
# 44.0    0.29    5.0      4.0  62.80   474.0  4.200  4.240  2.650         1.0
# 49.0    0.65    3.0      3.0  64.25  2290.5  5.355  5.320  3.425         1.0
# 50.0    1.51    3.0      2.0  61.50  8995.5  7.380  7.295  4.510         1.0
# 50.1    0.94    2.0      1.0  66.00  3353.0  6.130  6.170  4.060         1.0

# %%
#your comments here

"""
if you look to price, it varies a lot, meaning this does not affects price a lot
depth stays around the same value again
there is also not much to say about clarity, lot of variation, same for color and carat
table probably does not affect price a lot
"""

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.groupby('clarity').mean()
# Out:
#             carat     color      depth      table        price         x  \
# clarity
# 0        1.283846  2.968961  62.734278  58.303779  3924.168691  6.761093
# 1        1.077602  3.469967  61.771567  57.926823  5062.267356  6.404157
# 2        0.850482  3.448450  61.853042  57.662541  3996.001148  5.888383
# 3        0.763850  3.494370  61.724249  57.418040  3924.166204  5.658633
# 4        0.727108  3.161812  61.667968  57.313966  3839.144308  5.572860
# 5        0.596202  3.569483  61.663778  57.024990  3283.737071  5.218454
# 6        0.503131  3.350848  61.624521  56.883881  2519.512315  4.961721
# 7        0.505123  3.101676  61.510615  56.507207  2864.839106  4.968402
#
#                 y         z  validate_z
# clarity
# 0        6.709458  4.224688    0.950067
# 1        6.395579  3.952642    0.939173
# 2        5.888256  3.640636    0.945809
# 3        5.659782  3.492788    0.950718
# 4        5.580017  3.437925    0.951652
# 5        5.232118  3.221465    0.946309
# 6        4.976437  3.062132    0.940339
# 7        4.989827  3.061659    0.959777

# %%
#your comments here
"""
# carat decreases, so but the highest value is 1.2, not really close to 5
# color, depth, table around same value
# not a lot to say about the affect on price, it varies a lot
# therefore, i think clarity also does not affect price so much
# clarity, table and depth will probably not be the most important features for price determination
"""

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
"""
color and carat affect the price most, I also assumed clarity, however, it seems as if this is not the case
"""

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})
# Out:
# /Users/michelle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

"""
# if you look at the price pairplots, the price has a huger increase, than the increase of carat, but there is a strong
# positive relationship between these two variables

# color and clarity have no linear relationship with price
# same for depth and table

# also lengt width and depth, x, y, z have a strong positive relationship with the price, which was already assumed
as these determine the weight

# so most interesting is definitely the carat, so the weight of the diamond
"""

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
"""
as expected, carat has the strongest positive relationship, after this x, y, z
the relationship between carat and x, y, z, is also very strong, as weight is determined by the size: so length, 
width and depth 
"""

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# /Users/michelle/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804609

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
"""
you see a strong positive relationship between price and carat, it does seem that from carat being 3 or higher,
the effect of carat on price does decrease a bit, I think you cannot say if this is true or not as most values
of carat within this dataset ly between 0 and 3, you I already noticed at the histogram, it is skewed to the left
so probably I need more datapoints for these values to make this conclusion
"""

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here
"""
after cleaning the data, and seeing that carat definitely had most effect on the diamond price, it would make 
more sense to obtain more datapoints regarding carat and than make a new plot, than for now to plot other features
"""

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
