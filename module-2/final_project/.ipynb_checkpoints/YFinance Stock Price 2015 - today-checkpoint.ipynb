# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.figure_factory as ff
import plotly.express as px

# %%
sp_500 = pd.read_csv('constituents_csv.csv')
sp_500
# Out:
#     Symbol                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4     ABMD             ABIOMED Inc             Health Care
# ..     ...                     ...                     ...
# 500    YUM         Yum! Brands Inc  Consumer Discretionary
# 501   ZBRA      Zebra Technologies  Information Technology
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
sp_500.Sector.unique()
# Out:
# array(['Industrials', 'Health Care', 'Information Technology',
#        'Communication Services', 'Consumer Discretionary', 'Utilities',
#        'Financials', 'Materials', 'Real Estate', 'Consumer Staples',
#        'Energy'], dtype=object)

# %%
# first10 = sp_500[:10]
# first10

# %%
def get_tickers(dataframe):
    ticker_list = list(sp_500['Symbol'])
    print('Retrieved', str(len(ticker_list)), 'ticker symbols.')
    return ticker_list

get_tickers('sp_500')
# Out:
# Retrieved 505 ticker symbols.
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AAP',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
# ...

# %%
# def get_prices(ticker):
#     print('Retrieving data for', ticker)
#     prices = yf.download(tickers=ticker, period='5y')
#     prices['Ticker'] = ticker
#     return prices 

# data = []

# ticker_list = get_tickers('sp_500')

# for ticker in ticker_list:
#     prices = get_prices(ticker)
#     data.append(prices)
# Out:
# Retrieved 505 ticker symbols.
# Retrieving data for MMM
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for AOS
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for ABT
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for ABBV
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for ABMD
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for ACN
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for ATVI
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for ADBE
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for AAP
# [*********************100%***********************]  1 of 1 completed
# Retrieving data for AMD
# ...

# %%
# data

# %%
sp500_dataframe = pd.concat(data, sort=True)
sp500_dataframe
# Out:
#              Adj Close       Close        High         Low        Open Ticker  \
# Date
# 2015-11-18  137.250717  157.389999  157.500000  156.080002  156.179993    MMM
# 2015-11-19  138.114029  158.380005  158.509995  156.710007  157.630005    MMM
# 2015-11-20  138.611099  158.949997  159.839996  158.339996  158.679993    MMM
# 2015-11-23  138.349503  158.649994  159.770004  158.160004  158.899994    MMM
# 2015-11-24  137.564667  157.750000  158.339996  156.889999  157.369995    MMM
# ...                ...         ...         ...         ...         ...    ...
# 2020-11-11  164.949997  164.949997  165.919998  163.330002  164.990005    ZTS
# 2020-11-12  165.190002  165.190002  166.600006  163.789993  164.160004    ZTS
# 2020-11-13  165.779999  165.779999  167.029999  164.509995  165.460007    ZTS
# 2020-11-16  165.289993  165.289993  168.520004  164.600006  166.369995    ZTS
# 2020-11-17  165.429993  165.429993  166.110001  164.070007  164.490005    ZTS
#
#                Volume
# ...

# %%
sp500_dataframe.to_csv('sp500_clean.csv')

# %%
sp500_df = pd.read_csv('sp500_clean.csv')
sp500_df
# Out:
#               Date   Adj Close       Close        High         Low  \
# 0       2015-11-18  137.250717  157.389999  157.500000  156.080002
# 1       2015-11-19  138.114029  158.380005  158.509995  156.710007
# 2       2015-11-20  138.611099  158.949997  159.839996  158.339996
# 3       2015-11-23  138.349503  158.649994  159.770004  158.160004
# 4       2015-11-24  137.564667  157.750000  158.339996  156.889999
# ...            ...         ...         ...         ...         ...
# 625648  2020-11-11  164.949997  164.949997  165.919998  163.330002
# 625649  2020-11-12  165.190002  165.190002  166.600006  163.789993
# 625650  2020-11-13  165.779999  165.779999  167.029999  164.509995
# 625651  2020-11-16  165.289993  165.289993  168.520004  164.600006
# 625652  2020-11-17  165.429993  165.429993  166.110001  164.070007
#
#               Open Ticker     Volume
# 0       156.179993    MMM  2226900.0
# 1       157.630005    MMM  1518200.0
# 2       158.679993    MMM  1891100.0
# ...

# %%
sp_500 = sp_500.rename(columns={'Symbol': 'Ticker'})
sp_500
# Out:
#     Ticker                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4     ABMD             ABIOMED Inc             Health Care
# ..     ...                     ...                     ...
# 500    YUM         Yum! Brands Inc  Consumer Discretionary
# 501   ZBRA      Zebra Technologies  Information Technology
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
# sp500_df = sp500_df.reset_index()
# sp500_df

# %%
merged_stock_sp500 = sp500_df.merge(sp_500, left_on='Ticker', right_on='Ticker')
merged_stock_sp500
# Out:
#               Date   Adj Close       Close        High         Low  \
# 0       2015-11-18  137.250717  157.389999  157.500000  156.080002
# 1       2015-11-19  138.114029  158.380005  158.509995  156.710007
# 2       2015-11-20  138.611099  158.949997  159.839996  158.339996
# 3       2015-11-23  138.349503  158.649994  159.770004  158.160004
# 4       2015-11-24  137.564667  157.750000  158.339996  156.889999
# ...            ...         ...         ...         ...         ...
# 625648  2020-11-11  164.949997  164.949997  165.919998  163.330002
# 625649  2020-11-12  165.190002  165.190002  166.600006  163.789993
# 625650  2020-11-13  165.779999  165.779999  167.029999  164.509995
# 625651  2020-11-16  165.289993  165.289993  168.520004  164.600006
# 625652  2020-11-17  165.429993  165.429993  166.110001  164.070007
#
#               Open Ticker     Volume        Name       Sector
# 0       156.179993    MMM  2226900.0  3M Company  Industrials
# ...

# %%
merged_stock_sp500.to_csv('merged_stock_clean.csv')

# import pymysql
# from sqlalchemy import create_engine

# engine = create_engine('mysql+pymysql://student:IHisCool!@34.77.233.175:3306/stock_prices')

# merged_stock_sp500.to_sql('merged_stock_sp500', engine, if_exists ='replace', index=False)

# %%
merged_stock_sp500.Sector.unique()
# Out:
# array(['Industrials', 'Health Care', 'Information Technology',
#        'Communication Services', 'Consumer Discretionary', 'Utilities',
#        'Financials', 'Materials', 'Real Estate', 'Consumer Staples',
#        'Energy'], dtype=object)

# %%
pivot_sp500 = merged_stock_sp500.pivot_table(index= ['Date'], columns=['Sector'], values=['Close'])
pivot_sp500
# Out:
#                             Close                                          \
# Sector     Communication Services Consumer Discretionary Consumer Staples
# Date
# 2015-11-18             115.270435             146.618229        71.412488
# 2015-11-19             115.192173             147.136173        71.803423
# 2015-11-20             117.149129             147.182092        71.442039
# 2015-11-23             116.815869             147.979000        72.339111
# 2015-11-24             115.813914             147.596103        72.426870
# ...                           ...                    ...              ...
# 2020-11-11             232.681537             286.317052        99.999375
# 2020-11-12             231.714612             281.262623        99.918749
# 2020-11-13             235.142117             286.486561       101.268124
# 2020-11-16             235.781538             290.070000       102.313437
# 2020-11-17             234.972695             288.469502       101.798439
#
# ...

# %%
ax = pivot_sp500.plot(figsize = [10,10])
plt.legend(bbox_to_anchor=(1, 1), loc='best', ncol=1)
plt.suptitle('Stock Prices over Time', fontsize=15)
# ax.set_xticklabels(ax.get_xticklabels( ), rotation=90)
# Out:
# Text(0.5,0.98,'Stock Prices over Time')

# %%
import plotly.express as px

# newindex_pivot_sp500 = pivot_sp500.reset_index()
# newindex_pivot_sp500.columns
# # fig = px.line(newindex_pivot_sp500, x="Date", y="Close", color='Sector')
# # fig.show()

# %%
# fig, ax = plt.subplots()

# # grouped = merged_stock_sp500.groupby('Sector')
# for key, group in pivot_sp500:
#     group.plot(ax=ax, x='Date', y='Close', label=key)
    
#     ax.set_xticklabels(ax.get_xticklabels( ), rotation=90)
#     plt.legend(bbox_to_anchor=(1, 1), loc='best', ncol=1)
    
# plt.show()

# %%
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# pivot_sp500['Close','Communication Services'].plot(ax=axes[0,0], label='Communication')
# axes[0,0].set_title('Stock Prices by the Communication Services Industry')

# pivot_sp500['Close','Consumer Discretionary'].plot(ax=axes[0,1])
# axes[0,1].set_title('Stock Prices by the Consumer Discretionary Industry')

# pivot_sp500['Close','Consumer Staples'].plot(ax=axes[0,2])
# axes[0,2].set_title('Stock Prices by the Consumer Staples Industry')

# pivot_sp500['Close','Energy'].plot(ax=axes[0,3])
# axes[0,3].set_title('Stock Prices by the Energy Industry')

# pivot_sp500['Close','Financials'].plot(ax=axes[0,4])
# axes[0,4].set_title('Stock Prices by the Financials Industry')

# pivot_sp500['Close','Health Care'].plot(ax=axes[0,5])
# axes[0,5].set_title('Stock Prices by the Health Care Industry')

# pivot_sp500['Close','Industrials'].plot(ax=axes[0,6])
# axes[0,6].set_title('Stock Prices by the Industrials Industry')

# pivot_sp500['Close','Information Technology'].plot(ax=axes[0,7])
# axes[0,7].set_title('Stock Prices by the Tech Industry')

# pivot_sp500['Close','Materials'].plot(ax=axes[0,8])
# axes[0,8].set_title('Stock Prices by the Materials Industry')

# pivot_sp500['Close','Real Estate'].plot(ax=axes[0,9])
# axes[0,9].set_title('Stock Prices by the Real Estate Industry')

# pivot_sp500['Close','Utilities'].plot(ax=axes[0,10])
# axes[0,10].set_title('Stock Prices by the Utilities Industry')

# plt.tight_layout()

# plt.legend(bbox_to_anchor=(1, 1), loc='best', ncol=2)
# plt.suptitle('Stock Prices from 2015 -- today', fontsize=15)

# %%
# pivot_sp500[('Close','Financials')].plot()

# %%
MSFT = yf.download(tickers='MSFT', period='5y')
MSFT
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-11-17   53.169998   53.529999   52.849998   52.970001   48.463364
# 2015-11-18   53.000000   53.980000   52.980000   53.849998   49.268490
# 2015-11-19   53.990002   54.660000   53.779999   53.939999   49.350838
# 2015-11-20   54.250000   54.299999   53.270000   54.189999   49.579559
# 2015-11-23   54.250000   54.459999   53.750000   54.189999   49.579559
# ...                ...         ...         ...         ...         ...
# 2020-11-11  212.389999  218.039993  212.199997  216.550003  216.550003
# 2020-11-12  217.210007  219.110001  214.460007  215.440002  215.440002
# 2020-11-13  216.360001  217.419998  214.160004  216.509995  216.509995
# 2020-11-16  214.869995  217.740005  214.520004  217.229996  217.229996
# 2020-11-17  216.100006  217.679993  214.080002  214.300003  214.300003
#
#               Volume
# Date
# ...

# %%
msft = yf.Ticker("MSFT")
msft.info
msft.history(period='5y')
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2015-11-17   48.646345   48.975717   48.353571   48.463364  31551300
# 2015-11-18   48.490808   49.387431   48.472510   49.268490  29710000
# 2015-11-19   49.396587   50.009582   49.204450   49.350838  28149200
# 2015-11-20   49.634456   49.680201   48.737834   49.579559  37147600
# 2015-11-23   49.634456   49.826588   49.176995   49.579559  28235900
# ...                ...         ...         ...         ...       ...
# 2020-11-11  212.389999  218.039993  212.199997  216.550003  29440800
# 2020-11-12  217.210007  219.110001  214.460007  215.440002  21593900
# 2020-11-13  216.360001  217.419998  214.160004  216.509995  18621100
# 2020-11-16  214.869995  217.740005  214.520004  217.229996  24921400
# 2020-11-17  216.100006  217.679993  214.080002  214.539993  18141085
#
#             Dividends  Stock Splits
# Date
# 2015-11-17       0.36             0
# 2015-11-18       0.00             0
# ...

# %%
"""
returns:
{
 'quoteType': 'EQUITY',
 'quoteSourceName': 'Nasdaq Real Time Price',
 'currency': 'USD',
 'shortName': 'Microsoft Corporation',
 'exchangeTimezoneName': 'America/New_York',
  ...
}
"""
