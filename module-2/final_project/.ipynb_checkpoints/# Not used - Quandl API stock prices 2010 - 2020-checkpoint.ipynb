# %%
import pandas as pd

# %%
companies = pd.read_csv('companies.csv')
companies = companies.loc[[0,1,2]]
companies
# Out:
#   Ticker           Company
# 0   AAPL        Apple Inc.
# 1   NFLX     Netflix, Inc.
# 2   AMZN  Amazon.com, Inc.

# %%
# companies.to_csv('companies_clean.csv')

# %%
def get_tickers(path):
    companies = pd.read_csv(path)
    ticker_list = list(companies['Ticker'])
    print('Retrieved', str(len(ticker_list)), 'ticker symbols.')
    return ticker_list

get_tickers('companies_clean.csv')
# Out:
# Retrieved 3 ticker symbols.
# ['AAPL', 'NFLX', 'AMZN']

# %%
# import quandl
 
# def get_prices(ticker):
#     print('Retrieving data for', ticker)
#     prices = quandl.get('WIKI/' + ticker)['Adj. Close'].reset_index()
#     prices['Ticker'] = ticker
#     return prices
 
# data = []
 
# ticker_list = get_tickers('companies_clean.csv')
 
# for ticker in ticker_list:
#     prices = get_prices(ticker)
#     data.append(prices)

# %%
data = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = ['NFLX'], date = { 'gte': '2000-01-01', 'lte': '2020-01-01' },  api_key='zb3EEjzwn8sgrXYUqyTD')
data
# Out:
#      ticker       date   close
# None
# 0      NFLX 2018-03-27  300.69
# 1      NFLX 2018-03-26  320.35
# 2      NFLX 2018-03-23  300.94
# 3      NFLX 2018-03-22  306.70
# 4      NFLX 2018-03-21  316.48
# 5      NFLX 2018-03-20  317.50
# 6      NFLX 2018-03-19  313.48
# 7      NFLX 2018-03-16  318.45
# 8      NFLX 2018-03-15  321.09
# 9      NFLX 2018-03-14  321.55
# 10     NFLX 2018-03-13  315.88
# 11     NFLX 2018-03-12  321.30
# 12     NFLX 2018-03-09  331.44
# 13     NFLX 2018-03-08  317.00
# 14     NFLX 2018-03-07  321.16
# 15     NFLX 2018-03-06  325.22
# 16     NFLX 2018-03-05  315.00
# 17     NFLX 2018-03-02  301.05
# 18     NFLX 2018-03-01  290.39
# 19     NFLX 2018-02-28  291.38
# 20     NFLX 2018-02-27  290.61
# 21     NFLX 2018-02-26  294.16
# 22     NFLX 2018-02-23  285.93
# 23     NFLX 2018-02-22  278.14
# 24     NFLX 2018-02-21  281.04
# 25     NFLX 2018-02-20  278.55
# 26     NFLX 2018-02-16  278.52
# 27     NFLX 2018-02-15  280.27
# 28     NFLX 2018-02-14  266.00
# ...

# %%
data = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = ['AMZN'], date = { 'gte': '2020-01-01', 'lte': '2020-12-31' },  api_key='zb3EEjzwn8sgrXYUqyTD')
data
# Out:
# Empty DataFrame
# Columns: [ticker, date, close]
# Index: []

# %%
data = quandl.get_table('SHARADAR/SEP', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = ['AAPL'], date = { 'gte': '2010-01-01', 'lte': '2010-11-01' },  api_key='zb3EEjzwn8sgrXYUqyTD')
data
# Out:
# Empty DataFrame
# Columns: [ticker, date, close]
# Index: []

# %%
quandl.get_table('SHARADAR/SEP', date={'gte':'2018-09-01', 'lte':'2018-12-31'}, ticker='AAPL', api_key='zb3EEjzwn8sgrXYUqyTD')
# Out:
#      ticker       date    open    high     low   close       volume  \
# None
# 0      AAPL 2018-12-31  39.633  39.840  39.120  39.435  140013864.0
# 1      AAPL 2018-12-28  39.375  39.630  38.638  39.057  169165696.0
# 2      AAPL 2018-12-27  38.960  39.193  37.517  39.038  212468260.0
# 3      AAPL 2018-12-26  37.075  39.307  36.680  39.292  234330176.0
# 4      AAPL 2018-12-24  37.038  37.888  36.648  36.708  148676928.0
# 5      AAPL 2018-12-21  39.215  39.540  37.407  37.682  382977536.0
# 6      AAPL 2018-12-20  40.100  40.528  38.825  39.208  259091840.0
# 7      AAPL 2018-12-19  41.500  41.862  39.773  40.222  196189188.0
# 8      AAPL 2018-12-18  41.345  41.883  41.097  41.517  135366072.0
# 9      AAPL 2018-12-17  41.362  42.087  40.682  40.985  177151688.0
# 10     AAPL 2018-12-14  42.250  42.270  41.320  41.370  162814840.0
# 11     AAPL 2018-12-13  42.623  43.142  42.388  42.737  127591308.0
# 12     AAPL 2018-12-12  42.600  42.980  42.255  42.275  142510696.0
# ...
