# %% [markdown]
# ### This Script will Get the list of all games with its id number and ouput a file at `./data/game_id.csv`
# ### As of 11/8/2019. There are 345727 games. More information about the API can be found here https://rawg.io/apidocs and its endpoints can be found here https://api.rawg.io/docs/

# %%
import json
import requests
from pprint import pprint
import os
import csv
from time import time
import concurrent.futures
import functools
import math
from pandas import json_normalize
import pandas as pd

# %% [markdown]
# ## Multithreading
# #### This function is responsible for requesting pages of games (20 games per page) and save as a JSON file in `/data/game_id/`. As of 11/8/2019, there are 17272 pages

# %%
def threading(start_index, pages_per_worker, urls, downloaded_files, headers):
    for url in urls[start_index : start_index + pages_per_worker]:
        if url.rsplit("?page=")[-1] in downloaded_files: continue 
        try:
            # Request API
            json_data = json.loads(requests.get(url, headers=headers).text)

            # Get wanted data
            D = {game["id"]:game["slug"] for game in json_data["results"]}

            # Save data
            page_no = int(url.split("page=")[-1])
            with open(fr"./data/game_id/{page_no}.json", "w", encoding="utf8") as f:
                json.dump(D, f)
        except:
            print(f"Error with {url}")
    # Verbose notification
    print(f"Done from {page_no - N} to {page_no}")

# %% [markdown]
# #### Create folder if not existed

# %%
if not os.path.exists('data/game_id/'):
    os.makedirs('data/game_id/')

# %% [markdown]
# #### The following codes apply concurrent programming to speed up the progress. 50 workers are running at the same time. Each of the workers will individually make a request. Time was reduced from ~ 4 hours to ~40 minutes for  17272 pages

# %%
# Make the first request to get the total amount of pages to get
headers = { 'User-Agent': 'App Name: Education purpose',}
json_data = json.loads(requests.get(r"https://api.rawg.io/api/games", headers=headers).text)
no_of_pages = math.ceil(json_data["count"]/20)

# Set up number of workers
max_workers = 50
pages_per_worker = int(no_of_pages/max_workers)
start_index = range(0, no_of_pages, pages_per_worker)

# Make urls
url = "https://api.rawg.io/api/games?page=1"
urls = [url[:-1] + str(i) for i in range(1, no_of_pages + 1)]

# %%
# Skipped downloaded files
downloaded_files = {file.split(".",1)[0] for file in os.listdir("data/game_id/")}

# Time
t0=time()
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    temp = functools.partial(threading,
                             pages_per_worker=pages_per_worker,
                             urls=urls,
                             downloaded_files=downloaded_files,
                             headers=headers,
                            )
    executor.map(temp, start_index)
print(f"Time taken: {time()-t0}")
# Out:
# Error with https://api.rawg.io/api/games?page=10335
# Error with https://api.rawg.io/api/games?page=9864
# Error with https://api.rawg.io/api/games?page=5640
# Error with https://api.rawg.io/api/games?page=8929
# Error with https://api.rawg.io/api/games?page=14077
# Error with https://api.rawg.io/api/games?page=9865
# Error with https://api.rawg.io/api/games?page=10336
# Error with https://api.rawg.io/api/games?page=5641
# Error with https://api.rawg.io/api/games?page=17830Error with https://api.rawg.io/api/games?page=4229
#
# Error with https://api.rawg.io/api/games?page=6106Error with https://api.rawg.io/api/games?page=14078
#
# Error with https://api.rawg.io/api/games?page=2830
# Error with https://api.rawg.io/api/games?page=10337Error with https://api.rawg.io/api/games?page=21584
#
# Error with https://api.rawg.io/api/games?page=8462
# Error with https://api.rawg.io/api/games?page=1415
# Error with https://api.rawg.io/api/games?page=5642Error with https://api.rawg.io/api/games?page=20640
#
# Error with https://api.rawg.io/api/games?page=22057
# Error with https://api.rawg.io/api/games?page=20178
# Error with https://api.rawg.io/api/games?page=2354
# Error with https://api.rawg.io/api/games?page=19712
# Error with https://api.rawg.io/api/games?page=15957
# Error with https://api.rawg.io/api/games?page=22989
# Error with https://api.rawg.io/api/games?page=14079
# Error with https://api.rawg.io/api/games?page=22524
# Error with https://api.rawg.io/api/games?page=6107
# Error with https://api.rawg.io/api/games?page=17831
# Error with https://api.rawg.io/api/games?page=4230
# Error with https://api.rawg.io/api/games?page=10338
# Error with https://api.rawg.io/api/games?page=9867
# Error with https://api.rawg.io/api/games?page=2831
# Error with https://api.rawg.io/api/games?page=8463
# Error with https://api.rawg.io/api/games?page=1887
# Error with https://api.rawg.io/api/games?page=21585Error with https://api.rawg.io/api/games?page=20641
#
# Error with https://api.rawg.io/api/games?page=1416
# Error with https://api.rawg.io/api/games?page=5643
# Error with https://api.rawg.io/api/games?page=14547
# Error with https://api.rawg.io/api/games?page=22058Error with https://api.rawg.io/api/games?page=19713
#
# Error with https://api.rawg.io/api/games?page=11263
# Error with https://api.rawg.io/api/games?page=15958
# Error with https://api.rawg.io/api/games?page=13609
# Error with https://api.rawg.io/api/games?page=6108
# Error with https://api.rawg.io/api/games?page=17832
# Error with https://api.rawg.io/api/games?page=6579
# Error with https://api.rawg.io/api/games?page=22525
# Error with https://api.rawg.io/api/games?page=13144Error with https://api.rawg.io/api/games?page=4231
# Error with https://api.rawg.io/api/games?page=9868
#
# Error with https://api.rawg.io/api/games?page=10339
# Error with https://api.rawg.io/api/games?page=1888
# Error with https://api.rawg.io/api/games?page=21586
# Error with https://api.rawg.io/api/games?page=8464
# Error with https://api.rawg.io/api/games?page=16894
# Error with https://api.rawg.io/api/games?page=1417Error with https://api.rawg.io/api/games?page=20642
#
# Error with https://api.rawg.io/api/games?page=5207
# Error with https://api.rawg.io/api/games?page=16023
# Error with https://api.rawg.io/api/games?page=6628
# Error with https://api.rawg.io/api/games?page=19769
# Error with https://api.rawg.io/api/games?page=18829
# Error with https://api.rawg.io/api/games?page=8967
# Error with https://api.rawg.io/api/games?page=17883
# Error with https://api.rawg.io/api/games?page=19297
# Error with https://api.rawg.io/api/games?page=5208
# Error with https://api.rawg.io/api/games?page=19770
# Error with https://api.rawg.io/api/games?page=6629
# Error with https://api.rawg.io/api/games?page=8968Error with https://api.rawg.io/api/games?page=16024
#
# Error with https://api.rawg.io/api/games?page=10393
# Error with https://api.rawg.io/api/games?page=5209
# Error with https://api.rawg.io/api/games?page=17884
# Error with https://api.rawg.io/api/games?page=4751
# Error with https://api.rawg.io/api/games?page=6630
# Error with https://api.rawg.io/api/games?page=19298
# Error with https://api.rawg.io/api/games?page=19771
# Error with https://api.rawg.io/api/games?page=8969Error with https://api.rawg.io/api/games?page=10394
#
# Error with https://api.rawg.io/api/games?page=23056Error with https://api.rawg.io/api/games?page=17885
#
# Error with https://api.rawg.io/api/games?page=16025Error with https://api.rawg.io/api/games?page=5210
#
# Error with https://api.rawg.io/api/games?page=20674Error with https://api.rawg.io/api/games?page=19299
# Error with https://api.rawg.io/api/games?page=4752
#
# Error with https://api.rawg.io/api/games?page=17416Error with https://api.rawg.io/api/games?page=6631
#
# Error with https://api.rawg.io/api/games?page=18335
# Error with https://api.rawg.io/api/games?page=14601
# Error with https://api.rawg.io/api/games?page=32
# Error with https://api.rawg.io/api/games?page=17886Error with https://api.rawg.io/api/games?page=10395
#
# Error with https://api.rawg.io/api/games?page=8970
# Error with https://api.rawg.io/api/games?page=3822
# Error with https://api.rawg.io/api/games?page=23057Error with https://api.rawg.io/api/games?page=5211
#
# Error with https://api.rawg.io/api/games?page=13199
# Error with https://api.rawg.io/api/games?page=15074
# Error with https://api.rawg.io/api/games?page=20675Error with https://api.rawg.io/api/games?page=16026
#
# Error with https://api.rawg.io/api/games?page=4753Error with https://api.rawg.io/api/games?page=17417
#
# Error with https://api.rawg.io/api/games?page=19300
# Error with https://api.rawg.io/api/games?page=12715
# Error with https://api.rawg.io/api/games?page=973
# Error with https://api.rawg.io/api/games?page=10859
# Error with https://api.rawg.io/api/games?page=23090
# Error with https://api.rawg.io/api/games?page=11359Error with https://api.rawg.io/api/games?page=10461
#
# Error with https://api.rawg.io/api/games?page=6226
# Error with https://api.rawg.io/api/games?page=4833
# Error with https://api.rawg.io/api/games?page=3894
# Error with https://api.rawg.io/api/games?page=16587
# Error with https://api.rawg.io/api/games?page=20307Error with https://api.rawg.io/api/games?page=11848
# Error with https://api.rawg.io/api/games?page=16129
#
# Error with https://api.rawg.io/api/games?page=1511
# Error with https://api.rawg.io/api/games?page=11360
# Error with https://api.rawg.io/api/games?page=3422
# Error with https://api.rawg.io/api/games?page=6710
# Error with https://api.rawg.io/api/games?page=20739
# Error with https://api.rawg.io/api/games?page=10462
# Error with https://api.rawg.io/api/games?page=12324
# Error with https://api.rawg.io/api/games?page=4834
# Error with https://api.rawg.io/api/games?page=3895
# Error with https://api.rawg.io/api/games?page=16588Error with https://api.rawg.io/api/games?page=6227
#
# Error with https://api.rawg.io/api/games?page=19401
# Error with https://api.rawg.io/api/games?page=23164
# Error with https://api.rawg.io/api/games?page=19858
# Error with https://api.rawg.io/api/games?page=18395
# Error with https://api.rawg.io/api/games?page=17041
# Error with https://api.rawg.io/api/games?page=16130
# Error with https://api.rawg.io/api/games?page=11361Error with https://api.rawg.io/api/games?page=11849
#
# Error with https://api.rawg.io/api/games?page=3423Error with https://api.rawg.io/api/games?page=20308
#
# Error with https://api.rawg.io/api/games?page=20740Error with https://api.rawg.io/api/games?page=6711
#
# Error with https://api.rawg.io/api/games?page=1512
# Error with https://api.rawg.io/api/games?page=10463
# Error with https://api.rawg.io/api/games?page=8605
# Error with https://api.rawg.io/api/games?page=12325
# Error with https://api.rawg.io/api/games?page=3896Error with https://api.rawg.io/api/games?page=16589
# Error with https://api.rawg.io/api/games?page=1026
#
# Error with https://api.rawg.io/api/games?page=7655
# Error with https://api.rawg.io/api/games?page=2488
# Error with https://api.rawg.io/api/games?page=14678Error with https://api.rawg.io/api/games?page=19402Error with https://api.rawg.io/api/games?page=6228
# Error with https://api.rawg.io/api/games?page=4835
#
#
# Error with https://api.rawg.io/api/games?page=23165
# Error with https://api.rawg.io/api/games?page=17042
# Error with https://api.rawg.io/api/games?page=9511
# Error with https://api.rawg.io/api/games?page=21686
# Error with https://api.rawg.io/api/games?page=16131Error with https://api.rawg.io/api/games?page=15132Error with https://api.rawg.io/api/games?page=19859
#
# Error with https://api.rawg.io/api/games?page=1981
#
# Error with https://api.rawg.io/api/games?page=2937
# Error with https://api.rawg.io/api/games?page=11362
# Error with https://api.rawg.io/api/games?page=18396
# Error with https://api.rawg.io/api/games?page=3424
# Error with https://api.rawg.io/api/games?page=9991Error with https://api.rawg.io/api/games?page=20309Error with https://api.rawg.io/api/games?page=11850
#
#
# Error with https://api.rawg.io/api/games?page=568
# Error with https://api.rawg.io/api/games?page=6712
# Error with https://api.rawg.io/api/games?page=21224
# Error with https://api.rawg.io/api/games?page=1513
# Error with https://api.rawg.io/api/games?page=20741Error with https://api.rawg.io/api/games?page=12326
# Error with https://api.rawg.io/api/games?page=8606
#
# Error with https://api.rawg.io/api/games?page=5779
# Error with https://api.rawg.io/api/games?page=10464Error with https://api.rawg.io/api/games?page=3897
#
# Error with https://api.rawg.io/api/games?page=16590
# Error with https://api.rawg.io/api/games?page=14679Error with https://api.rawg.io/api/games?page=1027
# Error with https://api.rawg.io/api/games?page=7656
#
# Error with https://api.rawg.io/api/games?page=22619Error with https://api.rawg.io/api/games?page=19403
# Error with https://api.rawg.io/api/games?page=21687
#
# Error with https://api.rawg.io/api/games?page=6229
# Error with https://api.rawg.io/api/games?page=17043
# Error with https://api.rawg.io/api/games?page=23166
# Error with https://api.rawg.io/api/games?page=15133
# Error with https://api.rawg.io/api/games?page=9512
# Error with https://api.rawg.io/api/games?page=11363
# Error with https://api.rawg.io/api/games?page=19860
# Error with https://api.rawg.io/api/games?page=13352
# Error with https://api.rawg.io/api/games?page=12404
# Error with https://api.rawg.io/api/games?page=17583
# Error with https://api.rawg.io/api/games?page=19937Error with https://api.rawg.io/api/games?page=17146
#
# Error with https://api.rawg.io/api/games?page=4448Error with https://api.rawg.io/api/games?page=6795
#
# Error with https://api.rawg.io/api/games?page=20380
# Error with https://api.rawg.io/api/games?page=21755
# Error with https://api.rawg.io/api/games?page=12405Error with https://api.rawg.io/api/games?page=11932
#
# Error with https://api.rawg.io/api/games?page=13353Error with https://api.rawg.io/api/games?page=19013
# Error with https://api.rawg.io/api/games?page=22252
#
# Error with https://api.rawg.io/api/games?page=16694
# Error with https://api.rawg.io/api/games?page=14782
# Error with https://api.rawg.io/api/games?page=22681
# Error with https://api.rawg.io/api/games?page=19938Error with https://api.rawg.io/api/games?page=17147
# Error with https://api.rawg.io/api/games?page=17584
#
# Error with https://api.rawg.io/api/games?page=18047
# Error with https://api.rawg.io/api/games?page=21292
# Error with https://api.rawg.io/api/games?page=12886
# Error with https://api.rawg.io/api/games?page=6796
# Error with https://api.rawg.io/api/games?page=131
# Error with https://api.rawg.io/api/games?page=20381
# Error with https://api.rawg.io/api/games?page=4449
# Error with https://api.rawg.io/api/games?page=21756
# Error with https://api.rawg.io/api/games?page=13354
# Error with https://api.rawg.io/api/games?page=11933
# Error with https://api.rawg.io/api/games?page=22253Error with https://api.rawg.io/api/games?page=12406Error with https://api.rawg.io/api/games?page=3991Error with https://api.rawg.io/api/games?page=22682
#
#
#
# Error with https://api.rawg.io/api/games?page=14783Error with https://api.rawg.io/api/games?page=21293
#
# Error with https://api.rawg.io/api/games?page=12887
# Error with https://api.rawg.io/api/games?page=9135
# Error with https://api.rawg.io/api/games?page=18048
# Error with https://api.rawg.io/api/games?page=132
# Error with https://api.rawg.io/api/games?page=2062Error with https://api.rawg.io/api/games?page=6797
#
# Error with https://api.rawg.io/api/games?page=18473
# Error with https://api.rawg.io/api/games?page=4450
# Error with https://api.rawg.io/api/games?page=3027
# Error with https://api.rawg.io/api/games?page=11934
# Error with https://api.rawg.io/api/games?page=3524
# Error with https://api.rawg.io/api/games?page=12407
# Error with https://api.rawg.io/api/games?page=22683Error with https://api.rawg.io/api/games?page=3992
#
# Error with https://api.rawg.io/api/games?page=4921
# Error with https://api.rawg.io/api/games?page=5935Error with https://api.rawg.io/api/games?page=17598
#
# Error with https://api.rawg.io/api/games?page=140
# Error with https://api.rawg.io/api/games?page=1092Error with https://api.rawg.io/api/games?page=2077
# Error with https://api.rawg.io/api/games?page=16251
#
# Error with https://api.rawg.io/api/games?page=12415
# Error with https://api.rawg.io/api/games?page=3037
# Error with https://api.rawg.io/api/games?page=10070
# Error with https://api.rawg.io/api/games?page=11481Error with https://api.rawg.io/api/games?page=16708
#
# Error with https://api.rawg.io/api/games?page=18054
# Error with https://api.rawg.io/api/games?page=17599
# Error with https://api.rawg.io/api/games?page=19948
# Error with https://api.rawg.io/api/games?page=10977Error with https://api.rawg.io/api/games?page=14275
#
# Error with https://api.rawg.io/api/games?page=2078Error with https://api.rawg.io/api/games?page=18482
#
# Error with https://api.rawg.io/api/games?page=16252Error with https://api.rawg.io/api/games?page=1093
#
# Error with https://api.rawg.io/api/games?page=21305
# Error with https://api.rawg.io/api/games?page=12416
# Error with https://api.rawg.io/api/games?page=10071
# Error with https://api.rawg.io/api/games?page=16709Error with https://api.rawg.io/api/games?page=18055
# Error with https://api.rawg.io/api/games?page=6809
#
# Error with https://api.rawg.io/api/games?page=14276
# Error with https://api.rawg.io/api/games?page=2599Error with https://api.rawg.io/api/games?page=5937
#
# Error with https://api.rawg.io/api/games?page=18483Error with https://api.rawg.io/api/games?page=10978
# Error with https://api.rawg.io/api/games?page=16253
#
# Error with https://api.rawg.io/api/games?page=17600
# Error with https://api.rawg.io/api/games?page=1094
# Error with https://api.rawg.io/api/games?page=2079
# Error with https://api.rawg.io/api/games?page=21306
# Error with https://api.rawg.io/api/games?page=6810
# Error with https://api.rawg.io/api/games?page=18056Error with https://api.rawg.io/api/games?page=10072
#
# Error with https://api.rawg.io/api/games?page=16710
# Error with https://api.rawg.io/api/games?page=2600
# Error with https://api.rawg.io/api/games?page=14277
# Error with https://api.rawg.io/api/games?page=10979
# Error with https://api.rawg.io/api/games?page=5938
# Error with https://api.rawg.io/api/games?page=16254Error with https://api.rawg.io/api/games?page=6811
# Error with https://api.rawg.io/api/games?page=21307
#
# Error with https://api.rawg.io/api/games?page=1095
# Error with https://api.rawg.io/api/games?page=17601
# Error with https://api.rawg.io/api/games?page=10073
# Error with https://api.rawg.io/api/games?page=18057
# Error with https://api.rawg.io/api/games?page=9142
# Error with https://api.rawg.io/api/games?page=12418
# Error with https://api.rawg.io/api/games?page=4464
# Error with https://api.rawg.io/api/games?page=16711
# Error with https://api.rawg.io/api/games?page=2601
# Error with https://api.rawg.io/api/games?page=13824
# Error with https://api.rawg.io/api/games?page=17173
# Error with https://api.rawg.io/api/games?page=2101Error with https://api.rawg.io/api/games?page=10592
#
# Error with https://api.rawg.io/api/games?page=7285
# Error with https://api.rawg.io/api/games?page=13825
# Error with https://api.rawg.io/api/games?page=17174
# Error with https://api.rawg.io/api/games?page=10084
# Error with https://api.rawg.io/api/games?page=12429
# Error with https://api.rawg.io/api/games?page=12909
# Error with https://api.rawg.io/api/games?page=10593
# Error with https://api.rawg.io/api/games?page=23296
# Error with https://api.rawg.io/api/games?page=7286
# Error with https://api.rawg.io/api/games?page=19961Error with https://api.rawg.io/api/games?page=17175
#
# Error with https://api.rawg.io/api/games?page=12430Error with https://api.rawg.io/api/games?page=10992Error with https://api.rawg.io/api/games?page=10085
# Error with https://api.rawg.io/api/games?page=10594
# Error with https://api.rawg.io/api/games?page=13378
# Error with https://api.rawg.io/api/games?page=22697
# Error with https://api.rawg.io/api/games?page=21780
# Error with https://api.rawg.io/api/games?page=12910
# Error with https://api.rawg.io/api/games?page=23297
# Error with https://api.rawg.io/api/games?page=9154
# Error with https://api.rawg.io/api/games?page=13826Error with https://api.rawg.io/api/games?page=4484
# Error with https://api.rawg.io/api/games?page=19962Error with https://api.rawg.io/api/games?page=6338
#
#
# Error with https://api.rawg.io/api/games?page=7287
# Error with https://api.rawg.io/api/games?page=16272Error with https://api.rawg.io/api/games?page=12431Error with https://api.rawg.io/api/games?page=6828
#
#
# Error with https://api.rawg.io/api/games?page=22698Error with https://api.rawg.io/api/games?page=10086Error with https://api.rawg.io/api/games?page=13379
#
#
# Error with https://api.rawg.io/api/games?page=8189
# Error with https://api.rawg.io/api/games?page=9155
# Error with https://api.rawg.io/api/games?page=11957
# Error with https://api.rawg.io/api/games?page=18496Error with https://api.rawg.io/api/games?page=3548
#
# Error with https://api.rawg.io/api/games?page=4485
# Error with https://api.rawg.io/api/games?page=6339
# Error with https://api.rawg.io/api/games?page=19963
# Error with https://api.rawg.io/api/games?page=7288Error with https://api.rawg.io/api/games?page=21322
# Error with https://api.rawg.io/api/games?page=23298
#
# Error with https://api.rawg.io/api/games?page=15732
# Error with https://api.rawg.io/api/games?page=17177Error with https://api.rawg.io/api/games?page=16273Error with https://api.rawg.io/api/games?page=19536
#
#
# Error with https://api.rawg.io/api/games?page=6829
# Error with https://api.rawg.io/api/games?page=2103Error with https://api.rawg.io/api/games?page=12432Error with https://api.rawg.io/api/games?page=13827Error with https://api.rawg.io/api/games?page=13380
#
#
# Error with https://api.rawg.io/api/games?page=22277
#
# Error with https://api.rawg.io/api/games?page=22699
# Error with https://api.rawg.io/api/games?page=5471
# Error with https://api.rawg.io/api/games?page=21794
# Error with https://api.rawg.io/api/games?page=22286
# Error with https://api.rawg.io/api/games?page=1647
# Error with https://api.rawg.io/api/games?page=4502
# Error with https://api.rawg.io/api/games?page=6847
# Error with https://api.rawg.io/api/games?page=22287
# Error with https://api.rawg.io/api/games?page=16290
# Error with https://api.rawg.io/api/games?page=15748
# Error with https://api.rawg.io/api/games?page=12448
# Error with https://api.rawg.io/api/games?page=9638Error with https://api.rawg.io/api/games?page=21795
#
# Error with https://api.rawg.io/api/games?page=18080Error with https://api.rawg.io/api/games?page=7307
#
# Error with https://api.rawg.io/api/games?page=19046
# Error with https://api.rawg.io/api/games?page=14815Error with https://api.rawg.io/api/games?page=2631
#
# Error with https://api.rawg.io/api/games?page=22288Error with https://api.rawg.io/api/games?page=16291Error with https://api.rawg.io/api/games?page=4503
#
#
# Error with https://api.rawg.io/api/games?page=6848
# Error with https://api.rawg.io/api/games?page=7752
# Error with https://api.rawg.io/api/games?page=21796Error with https://api.rawg.io/api/games?page=20837Error with https://api.rawg.io/api/games?page=12449
#
#
# Error with https://api.rawg.io/api/games?page=8198Error with https://api.rawg.io/api/games?page=2632
#
# Error with https://api.rawg.io/api/games?page=9639Error with https://api.rawg.io/api/games?page=2119
#
# Error with https://api.rawg.io/api/games?page=7308
# Error with https://api.rawg.io/api/games?page=18081Error with https://api.rawg.io/api/games?page=14816
#
# Error with https://api.rawg.io/api/games?page=6849
# Error with https://api.rawg.io/api/games?page=5473
# Error with https://api.rawg.io/api/games?page=1114
# Error with https://api.rawg.io/api/games?page=16292Error with https://api.rawg.io/api/games?page=12450
#
# Error with https://api.rawg.io/api/games?page=22289
# Error with https://api.rawg.io/api/games?page=20838
# Error with https://api.rawg.io/api/games?page=7753
# Error with https://api.rawg.io/api/games?page=8199
# Error with https://api.rawg.io/api/games?page=2633
# Error with https://api.rawg.io/api/games?page=9640Error with https://api.rawg.io/api/games?page=7309
# Error with https://api.rawg.io/api/games?page=2120
#
# Error with https://api.rawg.io/api/games?page=14300Error with https://api.rawg.io/api/games?page=11969
#
# Error with https://api.rawg.io/api/games?page=14817Error with https://api.rawg.io/api/games?page=18509Error with https://api.rawg.io/api/games?page=4971
#
#
# Error with https://api.rawg.io/api/games?page=6850
# Error with https://api.rawg.io/api/games?page=18082
# Error with https://api.rawg.io/api/games?page=5474
# Error with https://api.rawg.io/api/games?page=5972
# Error with https://api.rawg.io/api/games?page=19546
# Error with https://api.rawg.io/api/games?page=4982
# Error with https://api.rawg.io/api/games?page=8215
# Error with https://api.rawg.io/api/games?page=21805
# Error with https://api.rawg.io/api/games?page=12464
# Error with https://api.rawg.io/api/games?page=16756Error with https://api.rawg.io/api/games?page=19563
# Error with https://api.rawg.io/api/games?page=17199
#
# Error with https://api.rawg.io/api/games?page=19063
# Error with https://api.rawg.io/api/games?page=4983
# Error with https://api.rawg.io/api/games?page=8216
# Error with https://api.rawg.io/api/games?page=21806
# Error with https://api.rawg.io/api/games?page=4517
# Error with https://api.rawg.io/api/games?page=19564
# Error with https://api.rawg.io/api/games?page=4984
# Error with https://api.rawg.io/api/games?page=16311Error with https://api.rawg.io/api/games?page=19064
#
# Error with https://api.rawg.io/api/games?page=8217
# Error with https://api.rawg.io/api/games?page=11986
# Error with https://api.rawg.io/api/games?page=17200
# Error with https://api.rawg.io/api/games?page=9654
# Error with https://api.rawg.io/api/games?page=664Error with https://api.rawg.io/api/games?page=21807
#
# Error with https://api.rawg.io/api/games?page=4518Error with https://api.rawg.io/api/games?page=4985Error with https://api.rawg.io/api/games?page=11987
#
#
# Error with https://api.rawg.io/api/games?page=16312
# Error with https://api.rawg.io/api/games?page=19565
# Error with https://api.rawg.io/api/games?page=1128
# Error with https://api.rawg.io/api/games?page=21808
# Error with https://api.rawg.io/api/games?page=9655
# Error with https://api.rawg.io/api/games?page=665
# Error with https://api.rawg.io/api/games?page=16758
# Error with https://api.rawg.io/api/games?page=4519
# Error with https://api.rawg.io/api/games?page=19066
# Error with https://api.rawg.io/api/games?page=11988
# Error with https://api.rawg.io/api/games?page=23319
# Error with https://api.rawg.io/api/games?page=17202
# Error with https://api.rawg.io/api/games?page=1129
# Error with https://api.rawg.io/api/games?page=15761
# Error with https://api.rawg.io/api/games?page=15268
# Error with https://api.rawg.io/api/games?page=9656
# Error with https://api.rawg.io/api/games?page=19067Error with https://api.rawg.io/api/games?page=16759Error with https://api.rawg.io/api/games?page=21809
#
#
# Error with https://api.rawg.io/api/games?page=666Error with https://api.rawg.io/api/games?page=14829
# Error with https://api.rawg.io/api/games?page=21347Error with https://api.rawg.io/api/games?page=12940
#
#
# Error with https://api.rawg.io/api/games?page=11989
# Error with https://api.rawg.io/api/games?page=4520
# Error with https://api.rawg.io/api/games?page=5489Error with https://api.rawg.io/api/games?page=23320Error with https://api.rawg.io/api/games?page=6868
#
# Error with https://api.rawg.io/api/games?page=22716
#
# Error with https://api.rawg.io/api/games?page=15269
# Error with https://api.rawg.io/api/games?page=2144
# Error with https://api.rawg.io/api/games?page=6381
# Error with https://api.rawg.io/api/games?page=2145
# Error with https://api.rawg.io/api/games?page=13879
# Error with https://api.rawg.io/api/games?page=6382
# Error with https://api.rawg.io/api/games?page=1137
# Error with https://api.rawg.io/api/games?page=19086
# Error with https://api.rawg.io/api/games?page=22734
# Error with https://api.rawg.io/api/games?page=17218Error with https://api.rawg.io/api/games?page=13880
# Error with https://api.rawg.io/api/games?page=2146
#
# Error with https://api.rawg.io/api/games?page=6383
# Error with https://api.rawg.io/api/games?page=19087
# Error with https://api.rawg.io/api/games?page=3606Error with https://api.rawg.io/api/games?page=22735
#
# Error with https://api.rawg.io/api/games?page=17219Error with https://api.rawg.io/api/games?page=11551
#
# Error with https://api.rawg.io/api/games?page=19997
# Error with https://api.rawg.io/api/games?page=13881
# Error with https://api.rawg.io/api/games?page=11999
# Error with https://api.rawg.io/api/games?page=19088
# Error with https://api.rawg.io/api/games?page=22736Error with https://api.rawg.io/api/games?page=2147
#
# Error with https://api.rawg.io/api/games?page=11552
# Error with https://api.rawg.io/api/games?page=19998Error with https://api.rawg.io/api/games?page=14321
#
# Error with https://api.rawg.io/api/games?page=12000Error with https://api.rawg.io/api/games?page=13882Error with https://api.rawg.io/api/games?page=10647
#
#
# Error with https://api.rawg.io/api/games?page=17220
# Error with https://api.rawg.io/api/games?page=3607Error with https://api.rawg.io/api/games?page=19089
#
# Error with https://api.rawg.io/api/games?page=22737
# Error with https://api.rawg.io/api/games?page=8230
# Error with https://api.rawg.io/api/games?page=14322
# Error with https://api.rawg.io/api/games?page=2148
# Error with https://api.rawg.io/api/games?page=18538
# Error with https://api.rawg.io/api/games?page=3608
# Error with https://api.rawg.io/api/games?page=19090
# Error with https://api.rawg.io/api/games?page=17221
# Error with https://api.rawg.io/api/games?page=22738Error with https://api.rawg.io/api/games?page=9669
#
# Error with https://api.rawg.io/api/games?page=5508
# Error with https://api.rawg.io/api/games?page=16793
# Error with https://api.rawg.io/api/games?page=190
# Error with https://api.rawg.io/api/games?page=20864
# Error with https://api.rawg.io/api/games?page=1702
# Error with https://api.rawg.io/api/games?page=5509Error with https://api.rawg.io/api/games?page=12011
#
# Error with https://api.rawg.io/api/games?page=19594
# Error with https://api.rawg.io/api/games?page=18556
# Error with https://api.rawg.io/api/games?page=16794
# Error with https://api.rawg.io/api/games?page=191
# Error with https://api.rawg.io/api/games?page=20865Error with https://api.rawg.io/api/games?page=22750
# Error with https://api.rawg.io/api/games?page=13895
#
# Error with https://api.rawg.io/api/games?page=23353Error with https://api.rawg.io/api/games?page=12012
#
# Error with https://api.rawg.io/api/games?page=5510
# Error with https://api.rawg.io/api/games?page=192
# Error with https://api.rawg.io/api/games?page=1703
# Error with https://api.rawg.io/api/games?page=21365Error with https://api.rawg.io/api/games?page=22751
#
# Error with https://api.rawg.io/api/games?page=12492Error with https://api.rawg.io/api/games?page=13896
#
# Error with https://api.rawg.io/api/games?page=23354
# Error with https://api.rawg.io/api/games?page=20866Error with https://api.rawg.io/api/games?page=1704
#
# Error with https://api.rawg.io/api/games?page=12013Error with https://api.rawg.io/api/games?page=16796
# Error with https://api.rawg.io/api/games?page=22752
#
# Error with https://api.rawg.io/api/games?page=11042
# Error with https://api.rawg.io/api/games?page=7789
# Error with https://api.rawg.io/api/games?page=18558
# Error with https://api.rawg.io/api/games?page=14331
# Error with https://api.rawg.io/api/games?page=13897
# Error with https://api.rawg.io/api/games?page=6017Error with https://api.rawg.io/api/games?page=11566
#
# Error with https://api.rawg.io/api/games?page=12493
# Error with https://api.rawg.io/api/games?page=19596
# Error with https://api.rawg.io/api/games?page=23355Error with https://api.rawg.io/api/games?page=15786
#
# Error with https://api.rawg.io/api/games?page=22753
# Error with https://api.rawg.io/api/games?page=12014
# Error with https://api.rawg.io/api/games?page=11043
# Error with https://api.rawg.io/api/games?page=7790
# Error with https://api.rawg.io/api/games?page=1705
# Error with https://api.rawg.io/api/games?page=2717
# Error with https://api.rawg.io/api/games?page=14875
# Error with https://api.rawg.io/api/games?page=2718
# Error with https://api.rawg.io/api/games?page=20455Error with https://api.rawg.io/api/games?page=22328
# Error with https://api.rawg.io/api/games?page=14876
#
# Error with https://api.rawg.io/api/games?page=20018Error with https://api.rawg.io/api/games?page=21377Error with https://api.rawg.io/api/games?page=2719
#
#
# Error with https://api.rawg.io/api/games?page=8806Error with https://api.rawg.io/api/games?page=13432
#
# Error with https://api.rawg.io/api/games?page=19120
# Error with https://api.rawg.io/api/games?page=22329
# Error with https://api.rawg.io/api/games?page=20019
# Error with https://api.rawg.io/api/games?page=21378
# Error with https://api.rawg.io/api/games?page=16808
# Error with https://api.rawg.io/api/games?page=2720
# Error with https://api.rawg.io/api/games?page=14877
# Error with https://api.rawg.io/api/games?page=15794
# Error with https://api.rawg.io/api/games?page=22764
# Error with https://api.rawg.io/api/games?page=13433
# Error with https://api.rawg.io/api/games?page=14339
# Error with https://api.rawg.io/api/games?page=8807
# Error with https://api.rawg.io/api/games?page=22330
# Error with https://api.rawg.io/api/games?page=6904
# Error with https://api.rawg.io/api/games?page=18576
# Error with https://api.rawg.io/api/games?page=20020
# Error with https://api.rawg.io/api/games?page=21379Error with https://api.rawg.io/api/games?page=16809Error with https://api.rawg.io/api/games?page=22765
#
#
# Error with https://api.rawg.io/api/games?page=2721
# Error with https://api.rawg.io/api/games?page=15795
# Error with https://api.rawg.io/api/games?page=8808
# Error with https://api.rawg.io/api/games?page=14878
# Error with https://api.rawg.io/api/games?page=13434
# Error with https://api.rawg.io/api/games?page=7799
# Error with https://api.rawg.io/api/games?page=14360Error with https://api.rawg.io/api/games?page=10691
#
# Error with https://api.rawg.io/api/games?page=14902
# Error with https://api.rawg.io/api/games?page=14361Error with https://api.rawg.io/api/games?page=6050
#
# Error with https://api.rawg.io/api/games?page=19139
# Error with https://api.rawg.io/api/games?page=20891
# Error with https://api.rawg.io/api/games?page=14903
# Error with https://api.rawg.io/api/games?page=19635Error with https://api.rawg.io/api/games?page=11613Error with https://api.rawg.io/api/games?page=6051
#
#
# Error with https://api.rawg.io/api/games?page=14362
# Error with https://api.rawg.io/api/games?page=10692
# Error with https://api.rawg.io/api/games?page=2742
# Error with https://api.rawg.io/api/games?page=19140
# Error with https://api.rawg.io/api/games?page=20892
# Error with https://api.rawg.io/api/games?page=14904
# Error with https://api.rawg.io/api/games?page=19636Error with https://api.rawg.io/api/games?page=17275
#
# Error with https://api.rawg.io/api/games?page=6430
# Error with https://api.rawg.io/api/games?page=11614Error with https://api.rawg.io/api/games?page=14363
#
# Error with https://api.rawg.io/api/games?page=10693
# Error with https://api.rawg.io/api/games?page=20893
# Error with https://api.rawg.io/api/games?page=19141Error with https://api.rawg.io/api/games?page=12037
# Error with https://api.rawg.io/api/games?page=10162
#
# Error with https://api.rawg.io/api/games?page=2743Error with https://api.rawg.io/api/games?page=17276
# Error with https://api.rawg.io/api/games?page=6052Error with https://api.rawg.io/api/games?page=4583
#
#
# Error with https://api.rawg.io/api/games?page=11069
# Error with https://api.rawg.io/api/games?page=14905Error with https://api.rawg.io/api/games?page=9225Error with https://api.rawg.io/api/games?page=19637
#
#
# Error with https://api.rawg.io/api/games?page=12996
# Error with https://api.rawg.io/api/games?page=6939
# Error with https://api.rawg.io/api/games?page=6431
# Error with https://api.rawg.io/api/games?page=1189
# Error with https://api.rawg.io/api/games?page=14364
# Error with https://api.rawg.io/api/games?page=10163Error with https://api.rawg.io/api/games?page=10694
#
# Error with https://api.rawg.io/api/games?page=12038
# Error with https://api.rawg.io/api/games?page=22346Error with https://api.rawg.io/api/games?page=11615
# Error with https://api.rawg.io/api/games?page=19142
# Error with https://api.rawg.io/api/games?page=17277
# Error with https://api.rawg.io/api/games?page=4584
# Error with https://api.rawg.io/api/games?page=2744
# Error with https://api.rawg.io/api/games?page=11070
# Error with https://api.rawg.io/api/games?page=14906Error with https://api.rawg.io/api/games?page=6940
#
# Error with https://api.rawg.io/api/games?page=9226
# Error with https://api.rawg.io/api/games?page=18147
# Error with https://api.rawg.io/api/games?page=11622
# Error with https://api.rawg.io/api/games?page=17707
# Error with https://api.rawg.io/api/games?page=5053Error with https://api.rawg.io/api/games?page=2193Error with https://api.rawg.io/api/games?page=14910Error with https://api.rawg.io/api/games?page=18148
#
#
# Error with https://api.rawg.io/api/games?page=3660
#
# Error with https://api.rawg.io/api/games?page=19151
# Error with https://api.rawg.io/api/games?page=7411Error with https://api.rawg.io/api/games?page=3135
#
# Error with https://api.rawg.io/api/games?page=17708
# Error with https://api.rawg.io/api/games?page=5054
# Error with https://api.rawg.io/api/games?page=20474
# Error with https://api.rawg.io/api/games?page=22785Error with https://api.rawg.io/api/games?page=11623
#
# Error with https://api.rawg.io/api/games?page=19152Error with https://api.rawg.io/api/games?page=224Error with https://api.rawg.io/api/games?page=3661
#
# Error with https://api.rawg.io/api/games?page=14911
#
# Error with https://api.rawg.io/api/games?page=13461Error with https://api.rawg.io/api/games?page=10168
# Error with https://api.rawg.io/api/games?page=7412Error with https://api.rawg.io/api/games?page=21848
#
#
# Error with https://api.rawg.io/api/games?page=18149
# Error with https://api.rawg.io/api/games?page=2194
# Error with https://api.rawg.io/api/games?page=19641
# Error with https://api.rawg.io/api/games?page=8841
# Error with https://api.rawg.io/api/games?page=18605
# Error with https://api.rawg.io/api/games?page=714
# Error with https://api.rawg.io/api/games?page=20475Error with https://api.rawg.io/api/games?page=22786Error with https://api.rawg.io/api/games?page=14912
#
#
# Error with https://api.rawg.io/api/games?page=5055
# Error with https://api.rawg.io/api/games?page=3662
# Error with https://api.rawg.io/api/games?page=17709
# Error with https://api.rawg.io/api/games?page=10169Error with https://api.rawg.io/api/games?page=21849
#
# Error with https://api.rawg.io/api/games?page=18150
# Error with https://api.rawg.io/api/games?page=225
# Error with https://api.rawg.io/api/games?page=7413Error with https://api.rawg.io/api/games?page=8842
#
# Error with https://api.rawg.io/api/games?page=19642Error with https://api.rawg.io/api/games?page=715Error with https://api.rawg.io/api/games?page=2195
#
#
# Error with https://api.rawg.io/api/games?page=12043Error with https://api.rawg.io/api/games?page=18606
#
# Error with https://api.rawg.io/api/games?page=20476
# Error with https://api.rawg.io/api/games?page=3663
# Error with https://api.rawg.io/api/games?page=14913Error with https://api.rawg.io/api/games?page=17710Error with https://api.rawg.io/api/games?page=5056
#
#
# Error with https://api.rawg.io/api/games?page=21850Error with https://api.rawg.io/api/games?page=22787
#
# Error with https://api.rawg.io/api/games?page=1193Error with https://api.rawg.io/api/games?page=10170Error with https://api.rawg.io/api/games?page=19154
#
#
# Error with https://api.rawg.io/api/games?page=14926
# Error with https://api.rawg.io/api/games?page=21406
# Error with https://api.rawg.io/api/games?page=10183Error with https://api.rawg.io/api/games?page=11084
#
# Error with https://api.rawg.io/api/games?page=21858Error with https://api.rawg.io/api/games?page=20044
#
# Error with https://api.rawg.io/api/games?page=9729
# Error with https://api.rawg.io/api/games?page=2762
# Error with https://api.rawg.io/api/games?page=18621
# Error with https://api.rawg.io/api/games?page=3682
# Error with https://api.rawg.io/api/games?page=21407Error with https://api.rawg.io/api/games?page=10714
#
# Error with https://api.rawg.io/api/games?page=17293
# Error with https://api.rawg.io/api/games?page=7838Error with https://api.rawg.io/api/games?page=11085
#
# Error with https://api.rawg.io/api/games?page=10184
# Error with https://api.rawg.io/api/games?page=15354
# Error with https://api.rawg.io/api/games?page=18160Error with https://api.rawg.io/api/games?page=8855
#
# Error with https://api.rawg.io/api/games?page=20045
# Error with https://api.rawg.io/api/games?page=2763
# Error with https://api.rawg.io/api/games?page=5076
# Error with https://api.rawg.io/api/games?page=17294Error with https://api.rawg.io/api/games?page=11646Error with https://api.rawg.io/api/games?page=5566
# Error with https://api.rawg.io/api/games?page=21408
#
# Error with https://api.rawg.io/api/games?page=7839Error with https://api.rawg.io/api/games?page=6446
# Error with https://api.rawg.io/api/games?page=10715
#
#
# Error with https://api.rawg.io/api/games?page=2204
# Error with https://api.rawg.io/api/games?page=20485Error with https://api.rawg.io/api/games?page=9730
#
# Error with https://api.rawg.io/api/games?page=15355
# Error with https://api.rawg.io/api/games?page=10185
# Error with https://api.rawg.io/api/games?page=237
# Error with https://api.rawg.io/api/games?page=18161
# Error with https://api.rawg.io/api/games?page=20046
# Error with https://api.rawg.io/api/games?page=3159Error with https://api.rawg.io/api/games?page=8856
#
# Error with https://api.rawg.io/api/games?page=5077
# Error with https://api.rawg.io/api/games?page=2764Error with https://api.rawg.io/api/games?page=11647
#
# Error with https://api.rawg.io/api/games?page=17295
# Error with https://api.rawg.io/api/games?page=6447
# Error with https://api.rawg.io/api/games?page=10716
# Error with https://api.rawg.io/api/games?page=2205
# Error with https://api.rawg.io/api/games?page=7840
# Error with https://api.rawg.io/api/games?page=9731
# Error with https://api.rawg.io/api/games?page=3684
# Error with https://api.rawg.io/api/games?page=4601
# Error with https://api.rawg.io/api/games?page=10186
# Error with https://api.rawg.io/api/games?page=15356Error with https://api.rawg.io/api/games?page=9243
# Error with https://api.rawg.io/api/games?page=20486
#
# Error with https://api.rawg.io/api/games?page=18162
# Error with https://api.rawg.io/api/games?page=8857
# Error with https://api.rawg.io/api/games?page=20047
# Error with https://api.rawg.io/api/games?page=7860
# Error with https://api.rawg.io/api/games?page=21416
# Error with https://api.rawg.io/api/games?page=6976
# Error with https://api.rawg.io/api/games?page=18173
# Error with https://api.rawg.io/api/games?page=7861Error with https://api.rawg.io/api/games?page=18634
#
# Error with https://api.rawg.io/api/games?page=2782
# Error with https://api.rawg.io/api/games?page=17319
# Error with https://api.rawg.io/api/games?page=6459
# Error with https://api.rawg.io/api/games?page=6977
# Error with https://api.rawg.io/api/games?page=18174
# Error with https://api.rawg.io/api/games?page=249
# Error with https://api.rawg.io/api/games?page=7862
# Error with https://api.rawg.io/api/games?page=18635
# Error with https://api.rawg.io/api/games?page=2783
# Error with https://api.rawg.io/api/games?page=8876
# Error with https://api.rawg.io/api/games?page=12062
# Error with https://api.rawg.io/api/games?page=14937Error with https://api.rawg.io/api/games?page=10732
#
# Error with https://api.rawg.io/api/games?page=18175
# Error with https://api.rawg.io/api/games?page=21867
# Error with https://api.rawg.io/api/games?page=21418
# Error with https://api.rawg.io/api/games?page=7863
# Error with https://api.rawg.io/api/games?page=8294
# Error with https://api.rawg.io/api/games?page=2784Error with https://api.rawg.io/api/games?page=250
#
# Error with https://api.rawg.io/api/games?page=12063
# Error with https://api.rawg.io/api/games?page=10733
# Error with https://api.rawg.io/api/games?page=8877
# Error with https://api.rawg.io/api/games?page=14938
# Error with https://api.rawg.io/api/games?page=21419
# Error with https://api.rawg.io/api/games?page=22378
# Error with https://api.rawg.io/api/games?page=20498Error with https://api.rawg.io/api/games?page=18176
#
# Error with https://api.rawg.io/api/games?page=21868
# Error with https://api.rawg.io/api/games?page=7864
# Error with https://api.rawg.io/api/games?page=8295
# Error with https://api.rawg.io/api/games?page=251Error with https://api.rawg.io/api/games?page=12064
#
# Error with https://api.rawg.io/api/games?page=6979
# Error with https://api.rawg.io/api/games?page=2785
# Error with https://api.rawg.io/api/games?page=10734
# Error with https://api.rawg.io/api/games?page=21420Error with https://api.rawg.io/api/games?page=8878
#
# Error with https://api.rawg.io/api/games?page=14939
# Error with https://api.rawg.io/api/games?page=12543
# Error with https://api.rawg.io/api/games?page=18637
# Error with https://api.rawg.io/api/games?page=22379
# Error with https://api.rawg.io/api/games?page=20499Error with https://api.rawg.io/api/games?page=15839
#
# Error with https://api.rawg.io/api/games?page=21869
# Error with https://api.rawg.io/api/games?page=17328
# Error with https://api.rawg.io/api/games?page=747
# Error with https://api.rawg.io/api/games?page=10216Error with https://api.rawg.io/api/games?page=12078
#
# Error with https://api.rawg.io/api/games?page=2801
# Error with https://api.rawg.io/api/games?page=5118
# Error with https://api.rawg.io/api/games?page=20933
# Error with https://api.rawg.io/api/games?page=10231Error with https://api.rawg.io/api/games?page=22820
#
# Error with https://api.rawg.io/api/games?page=16878
# Error with https://api.rawg.io/api/games?page=13508
# Error with https://api.rawg.io/api/games?page=20934Error with https://api.rawg.io/api/games?page=15397
#
# Error with https://api.rawg.io/api/games?page=5119
# Error with https://api.rawg.io/api/games?page=8333
# Error with https://api.rawg.io/api/games?page=10232
# Error with https://api.rawg.io/api/games?page=9765
# Error with https://api.rawg.io/api/games?page=22821Error with https://api.rawg.io/api/games?page=758
# Error with https://api.rawg.io/api/games?page=3736
# Error with https://api.rawg.io/api/games?page=16879
#
# Error with https://api.rawg.io/api/games?page=3235
# Error with https://api.rawg.io/api/games?page=15398
# Error with https://api.rawg.io/api/games?page=5120
# Error with https://api.rawg.io/api/games?page=7493
# Error with https://api.rawg.io/api/games?page=13055
# Error with https://api.rawg.io/api/games?page=17762
# Error with https://api.rawg.io/api/games?page=18661
# Error with https://api.rawg.io/api/games?page=8334
# Error with https://api.rawg.io/api/games?page=9766
# Error with https://api.rawg.io/api/games?page=3737
# Error with https://api.rawg.io/api/games?page=6490
# Error with https://api.rawg.io/api/games?page=16880Error with https://api.rawg.io/api/games?page=3236
#
# Error with https://api.rawg.io/api/games?page=15399Error with https://api.rawg.io/api/games?page=5121
#
# Error with https://api.rawg.io/api/games?page=4640
# Error with https://api.rawg.io/api/games?page=18200Error with https://api.rawg.io/api/games?page=4168Error with https://api.rawg.io/api/games?page=17763
#
#
# Error with https://api.rawg.io/api/games?page=13510
# Error with https://api.rawg.io/api/games?page=7494
# Error with https://api.rawg.io/api/games?page=276
# Error with https://api.rawg.io/api/games?page=13056
# Error with https://api.rawg.io/api/games?page=8335Error with https://api.rawg.io/api/games?page=20936
#
# Error with https://api.rawg.io/api/games?page=18662
# Error with https://api.rawg.io/api/games?page=20089Error with https://api.rawg.io/api/games?page=6491Error with https://api.rawg.io/api/games?page=2242
# Error with https://api.rawg.io/api/games?page=3738
# Error with https://api.rawg.io/api/games?page=9767
#
#
# Error with https://api.rawg.io/api/games?page=19687
# Error with https://api.rawg.io/api/games?page=16881Error with https://api.rawg.io/api/games?page=5122
#
# Error with https://api.rawg.io/api/games?page=4641
# Error with https://api.rawg.io/api/games?page=4169
# Error with https://api.rawg.io/api/games?page=17764
# Error with https://api.rawg.io/api/games?page=15400Error with https://api.rawg.io/api/games?page=18201
# Error with https://api.rawg.io/api/games?page=277
#
# Error with https://api.rawg.io/api/games?page=7495
# Error with https://api.rawg.io/api/games?page=19688Error with https://api.rawg.io/api/games?page=20090
#
# Error with https://api.rawg.io/api/games?page=18663
# Error with https://api.rawg.io/api/games?page=6492Error with https://api.rawg.io/api/games?page=16882
#
# Error with https://api.rawg.io/api/games?page=20937
# Error with https://api.rawg.io/api/games?page=3739
# Error with https://api.rawg.io/api/games?page=20532
# Error with https://api.rawg.io/api/games?page=3251
# Error with https://api.rawg.io/api/games?page=21444Error with https://api.rawg.io/api/games?page=20533
#
# Error with https://api.rawg.io/api/games?page=20098
# Error with https://api.rawg.io/api/games?page=2254Error with https://api.rawg.io/api/games?page=20948Error with https://api.rawg.io/api/games?page=1791
#
# Error with https://api.rawg.io/api/games?page=3252Error with https://api.rawg.io/api/games?page=13992
#
#
# Error with https://api.rawg.io/api/games?page=7030
# Error with https://api.rawg.io/api/games?page=21445
# Error with https://api.rawg.io/api/games?page=288Error with https://api.rawg.io/api/games?page=15870Error with https://api.rawg.io/api/games?page=8351
#
# Error with https://api.rawg.io/api/games?page=14979
# Error with https://api.rawg.io/api/games?page=20099
# Error with https://api.rawg.io/api/games?page=20534
#
# Error with https://api.rawg.io/api/games?page=11693Error with https://api.rawg.io/api/games?page=4181
# Error with https://api.rawg.io/api/games?page=1792
# Error with https://api.rawg.io/api/games?page=770Error with https://api.rawg.io/api/games?page=2255
#
# Error with https://api.rawg.io/api/games?page=13993
#
# Error with https://api.rawg.io/api/games?page=15412
# Error with https://api.rawg.io/api/games?page=12577
# Error with https://api.rawg.io/api/games?page=7031
# Error with https://api.rawg.io/api/games?page=8352
# Error with https://api.rawg.io/api/games?page=15871Error with https://api.rawg.io/api/games?page=21446
#
# Error with https://api.rawg.io/api/games?page=21899
# Error with https://api.rawg.io/api/games?page=18211Error with https://api.rawg.io/api/games?page=20100
#
# Error with https://api.rawg.io/api/games?page=289
# Error with https://api.rawg.io/api/games?page=2256Error with https://api.rawg.io/api/games?page=14980
#
# Error with https://api.rawg.io/api/games?page=13994
# Error with https://api.rawg.io/api/games?page=1793Error with https://api.rawg.io/api/games?page=771
#
# Error with https://api.rawg.io/api/games?page=11694
# Error with https://api.rawg.io/api/games?page=23449
# Error with https://api.rawg.io/api/games?page=4182
# Error with https://api.rawg.io/api/games?page=9287
# Error with https://api.rawg.io/api/games?page=18680
# Error with https://api.rawg.io/api/games?page=7032Error with https://api.rawg.io/api/games?page=12578
#
# Error with https://api.rawg.io/api/games?page=3254
# Error with https://api.rawg.io/api/games?page=8353Error with https://api.rawg.io/api/games?page=21447
#
# Error with https://api.rawg.io/api/games?page=15872
# Error with https://api.rawg.io/api/games?page=18212
# Error with https://api.rawg.io/api/games?page=21900
# Error with https://api.rawg.io/api/games?page=20101
# Error with https://api.rawg.io/api/games?page=2257
# Error with https://api.rawg.io/api/games?page=772
# Error with https://api.rawg.io/api/games?page=14981Error with https://api.rawg.io/api/games?page=1794
# Error with https://api.rawg.io/api/games?page=23450
#
# Error with https://api.rawg.io/api/games?page=11695Error with https://api.rawg.io/api/games?page=13517
#
# Error with https://api.rawg.io/api/games?page=18681Error with https://api.rawg.io/api/games?page=20536
#
# Error with https://api.rawg.io/api/games?page=7033Error with https://api.rawg.io/api/games?page=12579
#
# Error with https://api.rawg.io/api/games?page=8354
# Error with https://api.rawg.io/api/games?page=15873Error with https://api.rawg.io/api/games?page=9288
#
# Error with https://api.rawg.io/api/games?page=15414
# Error with https://api.rawg.io/api/games?page=18213
# Error with https://api.rawg.io/api/games?page=21901Error with https://api.rawg.io/api/games?page=7898
#
# Error with https://api.rawg.io/api/games?page=1795
# Error with https://api.rawg.io/api/games?page=773Error with https://api.rawg.io/api/games?page=20102
#
# Error with https://api.rawg.io/api/games?page=17776Error with https://api.rawg.io/api/games?page=14982
#
# Error with https://api.rawg.io/api/games?page=12101
# Error with https://api.rawg.io/api/games?page=20537Error with https://api.rawg.io/api/games?page=1251
#
# Error with https://api.rawg.io/api/games?page=12580Error with https://api.rawg.io/api/games?page=9776
# Error with https://api.rawg.io/api/games?page=20951
#
# Error with https://api.rawg.io/api/games?page=7034
# Error with https://api.rawg.io/api/games?page=15874Error with https://api.rawg.io/api/games?page=18682
#
# Error with https://api.rawg.io/api/games?page=21902
# Error with https://api.rawg.io/api/games?page=15415Error with https://api.rawg.io/api/games?page=13996
#
# Error with https://api.rawg.io/api/games?page=18214
# Error with https://api.rawg.io/api/games?page=9289
# Error with https://api.rawg.io/api/games?page=17777Error with https://api.rawg.io/api/games?page=22404Error with https://api.rawg.io/api/games?page=3256
# Error with https://api.rawg.io/api/games?page=774
# Error with https://api.rawg.io/api/games?page=19229
# Error with https://api.rawg.io/api/games?page=7899
#
#
# Error with https://api.rawg.io/api/games?page=20103
# Error with https://api.rawg.io/api/games?page=12581
# Error with https://api.rawg.io/api/games?page=9777Error with https://api.rawg.io/api/games?page=12102
#
# Error with https://api.rawg.io/api/games?page=1252
# Error with https://api.rawg.io/api/games?page=18683
# Error with https://api.rawg.io/api/games?page=15875
# Error with https://api.rawg.io/api/games?page=14983Error with https://api.rawg.io/api/games?page=20952
#
# Error with https://api.rawg.io/api/games?page=20538Error with https://api.rawg.io/api/games?page=7035Error with https://api.rawg.io/api/games?page=15416
#
#
# Error with https://api.rawg.io/api/games?page=9290Error with https://api.rawg.io/api/games?page=13997
#
# Error with https://api.rawg.io/api/games?page=11697
# Error with https://api.rawg.io/api/games?page=13519Error with https://api.rawg.io/api/games?page=18215
# Error with https://api.rawg.io/api/games?page=22405Error with https://api.rawg.io/api/games?page=3257
#
# Error with https://api.rawg.io/api/games?page=7900
#
# Error with https://api.rawg.io/api/games?page=775Error with https://api.rawg.io/api/games?page=13066Error with https://api.rawg.io/api/games?page=17778
#
# Error with https://api.rawg.io/api/games?page=8356
# Error with https://api.rawg.io/api/games?page=12582
#
# Error with https://api.rawg.io/api/games?page=20104
# Error with https://api.rawg.io/api/games?page=9778Error with https://api.rawg.io/api/games?page=12103
#
# Error with https://api.rawg.io/api/games?page=1797Error with https://api.rawg.io/api/games?page=1253
#
# Error with https://api.rawg.io/api/games?page=18684
# Error with https://api.rawg.io/api/games?page=7954
# Error with https://api.rawg.io/api/games?page=21494
# Error with https://api.rawg.io/api/games?page=1307
# Error with https://api.rawg.io/api/games?page=7955
# Error with https://api.rawg.io/api/games?page=13580
# Error with https://api.rawg.io/api/games?page=12167
# Error with https://api.rawg.io/api/games?page=18737
# Error with https://api.rawg.io/api/games?page=1308
# Error with https://api.rawg.io/api/games?page=7956
# Error with https://api.rawg.io/api/games?page=1309Error with https://api.rawg.io/api/games?page=12168
#
# Error with https://api.rawg.io/api/games?page=18265Error with https://api.rawg.io/api/games?page=11175
#
# Error with https://api.rawg.io/api/games?page=7957
# Error with https://api.rawg.io/api/games?page=338
# Error with https://api.rawg.io/api/games?page=1310
# Error with https://api.rawg.io/api/games?page=8425
# Error with https://api.rawg.io/api/games?page=11176
# Error with https://api.rawg.io/api/games?page=12169Error with https://api.rawg.io/api/games?page=18266
#
# Error with https://api.rawg.io/api/games?page=20988
# Error with https://api.rawg.io/api/games?page=13582
# Error with https://api.rawg.io/api/games?page=14058
# Error with https://api.rawg.io/api/games?page=339
# Error with https://api.rawg.io/api/games?page=18739
# Error with https://api.rawg.io/api/games?page=7958
# Error with https://api.rawg.io/api/games?page=8426
# Error with https://api.rawg.io/api/games?page=1311
# Error with https://api.rawg.io/api/games?page=11177
# Error with https://api.rawg.io/api/games?page=18267Error with https://api.rawg.io/api/games?page=20989Error with https://api.rawg.io/api/games?page=13583
#
#
# Error with https://api.rawg.io/api/games?page=8427
# Error with https://api.rawg.io/api/games?page=340Error with https://api.rawg.io/api/games?page=7959
#
# Error with https://api.rawg.io/api/games?page=15919
# Error with https://api.rawg.io/api/games?page=20581Error with https://api.rawg.io/api/games?page=1312
#
# Error with https://api.rawg.io/api/games?page=13584Error with https://api.rawg.io/api/games?page=20990
#
# Error with https://api.rawg.io/api/games?page=11178
# Error with https://api.rawg.io/api/games?page=22865Error with https://api.rawg.io/api/games?page=9354
#
# Error with https://api.rawg.io/api/games?page=7960Error with https://api.rawg.io/api/games?page=341
# Error with https://api.rawg.io/api/games?page=13117
#
# Error with https://api.rawg.io/api/games?page=20582
# Error with https://api.rawg.io/api/games?page=15920Error with https://api.rawg.io/api/games?page=20147
#
# Error with https://api.rawg.io/api/games?page=1313
# Error with https://api.rawg.io/api/games?page=12171
# Error with https://api.rawg.io/api/games?page=11179
# Error with https://api.rawg.io/api/games?page=13585
# Error with https://api.rawg.io/api/games?page=18741
# Error with https://api.rawg.io/api/games?page=22866
# Error with https://api.rawg.io/api/games?page=9355
# Error with https://api.rawg.io/api/games?page=13118Error with https://api.rawg.io/api/games?page=14060Error with https://api.rawg.io/api/games?page=342
#
#
# Error with https://api.rawg.io/api/games?page=1314Error with https://api.rawg.io/api/games?page=7961Error with https://api.rawg.io/api/games?page=15921
#
# Error with https://api.rawg.io/api/games?page=20583
#
# Error with https://api.rawg.io/api/games?page=18742Error with https://api.rawg.io/api/games?page=20148
#
# Error with https://api.rawg.io/api/games?page=11180
# Error with https://api.rawg.io/api/games?page=9356
# Error with https://api.rawg.io/api/games?page=22867
# Time taken: 6299.155867815018

# %% [markdown]
# #### Load each JSON file in `data/game_id/` and write to a CSV file which i saved at `data/game_id.csv`

# %%
with open("data/game_id.csv", "w") as f:
    csv_file = csv.writer(f, lineterminator="\n")
    for file in os.listdir("./data/game_id/"):
        try:
            json_data = json.load(open(f"./data/game_id/{file}", "r"))
        except:
            print(file)
        for game_id, game_name in json_data.items():
            csv_file.writerow([game_id, game_name])
