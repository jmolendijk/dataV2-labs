# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# %%
# One project requirement was to use one SQL QUERY

data = pd.read_csv('/Users/nelly/dataV2-labs/module-2/Project-2-Data-Breach/GDPR_fines_cleaned.csv')

engine = create_engine('mysql+pymysql://root:XXXXXXX@localhost/CNIL_FINES')

data.to_sql('cnil_gdpr_fines', engine, if_exists='replace', index=False)

# %%
from IPython.display import Image
Image('/Users/nelly/dataV2-labs/module-2/Project-2-Data-Breach/SQL_query_France_GDPR_fines.png')

# %%
# I now will use a dataframe 

fines = pd.read_csv('/Users/nelly/dataV2-labs/module-2/Project-2-Data-Breach/GDPR_fines_cleaned.csv')

# %%
#fines.drop(['Unnamed: 0'], inplace=True)

fines.head()
# Out:
#    Country                                 Authority        Date Fine_EUR  \
# 0  AUSTRIA  Austrian Data Protection Authority (dsb)  2018-12-09    4,800
# 1  AUSTRIA  Austrian Data Protection Authority (dsb)        2018    1,800
# 2  AUSTRIA  Austrian Data Protection Authority (dsb)  2018-09-27      300
# 3  AUSTRIA  Austrian Data Protection Authority (dsb)  2018-12-20    2,200
# 4  BELGIUM   Belgian Data Protection Authority (APD)  2019-05-28    2,000
#
#           Controller                                       GDPR_article  \
# 0      Betting place                                       Art. 13 GDPR
# 1   Kebab restaurant            Art. 5 GDPR, Art. 13 GDPR, Art. 14 GDPR
# 2  Private car owner                    Art. 5 (1) a) GDPR, Art. 6 GDPR
# 3     Private person  Art. 5 (1) a) GDPR, Art. 5 (1) c) GDPR, Art. 6...
# 4              Mayor                    Art. 5 (1) b) GDPR, Art. 6 GDPR
#
#                                                 Type  \
# ...

# %%
FR_fine = fines[fines['Country'] == 'FRANCE']

# %%
FR_fine
# Out:
#     Country                                Authority        Date    Fine_EUR  \
# 22   FRANCE  French Data Protection Authority (CNIL)  2019-01-21  50,000,000
# 23   FRANCE  French Data Protection Authority (CNIL)  2019-05-28     400,000
# 50   FRANCE  French Data Protection Authority (CNIL)  2019-06-13      20,000
# 63   FRANCE  French Data Protection Authority (CNIL)  2019-07-25     180,000
# 117  FRANCE  French Data Protection Authority (CNIL)  2019-11-21     500,000
# 361  FRANCE  French Data Protection Authority (CNIL)  2020-08-05     250,000
#
#                           Controller  \
# 22                       Google Inc.
# 23              SERGIC (Real Estate)
# 50        Employer UNIONTRAD COMPANY
# 63   ACTIVE ASSURANCES (car insurer)
# 117            Futura Internationale
# 361                          Spartoo
#
#                                           GDPR_article  \
# 22   Art. 13 GDPR, Art. 14 GDPR, Art. 6 GDPR, Art. ...
# ...

# %%
fig = px.bar(FR_fine, x="Fine_EUR", y="Controller", orientation='h', color='Fine_EUR', text='Fine_EUR' , title='GDPR fines in France')

fig
# Out:
# <div>
#
#
#             <div id="897a601b-4675-46c0-94a2-640239bf6c29" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("897a601b-4675-46c0-94a2-640239bf6c29")) {
#                     Plotly.newPlot(
#                         '897a601b-4675-46c0-94a2-640239bf6c29',
# ...
