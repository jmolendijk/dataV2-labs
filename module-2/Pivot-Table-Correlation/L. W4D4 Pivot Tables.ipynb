# %%
import pandas as pd
import numpy as np

vehicles = pd.read_csv('vehicles.csv')
vehicles.head(50)
# Out:
#                 Make                Model  Year  Engine Displacement  \
# 0         AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1         AM General     FJ8c Post Office  1984                  4.2
# 2         AM General  Post Office DJ5 2WD  1985                  2.5
# 3         AM General  Post Office DJ8 2WD  1985                  4.2
# 4   ASC Incorporated                  GNX  1987                  3.8
# 5              Acura          2.2CL/3.0CL  1997                  2.2
# 6              Acura          2.2CL/3.0CL  1997                  2.2
# 7              Acura          2.2CL/3.0CL  1997                  3.0
# 8              Acura          2.3CL/3.0CL  1998                  2.3
# 9              Acura          2.3CL/3.0CL  1998                  2.3
# 10             Acura          2.3CL/3.0CL  1998                  3.0
# 11             Acura          2.3CL/3.0CL  1999                  2.3
# 12             Acura          2.3CL/3.0CL  1999                  2.3
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"])
# Out:
#                                     CO2 Emission Grams/Mile   City MPG  \
# Vehicle Class
# Compact Cars                                     396.758088  20.570685
# Large Cars                                       484.391278  16.130310
# Midsize Cars                                     432.861095  18.950775
# Midsize Station Wagons                           432.128533  18.360577
# Midsize-Large Station Wagons                     452.981561  17.590837
# Minicompact Cars                                 443.861984  18.380363
# Minivan - 2WD                                    469.287896  16.679758
# Minivan - 4WD                                    504.595699  15.425532
# Small Pickup Trucks                              450.039261  18.416031
# Small Pickup Trucks 2WD                          454.361734  17.922693
# Small Pickup Trucks 4WD                          497.689565  16.405000
# Small Sport Utility Vehicle 2WD                  378.034759  21.147059
# ...

# %%
vehicles[['City MPG','Highway MPG', 'Combined MPG', 'Vehicle Class', 'Cylinders']].pivot_table(index=["Vehicle Class"], columns='Cylinders')
# Out:
#                                      City MPG                        \
# Cylinders                                2.0        3.0        4.0
# Vehicle Class
# Compact Cars                              NaN  33.083333  22.486025
# Large Cars                                NaN        NaN  21.227586
# Midsize Cars                              NaN        NaN  23.011199
# Midsize Station Wagons                    NaN        NaN  20.828025
# Midsize-Large Station Wagons              NaN        NaN  18.596970
# Minicompact Cars                    15.000000  35.736842  22.325459
# Minivan - 2WD                             NaN        NaN  19.151515
# Minivan - 4WD                             NaN        NaN        NaN
# Small Pickup Trucks                       NaN        NaN  19.658192
# Small Pickup Trucks 2WD                   NaN        NaN  19.383333
# Small Pickup Trucks 4WD                   NaN        NaN  18.102564
# Small Sport Utility Vehicle 2WD           NaN        NaN  22.322709
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], columns=["Cylinders"])
# Out:
#                                    CO2 Emission Grams/Mile              \
# Cylinders                                             2.0         3.0
# Vehicle Class
# Compact Cars                                           NaN  243.666667
# Large Cars                                             NaN         NaN
# Midsize Cars                                           NaN         NaN
# Midsize Station Wagons                                 NaN         NaN
# Midsize-Large Station Wagons                           NaN         NaN
# Minicompact Cars                                493.722222  234.692515
# Minivan - 2WD                                          NaN         NaN
# Minivan - 4WD                                          NaN         NaN
# Small Pickup Trucks                                    NaN         NaN
# Small Pickup Trucks 2WD                                NaN         NaN
# Small Pickup Trucks 4WD                                NaN         NaN
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], columns=["Cylinders"],
                     values=["CO2 Emission Grams/Mile"], fill_value=0)
# Out:
#                                    CO2 Emission Grams/Mile              \
# Cylinders                                             2.0         3.0
# Vehicle Class
# Compact Cars                                      0.000000  243.666667
# Large Cars                                        0.000000    0.000000
# Midsize Cars                                      0.000000    0.000000
# Midsize Station Wagons                            0.000000    0.000000
# Midsize-Large Station Wagons                      0.000000    0.000000
# Minicompact Cars                                493.722222  234.692515
# Minivan - 2WD                                     0.000000    0.000000
# Minivan - 4WD                                     0.000000    0.000000
# Small Pickup Trucks                               0.000000    0.000000
# Small Pickup Trucks 2WD                           0.000000    0.000000
# Small Pickup Trucks 4WD                           0.000000    0.000000
# ...

# %%
def sayone(x):
    return 1

vehicles.pivot_table(index=["Vehicle Class"], 
                     values=["Combined MPG", "Year"],
                     aggfunc=np.max)
# Out:
#                                     Combined MPG  Year
# Vehicle Class
# Compact Cars                                  50  2017
# Large Cars                                    40  2017
# Midsize Cars                                  56  2017
# Midsize Station Wagons                        42  2017
# Midsize-Large Station Wagons                  36  1997
# Minicompact Cars                              48  2017
# Minivan - 2WD                                 24  2017
# Minivan - 4WD                                 20  2017
# Small Pickup Trucks                           32  1997
# Small Pickup Trucks 2WD                       31  2017
# Small Pickup Trucks 4WD                       25  2017
# Small Sport Utility Vehicle 2WD               33  2017
# Small Sport Utility Vehicle 4WD               33  2017
# Small Station Wagons                          39  2017
# Special Purpose Vehicle                       22  2003
# Special Purpose Vehicle 2WD                   31  2017
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], 
                     values=["Combined MPG", "Year", "CO2 Emission Grams/Mile"],
                     aggfunc=['count', np.mean])
#vehicles[vehicles['Vehicle Class']=='Compact Cars']['Year']
# Out:
#                                                      count                     \
#                                    CO2 Emission Grams/Mile Combined MPG  Year
# Vehicle Class
# Compact Cars                                          5185         5185  5185
# Large Cars                                            1742         1742  1742
# Midsize Cars                                          4063         4063  4063
# Midsize Station Wagons                                 416          416   416
# Midsize-Large Station Wagons                           633          633   633
# Minicompact Cars                                      1212         1212  1212
# Minivan - 2WD                                          331          331   331
# Minivan - 4WD                                           47           47    47
# Small Pickup Trucks                                    524          524   524
# Small Pickup Trucks 2WD                                401          401   401
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], 
                     values=["Combined MPG", "CO2 Emission Grams/Mile"],
                     aggfunc=np.max)
# Out:
#                                     CO2 Emission Grams/Mile  Combined MPG
# Vehicle Class
# Compact Cars                                    1110.875000            50
# Large Cars                                      1110.875000            40
# Midsize Cars                                    1110.875000            56
# Midsize Station Wagons                           634.785714            42
# Midsize-Large Station Wagons                     592.466667            36
# Minicompact Cars                                 807.909091            48
# Minivan - 2WD                                    634.785714            24
# Minivan - 4WD                                    555.437500            20
# Small Pickup Trucks                              634.785714            32
# Small Pickup Trucks 2WD                          592.466667            31
# Small Pickup Trucks 4WD                          634.785714            25
# ...
