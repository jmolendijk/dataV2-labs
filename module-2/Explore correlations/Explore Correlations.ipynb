# %% [markdown]
# ### Explore correlations
#
# Using the Canadian Disaster Database (CDD.csv, can be found on the share directory), you will explore the correlations between the numerical columns in the dataset. More info on the dataset can be found at https://www.kaggle.com/criticalhits/canadian-disaster-database#CDD.csv
#
# Description:
#
# #### Type
# The type of disaster (e.g. flood, earthquake, etc.) that occurred.
# #### Date of Event
# The date a specific event took place.
# #### Specific Location
# The city, town or region where a specific event took place.
# #### Description of Event
# A brief description of a specific event, including pertinent details that may not be captured in other data fields (e.g. amount of precipitation, temperatures, neighbourhoods, etc.)
# #### Fatalities
# The number of people killed due to a specific event.
# #### Injured/Infected
# The number of people injured or infected due to a specific event.
# #### Evacuees
# The number of individuals evacuated by the government of Canada due to a specific event.
# #### Latitude & Longitude
# The exact geographic location of a specific event.
# #### Province/Territory
# The province or territory where a specific event took place.
# #### Estimated Total Cost
# A roll-up of all the costs listed within the financial data fields for a specific event.
# #### DFAA Payments
# The amount, in dollars, paid out by Disaster Financial Assistance Arrangements (Public Safety Canada) due to a specific event.
# #### Insurance Payments
# The amount, in dollars, paid out by insurance companies due to a specific event.
# #### Provincial/Territorial Costs/Payments
# The amount, in dollars, paid out by a Province or Territory due to a specific event.
# #### Utility Costs/Losses
# The amount of people whose utility services (power, water, etc.) were interrupted/affected by a specific event.
# #### Magnitude
# A measure of the size of an earthquake, related to the amount of energy released.
# #### Other Federal Institution Costs
# The amount, in dollars, paid out by other federal institutions.

# %%
# import libraries here
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %%
cdd = pd.read_csv('/Users/ajiacovic/Downloads/CDD.csv',sep = '\t')
cdd
# Out:
#      EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0          Disaster     Natural  Meteorological - Hydrological
# 1          Disaster     Natural  Meteorological - Hydrological
# 2          Disaster     Natural  Meteorological - Hydrological
# 3          Disaster     Natural                     Biological
# 4          Incident  Technology            Hazardous Chemicals
# ...             ...         ...                            ...
# 1084       Disaster     Natural  Meteorological - Hydrological
# 1085       Incident  Technology                      Explosion
# 1086       Incident  Technology                      Explosion
# 1087       Incident  Technology         Infrastructure failure
# 1088       Incident  Technology                           Fire
#
#                        EVENT TYPE                                 PLACE  \
# 0     Storm - Unspecified / Other                   Christmas Island NS
# ...

# %% [markdown]
# 1. Print the correlation matrix

# %%
cdd.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %% [markdown]
# 2. Print a heat map of this correlation matrix (hint: use seaborn.heatmap())

# %%
sns.heatmap(cdd.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3. Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero and one pair that is negatively correlated. In each case write down an explanation why we see this correlation

# %%
#1) highly positively correlated:
''' INJURED/INFECTED
        vs. 
    FATALITIES 
    
    The number of people injured or infected due to a specific event is highly 
    and positively correlated to the the number of people killed due to a specific event.
    Well this would mean that, in a disaster, the higher the amount of people affected/injured 
    the higher the mount of people killed. 
    It sounds odd to reason this way I would say. 
    I believe that the higher the amount of people injured: there is a higher possibility for 
    the injured population to die. That is not necessarily the case though. 
    We could ask the question on how is this calculated: is the percentage of people killed
    also included in the population injured at some point?
    
'''
#2) correlation is almost zero: 
''' MAGNITUDE 
    vs.
    INSURANCE PAYMENTS
   
    This correlation is close to zero, this mean that a disaster caused by a 
    certain magniture will not have an influence 
    in the amount paid out by insurances due to the specific event.
    So, it basically meas that if we have 2 disasters: one caused by a high 
    magnitude and one by a low magnitude,
    the amount paid by the insureance can be unchanged/unaffected 
    
    One may think that the magnitude is an outcome variable, whereas the 
    payment is more related to the damage, type of initial policy taken by 
    the user, policy by the government, age of the person injured, type of 
    disaster etc...
''' 
#3) negatively correlated:  
''' OGD COSTS 
    vs. 
    UTILITY - PEOPLE AFFECTED
     The amount paid out by other federal institutions, in the case of a disaster is 
     negatively correlated to the amount of people whose utility services 
    (power, water, etc.) were interrupted/affected by a specific event.
    
    This would mean that the higher the amount of people whose utilities were interrupted, 
    the lower the amount paid by other federal institutions.
    this point without further analisis would sound very unrelated, but for the purpose of this
    exercice, one could argue that the utilities are a matter for 'local' governmental 
    institutions/insurance whchi could reasonably explain why the amount paid by of 'other'
    federal institutins in the case of disaster, would be lower?
    Furthermore, the coefficient is quite low, which would suggest more of a low correlation
    between the two.

'''

# %% [markdown]
# 4. Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. Does what you see confirm your ideas? Describe in a comment.

# %%
cdd.fillna(0)
sns.pairplot(cdd[['FATALITIES','INJURED / INFECTED','MAGNITUDE','INSURANCE PAYMENTS','OGD COSTS','UTILITY - PEOPLE AFFECTED']])
