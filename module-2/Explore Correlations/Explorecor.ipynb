# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
data = pd.read_csv('/Users/bert/Desktop/dataV2-labs/module-2/Explore Correlations/Data/CDD.csv', sep="\t")
data.head()
# Out:
#   EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0       Disaster     Natural  Meteorological - Hydrological
# 1       Disaster     Natural  Meteorological - Hydrological
# 2       Disaster     Natural  Meteorological - Hydrological
# 3       Disaster     Natural                     Biological
# 4       Incident  Technology            Hazardous Chemicals
#
#                     EVENT TYPE                                 PLACE  \
# 0  Storm - Unspecified / Other                   Christmas Island NS
# 1                 Winter Storm  Nova Scotia and Prince Edward Island
# 2                        Flood             Red Earth First Nation SK
# 3                     Epidemic              Alberta and Saskatchewan
# 4         Leak / Spill Release                   Seaforth Channel BC
#
#          EVENT START DATE                                           COMMENTS  \
# 0  25/12/2016 12:00:00 AM  Christmas Island NS, December 25, 2016. Reside...
# ...

# %%
#Corr but not the default --> because I think these data is not lineair: 

correlation = data.corr(method='spearman')
correlation
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.419547  -0.171046
# INJURED / INFECTED                0.419547            1.000000  -0.022766
# EVACUATED                        -0.171046           -0.022766   1.000000
# ESTIMATED TOTAL COST              0.019583           -0.071191   0.026410
# NORMALIZED TOTAL COST             0.025487           -0.077560   0.009316
# FEDERAL DFAA PAYMENTS            -0.080364           -0.106273   0.371747
# PROVINCIAL DFAA PAYMENTS         -0.147506           -0.114675   0.179450
# PROVINCIAL DEPARTMENT PAYMENTS    0.017031           -0.007913   0.280840
# MUNICIPAL COSTS                   0.467998            0.250851   0.165747
# OGD COSTS                        -0.003660            0.173011   0.230256
# INSURANCE PAYMENTS                0.383134            0.168387   0.469603
# NGO PAYMENTS                      0.109109            0.109109   0.198206
# ...

# %%
#Create a heatmap
from matplotlib import pyplot as plt

plt.figure(figsize=(15,8))
heatmap = sns.heatmap(correlation, annot=True, cmap="YlGnBu")
heatmap

# %%
"""
First Pair: highly positively correlated: 
ESTIMATED TOTAL COST & NORMALIZED TOTAL COST

"Because if you make a good estimation of your costs the cost to restore it to a normal condition should be the 
 same. But you gonna have always have small differences."

"""

positive = data[['ESTIMATED TOTAL COST', 'NORMALIZED TOTAL COST']]

# %%
"""
Second Pair: Almost zero: 
MAGNITUDE & FATALITIES

"There is no relationship between those 2 items. It makes sense because you can have a lot of deaths with a small 
 magnitude and no deaths with a huge magnitude. Also the government try to warn for those disasters because they want
 to have as few deaths as possible. Simply there is no relationship between MAGNITUDE & FATALITIES!

"""
zero = data[['MAGNITUDE', 'FATALITIES']]

# %%
"""
Third Pair: negatively correlated: 

There is no really BIG negatively correlated pair in this dataset. 
For learing the pairplot I've make a the correlation between Evacuated and Fatalities. 
-> That make senses that they are each others opposites because somebody that is death, doesn't have to be rescued but
   a person who's died needs to burried. 
"""

negative = data[['EVACUATED', 'FATALITIES']]

# %%
sns.pairplot(positive);

# %%
sns.pairplot(zero);

# %%
sns.pairplot(negative);
