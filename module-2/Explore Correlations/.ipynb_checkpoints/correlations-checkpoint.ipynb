# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pd.read_csv(r'../Temp_States.csv')
cdd_data = pd.read_csv(r'C:/Users/tusha/dataV2-labs/module-2/Explore Correlations/CDD.csv', sep='\t')

# %%
cdd_data
# Out:
#      EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0          Disaster     Natural  Meteorological - Hydrological
# 1          Disaster     Natural  Meteorological - Hydrological
# 2          Disaster     Natural  Meteorological - Hydrological
# 3          Disaster     Natural                     Biological
# 4          Incident  Technology            Hazardous Chemicals
# ...             ...         ...                            ...
# 1084       Disaster     Natural  Meteorological - Hydrological
# 1085       Incident  Technology                      Explosion
# 1086       Incident  Technology                      Explosion
# 1087       Incident  Technology         Infrastructure failure
# 1088       Incident  Technology                           Fire
#
#                        EVENT TYPE                                 PLACE  \
# 0     Storm - Unspecified / Other                   Christmas Island NS
# 1                    Winter Storm  Nova Scotia and Prince Edward Island
# 2                           Flood             Red Earth First Nation SK
# 3                        Epidemic              Alberta and Saskatchewan
# 4            Leak / Spill Release                   Seaforth Channel BC
# ...                           ...                                   ...
# 1084                        Flood             Saint John River Basin NB
# 1085              Non-Residential                          Cranberry BC
# 1086              Non-Residential                        Grand Forks BC
# 1087     Manufacturing / Industry                         Wellington BC
# 1088              Non-Residential                 Ottawa ON and Hull QC
#
#             EVENT START DATE  \
# 0     25/12/2016 12:00:00 AM
# 1     27/11/2016 12:00:00 AM
# 2     14/11/2016 12:00:00 AM
# 3     26/10/2016 12:00:00 AM
# 4     13/10/2016 12:00:00 AM
# ...                      ...
# 1084  01/03/1902 12:00:00 AM
# 1085  01/01/1902 12:00:00 AM
# 1086  01/01/1901 12:00:00 AM
# 1087  01/01/1901 12:00:00 AM
# 1088  26/04/1900 12:00:00 AM
#
#                                                COMMENTS  FATALITIES  \
# 0     Christmas Island NS, December 25, 2016. Reside...         NaN
# 1     Nova Scotia and Prince Edward Island, November...         NaN
# 2     Red Earth First Nation SK, July 14-18, 2016. H...         NaN
# 3     Alberta and Saskatchewan, October 26 to Decemb...         NaN
# 4     Seaforth Channel BC, October 13, 2016. The art...         NaN
# ...                                                 ...         ...
# 1084  Saint John River Basin NB, March 1902. An unus...         2.0
# 1085  Cranberry BC, 1902. An explosion in the Extens...        32.0
# 1086  Grand Forks BC, 1901. An explosion in the Unio...        64.0
# 1087  Wellington BC, 1901. Sixteen people were entom...        16.0
# 1088  Ottawa ON and Hull QC, April 26, 1900.  A smal...         7.0
#
#       INJURED / INFECTED  EVACUATED  ...          EVENT END DATE  \
# 0                    NaN        NaN  ...  25/12/2016 12:00:00 AM
# 1                    NaN        NaN  ...  29/11/2016 12:00:00 AM
# 2                    NaN      576.0  ...  18/11/2016 12:00:00 AM
# 3                    NaN        NaN  ...  21/12/2016 12:00:00 AM
# 4                    NaN        NaN  ...  13/10/2016 12:00:00 AM
# ...                  ...        ...  ...                     ...
# 1084                 0.0        0.0  ...  01/03/1902 12:00:00 AM
# 1085                 0.0        0.0  ...  01/01/1902 12:00:00 AM
# 1086                 0.0        0.0  ...  01/01/1901 12:00:00 AM
# 1087                 0.0        0.0  ...  01/01/1901 12:00:00 AM
# 1088                 0.0    15000.0  ...  26/04/1900 12:00:00 AM
#
#       FEDERAL DFAA PAYMENTS PROVINCIAL DFAA PAYMENTS  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                16700000.0                      NaN
# 4                       NaN                      NaN
# ...                     ...                      ...
# 1084                    NaN                      NaN
# 1085                    NaN                      NaN
# 1086                    NaN                      NaN
# 1087                    NaN                      NaN
# 1088                    NaN                      NaN
#
#       PROVINCIAL DEPARTMENT PAYMENTS  MUNICIPAL COSTS  OGD COSTS  \
# 0                                NaN              NaN        NaN
# 1                                NaN              NaN        NaN
# 2                                NaN              NaN        NaN
# 3                                NaN              NaN        NaN
# 4                                NaN              NaN        NaN
# ...                              ...              ...        ...
# 1084                             NaN              NaN        NaN
# 1085                             NaN              NaN        NaN
# 1086                             NaN              NaN        NaN
# 1087                             NaN              NaN        NaN
# 1088                             NaN              NaN        NaN
#
#       INSURANCE PAYMENTS  NGO PAYMENTS  UTILITY - PEOPLE AFFECTED  MAGNITUDE
# 0                    NaN           NaN                    10038.0        NaN
# 1                    NaN           NaN                    69000.0        NaN
# 2                    NaN           NaN                        NaN        NaN
# 3                    NaN           NaN                        NaN        NaN
# 4                    NaN           NaN                        NaN        NaN
# ...                  ...           ...                        ...        ...
# 1084                 NaN           NaN                        0.0        0.0
# 1085                 NaN           NaN                        0.0        0.0
# 1086                 NaN           NaN                        0.0        0.0
# 1087                 NaN           NaN                        0.0        0.0
# 1088                 NaN           NaN                        0.0        0.0
#
# [1089 rows x 22 columns]

# %%
#cdd_data.corr()
cdd_data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col8 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col9 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col11 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col12 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col3 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col5 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col6 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col7 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col8 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col9 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col10 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col12 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col3 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col4 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col5 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col8 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col9 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col10 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col12 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row2_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col1 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col2 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col4 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col5 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col6 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col7 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col8 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col9 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col10 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col12 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row3_col13 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row4_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row4_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row4_col2 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_35c2b872_1df1_11eb_9ecb_ac675dac6b69row4_col3 {
#             background-color:  #b8122a;
#             colo

# %%
cdd_data['INJURED / INFECTED'].corr(cdd_data['MUNICIPAL COSTS'])
# positively coorelated: More the number of injured people will cause an effect on the costs on the munucipality
# Out:
# 0.9652859446245872

# %%
#one for which the correlation is almost zero.
cdd_data['EVACUATED'].corr(cdd_data['PROVINCIAL DFAA PAYMENTS'])
# Number of evacuated people less or more will not to effect the DFAA payments as payments havde to be done in case of a disaster
#and it should not be effected by the number of evacuated people.
# Out:
# 0.0836917705825122

# %%
cdd_data['UTILITY - PEOPLE AFFECTED'].corr(cdd_data['OGD COSTS'])
# both paramenters have little or no effect on each other with their respective increase or decrease.
# Out:
# -0.09298259907022133

# %%
import seaborn as sns
# %matplotlib inline

# %%
ax = sns.heatmap(cdd_data.corr(), annot=True) #notation: "annot" not "annotate"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (14.5, -0.5)

# %%
#Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. Does what you see confirm your ideas? Describe in a comment.

# %%
#df = seaborn.load_dataset('tips')

#seaborn.pairplot(df, hue ='abcd')
#sns.pairplot(cdd_data, hue = 'INJURED / INFECTED')

# %%
#plt.show()

# %%
sns.jointplot('INJURED / INFECTED','MUNICIPAL COSTS', data= cdd_data)
# found the above alternative to print a plot to compare the parameters

# %%
sns.jointplot('EVACUATED','PROVINCIAL DFAA PAYMENTS', data= cdd_data)

# %%
sns.jointplot('UTILITY - PEOPLE AFFECTED','OGD COSTS', data= cdd_data)

# %%
#g = sns.pairplot(cdd_data,hue="INJURED / INFECTED")

# %%
#method 2, tried a few plot types but none seem to display the data clearly as of now


#sns.jointplot('INJURED / INFECTED','MUNICIPAL COSTS', data= cdd_data)

# Draw a nested barplot
g = sns.catplot(data=cdd_data, kind="bar",x="INJURED / INFECTED", y="MUNICIPAL COSTS",ci="sd", palette="dark", alpha=.6, height=6)
g.despine(left=True)
g.set_axis_labels("", "MUNICIPAL COSTS")
#g.legend.set_title("")
