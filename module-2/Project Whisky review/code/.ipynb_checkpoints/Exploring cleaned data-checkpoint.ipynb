# %% [markdown]
# Exploratory Data Analysis

# %%
import pandas as pd
import json
import pymysql
from sqlalchemy import create_engine
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Creating engine and calling the cleaned data from MySQL database

# %%
#engine = create_engine('mysql+pymysql://student:IHisCool!@34.77.233.175:3306/publications')
# engine = create_engine('mysql+pymysql://username:password@localhost/publications')

# %%
engine = create_engine('mysql+pymysql://root:XXXXXX@127.0.0.1/scotch')

# %%
data = pd.read_sql_query('SELECT * FROM scotch.df_clean', engine)

# %%
data
# Out:
#       MyUnknownColumn                                               name  \
# 0                   0                     Johnnie Walker Blue Label, 40%
# 1                   1    Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2                   2        Bowmore 46 year old (distilled 1964), 42.9%
# 3                   3                     Compass Box The General, 53.4%
# 4                   4                            Chivas Regal Ultis, 40%
# ...               ...                                                ...
# 2196             2242  Duncan Taylor (distilled at Cameronbridge), Ca...
# 2197             2243  Distillery Select 'Craiglodge' (distilled at L...
# 2198             2244         Edradour Barolo Finish, 11 year old, 57.1%
# 2199             2245  Highland Park, Cask #7380, 1981 vintage, 25 ye...
# 2200             2246  Distillery Select 'Inchmoan' (distilled at Loc...
#
#                         category  points    price  \
# ...

# %%
#data=df.reset_index() then df=df.drop(['index'],axis=1)
data  = data.reset_index()

# %%
data=data.drop(['MyUnknownColumn'],axis=1)

# %%
data
# Out:
#       index                                               name  \
# 0         0                     Johnnie Walker Blue Label, 40%
# 1         1    Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2         2        Bowmore 46 year old (distilled 1964), 42.9%
# 3         3                     Compass Box The General, 53.4%
# 4         4                            Chivas Regal Ultis, 40%
# ...     ...                                                ...
# 2196   2196  Duncan Taylor (distilled at Cameronbridge), Ca...
# 2197   2197  Distillery Select 'Craiglodge' (distilled at L...
# 2198   2198         Edradour Barolo Finish, 11 year old, 57.1%
# 2199   2199  Highland Park, Cask #7380, 1981 vintage, 25 ye...
# 2200   2200  Distillery Select 'Inchmoan' (distilled at Loc...
#
#                         category  points    price  \
# 0          Blended Scotch Whisky      97    225.0
# 1             Single Malt Scotch      97   4500.0
# 2             Single Malt Scotch      97  13500.0
# ...

# %%
data.dtypes
# Out:
# MyUnknownColumn      int64
# name                object
# category            object
# points               int64
# price              float64
# description         object
# price_p_points     float64
# age                 object
# Abv                float64
# dtype: object

# %%
#changing age column to numeric

data["age"] = pd.to_numeric(data["age"])

# %%
data.dtypes
# Out:
# MyUnknownColumn      int64
# name                object
# category            object
# points               int64
# price              float64
# description         object
# price_p_points     float64
# age                float64
# Abv                float64
# dtype: object

# %%
data.describe()
# Out:
#        MyUnknownColumn       points          price  price_p_points  \
# count      2201.000000  2201.000000    2201.000000     2201.000000
# mean       1121.846433    86.711495     570.601545        6.324357
# std         647.981329     4.049792    4066.213972       43.901559
# min           0.000000    63.000000      12.000000        0.147727
# 25%         559.000000    84.000000      70.000000        0.812500
# 50%        1123.000000    87.000000     110.000000        1.264368
# 75%        1683.000000    90.000000     200.000000        2.349398
# max        2246.000000    97.000000  157000.000000     1688.172043
#
#                age          Abv
# count  1186.000000  2201.000000
# mean     20.935076    47.889864
# std      10.067284     5.865116
# min       3.000000    40.000000
# 25%      13.000000    43.000000
# 50%      18.000000    46.000000
# 75%      26.000000    52.100000
# max      70.000000    67.400000

# %% [markdown]
# For the 'price' attribute, the mean is 570 dollars, while its median is only 110.
#
# The age of scotch starts from 3 years, which is the minimum maturation time before a spirit can be called (Scotch) whisky.
#
# Source: https://scotchwhisky.com/magazine/ask-the-professor/8033/whisky-and-maturity-why-three-years/
#
# Alcohol content (ABV) starts from 40% which is minimum percentage for a (Scotch) whisky according to Scottish regulations.
#
# Source: https://flaviar.com/blog/alcohol-content-in-whisky
#
# The above points show the data extracted ccorrectly shows the age and alcohol content.
#
# price to points ratio is not giving me any useful information it seems but it was worth trying
#
# Data visualization of the above points follows:-

# %%
# attributes = ['price', 'points', 'age', 'alcohol%'] 

# # plt.axvline(attributes.mean(), color='k', linestyle='dashed', linewidth=1)


# data[attributes].hist(figsize = (15, 10), color = 'green');

# %%
# Most bottles are 10 to 25 years old.
sns.distplot(data['age'], kde=False, color='orange', bins=10)
plt.title('Age distribution', fontsize=14)
plt.xlabel('Age-->', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.axvline((data.age).mean(), color="k", linestyle="--");

# %%
#Alcohol percent or ABV distribtion
#
sns.distplot(data['Abv'], kde=False, color='orange', bins=10)
plt.title('ABV% Distribution', fontsize=14)
plt.xlabel('Alcohol percentage', fontsize=12)
plt.ylabel('Distribution', fontsize=12)
plt.axvline((data.Abv).mean(), color="k", linestyle="--");

# %%
# Points distribution of the whiskies

# Shows no whisky is actually bad just that one tastes better than the others 

sns.distplot(data['points'], kde=False, color='brown', bins=10)
plt.title('Average score out of 100', fontsize=14)
plt.xlabel('Points count', fontsize=12)
plt.ylabel('Total bottles with score', fontsize=12)
plt.axvline((data.points).mean(), color="k", linestyle="--");

# %%
# Price distribution  of the whiskies with KDE

# A histogram aims to approximate the underlying probability density function that generated the data by binning and counting observations. Kernel density estimation (KDE) presents a different solution to the same problem. Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate:

sns.distplot(data['price'], kde=True, color='green', bins=1, kde_kws={"color": "k", "lw": 3, "label": "KDE"})
plt.title('Average price(Dollars)', fontsize=14)
plt.xlabel('Price--->', fontsize=12)
plt.ylabel('Density', fontsize=12)
# Out:
# Text(0, 0.5, 'Density')

# %%
# Whisky Categories

# %%
data['category'].value_counts()
# Out:
# Single Malt Scotch            1776
# Blended Scotch Whisky          210
# Blended Malt Scotch Whisky     131
# Single Grain Whisky             57
# Grain Scotch Whisky             27
# Name: category, dtype: int64

# %%
colors = ['#BB342F', '#EDAFB8', '#666A86', '#95B8D1', '#D1D0A3']
categories_index = data['category'].value_counts().index

fig = plt.figure(figsize = (7, 4))
sns.countplot(y = 'category', data = data, palette = colors, order = data['category'].value_counts().index)

# include the percentage of each category next to each bar
for index, value in enumerate(data['category'].value_counts()):
    label =  '{}%'.format(round( (value/data['category'].shape[0])*100, 2)) 
    plt.annotate(label, xy = (value + 11, index + 0.1), color = colors[index])

plt.title('Number of bottles by category (with percentages)')
plt.ylabel('Category')
plt.xlabel('Count');

# %% [markdown]
# More than 80% of all whiskies in dataset are Single Malts and the most reviewed category as well.
#
# Blended whisky and Blended Malt whisky come second and third, corresponding to approximately 9% and 6% of the dataset, respectively, and
# Single Grain and Grain whisky combined correspond to less than 4% of the dataset.

# %%
#Verifying the distribution of each category.


plt.figure(figsize=(8,8))
sns.distplot(data['points'],color='red')
plt.title('Distribution of review points over 5 categories')
plt.xlabel('Points')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %% [markdown]
# The distribution is almost a normal curve where the mode is centered around 85-90 .

# %%
#comparing their (mean) price and points:

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (13, 5))

ax1.set_title('Mean price by category')
sns.barplot(x = 'price', y = 'category', data = data, order = categories_index, palette = colors, ax = ax1)

ax2.set_title('Mean points by category')
sns.barplot(x = 'points', y = 'category', data = data, order = categories_index, palette = colors, ax = ax2)
ax2.set(yticklabels = [])
ax2.set_ylabel('')
ax2.set_xlim(80, 89);

# %% [markdown]
# The error bar for Blended whiskies is quite big, so we should probably not draw any conclusions using the mean
# (we could try the median of each category - see boxplot).
# On average, Blended Malt whiskies score higher with Blended whiskies following closely.
# We can use Seaborn's boxplot() to visualize the distribution of values for 'price' and 'points'.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 6))
sns.boxplot(x = 'price', y = 'category', data = data, order = categories_index, palette = colors, showfliers = False, ax = ax1)
sns.boxplot(x = 'points', y = 'category', data = data, order = categories_index, palette = colors, ax = ax2)
ax2.set(yticklabels = [])
ax2.set_ylabel('')

plt.tight_layout();

# %% [markdown]
# Observations:
#
# Blended and Blended malt whiskies have a similar median price which is approximately 50 dollars lower than the rest of the categories,
#
# The median points have a small range of values: from 86 (Single Grain) to 88 (Blended Malts),
#
# The boxplot for 'price' has a positive skew (median is closer to the bottom of the box) for all categories, and
# The distribution of 'points' resembles more a normal distribution.
#
# We can perform a similar analysis for the 'age' and 'alcohol%':

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (13, 5))

ax1.set_title('Mean age by category')
sns.barplot(x = 'age', y = 'category', data = data, order = categories_index, palette = colors, ax = ax1)

ax2.set_title('Mean alcohol% by category')
sns.barplot(x = 'alcohol%', y = 'category', data = data, order = categories_index, palette = colors, ax = ax2)
ax2.set(yticklabels = [])
ax2.set_ylabel('')
ax2.set_xlim(30, 55);

# %% [markdown]
# Observations:
#
# 1) Single Grain and Grain Scotch whiskies are the common categories of whiskies.
#
# 2) Single Grain Scotch has the most alcohol percentage.

# %%
#The Most Expensive Whisky and its attributes 


data.loc[data['price'].idxmax()]
# Out:
# index                                                            85
# name                   Diamond Jubilee by John Walker & Sons, 42.5%
# category                                      Blended Scotch Whisky
# points                                                           93
# price                                                        157000
# description       Bright gold. Amazingly fresh fruits and quince...
# price_p_points                                              1688.17
# age                                                             NaN
# alcohol%                                                       42.5
# Name: 85, dtype: object

# %%
data.sort_values(by = 'price', ascending = False).head()
# Out:
#      index                                               name  \
# 85      85       Diamond Jubilee by John Walker & Sons, 42.5%
# 107    107                           Dalmore 50 year old, 40%
# 49      49                    Bowmore 1966 50 year old, 41.5%
# 400    400  Balvenie DCS Compendium 1st Chapter 1968 46 ye...
# 20      20        Bowmore 50 year old (distilled 1961), 40.7%
#
#                   category  points     price  \
# 85   Blended Scotch Whisky      93  157000.0
# 107     Single Malt Scotch      93   60000.0
# 49      Single Malt Scotch      94   30000.0
# 400     Single Malt Scotch      90   27620.0
# 20      Single Malt Scotch      95   26650.0
#
#                                            description  price_p_points   age  \
# 85   Bright gold. Amazingly fresh fruits and quince...     1688.172043   NaN
# 107  This veteran Dalmore was matured successively ...      645.161290  50.0
# 49   The third and most exclusive release in Bowmor...      319.148936  50.0
# ...

# %% [markdown]
# Diamond Jubilee comes first with a price of 157,000 dollars (Blended Scotch Whisky)
#
# Interestingly, it is almost 100,000 dollars more expensive than the second whisky of this list, Dalmore 50 year old.
#
# Bowmore distillery has two bottles in the top5 list.

# %%
#Least expensive whisky bottle

data.loc[data['price'].idxmin()]
# Out:
# index                                                          2034
# name                                       Monarch of the Glen, 40%
# category                                      Blended Scotch Whisky
# points                                                           81
# price                                                            12
# description       Aromas of liquid honey, light toffee, dried ap...
# price_p_points                                             0.148148
# age                                                             NaN
# alcohol%                                                         40
# Name: 2034, dtype: object

# %%
data.sort_values(by = 'price', ascending = True).head()
# Out:
#       index                              name               category  points  \
# 2034   2034          Monarch of the Glen, 40%  Blended Scotch Whisky      81
# 952     952                      Carlyle, 40%     Single Malt Scotch      88
# 2125   2125        MacQueen’s 3 year old, 40%  Blended Scotch Whisky      80
# 2181   2181                     Clansman, 40%  Blended Scotch Whisky      77
# 2033   2033  Sir Edward’s Blended Whisky, 40%  Blended Scotch Whisky      81
#
#       price                                        description  \
# 2034   12.0  Aromas of liquid honey, light toffee, dried ap...
# 952    13.0  This noble Scot consists of a blend of 20 diff...
# 2125   13.0  MacQueen’s has an impressive range of age stat...
# 2181   14.0  This Highland blend has a nose of lemon peel, ...
# 2033   14.0  From the perfumed nose to the sweet and short ...
#
#       price_p_points  age  alcohol%
# 2034        0.148148  NaN      40.0
# 952         0.147727  NaN      40.0
# ...

# %% [markdown]
# Monarch of the Glen is cheapest option with a price of only 12 dollars(Blended Scotch Whisky)

# %% [markdown]
# #bottle with the highest reviewed points

# %%
data.sort_values(by = 'points', ascending = False).head()
# Out:
#     index                                               name  \
# 0       0                     Johnnie Walker Blue Label, 40%
# 2       2        Bowmore 46 year old (distilled 1964), 42.9%
# 1       1    Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 8       8                    The Dalmore, 50 year old, 52.8%
# 11     11  Macallan 1976 Vintage, 29 year old, cask #1135...
#
#                  category  points    price  \
# 0   Blended Scotch Whisky      97    225.0
# 2      Single Malt Scotch      97  13500.0
# 1      Single Malt Scotch      97   4500.0
# 8      Single Malt Scotch      96   1500.0
# 11     Single Malt Scotch      96   1500.0
#
#                                           description  price_p_points   age  \
# 0   Magnificently powerful and intense. Caramels, ...        2.319588   NaN
# 2   There have been some legendary Bowmores from t...      139.175258  46.0
# 1   What impresses me most is how this whisky evol...       46.391753  42.0
# ...

# %% [markdown]
# Three whiskies almost touch perfection, scoring 97 points! The most affordable of the three is Johnnie Walker Blue Label.

# %%
 # MOst highly rated whisky and affordable i.e. Which whisky give the best value for money?

# %%
data.sort_values(by = 'points', ascending = True).head()
# Out:
#       index                                               name  \
# 2200   2200  Distillery Select 'Inchmoan' (distilled at Loc...
# 2199   2199  Highland Park, Cask #7380, 1981 vintage, 25 ye...
# 2198   2198         Edradour Barolo Finish, 11 year old, 57.1%
# 2197   2197  Distillery Select 'Craiglodge' (distilled at L...
# 2196   2196  Duncan Taylor (distilled at Cameronbridge), Ca...
#
#                  category  points  price  \
# 2200   Single Malt Scotch      63   60.0
# 2199   Single Malt Scotch      70  225.0
# 2198   Single Malt Scotch      70   80.0
# 2197   Single Malt Scotch      71   60.0
# 2196  Grain Scotch Whisky      72  125.0
#
#                                             description  price_p_points   age  \
# 2200  Fiery peat kiln smoke, tar, and ripe barley on...        0.952381  13.0
# 2199  The sherry is very dominant and cloying, which...        3.214286  25.0
# 2198  Earthy, fleshy notes with brooding grape notes...        1.142857  11.0
# ...

# %% [markdown]
# Carlyle 40% is a bargain since with a total of 88 points for only 13 dollars.

# %%
# OLDEST Whiskey

# %%
data.sort_values(by = 'age', ascending = False).head()
# Out:
#       index                                               name  \
# 460     460  Gordon & MacPhail Generations: The Glenlivet 7...
# 195     195  Gordon & MacPhail (distilled at Glen Grant) 60...
# 2190   2190  The Macallan Lalique Decanter, 55 year old, 40.1%
# 93       93                   Balvenie 1961 55 year old, 41.7%
# 546     546  Port Dundas 52 year old (Diageo Special Releas...
#
#                  category  points    price  \
# 460    Single Malt Scotch      90  21000.0
# 195    Single Malt Scotch      92  12000.0
# 2190   Single Malt Scotch      74  12000.0
# 93     Single Malt Scotch      93  15000.0
# 546   Single Grain Whisky      90    900.0
#
#                                             description  price_p_points   age  \
# 460   You would expect any 70 year old whisky to be ...      233.333333  70.0
# 195   Rich gold. Superb mature nose with subtle whis...      130.434783  60.0
# 2190  Deep, thick nose, with sappy oak, dried citrus...      162.162162  55.0
# ...

# %% [markdown]
# The Gordon & MacPhail Generations: Glenlivet is the oldest bottle with an age of 70, and exceeds the second oldest bottle by 10 years.

# %% [markdown]
# CONCLUSION:--
#
# We used a dataset containing reviews for more than 2K whisky bottles, to discover useful and interesting facts related to the world of Scottish whisky. The most important things to remember are:
#
# There are five categories of whiskies: Single malts, Blended whiskies, Blended malts, Single Grain whiskies and Grain whiskies.
#
# The most common category in our dataset is Single malts.
#
# Blended Malt whiskies receive a higher score on average.
#
# Single Grain and Grain whiskies have on average a higher age and alcohol content.

# %%
data.dtypes
# Out:
# index               int64
# name               object
# category           object
# points              int64
# price             float64
# description        object
# price_p_points    float64
# age               float64
# alcohol%          float64
# dtype: object

# %%
data.age.mean()
# Out:
# 20.935075885328835

# %%
#Comparison to show the price of a whisky is positively correlated with age of the whiskey
#Method 1

data.plot.scatter(x='age', y='price', marker="o",color='g',linewidths=3)
#plt.xticks(rotation=90)
plt.gcf().set_size_inches((15, 5)) 
#plt.yticks(np.arange(0, 100000))
# plt.plot(range(0, 10)
# plt.xticks(np.arange(0, 70, 5)

# #ax.scatter(x = df['Gr Liv Area'], y = df['SalePrice'], color = "blue", edgecolors = "white", linewidths = 0.1, alpha = 0.7)

# %%
#Method 2
sns.jointplot(data=data, x="age", y="price")

# %% [markdown]
# Check the description column to find the most common ingredients/flavours/tastes added to a single malt and blended whisky of a scotch whisky sin

# %% [markdown]
# Source code Inspiration :  https://www.datacamp.com/community/tutorials/wordcloud-python

# %%
import sys
#!{sys.executable} -m pip install wordcloud

from wordcloud import WordCloud, STOPWORDS

def create_word_cloud(df, bg_color, max_words, mask, stop_words, max_font_size, colormap):
    
    wc = WordCloud(background_color = bg_color, max_words = max_words, mask = mask, stopwords = stop_words, max_font_size = max_font_size)
    wc.generate(' '.join(df))
    
    return wc.recolor(colormap = colormap, random_state = 42)

# %%
sm_df = data[data['category'] == 'Single Malt Scotch']['description'].values
bd_df = data[data['category'] == 'Blended Scotch Whisky']['description'].values

# %%
from PIL import Image
import requests # https://stackoverflow.com/questions/12020657/how-do-i-open-an-image-from-the-internet-in-pil/12020860

mask_sm = np.array(Image.open(requests.get('https://imgur.com/dAYKIVT.png', stream = True).raw))  # mask for single malts
mask_bd = np.array(Image.open(requests.get('https://imgur.com/upL1TBW.png', stream = True).raw))  # mask for blended whiskies

# %%
stop_words = list(STOPWORDS)

fig, ax = plt.subplots(2, 1, figsize = (7, 14))

ax[0].imshow(create_word_cloud(df = sm_df, bg_color = 'white', max_words = 50, mask = mask_sm, stop_words = stop_words,
                             max_font_size = 50, colormap = 'winter'), alpha = 1, interpolation = 'bilinear')
ax[0].set_title('Single Malts - Initial', size = 16, y = 1.06)
ax[0].axis('off')

ax[1].imshow(create_word_cloud(df = bd_df, bg_color = 'white', max_words = 50, mask = mask_bd, stop_words = stop_words,
                             max_font_size = 50, colormap = 'tab10'), alpha = 1, interpolation = 'bilinear')
ax[1].set_title('Blended Whiskies - Initial', size = 16, y = 1.04)
ax[1].axis('off');

# %% [markdown]
# Words such as whisky, palate, note etc. aren't really informative. Adding them to stopwords and re-generating the cloud:

# %%
stop_words = ['whisky', 'whiskies', 'blend', 'note', 'notes', 'year', 'years', 'old', 'nose', 'finish', 'bottle',
              'bottles', 'bottled', 'along', 'release', 'flavor', 'cask', 'well', 'make', 'mouth', 'palate', 'hint',
              'one', 'bottling', 'distillery', 'quite', 'time', 'date', 'show', 'first'] + list(STOPWORDS)

# %%
fig, ax = plt.subplots(2, 1, figsize = (7, 14))

ax[0].imshow(create_word_cloud(df = sm_df, bg_color = 'white', max_words = 50, mask = mask_sm, stop_words = stop_words,
                             max_font_size = 50, colormap = 'winter'), alpha = 1, interpolation = 'bilinear')
ax[0].set_title('Single Malts - Improved', size = 16, y = 1.06)
ax[0].axis('off')

ax[1].imshow(create_word_cloud(df = bd_df, bg_color = 'white', max_words = 50, mask = mask_bd, stop_words = stop_words,
                             max_font_size = 50, colormap = 'tab10'), alpha = 1, interpolation = 'bilinear')
ax[1].set_title('Blended Whiskies - Improved', size = 16, y = 1.04)
ax[1].axis('off');

# %% [markdown]
# Observations:-
#
# The most common flavours/ingredients/tastes added to the Single Malt Scotches are vanilla, fruits, spices, ginger, chocolate
#
# while for Blended whiskies are:  orange, oak, honey, caramel, chocolate.
#
# Differences: Sublte, floral, matured, soft

# %%
data.rename(columns={"alcohol%": "Abv"}, inplace = True)

# %%
data.head()
# Out:
#    MyUnknownColumn                                             name  \
# 0                0                   Johnnie Walker Blue Label, 40%
# 1                1  Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2                2      Bowmore 46 year old (distilled 1964), 42.9%
# 3                3                   Compass Box The General, 53.4%
# 4                4                          Chivas Regal Ultis, 40%
#
#                      category  points    price  \
# 0       Blended Scotch Whisky      97    225.0
# 1          Single Malt Scotch      97   4500.0
# 2          Single Malt Scotch      97  13500.0
# 3  Blended Malt Scotch Whisky      96    325.0
# 4  Blended Malt Scotch Whisky      96    160.0
#
#                                          description  price_p_points   age  \
# 0  Magnificently powerful and intense. Caramels, ...        2.319588
# 1  What impresses me most is how this whisky evol...       46.391753  42.0
# ...

# %%
A One sample t-test : testing the mean of a single group against a known mean.

# %% [markdown]
# value of α is 0.05.
#
# CI :  95% confidence that the conclusion of this test will be valid.
#
# Null Hypothesis (H0) : Average Alcohol percentage (ABV) is less than or equal to 43% for all scotch whiskies.
#
# H1 : Average  Alcohol percentage is not less than 43% for all scotch whiskies

# %%
from scipy import stats
from scipy.stats import ttest_1samp
tstats, pvalue = stats.ttest_1samp(data.Abv, 43)
print(tstats, pvalue)
data.Abv.mean()
# Out:
# 39.113812839268164 1.6718262678391944e-254
# 47.88986369831898

# %% [markdown]
# Result: P is less than 0.05 so we can reject H0.
