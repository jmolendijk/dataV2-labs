# %%
import numpy as np
import pandas as pd

vehicles = pd.read_csv('vehicles.csv')
# lets look if City Mileage and Highway Mileage are related, 
# that is: change in the same direction
vehicles[['City MPG', 'Highway MPG']].head(50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e1c5f2c0e85d> in <module>
#       2 import pandas as pd
#       3
# ----> 4 vehicles = pd.read_csv('vehicles.csv')
#       5 # lets look if City Mileage and Highway Mileage are related,
#       6 # that is: change in the same direction
#
# ...

# %%
# we can visualise the relationship using a scatter plot:
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x=vehicles['City MPG'],y=vehicles['Highway MPG'])

# %%
# we can quantify this by using the corr() method
vehicles['City MPG'].corr(vehicles['Highway MPG'])

# %%
vehicles.columns

# %%
# calling the corr() method on a dataframe gives the pairwise correlation 
# between all numeric vaiables - this is called the 'correlation matrix'
vehicles.corr()

# %%
# 3 slightly differentways to define correlation
# 'regular' one is pearson-correlation 
# (used 99% of the time, and therefore the default)
vehicles.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19d5f2bb490c> in <module>
#       2 # 'regular' one is pearson-correlation
#       3 # (used 99% of the time, and therefore the default)
# ----> 4 vehicles.corr(method='pearson')
#
# NameError: name 'vehicles' is not defined

# %%
# alternative ones are called 'spearman' and 'kendall'
# spearman correlation is useful for non-linear relationships, 
# just looks if the data moves in roughly the same direction
vehicles.corr(method='spearman')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-757ff6fd86d1> in <module>
#       2 # spearman correlation is useful for non-linear relationships,
#       3 # just looks if the data moves in roughly the same direction
# ----> 4 vehicles.corr(method='spearman')
#
# NameError: name 'vehicles' is not defined

# %%
# kendall or "kendall's-tau" is used even more rarely
vehicles.corr(method='kendall')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d822925953d3> in <module>
#       1 # kendall or "kendall's-tau" is used even more rarely
# ----> 2 vehicles.corr(method='kendall')
#
# NameError: name 'vehicles' is not defined

# %%
vehicles['City MPG'].corr(vehicles['Highway MPG'], method="kendall")
# Out:
# 0.8171408108342495

# %%
# Show correlation matrix as a heatmap

# %%
#simple
vehicles.corr().style.background_gradient(cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e73c727d219d> in <module>
#       1 #simple
# ----> 2 vehicles.corr().style.background_gradient(cmap='coolwarm')
#
# NameError: name 'vehicles' is not defined

# %%
# more visually appealing
import seaborn as sns
# %matplotlib inline
sns.heatmap(vehicles.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6c6e0ec2cb8e> in <module>
#       2 import seaborn as sns
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 sns.heatmap(vehicles.corr())
#
# NameError: name 'vehicles' is not defined

# %%
#correct the height of the top and bottom rows
#ax = sns.heatmap(vehicles.corr()) 
ax = sns.heatmap(vehicles.corr(), annot=True) #notation: "annot" not "annotate"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

# or upgrade seaborn to seaborn version 3.1.2  :-)
# Out:
# (9.0, 0.0)
