# %%
import pandas as pd
data = pd.read_csv('Fitbit2.csv')
data.head(5)

data[['NumberOfAwakings', 'MinutesOfBeingAwake']]
# Out:
#      NumberOfAwakings  MinutesOfBeingAwake
# 0                  23                   26
# 1                  21                   35
# 2                  25                   46
# 3                  21                   31
# 4                  44                   65
# ..                ...                  ...
# 362                18                   33
# 363                 8                   21
# 364                15                   35
# 365                22                   42
# 366                31                   57
#
# [367 rows x 2 columns]

# %%
import seaborn as sns
sns.pairplot(data[['NumberOfAwakings', 'MinutesOfBeingAwake', 'Minutes Lightly Active']])

#

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.scatter(data['NumberOfAwakings'], data['MinutesOfBeingAwake'])

# %%
#linear regression
from scipy import stats
X = data ['NumberOfAwakings'] #input variable. From one, I can caluculate the other 
Y = data['MinutesOfBeingAwake']

slope, intercept, r_value,p_value, std_err = stats.linregress(X,Y)

print(str(slope))
print(str(intercept))
# Out:
# 1.6405141436199793
# 1.4381033523783202

# %%
#Different factors determines the outcome:

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
residual = [data['MinutesOfBeingAwake']][i] - predictions[i] for i
