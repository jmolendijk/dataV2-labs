# %%
import pandas as pd

cdd = pd.read_csv('/Users/victoria/Downloads/CDD.csv', sep='\t')
cdd
# Out:
#      EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0          Disaster     Natural  Meteorological - Hydrological
# 1          Disaster     Natural  Meteorological - Hydrological
# 2          Disaster     Natural  Meteorological - Hydrological
# 3          Disaster     Natural                     Biological
# 4          Incident  Technology            Hazardous Chemicals
# ...             ...         ...                            ...
# 1084       Disaster     Natural  Meteorological - Hydrological
# 1085       Incident  Technology                      Explosion
# 1086       Incident  Technology                      Explosion
# 1087       Incident  Technology         Infrastructure failure
# 1088       Incident  Technology                           Fire
#
#                        EVENT TYPE                                 PLACE  \
# 0     Storm - Unspecified / Other                   Christmas Island NS
# ...

# %%
cdd['MUNICIPAL COSTS'].isnull().sum()
# Out:
# 1060

# %%
#1. Print the correlation matrix
cdd.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %%
#2. Print a heat map of this correlation matrix (hint: use seaborn.heatmap())
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(cdd.corr(), annot=True, square=True)
# Out:
# <AxesSubplot:>

# %%
#3. Find 3 pairs of columns

#highly positively correlated - Municipal Costs & NGO Payments (correlation is almost perfect - 0.999999).
"""
that may mean that the disaster was huge and municipality and NGO correlated the value of payments they make. 
for example, municipality paid twice as NGO did.
"""
pos = pd.DataFrame(cdd['MUNICIPAL COSTS'], cdd['NGO PAYMENTS'])

#correlation is almost zero - Utility - People Affected & Injured/Infected (-0.001498).
"""
The number of people injured or infected due to a specific event doesn't depend on the amount of people 
whose utility services (power, water, etc.) were interrupted/affected by a specific event. Many events have nothing
to do with utilities.
"""
no = pd.DataFrame(cdd['UTILITY - PEOPLE AFFECTED'], cdd['INJURED / INFECTED'])

#negatively correlated - all are very weak. Let's take OGD Costs & Injured/Infected (-0.036915)
"""
The more there are Injured/Infected the less Other Government Departments pay? That make sense because they have the
specific department DFAA for disasters. But still, it's so weak that we can't say there is a correlation.
"""
neg = pd.DataFrame(cdd['OGD COSTS'], cdd['INJURED / INFECTED'])

# %%
#4. Look up the pairplot function in Seaborn.
sns.pairplot(cdd, vars = ['MUNICIPAL COSTS','NGO PAYMENTS'])

# %%
sns.pairplot(cdd, vars = ['UTILITY - PEOPLE AFFECTED','INJURED / INFECTED'])

# %%
sns.pairplot(cdd, vars = ['OGD COSTS','INJURED / INFECTED'])

# %%
#first one yes. At fisrt they are all 0. Then NGO payment = 1.25, Municipal costs = 2, so the higher the higher
#second one confirms that there is no correlation 
# 3 - injured/infected stay the same, ogd costs rise.
