# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# 3 different plots in different lines
import numpy as np
plt.plot(x, label='linear')
plt.show()
plt.plot(y, label='linear')
plt.show()
plt.plot(z, label='linear')
plt.show()

# Two plots in one
plt.plot(x,y,z)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Using sub plots


fig, [ax1, ax2, ax3] = plt.subplots(1,3)

ax1.plot(x)
ax2.plot(y)
ax3.plot(z)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig, [ax1, ax2, ax3] = plt.subplots(1,3)

ax1.plot(x)
ax1.set_title('X')
ax1.set_xlabel('x axis')     
ax1.set_ylabel('y axis') 

ax2.plot(x*2)
ax2.set_title('X times 2') 
ax2.set_xlabel('x axis')     
ax2.set_ylabel('y axis') 

ax3.plot(x**2)
ax3.set_title('X squared') 
ax3.set_xlabel('x axis')     
ax3.set_ylabel('y axis') 
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here


# Two plots in one
x = np.arange(0,100)
y1 = x**2
y2 = np.exp(x)

plt.plot(y1)
plt.plot(y2)
plt.show()


# One plot with two scales one normal and one logarithmic 

fig, ax1 = plt.subplots()

ax1.plot(x,y1)
ax1.set_yscale('linear')

ax2 = ax1.twinx()

ax2.plot(x,y2)
ax2.set_yscale('log')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

fig, ax1 = plt.subplots()

ax1.plot(x,y1)
ax1.set_yscale('linear')
ax1.set_ylabel('y squared')

ax2 = ax1.twinx()

ax2.plot(x,y2)
ax2.set_yscale('log')
ax2.set_ylabel('y log')


plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv("/Users/nelly/dataV2-labs/module-2/Matplotlib-Seaborn/your-code/Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

fitbit = pd.read_csv("/Users/nelly/dataV2-labs/module-2/Matplotlib-Seaborn/your-code/Fitbit2.csv")

fitbit_steps = fitbit.pivot_table(index=["Months"], values=["Steps"], aggfunc=np.mean)


fitbit_steps.head(30).plot(kind='barh', figsize=(12,4))

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

fitbit_steps = fitbit.pivot_table(index=["Work_or_Weekend"], values=["Steps"], aggfunc=np.mean)

plot2 = fitbit_steps.head(30).plot(kind='barh', figsize=(12,4))

plot2
# Out:
# <AxesSubplot:ylabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

fitbit = pd.read_csv("/Users/nelly/dataV2-labs/module-2/Matplotlib-Seaborn/your-code/Fitbit2.csv")
df =pd.DataFrame(fitbit['Steps'], fitbit['Minutes Lightly Active'],fitbit['Minutes Very Active'])

import matplotlib.pyplot as plt

x=[fitbit['Steps'],fitbit['Steps'],fitbit['Steps']]
y=[fitbit['Minutes Lightly Active'],fitbit['Minutes Very Active'],fitbit['Minutes Sedentary'] ]
for i in range(len(x)):
    plt.figure()
    plt.scatter(x[i],y[i])
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv("/Users/nelly/dataV2-labs/module-2/Matplotlib-Seaborn/your-code/Titanic.csv")

titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

numerical = titanic.select_dtypes(include=['float', 'int'])

# %%
# CATEGORICAL VARIABLES
# your code here

objects = titanic.select_dtypes(include=['object'])

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.plot(numerical)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

plt.hist(titanic['Age'])
# Out:
# (array([ 63.,  51., 242., 211., 142.,  88.,  49.,  28.,  11.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

plt.hist(titanic['Age'], bins=[10,20,50])
# Out:
# (array([128., 616.]), array([10, 20, 50]), <BarContainer object of 2 artists>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

We can't see it correctly , it was better witht the original 10 bins instead of 3
"""
# Out:
# "\nyour comments here\n\nWe can't see it correctly , it was better witht the original 10 bins instead of 3\n"

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.distplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here


sns.catplot(x="Sex", y="Age", kind="box", data=titanic)

# %%
# Method 2 - seaborn
# your code here

sns.catplot(x="Sex", kind="count", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.catplot(x="Sex", y="Age", hue='Pclass', kind='bar', data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.catplot(x="Sex", y="Age", hue= 'Pclass', kind='bar', data=titanic)

# %%
"""
your comments here

With this plot we can see the sex and class according to the age.
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

Most of the people were more than 20 years old and after 35 years ols is more likely to be in 1st class.
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here



sns.catplot(y="Age", kind="boxen", data=titanic)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here

Average age is 27
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

sns.catplot(x="Fare", y="Age", data=titanic)

# %%
# Method 2 - seaborn
# your code here

sns.regplot(x="Age", y="Fare", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

plt.figure(figsize=(20, 20))
p = sns.heatmap(titanic.corr(), annot=True, square=True)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

Parents/Childen Aboard and Siblings /Spouses Aboard
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.catplot(x="Pclass", y="Age", hue= "Survived", data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.catplot(x="Sex", y="Age", kind='box', data=titanic)
