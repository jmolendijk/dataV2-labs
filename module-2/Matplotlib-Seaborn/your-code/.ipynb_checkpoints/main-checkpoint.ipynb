# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1 usigng plt.plot method
plt.plot(x, y, label='quadratic', linewidth=3, color='orange', linestyle='dashed')
#linewidth=5, color='green', linestyle='dashed'
plt.xlabel('x label')
plt.ylabel('y label')
plt.legend()

# %%
plt.plot(x, z, label='quadratic', linewidth=4, color='blue', linestyle=':')
plt.xlabel('x label')
plt.ylabel('y label')
plt.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2 :subplots 
fig, [xy, xz] = plt.subplots(1,2)
xy.plot(x,y)
xy.set_title('SQUARED PLOT')   
xy.set_xlabel('x')     
xy.set_ylabel('y is square of x')   

xz.plot(x,z) 
xz.set_title('SQUARED PLOT 2')
xz.set_xlabel('x')
xz.set_ylabel('z is square of x')

fig.suptitle('figures showing squared results')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [xy, xz] = plt.subplots(1,2,figsize=(15,5))
xy.plot(x,y)
xy.set_title('SQUARED PLOT')   
xy.set_xlabel('x')     
xy.set_ylabel('y is square of x')   

xz.plot(x,z) 
xz.set_title('SQUARED PLOT 2')
xz.set_xlabel('x')
xz.set_ylabel('z is square of x')

fig.suptitle('figures showing squared results')
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y = x**2
z = np.exp(x)

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig.suptitle('f(x)=x² & f(x)=exp(x)', fontsize=20, fontweight='bold')
plt.plot(x, y, linewidth=5, color='b', linestyle='-')
plt.plot(x, z, linewidth=5, color='r',linestyle='dashdot')

ax.set_xscale('linear')
ax.set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, ax = plt.subplots(figsize=(10,5))
fig.suptitle('f(x)=x² & f(x)=exp(x)', fontsize=20, fontweight='bold')
plt.plot(x, y, linewidth=5, color='b', linestyle='-')
plt.plot(x, z, linewidth=5, color='r',linestyle='dashdot')

ax.set_xscale('linear')
ax.set_yscale('log')

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
import pandas as pd
fitbit = pd.read_csv(r'C:\Users\tusha\Downloads\fitbit2.csv')
fitbit.head()
#fitbit.shape
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
df_months = fitbit.groupby('Months_encoded').agg({'Steps':'median'})
df_months
# your code here

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
# Out:
#                   Steps
# Months_encoded
# 1               10366.0
# 2                9235.0
# 3               11122.0
# 4               13846.5
# 5               11998.0
# 6               12935.5
# 7               10644.0
# 8               12213.0
# 9                9343.0
# 10               7865.0
# 11               9453.5
# 12               8531.0

# %%
df_weekdays = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median()

# %%
df_weekdays = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'})

# %%
df_weekdays
# Out:
#                    Steps
# Work_or_Weekend
# 0                 9998.0
# 1                10445.5

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
fig.suptitle('Average Steps per month & during the week',fontsize= 10, fontweight="bold")

#plotting linechart
ax[0].set_title('Median steps per month', fontsize=10)
ax[0].plot(df_months.index, df_months['Steps'], lw=3, linestyle='--')
ax[0].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
ax[0].set_xlabel('steps in units')
ax[0].set_ylabel('months')
ax[0].grid(True)

#plotting barchart and exploring different parameters for practice e.g. colour etc.

ax[1].bar(df_weekdays.index, df_weekdays['Steps'], edgecolor ='b', alpha=0.5)
ax[1].set_title('Median Nb of Steps Week days vs. Week-end', fontsize=15)
plt.xticks(ticks=range(2), labels=['Weekdays', 'Week-end'], rotation=0)
ax[1].set_xlabel('days')
ax[1].set_ylabel('steps in units')
ax[1].grid(True)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
list_features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

fig, ax = plt.subplots(1,3,figsize=(12,4))

for i in range(3):
    plt.sca(ax[i])
    plt.scatter(fitbit[list_features[i]], fitbit['Steps'])
    plt.title(f'{list_features[i]} VS. Steps')
    plt.xlabel(list_features[i])
    plt.ylabel('Steps')
plt.savefig("3 Activity variable vs. Steps.svg")

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv(r'C:\Users\tusha\Downloads\titanic.csv')
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
import seaborn as sns
sns.pairplot(titanic)

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.dtypes

"""
Following are numerical: 

Survived                     int64
Pclass                       int64
Age                        float64
Siblings/Spouses Aboard      int64
Parents/Children Aboard      int64
Fare                       float64

"""
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %%
# CATEGORICAL VARIABLES
"""
Following are categorical:

Survived                     int64
Pclass                       int64
Sex                         object
Siblings/Spouses Aboard      int64
Parents/Children Aboard      int64
 
# your code here
"""

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
# as per the info.(https://seaborn.pydata.org/tutorial/aesthetics.html) style can be one of white, dark, whitegrid, darkgrid, ticks
sns.set_style('darkgrid')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
#source: https://seaborn.pydata.org/tutorial/distributions.html
plt.figure(figsize=(12,5))
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, ax = plt.subplots(1,3, figsize=(20,10))

#using plt.sca to switch frame
plt.sca(ax[0])
plt.hist(x=titanic['Age'], bins=10)

plt.sca(ax[1])
plt.hist(x=titanic['Age'], bins=20)

plt.sca(ax[2])
plt.hist(x=titanic['Age'], bins=50)
# Out:
# (array([25.,  7., 17.,  3., 11.,  8.,  6.,  4.,  8., 25., 16., 69., 58.,
#         39., 60., 25., 47., 64., 35., 40., 19., 39., 36., 12., 36., 11.,
#         24.,  9., 22., 22.,  8., 17.,  6., 10.,  8.,  3.,  7.,  5.,  8.,
#          5.,  3.,  2.,  0.,  3.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

The higher the number of bins, the more accurate is the Age split and allows to see more precisely the amount of persons for each Age category
small bin number allows to do more general observation

"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
fig, ax = plt.subplots(1,3, figsize=(20,10))
plt.sca(ax[0])
sns.distplot(titanic['Age'], bins=10)
plt.sca(ax[1])
sns.distplot(titanic['Age'], bins=20)
plt.sca(ax[2])
sns.distplot(titanic['Age'], bins=50)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.figure(figsize=(15,7))

titanic['Sex'].value_counts().plot(kind='bar')
plt.xlabel('gender')
plt.ylabel('count')

plt.show()

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize=(15,7))
sns.countplot(x='Sex', data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
plt.figure(figsize=(15,7))
sns.countplot(x='Pclass', data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
#https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html
plt.figure(figsize=(20,10))
sns.boxenplot(titanic['Age'],  orient="h", palette="Accent")

# %%
"""
your comments here
50% of the population between 23 & 37 years old
min age = 0 i.e. there were several babies & young among the passengers
max age = 80
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.figure(figsize=(20,10))
plt.scatter(x=titanic['Age'], y=titanic['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare - in $')
# Out:
# Text(0, 0.5, 'Fare - in $')

# %%
# Method 2 - seaborn
# your code here
sns.jointplot(x='Fare', y='Age', data=titanic, height=10, kind='reg')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

corr_titanic =titanic.corr()

plt.figure(figsize=(20,10))
plt.title('Correlation Matrix of Titanic data')
sns.heatmap(corr_titanic, annot=True, annot_kws={"size": 20})

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

PClass & Fare are negatively correlated : 1st class must be the most expensive, whereas 3rd class would be the cheapest ; hence negative correaltion
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.catplot(x='Pclass', y='Age', data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.set() 
g = sns.FacetGrid(data=titanic, col='Sex')
g.map(sns.distplot,'Age')
