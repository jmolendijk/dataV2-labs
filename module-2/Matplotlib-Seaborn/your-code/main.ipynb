# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

plt.plot(x, y, linewidth=3, color='red')
plt.plot(x, z, linewidth=3, color='blue', linestyle='dashed');

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fiq, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
ax1.plot(x, y)
ax2.plot(x, z);

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fiq, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(10, 10))
ax1.plot(x, y)
ax2.plot(x, z);

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

fiq, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(10, 10))
ax1.plot(y**2)
ax1.set_xscale('linear')
ax1.set_yscale('linear');
ax2.plot(np.exp(y))
ax2.set_xscale('log');
ax2.set_yscale('log');

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv('../data/Fitbit2.csv')

# fitbit.head()

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

fig, [ax1,ax2] = plt.subplots(1,2, figsize = (12,4))

month_steps = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()

plt.sca(ax1)
month_steps.plot(kind='line')
plt.title("Median Steps by Month")
plt.xlabel('Months')
plt.ylabel('Steps')
plt.xticks(np.arange(13), ['','January','February','March', 'April', 'May', 'June', 'July', 'August', 'September', 'October','November', 'December'], rotation=45)
plt.savefig('../plots/month_steps.png')



# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

work_weekend_steps = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median()

plt.sca(ax2)
work_weekend_steps.plot(kind='bar')
plt.title("Median Steps by Work or Weekend")
plt.xlabel('Work or Weekend')
plt.ylabel('Steps')
plt.xticks([0,1], ['Weekend', 'Work'])
plt.savefig('../plots/work_weekend_steps.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

list_plots = ['Minutes Lightly Active', 'Minutes Very Active','Minutes Sedentary','Steps']
data = fitbit[list_plots]

fig, ax = plt.subplots(1,3, figsize = (18,8))

for i in range(3):
    plt.sca(ax[i])
    plt.scatter(data[list_plots[i]], data[list_plots[3]])
    plt.title(list_plots[i])
    plt.xlabel(list_plots[i])
    plt.ylabel(list_plots[3])

plt.savefig('../plots/minute_steps.png', bbox_inches='tight');

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv('../data/titanic.csv')

# titanic.head()

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(include=['float64','int64']).columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(exclude=['float64','int64']).columns
# Out:
# Index(['Name', 'Sex'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
# sns.set_style('classic')

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

titanic['Age'].hist()

plt.title('Distribution of column Age')
plt.xlabel('Age')
plt.ylabel('Num persons');

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, ax = plt.subplots(1,3)

bins = [10,20,50]

for i in range(3):
    plt.sca(ax[i])
    titanic['Age'].hist(bins=bins[i]);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

The overall structure is the same but it gets much more detailed with the use of bins.

"""
# Out:
# '\nyour comments here\n\nThe overall structure is the same but it gets much more detailed with the use of bins.\n\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.distplot(titanic['Age']);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

gender = titanic['Sex'].value_counts()

gender.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn
# your code here

sns.countplot(x='Sex', data=titanic);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x='Pclass', data=titanic);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

titanic.boxplot(column='Age');

# %%
"""
your comments here

I used a boxplot because it shows all the relevant information for this value.

"""
# Out:
# '\nyour comments here\n\nI used a boxplot because it shows all the relevant information for this value.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

Most people where between the age of 20 and 40.

"""
# Out:
# '\nyour comments here\n\nMost people where between the age of 20 and 40.\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.violinplot("Age", data=titanic);

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here

It adds a distribution of the values.

"""
# Out:
# '\nyour comments here\n\nIt adds a distribution of the values.\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic['Fare'], titanic['Age']);

# %%
# Method 2 - seaborn
# your code here

sns.jointplot(x='Fare', y='Age', data=titanic);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

sns.heatmap(titanic.corr(), annot=True);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

The class and if they are children.

"""
# Out:
# '\nyour comments here\n\nThe class and if they are children.\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x='Pclass', y='Age', data=titanic);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

gender = sns.FacetGrid(titanic, col="Sex", col_order=["female", "male"])

gender.map(plt.hist, 'Age');
