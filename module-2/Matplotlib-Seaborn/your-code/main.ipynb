# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, label='linear',ls='-.')
plt.plot(x,z,label ='quadratic',ls=':')
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig,[plot1,plot2] = plt.subplots(1,2)
plot1.plot(x,y,ls='--')
plot1.set_title('Linear plot')
plot2.plot(x,z,ls='-')
plot2.set_title('squared')
plt.show()
fig.suptitle('Plotting 2 plots')#This one didn't work...
# Out:
# Text(0.5, 0.98, 'Plotting 2 plots')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig,[plot1,plot2] = plt.subplots(1,2,figsize=(12,6))
plot1.plot(x,y)
plot1.set_title('Linear plot',fontsize= 18)
plot1.set_xlabel('this is the x label')
plot1.set_ylabel('this is the y label')
plot2.plot(x,z)
plot2.set_title('squared',fontsize= 18)
fig.suptitle('Plotting 2 plots',fontsize=20,fontweight='normal')
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
#I misread the ex. and thught we needed to plot them together
# -->Like this I did not managed to set the different scale

# your code here
x = np.arange(0,100)
y = x**2
z = np.exp(x)
from matplotlib.ticker import NullFormatter, FixedLocator
fig = plt.figure()

# setting the axes at the centre
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')#y axis in the center
ax.spines['bottom'].set_position('zero')#y=0 crossing the axis line
ax.spines['right'].set_color('none')#taking out the right line
ax.spines['top'].set_color('none')#now the top one
ax.xaxis.set_ticks_position('bottom')#These 2 I did not see the difference...
ax.yaxis.set_ticks_position('left')



# plot the function
plt.plot(x,y,'r', label='x^2')#r is red :- if nothing added then is blue
plt.plot(x,z,'y', label='y=e^x')
plt.legend(loc='upper left')

# show the plot
plt.show()

# %%
#in 2 graphs:

fig, [p1, p2] = plt.subplots(1,2, figsize=(12,6))
p1.plot(x,y,'r',x,z,'y',label='x^2')
p1.set_title('x^2')
p1.set_xlabel('x_values')
p1.set_ylabel('y_values')

p2.plot(x,y,'r',x,z,'y',label='y=e^x')
p2.set_title('e^x')
p2.set_xlabel('x_values')
p2.set_ylabel('y_values')
p2.set_xscale('log')
p2.set_yscale('log')

fig.suptitle('Plot2 and Plot3', fontsize=20)
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
#done above :-)

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('/Users/ajiacovic/Downloads/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#First I need to group them to see the steps per month, then take the median
Month = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()


# MEDIAN STEPS BY MONTH_ENCODED
# your code here

fig, [h1, h2] = plt.subplots(1,2, figsize=(12,6))


plt.sca(h1) #Sca sets values on the plot sca mentions
Month.plot(ls='--',color='m')
plt.title('MEDIAN STEPS BY MONTH_ENCODED')
plt.xlabel('Months')
plt.ylabel('steps')
plt.xticks(np.arange(0,12,1),('Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'), rotation=90)

plt.savefig('figures/month.jpeg',bbox_inches='tight')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

#Now that we change graph, we have to change sca
plt.sca(h2)
work_weekend = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median().sort_values()
# plt.hist(work_weekend, color='r', bins=3)#it is not showing me what I need
work_weekend.plot(kind = 'bar',color='y')
plt.title('MEDIAN STEPS BY WORK_OR_WEEKEND')
plt.xlabel('Work or Weekend')
plt.ylabel('steps')
plt.xticks(np.arange(0,2),('Weekend','Work'), rotation=0)
plt.savefig('figures/work_weekend.jpeg',bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('/Users/ajiacovic/Downloads/titanic.csv')
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(int, float)
# Out:
#      Survived  Pclass  Siblings/Spouses Aboard  Parents/Children Aboard
# 0           0       3                        1                        0
# 1           1       1                        1                        0
# 2           1       3                        0                        0
# 3           1       1                        1                        0
# 4           0       3                        0                        0
# ..        ...     ...                      ...                      ...
# 882         0       2                        0                        0
# 883         1       1                        0                        0
# 884         0       3                        1                        2
# 885         1       1                        0                        0
# 886         0       3                        0                        0
#
# [887 rows x 4 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(object)
#Name,Sex,Age, I have a doubt for Survived because we are given a value for it
#that we can compute but at its core is categorical survived: yes/no
# Out:
#                                                   Name     Sex
# 0                               Mr. Owen Harris Braund    male
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  female
# 2                                Miss. Laina Heikkinen  female
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  female
# 4                              Mr. William Henry Allen    male
# ..                                                 ...     ...
# 882                               Rev. Juozas Montvila    male
# 883                        Miss. Margaret Edith Graham  female
# 884                     Miss. Catherine Helen Johnston  female
# 885                               Mr. Karl Howell Behr    male
# 886                                 Mr. Patrick Dooley    male
#
# [887 rows x 2 columns]

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#looking for these I found (not sure about them)
# sns.set_style('classic')#doesn't seem to work
plt.style.use('classic')
fig,ax= plt.figsize=(12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
age = titanic['Age']
plt.hist([age],color='y',bins=50) 
plt.title('Age distribution')
plt.xlabel('Age range')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, plot = plt.subplots(1,3)

plt.sca(plot[0])
plt.hist([age],color='y', bins=10)
plt.xlabel('Age')
plt.ylabel('Count')

plt.sca(plot[1])
plt.hist([age],color='y', bins=20)
plt.xlabel('Age')
plt.ylabel('Count')

plt.sca(plot[2])
plt.hist([age],color='y', bins=50)
plt.xlabel('Age')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
If we use a bigger bins size makes our graph smalle (thinner bins)
I think that wider bins are easier to read, despite their lack of precision?
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here


sns.distplot(age, bins = 20)
# Out:
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
