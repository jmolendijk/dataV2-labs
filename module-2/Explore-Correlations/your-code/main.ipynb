# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import plotly.express as px

# %matplotlib inline

# %%
cdd = pd.read_csv('CDD.csv', sep = '\t')

# %%
cdd.shape
# Out:
# (1089, 22)

# %% [markdown]
# # No 1
#
# #### Print the correlation matrix

# %%
#null values
cdd.isnull().sum()
# Out:
# EVENT CATEGORY                       0
# EVENT GROUP                          0
# EVENT SUBGROUP                       0
# EVENT TYPE                           0
# PLACE                                0
# EVENT START DATE                     0
# COMMENTS                             0
# FATALITIES                          89
# INJURED / INFECTED                 115
# EVACUATED                           70
# ESTIMATED TOTAL COST               531
# NORMALIZED TOTAL COST              531
# EVENT END DATE                       0
# FEDERAL DFAA PAYMENTS              604
# PROVINCIAL DFAA PAYMENTS           678
# PROVINCIAL DEPARTMENT PAYMENTS     997
# MUNICIPAL COSTS                   1060
# OGD COSTS                         1075
# INSURANCE PAYMENTS                1017
# NGO PAYMENTS                      1081
# UTILITY - PEOPLE AFFECTED           83
# MAGNITUDE                          114
# dtype: int64

# %%
#descriptove statistics
cdd.describe().transpose()
# Out:
#                                  count          mean           std       min  \
# FATALITIES                      1000.0  6.352700e+01  1.583137e+03       0.0
# INJURED / INFECTED               974.0  2.088787e+03  6.408480e+04       0.0
# EVACUATED                       1019.0  1.150980e+03  9.261735e+03       0.0
# ESTIMATED TOTAL COST             558.0  4.839952e+07  3.045786e+08       0.0
# NORMALIZED TOTAL COST            558.0  2.870350e+06  1.730852e+07       0.0
# FEDERAL DFAA PAYMENTS            485.0  1.194386e+07  7.049849e+07       0.0
# PROVINCIAL DFAA PAYMENTS         411.0  1.521750e+06  4.123510e+06       0.0
# PROVINCIAL DEPARTMENT PAYMENTS    92.0  1.715572e+07  4.936284e+07       0.0
# MUNICIPAL COSTS                   29.0  1.091247e+08  3.807072e+08       0.0
# OGD COSTS                         14.0  2.039078e+08  2.875737e+08  358000.0
# INSURANCE PAYMENTS                72.0  1.802493e+08  5.219343e+08  144003.0
# ...

# %%
cdd.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %% [markdown]
# # No 2
#
# #### Print a heat map of this correlation matrix

# %%
plt.figure(figsize = (10,8))
sns.heatmap(cdd.corr(), annot = True, fmt='.2f', cmap = "Spectral")

# %% [markdown]
# # No 3
#
# #### Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero and one pair that is negatively correlated. In each case write down an explanation why we see this correlation

# %%
""" 
Highly positively correlated:

FEDERAL DFAA PAYMENTS should be highly correlated with ESTIMATED TOTAL COST, because the ESTIMATED TOTAL COST 
is probably driving the pay out
"""

cdd['FEDERAL DFAA PAYMENTS'].corr(cdd['ESTIMATED TOTAL COST'])
# Out:
# 0.7960164670635514

# %%
""" 
Correlation is almost zero:

MAGNITUDE is recorded only for th earthquakes, so for the vast majority of events it is going to be zero and not
correlate with FATALITIES. You can also see this in the scatterplot below
"""

cdd['FATALITIES'].corr(cdd['MAGNITUDE'])
# Out:
# -0.0039881620658718

# %%
#positively correlated
plt.scatter(x = cdd['FEDERAL DFAA PAYMENTS'], y = cdd['ESTIMATED TOTAL COST'])

# %%
""" 
Correlation is negative:

There are no highly negatively correlated column pairs. 

The highest negative correlation si between 
'UTILITY - PEOPLE AFFECTED (the amount of people whose utility services 
(power, water, etc.) were interrupted/affected by a specific event)
and 'OGD COSTS' (the cost, in dollars, as reported in Open Government Data sources)

I woudl expect positive correlation between these two, so mgiht be the case of data collection,
for example OGD COSTS are available only for 14 out of 1089 records in the dataset, and 
'UTILITY - PEOPLE AFFECTED' are mostly 0, so this explains very weak correlation

"""
cdd['UTILITY - PEOPLE AFFECTED'].corr(cdd['OGD COSTS'])
# Out:
# -0.09298259907022129

# %% [markdown]
# # No 4
#
# #### Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. Does what you see confirm your ideas? Describe in a comment.

# %%
"""
will include  'UTILITY - PEOPLE AFFECTED' and 'OGD COSTS'
"""
plt.figure(figsize = (6,6))

sns.pairplot(
    cdd, vars = [
        'FEDERAL DFAA PAYMENTS',
        'ESTIMATED TOTAL COST',
        'FATALITIES',
        'MAGNITUDE'
    ]
)

# %%
sns.pairplot(
    cdd, vars = [ 
        'UTILITY - PEOPLE AFFECTED',
        'OGD COSTS'
    ]
)

# %%
cdd['NGO PAYMENTS'].hist()
