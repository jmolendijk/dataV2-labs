# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
wnba_current = pd.read_csv(r'C:\Users\tusha\dataV2-labs\module-2\M2-mini-project2\data\current players.csv')

# %%
wnba_current
# Out:
#                 SCHOOL            PLAYER
# 0    Abilene Christian  Johannah Leedham
# 1    Abilene Christian   Latoya Williams
# 2    Abilene Christian     Paola Ferrari
# 3        Arizona State    Briann January
# 4        Arizona State      Dymond Simon
# ..                 ...               ...
# 148           Virginia     Monica Wright
# 149           Virginia      Sharnee Zoll
# 150      West Virginia  Yelena Leuchanka
# 151    Wisc.-Green Bay       Julie Wojta
# 152             Xavier      Amber Harris
#
# [153 rows x 2 columns]

# %%
#wnba_current = wnba_current(['SCHOOL']).unique()
wnba_current.describe()
# Out:
#              SCHOOL           PLAYER
# count           153              153
# unique           66              153
# top     Connecticut  Shannon Bobbitt
# freq             13                1

# %%
z = wnba_current['SCHOOL'].value_counts()

# %%
z
# Out:
# Connecticut        13
# Tennessee          12
# Duke                8
# Rutgers             7
# Louisiana State     6
#                    ..
# Penn State          1
# Poland              1
# Temple              1
# Missouri            1
# Colorado State      1
# Name: SCHOOL, Length: 66, dtype: int64

# %%
ax = wnba_current['SCHOOL'].value_counts().plot(kind='bar',
                                    figsize=(20,8),
                                    title="Total Number of Players from each college season 2020")
ax.set_xlabel("school name")
ax.set_ylabel("number of players")
# Out:
# Text(0, 0.5, 'number of players')
