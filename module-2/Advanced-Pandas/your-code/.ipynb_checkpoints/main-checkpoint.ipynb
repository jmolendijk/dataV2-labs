# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np
import requests
from io import StringIO
import re

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
orig_url = 'https://drive.google.com/file/d/1gWEBLFHtDsPcbhFwD4gzBo6TiITQ73oT/view?usp=sharing'

file_id = orig_url.split('/')[-2]
dwn_url = 'https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
admissions = pd.read_csv(csv_raw)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
admissions.columns = admissions.columns.str.strip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
# Tried this first but all data get's shifted by one raw, couldn't find how to fix it.
# admissions.reindex(admissions['Serial No.'])

# %%
# Feels like workaround for me but couldn't find neater sollution.
admissions = admissions.set_index('Serial No.')
admissions['Serial No.'] = admissions.index
admissions.index.name = None
admissions
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 1          337          118                  4  4.5  4.5  9.65         1
# 2          324          107                  4  4.0  4.5  8.87         1
# 3          316          104                  3  3.0  3.5  8.00         1
# 4          322          110                  3  3.5  2.5  8.67         1
# 5          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        330          116                  4  5.0  4.5  9.45         1
# 399        312          103                  3  3.5  4.0  8.78         0
# 400        333          117                  4  5.0  4.0  9.66         1
#
#      Chance of Admit  Serial No.
# 1               0.92           1
# ...

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here
a = list(str(x)+' '+str(y) for x,y in zip(admissions['GRE Score'], admissions['CGPA']))
print(len(a))
print(len(set(a)))
a
# This combination is not unique. I wouldn't use it for index.
# Out:
# 400
# 385
# ['337 9.65',
#  '324 8.87',
#  '316 8.0',
#  '322 8.67',
#  '314 8.21',
#  '330 9.34',
#  '321 8.2',
#  '308 7.9',
#  '302 8.0',
#  '323 8.6',
#  '325 8.4',
#  '327 9.0',
#  '328 9.1',
#  '307 8.0',
#  '311 8.2',
#  '314 8.3',
#  '317 8.7',
#  '319 8.0',
#  '318 8.8',
#  '303 8.5',
#  '312 7.9',
#  '325 8.4',
#  '328 9.5',
#  '334 9.7',
#  '336 9.8',
#  '340 9.6',
#  '322 8.8',
#  '298 7.5',
#  '295 7.2',
#  '310 7.3',
#  '300 8.1',
#  '327 8.3',
#  '338 9.4',
#  '340 9.6',
#  '331 9.8',
#  '320 9.2',
#  '299 8.4',
#  '300 7.8',
#  '304 7.5',
#  '307 7.7',
#  '308 8.0',
#  '316 8.2',
#  '313 8.5',
#  '332 9.1',
#  '326 9.4',
#  '322 9.1',
#  '329 9.3',
#  '339 9.7',
#  '321 8.85',
#  '327 8.4',
#  '313 8.3',
#  '312 7.9',
#  '334 8.0',
#  '324 8.1',
#  '322 8.0',
#  '320 7.7',
#  '316 7.4',
#  '298 7.6',
#  '300 6.8',
#  '311 8.3',
#  '309 8.1',
#  '307 8.2',
#  '304 8.2',
#  '315 8.5',
#  '325 8.7',
#  '325 8.92',
#  '327 9.02',
#  '316 8.64',
#  '318 9.22',
# ...

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
# As identified above combination doesn't provide list of unique values, so I will copy my original df to the new one just to
# practice tasks below.
df_copy = admissions.copy()
df_copy.index = a
df_copy.drop(['GRE Score', 'CGPA'], axis=1, inplace=True)
df_copy
# Out:
#           TOEFL Score  University Rating  SOP  LOR  Research  Chance of Admit  \
# 337 9.65          118                  4  4.5  4.5         1             0.92
# 324 8.87          107                  4  4.0  4.5         1             0.76
# 316 8.0           104                  3  3.0  3.5         1             0.72
# 322 8.67          110                  3  3.5  2.5         1             0.80
# 314 8.21          103                  2  2.0  3.0         0             0.65
# ...               ...                ...  ...  ...       ...              ...
# 324 9.04          110                  3  3.5  3.5         1             0.82
# 325 9.11          107                  3  3.0  3.5         1             0.84
# 330 9.45          116                  4  5.0  4.5         1             0.91
# 312 8.78          103                  3  3.5  4.0         0             0.67
# 333 9.66          117                  4  5.0  4.0         1             0.95
#
#           Serial No.
# ...

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# your code here
df_copy.reset_index(inplace=True)
df_copy
# Out:
#         index  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0    337 9.65          118                  4  4.5  4.5         1
# 1    324 8.87          107                  4  4.0  4.5         1
# 2     316 8.0          104                  3  3.0  3.5         1
# 3    322 8.67          110                  3  3.5  2.5         1
# 4    314 8.21          103                  2  2.0  3.0         0
# ..        ...          ...                ...  ...  ...       ...
# 395  324 9.04          110                  3  3.5  3.5         1
# 396  325 9.11          107                  3  3.0  3.5         1
# 397  330 9.45          116                  4  5.0  4.5         1
# 398  312 8.78          103                  3  3.5  4.0         0
# 399  333 9.66          117                  4  5.0  4.0         1
#
#      Chance of Admit  Serial No.
# 0               0.92           1
# 1               0.76           2
# 2               0.72           3
# 3               0.80           4
# ...

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here
# I'm working with original data frame where we have all required columns.

admissions.loc[(admissions['CGPA'] > 9) & (admissions['Research'] > 0)]
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 1          337          118                  4  4.5  4.5  9.65         1
# 6          330          115                  5  4.5  3.0  9.34         1
# 13         328          112                  4  4.0  4.5  9.10         1
# 23         328          116                  5  5.0  5.0  9.50         1
# 24         334          119                  5  5.0  4.5  9.70         1
# ..         ...          ...                ...  ...  ...   ...       ...
# 395        329          111                  4  4.5  4.0  9.23         1
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        330          116                  4  5.0  4.5  9.45         1
# 400        333          117                  4  5.0  4.0  9.66         1
#
#      Chance of Admit  Serial No.
# 1               0.92           1
# ...

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
admissions.loc[(admissions['CGPA'] > 9) & (admissions['SOP'] < 3.5)]['Chance of Admit'].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    # your code here
    return col.apply(lambda x: (x-np.mean(col))/np.std(col))
    
standardize(admissions['CGPA'])
# Out:
# 1      1.764818
# 2      0.455151
# 3     -1.005631
# 4      0.119339
# 5     -0.653029
#          ...
# 396    0.740592
# 397    0.858126
# 398    1.429006
# 399    0.304036
# 400    1.781609
# Name: CGPA, Length: 400, dtype: float64

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here
admissions['CGPA_std'] = standardize(admissions['CGPA'])
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std'] = standardize(admissions['LOR'])

admissions
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 1          337          118                  4  4.5  4.5  9.65         1
# 2          324          107                  4  4.0  4.5  8.87         1
# 3          316          104                  3  3.0  3.5  8.00         1
# 4          322          110                  3  3.5  2.5  8.67         1
# 5          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        330          116                  4  5.0  4.5  9.45         1
# 399        312          103                  3  3.5  4.0  8.78         0
# 400        333          117                  4  5.0  4.0  9.66         1
#
#      Chance of Admit  Serial No.  CGPA_std   GRE_std   LOR_std
# ...

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
admissions['deciding_column'] = admissions.lookup(admissions.index, decision_choice)
admissions
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 1          337          118                  4  4.5  4.5  9.65         1
# 2          324          107                  4  4.0  4.5  8.87         1
# 3          316          104                  3  3.0  3.5  8.00         1
# 4          322          110                  3  3.5  2.5  8.67         1
# 5          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        330          116                  4  5.0  4.5  9.45         1
# 399        312          103                  3  3.5  4.0  8.78         0
# 400        333          117                  4  5.0  4.0  9.66         1
#
#      Chance of Admit  Serial No.  CGPA_std   GRE_std   LOR_std  \
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here
admissions['decision'] = np.where(admissions['deciding_column'] > 0.8, 1, 0)
admissions
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 1          337          118                  4  4.5  4.5  9.65         1
# 2          324          107                  4  4.0  4.5  8.87         1
# 3          316          104                  3  3.0  3.5  8.00         1
# 4          322          110                  3  3.5  2.5  8.67         1
# 5          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        330          116                  4  5.0  4.5  9.45         1
# 399        312          103                  3  3.5  4.0  8.78         0
# 400        333          117                  4  5.0  4.0  9.66         1
#
#      Chance of Admit  Serial No.  CGPA_std   GRE_std   LOR_std  \
# ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here
admissions['decision'].value_counts()
# 89 students will be accepted.
# Out:
# 0    314
# 1     86
# Name: decision, dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here
admissions.columns = [re.sub('\W', '', re.sub(' ', '_', i.lower())) for i in admissions.columns]
admissions
# Out:
#      gre_score  toefl_score  university_rating  sop  lor  cgpa  research  \
# 1          337          118                  4  4.5  4.5  9.65         1
# 2          324          107                  4  4.0  4.5  8.87         1
# 3          316          104                  3  3.0  3.5  8.00         1
# 4          322          110                  3  3.5  2.5  8.67         1
# 5          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        330          116                  4  5.0  4.5  9.45         1
# 399        312          103                  3  3.5  4.0  8.78         0
# 400        333          117                  4  5.0  4.0  9.66         1
#
#      chance_of_admit  serial_no  cgpa_std   gre_std   lor_std  \
# ...

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here
admissions['gre_score'] = np.where(admissions['university_rating'] >= 4, admissions['gre_score']+10, admissions['gre_score'])
admissions
# Out:
#      gre_score  toefl_score  university_rating  sop  lor  cgpa  research  \
# 1          347          118                  4  4.5  4.5  9.65         1
# 2          334          107                  4  4.0  4.5  8.87         1
# 3          316          104                  3  3.0  3.5  8.00         1
# 4          322          110                  3  3.5  2.5  8.67         1
# 5          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 396        324          110                  3  3.5  3.5  9.04         1
# 397        325          107                  3  3.0  3.5  9.11         1
# 398        340          116                  4  5.0  4.5  9.45         1
# 399        312          103                  3  3.5  4.0  8.78         0
# 400        343          117                  4  5.0  4.0  9.66         1
#
#      chance_of_admit  serial_no  cgpa_std   gre_std   lor_std  \
# ...
